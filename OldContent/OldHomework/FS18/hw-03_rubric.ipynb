# %% [markdown]
# # CMSE 201 - Homework 1 Rubric
#
# The total number of points possible in this assignment is: **19**
#
# ## Question 01: Modeling chaotic dynamics (7 points total)
#
# ### Part 1: Solving the Rössler System with `odeint` (3 points)
#
# * <span style="color:green">**1.5**</span> points for the derivatives function.
# * <span style="color:green">**1.5**</span> points for setting up the parameters (a,b,c), the array of times, the initial values, and using `odeint` to solve the system.
# * Subtract <span style="color:red">**0.5**</span> points if they do not pass the parameters (a,b,c) as arguments (i.e., they hardcode them into their derivatives function).
#
# ### Part 2: Plotting your solution and interpreting the data (2 points)
#
# * <span style="color:green">**1.0**</span> point for the plots (if the student does not write a function to make these plots, that's okay even though the assignment explicity says to do this).
# * <span style="color:green">**1.0**</span> point for the explanation.
#
# ### Part 3: Trying other parameters (2 points)
#
# * <span style="color:green">**1.0**</span> point for the plots.
# * <span style="color:green">**1.0**</span> point for the explanation.
#
# ## Question 2: Viral kinetics revisited (7 points)
#
# ### Part 1: More potent and longer lasting viruses (3 points)
#
# * <span style="color:green">**0.5**</span> point for the picture/drawing of the compartmental model.
# * <span style="color:green">**0.5**</span> point for the ODE equations.
# * <span style="color:green">**1.0**</span> point for the derivatives function and using `odeint` to solve the system (half point each).
# * <span style="color:green">**0.5**</span> point for the plots.
# * <span style="color:green">**0.5**</span> point for the explanation.
#
# ### Part 2: Anti-viral drugs (4 points)
#
# * <span style="color:green">**0.5**</span> point for the picture/drawing of the compartmental model.
# * <span style="color:green">**0.5**</span> point for the ODE equations.
# * <span style="color:green">**1.0**</span> point for the derivatives function.
# * <span style="color:green">**1.0**</span> point for solving with `odeint` using the correct initial conditions (i.e., using $T(50)$, $I(50)$ and $V(50)$ from the previous part).
# * <span style="color:green">**0.5**</span> point for the plots.
# * <span style="color:green">**0.5**</span> point for the interpretation.
#
# ## Question 3: Simulating heat diffusion (5 points)
#
# ### Part 1: Creating a hot plate in Python (2 points)
#
# * <span style="color:green">**1.0**</span> point for the `make_hotplate` function.
# * <span style="color:green">**1.0**</span> point for displaying the hot plate.
#
# ### Part 2: Implement the update equation using Numpy (1 point)
#
# * <span style="color:green">**1.0**</span> point for completing the `do_timestep` function.
#
# ### Part 3: Simulating heat diffusion (2 points)
#
# * Depending upon how the student approaches the problem, this can either be easy or hard to breakdown. Essentially, though, <span style="color:green">**1.0**</span> point for simulating the heat diffusion, and <span style="color:green">**1.0**</span> point for the display.
