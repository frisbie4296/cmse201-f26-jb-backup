# %% [markdown]
# ### ANSWER
# # Homework 2 if/elif/else statements, Functions, NumPy, and Matplotlib

# %% [markdown]
# ### ANSWER
#
# ## README
#
# These templates have been drafted to standardize the homework assignments to the course learning objectives and keep them of similar difficulty, length, and point values throughout the semester.
# Homework drafts are due to the Lead Instructor and Associate Instructors at least **10 days** prior to their release date in order to give instructors enough time to review the assignment, the assignment lead enough time to integrate feedback, and all staff enough time to review the final assignment prior to release.
#
# It is expected that the assignments follow the learning objectives and the general structure/point distribution provided, but the framing of the problems is left up to the assignment lead(s). A specific rubric should be included with the finished assignment to foster equity in grading across sections. It is encouraged to explore a variety of discipline areas in the problem framing, particularly those represented by our students (biology, chemistry, data science, physics, astronomy, business, etc.)! Some example questions have been provided for reference. If you have questions about your homework assignment as you develop it, they can be directed to the lead instructor.
#
# Finally, homework assignments are designed to assess the material covered in the Pre-class and In Class assignments and should therefore **not contain anything that is not covered in those assignments.**

# %% [markdown]
# # Homework 2: Dictionaries, If Statements, Functions, and Modules

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # __CMSE  201 &ndash; Spring 2025__
#
# <img src="https://cmse.msu.edu/sites/_cmse/assets/Image/image002.jpg"
#      alt="CMSE Logo"
#      align="right"
#      height="100"
#      width="100" />
#
#
# ## Learning Goals
#
# ### Content Goals
#  * Use if/elif/else statements to implement a logical flow
#  * Write and execute functions
#  * Use the numpy module for math and data
#  * Display data on plots using matplotlib
#  * Utilize dictionaries to store data
#
# ### Practice Goals
# * Coding conventions
# * More advanced debugging
# * Using functions to build reusable/transferable code
# * Use visualization best practices to make informative plots

# %% [markdown]
# ### ANSWER
#
# Homework Structure: All about functions with numpy and matplotlib!
# * Something with dictionaries that is simple (this can be dropped in favor of more in depth other problems)
# * Debugging a function (like pca 5)
# * Problem with if/else and functions
# * Problem with function inside a function
# * Problem with numpy to read in data, do math, and plot (possibly using a function too)
#
# **NOTE FOR CONTENT TEAM:** PLEASE ENSURE THAT YOU ARE ASKING "METACOGNITION" STYLE QUESTIONS FOR EACH PROBLEM AND INCLUDING PLACES FOR POINTS TO BE GIVEN (OR DEDUCTED) FOR USING RESOURCES
# ___

# %% [markdown]
# ### ANSWER (to make sure this gets removed)
#
# ## Note to Instructors:
# This homework is primarily targeted at folks that are just starting to learn to code. There are several practices that I’m specifically targeting with this homework:
# 1. Using good coding practices: useful variable names, pseudocode/comments and modular code (functions)
# 2. Introducing visualization best practices: axis labels, title, large enough text, legend, meaningful colors/symbols
# 3. Debugging at a more advanced level
#
# ## Note to Graders:
# I have provided rubrics with points values for each part as a guide
#
# #### Rubric
#
# Academic Integrity - 2 points
#
# 1. Dictionaries (10 points total)
# 2. Debugging Functions (10 points total)
# 3. Functions, if/else, and Manufacturing (10 points)
# 4. Numpy, matplotlib, and functions (18 points)
#
# Total points possible: **50**

# %% [markdown]
# ## Assignment instructions
#
# Work through the following assignment, making sure to follow all the directions and answer all the questions.
#
# **This assignment is due at 11:59 pm on Friday, February 28th.** It should be uploaded into the "Homework Assignments" submission folder for Homework #2.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ## Academic integrity statement (2 Points)
#
# In the markdown cell below, paste your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# ## 1. Dictionaries (10 Points)

# %% [markdown]
# Python dictionaries are particularly useful for keeping track of pieces of information of different types.
#
# **Scenario:** You are building a database of the two basic types of animals invertebrates and vertebrates. Each type contains basic animal classes. For example, vertebrates include fish, reptiles, etc., while invertebrates encompasses porifera, molluscs, etc. Scientists on a worldwide expedition will use your dictionary to categorize interesting wild life they may encounter during their journey. You will start the database by including 4 animal classes for each of the two animal types. For each animal class, you will list 3 examples to jumpstart the database.

# %% [markdown]
# ### &#9989;&nbsp; 1.1 Task (5 Points)
#
# In the cell below, create a Python dictionary that includes entries for the two basic types of animals: (1) invertebrates and (2) vertebrates. Each of these two entries will contain as their values a list of 3 animal classes under the corresponding type. The dictionary must also contain a separate entry for each of the 6 animal classes that lists 3 example animals from these classes. Make sure that the entries are consistently typed within the dictionary. For example, if you use "fish" as an example of verbetrate, then you must use "fish" (not "Fish" or "fishies") as the key of the entry that includes 3 examples of "fish."

# %%
# Put your answer here

# %%
### ANSWER

# 4 points for correct syntax
# 1 point for reasonable entries (quick check only, do not worry about 100% correctness of animal types/examples)
# Reference: https://www.yourdictionary.com/articles/animals-types-characteristics

animal_journal = {"vertebrate":["amphibians", "mammals", "birds"],
               "invertebrate": ["arthropods", "molluscs", "annelids"],
               "amphibians": ["axolotl", "frogs", "salamanders"],
              "mammals":["dogs", "cats", "lions"],
              "birds":["eagle", "owl", "toucan"],
              "arthropods":["crustacean", "insects", "spiders"],
              "molluscs":["octopus","scallops","clams"],
              "annelids":["earthworm", "leech", "sandworm"]}

# %% [markdown]
# ### &#9989;&nbsp; 1.2 Task (5 Points)
#
# You have made your animal database, now it's time to use it!
#
# In the cell below, write a print statement that describes the membership of one of the example animals to its class and type. The example animal and its class must be fetched from the dictionary, while the connecting statements such as "belongs to" can be typed manually into the print statement. For example, your output could be:
#
# `'[sparrow] belongs to the [birds] class which belongs to the vertebrate animal type.'`
#
# Note that the output inside [] must be obtained from the animal examples and classes in your dictionary, while the other strings in the output are typed manually in the print statement.

# %%
# put your answer here

# %%
### ANSWER 
print(animal_journal['annelids'][0], "belongs to the", animal_journal['invertebrate'][2], "class which belong to the vebetrate animal type.")

# 4 points for using the dictionary keys to access the animal example and class.
# 1 point for constructing print statements that run
# Out:
# earthworm belongs to the annelids class which belong to the vebetrate animal type.

# %% [markdown]
# ## 2. Debugging a Function (10 Points)

# %% [markdown]
# In the Tasks below, you will be asked to find, describe, and fix the bugs in each example.

# %% [markdown]
# In the cell below, you will find a function that takes in the mass of an object and a planet in the solar system and returns the weight of that ball as measured on the input planet.
#
# The weight $w$ is computed according to:
#
# $\begin{equation}
# w=m*g,
# \end{equation}$
#
#
# where $m$ is the mass of the ball and $g$ is the acceleration due to gravity on the planet.
#
# **Run the cell below** because it will be used later. Take a few minutes to study the given function and read the comments that describe its inputs and outputs, as well as what the different lines of code do.
# **Do not change the given code. You will have the chance to make edits in a different cell.**
#
# For reference, here are some examples for [official sports ball masses](https://www.topendsports.com/resources/equipment/ball-weight.htm).

# %%
# Do not edit this cell

# generate some initial data for testing
mass = 20   # kg
planet = 'earth'

def compute_weight(object_mass=1, planet='earth'):
    """
    Computes the weight of an object on a planet in the solar system

    Args:
        mass (float): The mass of the object
        planet (str): The planet name. 
        Must be be one of the options 'earth', 'jupiter', 'mars', 
        'mercury', 'mars', 'venus', 'saturn', 'neptune'.

    Returns:
        float: The weight of the object on the selected planet.
    """

    # create a message documenting the received input
    msg = "mass entered is {}. Planet entered is {}".format(object_mass, planet)

    # acceleration due to gravity for planets in the solar system in m/s^2
    # Source: https://aerospaceweb.org/question/astronomy/q0227.shtml
    g_earth = 9.81      # m/s^2, Earth
    g_jupiter = 24.79   # m/s^2, Jupiter
    g_mercury = 3.7     # m/s^2, Mercury
    g_mars = 3.73       # m/s^2, Mars
    g_venus = 8.87      # m/s^2, Venus
    g_saturn = 10.44    # m/s^2, Saturn
    g_neptune = 11.15   # m/s^2, Neptune
    # g_pluto = 0.62      # m/s^2, Pluto (not a planet any more :( )

    # set the gravity constant g to the correct value
    if planet == 'earth':
        g = g_earth
    elif planet == 'jupiter':
        g = g_jupiter
    elif planet == 'mercury':
        g = g_mercury
    elif planet == 'mars':
        g = g_mars
    elif planet == 'venus':
        g = g_venus
    elif planet == 'saturn':
        g = g_saturn
    elif planet == 'neptune':
        g = g_neptune
    elif planet == 'pluto':
        print('pluto is no longer a planet')
        # Input invalid. Exit the function without returning anything
        return
    else:
        print("Incorrect planet. Planet must be on of 'earth', 'jupiter', 'mars', 'mercury', 'mars', 'venus', 'saturn', or 'neptune'")
        # Input invalid. Exit the function without returning anything
        return
    
    # after setting the correct g, return the weight of the object
    return g * mass  

# Now let's play with some examples.

mass_ball = 0.45  # kg, mass of a soccer ball for example

# let's see what the mweight of the ball on Mars is
weight_ball = compute_weight(mass_ball, 'mars')

print(weight_ball)
# Out:
# 74.6

# %% [markdown]
# ### &#9989;&nbsp; 2.1 Task (1 Point)
#
# The cell below tests the ```compute_weight``` function by giving a test data composed of [masses of sports balls](https://www.topendsports.com/resources/equipment/ball-weight.htm) in kilograms, as well as their weights on Earth (g_earth=9.81 m/s^2) and on Mars (g_mars=3.73 m/s^2). Note that $g_{\text{earth}} > g_{\text{mars}}$. However, something seems to be wrong with the output.
#
# Find any issues with the function that could be causing the incorrect output (remember that this is called "debugging"!).
#
# **Write any bugs that you found in the space below. You will fix bugs in the next question, don't worry about doing that here!**

# %%
import numpy as np

# define masses of sports balls
sports_balls = 10**-3 * np.array([2.7 ,  # kg, table tennis
             45.93,          # kg, golf
             145,            # kg, baseball
             410])            # kg, american football

# call the function and print weights on earth and on Mars
for ball in sports_balls:
    print("For mass = {:.2f} gram the weight on earth is {:.2f}, the weight on Mars is {:2f}".format(ball*10**3, compute_weight(ball, 'earth'), compute_weight(ball, 'mars')))
# Out:
# For mass = 2.70 gram the weight on earth is 196.20, the weight on Mars is 74.600000
# For mass = 45.93 gram the weight on earth is 196.20, the weight on Mars is 74.600000
# For mass = 145.00 gram the weight on earth is 196.20, the weight on Mars is 74.600000
# For mass = 410.00 gram the weight on earth is 196.20, the weight on Mars is 74.600000

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> Put your answer for 2.1 here

# %% [markdown]
# ### Answer
#
# <font size=6 color="#009600">&#9998;</font> 2.1: scope error for the mass variable. Specifically, mass =20 above the function, the function returning mass * g instead of returning object_mass * g
#
# ### Rubric
# 1 point for correctly identifying the bug, no partial credit

# %% [markdown]
# ### &#9989;&nbsp; 2.2 Task (4 Points)
#
# The function and the test code are copied into the cell below. Fix the bug you found, and run the test code.

# %%
import numpy as np

# Write your answer for 2.2 here by editing the function definition to fix the bug

# generate some initial data for testing  # 
mass = 20   # kg
planet = 'earth'

def compute_weight(object_mass=1, planet='earth'):
    """
    Computes the weight of an object on a planet in the solar system

    Args:
        mass (float): The mass of the object
        planet (str): The planet name. 
        Must be be one of the options 'earth', 'jupiter', 'mars', 
        'mercury', 'mars', 'venus', 'saturn', 'neptune'.

    Returns:
        float: The weight of the object on the selected planet.
    """

    # create a message documenting the received input
    msg = "mass entered is {}. Planet entered is {}".format(object_mass, planet)

    # acceleration due to gravity for planets in the solar system in m/s^2
    # Source: https://aerospaceweb.org/question/astronomy/q0227.shtml
    g_earth = 9.81      # m/s^2, Earth
    g_jupiter = 24.79   # m/s^2, Jupiter
    g_mercury = 3.7     # m/s^2, Mercury
    g_mars = 3.73       # m/s^2, Mars
    g_venus = 8.87      # m/s^2, Venus
    g_saturn = 10.44    # m/s^2, Saturn
    g_neptune = 11.15   # m/s^2, Neptune
    # g_pluto = 0.62      # m/s^2, Pluto (not a planet any more :( )

    # set the gravity constant g to the correct value
    if planet == 'earth':
        g = g_earth
    elif planet == 'jupiter':
        g = g_jupiter
    elif planet == 'mercury':
        g = g_mercury
    elif planet == 'mars':
        g = g_mars
    elif planet == 'venus':
        g = g_venus
    elif planet == 'saturn':
        g = g_saturn
    elif planet == 'neptune':
        g = g_neptune
    elif planet == 'pluto':
        print('pluto is no longer a planet')
        # Input invalid. Exit the function without returning anything
        return
    else:
        print("Incorrect planet. Planet must be on of 'earth', 'jupiter', 'mars', 'mercury', 'mars', 'venus', 'saturn', or 'neptune'")
        # Input invalid. Exit the function without returning anything
        return
    
    # after setting the correct g, return the weight of the object
    return g * mass  

#--------------------------------------Do not edit the code below-------------------------
# Testing the function
# define masses of sports balls
sports_balls = 10**-3 * np.array([2.7 ,  # kg, table tennis
             45.93,          # kg, golf
             145,            # kg, baseball
             410])            # kg, american football

# call the function and print weights on earth and on Mars
for ball in sports_balls:
    print("For mass = {:.2f} gram the weight on earth is {:.2f}, the weight on Mars is {:2f}".format(ball*10**3, compute_weight(ball, 'earth'), compute_weight(ball, 'mars')))
# Out:
# For mass = 2.70 gram the weight on earth is 196.20, the weight on Mars is 74.600000
# For mass = 45.93 gram the weight on earth is 196.20, the weight on Mars is 74.600000
# For mass = 145.00 gram the weight on earth is 196.20, the weight on Mars is 74.600000
# For mass = 410.00 gram the weight on earth is 196.20, the weight on Mars is 74.600000

# %%
### ANSWER ###

# answer for 2.2
### RUBRIC
# 1 point for identifying the scope error:
#  mass =20 above the function, the function returning mass * g instead of returning object_mass * g
# 2 points for fixing it by editing return mass * g to return object_mass * g
# 2 points for correctly rerunning the test code

# generate some initial data for testing  # <--- mass and planet are not used. Some students may also delete them. It's fine whetehr the students delete them or keep them
mass = 20   # kg
planet = 'earth'

def compute_weight(object_mass=1, planet='earth'):
    """
    Computes the weight of an object on a planet in the solar system

    Args:
        mass (float): The mass of the object
        planet (str): The planet name. 
        Must be be one of the options 'earth', 'jupiter', 'mars', 
        'mercury', 'mars', 'venus', 'saturn', 'neptune'.

    Returns:
        float: The weight of the object on the selected planet.
    """

    # create a message documenting the received input
    msg = "mass entered is {}. Planet entered is {}".format(object_mass, planet)

    # acceleration due to gravity for planets in the solar system in m/s^2
    # Source: https://aerospaceweb.org/question/astronomy/q0227.shtml
    g_earth = 9.81      # m/s^2, Earth
    g_jupiter = 24.79   # m/s^2, Jupiter
    g_mercury = 3.7     # m/s^2, Mercury
    g_mars = 3.73       # m/s^2, Mars
    g_venus = 8.87      # m/s^2, Venus
    g_saturn = 10.44    # m/s^2, Saturn
    g_neptune = 11.15   # m/s^2, Neptune
    # g_pluto = 0.62      # m/s^2, Pluto (not a planet any more :( )

    # set the gravity constant g to the correct value
    if planet == 'earth':
        g = g_earth
    elif planet == 'jupiter':
        g = g_jupiter
    elif planet == 'mercury':
        g = g_mercury
    elif planet == 'mars':
        g = g_mars
    elif planet == 'venus':
        g = g_venus
    elif planet == 'saturn':
        g = g_saturn
    elif planet == 'neptune':
        g = g_neptune
    elif planet == 'pluto':
        print('pluto is no longer a planet')
        # Input invalid. Exit the function without returning anything
        return
    else:
        print("Incorrect planet. Planet must be on of 'earth', 'jupiter', 'mars', 'mercury', 'mars', 'venus', 'saturn', or 'neptune'")
        # Input invalid. Exit the function without returning anything
        return
    
    # after setting the correct g, return the weight of the object
    return g * object_mass  # <--------------------------------------------------- mass in original function replaced with object_mass


#--------------------------------------Do not edit the code below-------------------------
# Testing the function
# define masses of sports balls
sports_balls = 10**-3 * np.array([2.7 ,  # kg, table tennis
             45.93,          # kg, golf
             145,            # kg, baseball
             410])            # kg, american football

# call the function and print weights on earth and on Mars
for ball in sports_balls:
    print("For mass = {:.2f} gram the weight on earth is {:.2f}, the weight on Mars is {:2f}".format(ball*10**3, compute_weight(ball, 'earth'), compute_weight(ball, 'mars')))
# Out:
# For mass = 2.70 gram the weight on earth is 0.03, the weight on Mars is 0.010071
# For mass = 45.93 gram the weight on earth is 0.45, the weight on Mars is 0.171319
# For mass = 145.00 gram the weight on earth is 1.42, the weight on Mars is 0.540850
# For mass = 410.00 gram the weight on earth is 4.02, the weight on Mars is 1.529300

# %% [markdown]
# ### &#9989;&nbsp; 2.3 Task (5 Points)
#
# In the code cell below, you have a function and a function call written for you. The function definition and/or the function call have some errors. You should do/answer the following:
#
# 1. What should the output of the function call be?
# 2. Write a plain English description of the bug. Search the web for unfamiliar error messages that you may receive when running the cell.
# 3. Fix the function definition to remove bugs in the code cell below, and write down how you fixed it. Rerun the fixed code and make sure it gives the correct answer.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer for 2.3 here*
#
# 1.
# 2.
# 3.

# %% [markdown]
# ### Answer
#
#
# 1. (1 pt) "MSU is top 30 university. The student population is 51316, and its campus spans 5200 acres. MSU has 400+ academic programs, and the student-teacher ratio is 16:1"
# 2. (2 pts- 0.5 pt baseline + 0.5 pt to each part) The errors are:
#     * Arguments with default cannot precede arguments without default values (area must be last argument)
#     * In string1 acres is used instead of the argument area in the function signature
#     * Edit the function call so that acres is the last argument to pass
# 3. (2 pts- 0.5 pt baseline + 0.5 pt to each part) The fixes are (fixed code must correctly run to receive credit for this part):
#     * Move area to be the last argument in the function signature
#     * replace acres in the format method of string1 with 'area'
#     * pass acres last in the function call

# %%
# 2.3: Correct this function definition, and if needed, the function call

# A function to print MSU facts 
# Source: https://msu.edu/about/facts

def print_MSU_facts(ranking, student_population, area=5000, num_programs, student_teacher_ratio):
    string1 = "MSU is top {:d} university. The student population is {:d}, and its campus spans {:d} acres.".format(ranking, student_population, acres)
    string2 = "MSU has {:d}+ academic programs, and the student-teacher ratio is {}".format(num_programs, student_teacher_ratio)
    output_string =  string1 + string2

    print(output_string)


# Code to test the function. 
# MSU facts
public_uni_ranking = 30
num_students = 51316
acres = 5200
num_academic_prgrams = 400
student_faculty_ratio = '16:1'

# call the function
print_MSU_facts(public_uni_ranking, num_students, acres, num_academic_prgrams, student_faculty_ratio)
# Out:
#   Cell In[53], line 6
#     def print_MSU_facts(ranking, student_population, area=5000, num_programs, student_teacher_ratio):
#                                                                 ^
# SyntaxError: non-default argument follows default argument

# %%
### ANSWER ###

# 2.3 

# A function to print MSU facts
def print_MSU_facts(ranking, student_population, num_programs, student_teacher_ratio, area=5000):  # <------------ arguments with default cannot precede arguments without default values
    string1 = "MSU is top {:d} university. The student population is {:d}, and its campus spans {:d} acres.".format(ranking, student_population, area)  # <----- replace acreas with area in format(...)
    string2 = " MSU has {:d}+ academic programs, and the student-teacher ratio is {}.".format(num_programs, student_teacher_ratio)
    output_string =  string1 + string2

    print(output_string)


# Code to test the function
# MSU facts
public_uni_ranking = 30
num_students = 51316
acres = 5200
num_academic_prgrams = 400
student_faculty_ratio = '16:1'

# call the function
print_MSU_facts(public_uni_ranking, num_students, num_academic_prgrams, student_faculty_ratio, acres) # <------ Fix function call so acres is passed last
# Out:
# MSU is top 30 university. The student population is 51316, and its campus spans 5200 acres. MSU has 400+ academic programs, and the student-teacher ratio is 16:1.

# %% [markdown]
# ## 3. Functions, if/else, and Manufacturing! (10 Points)
#
# Different products require different surface finish. For example, consumer products are often expected to be smooth and shiny, while non-critical components of boilers can be rough. Certain industries have stricter requirements on surface finish and tolerance such as the aerospace industry. However, tighter tolerances and smoother surfaces come at the cost of increased production expenses and longer production times, see [here](https://web.mae.ufl.edu/designlab/Lab%20Assignments/EML2322L-Tolerances.pdf).
#
# Different production processes have limitations on the surface finish (measured in micrometers $\mu m$ which is one millionth of a meter, or microns). For example, [grinding](https://en.wikipedia.org/wiki/Grinding_(abrasive_cutting)) can produce finer surfaces than [turning](https://en.wikipedia.org/wiki/Turning) or [milling](https://en.wikipedia.org/wiki/Milling_(machining)), see Fig. 15.8 [here](https://web.mae.ufl.edu/designlab/Lab%20Assignments/EML2322L-Tolerances.pdf).
#
# Rough ranges for surface finished produced by turning, milling, and grinding are:
# * Grinding: 0.025 $\mu m$ -- 3.2 $\mu m$.
# * Turning: 0.40 $\mu m$ -- 3.2 $\mu m$.
# * Milling: 0.40 $\mu m$ -- 25 $\mu m$.

# %% [markdown]
# ### 3.1 Selecting the right process for the job  (3 points)
#
# Write a function that takes in the desired surface finish (in microns) and a manufacturing process as a string ('turning', 'milling', or 'grinding') and returns the Boolean "True" if the process can produce the required surface finish, and definition and "False" if it cannot.
#
# Write your function in the cell below. Demonstrate that your function works using the test data given (`surface_finish_test_data`).
#
# __hint__: You can test if a string is in a list using ```in```. For example, ``` 'cat' in ['dog', 'dolphin', 'cat']``` will evaluate to ```True```.

# %%
#----------------Run this cell before proceeding, but do no edit it.
# test surface finish (in microns)
surface_finish_test_data = [11.56,  0.78,  0.11,  0.96, 12.33,  0.84, 13.42,  0.91,  0.13, 10.45,  0.09,  0.10 ]  # in microns

# %%
# Write your Answer to 3.1 here:

# %%
### ANSWER ###

# 3.1
# Grading:
# * 2 points on the conditional statements
# * 1 point for the loop that prints the output

def select_process(surface_roughness, process):
    if surface_roughness >= 0.025 and surface_roughness < 0.4:
        return (process == 'grinding')
    elif surface_roughness >=0.4 and surface_roughness <= 3.2:
        return (process in ['grinding', 'milling', 'turning'])
    elif surface_roughness > 3.2 and surface_roughness <= 25:
        return (process == 'milling')        
    else:
        return False
    
manufacturing_process = 'turning'
for i in range(len(surface_finish_test_data)):
    print(select_process(surface_finish_test_data[i], manufacturing_process))
# Out:
# False
# True
# False
# True
# False
# True
# False
# True
# False
# False
# False
# False

# %%
### Answer

# This cell is used to generate the models for the surface finish versus production time
# remove from the student's version 


import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def func(x, a, b):
    return a * np.exp(-b * x)

turning_pts = np.array([[0.3848289585419861, 5.891427542155652],
                        [0.4220370491061196, 5.528410901583692],
                        [0.45738538834478376, 5.099663308993668],
                        [0.5075937224914345, 4.802377620439775],
                        [0.5501608225848919, 4.406550926246659],
                        [0.6034123609962386, 4.0764551840716035],
                        [0.6852648239805434, 3.680185110775498],
                        [0.7782205160825544, 3.283915037479389],
                        [0.88387046509442, 2.920565862580188],
                        [1.0274679125166684, 2.5240740997325855],
                        [1.1807654262102125, 2.193534978454546],
                        [1.357195488883576, 1.928837653970319],
                        [1.541890320623904, 1.6642511742618378],
                        [1.7520559702617418, 1.4655064913471745],
                        [2.0857947904215113, 1.2333975309326108],
                        [2.454534755225406, 1.034320313690706],
                        [2.8560507930427956, 0.9670375348121778],
                        [3.209233104032792, 0.9330081886577972]])

milling_pts = np.array([[0.36860483991520154, 11.126404611142675],
                        [0.4137893177979592, 10.763166281019219],
                        [0.43818650009334104, 10.4004821747745],
                        [0.48610054878438724, 9.97151289263298],
                        [0.5328955648032652, 9.476812658473392],
                        [0.5774735604696214, 9.015144167486456],
                        [0.6480126866308925, 8.520222243775375],
                        [0.7442667402897453, 7.9921577321158885],
                        [0.8254116630434553, 7.464425754783644],
                        [0.94801608135862, 6.93636124312416],
                        [1.063613127590268, 6.37559752261926],
                        [1.2215993478718594, 5.847533010959777],
                        [1.419383951744018, 5.286436756127637],
                        [1.6308417907873023, 4.890055838055783],
                        [1.8095157551499383, 4.526928352708078],
                        [2.1277779316506074, 4.064483948290912],
                        [2.4732284672179174, 3.6350712870464004],
                        [2.9096229636324664, 3.337231374613773],
                        [3.344057877591002, 3.0396131517326426],
                        [4.025840319918349, 2.642788854557797],
                        [4.8480203409781835, 2.344727252573676],
                        [5.703440462229057, 2.0468873401410477],
                        [6.711730656912326, 1.847810122899142],
                        [8.769495929026528, 1.5160517090878716],
                        [10.562480934304121, 1.2838319038975747],
                        [17.43017914258233, 0.9827774929682789],
                        [22.79383221897322, 0.9473071647291809],
                        [28.12134122362434, 0.9453119587657388]])

grinding_pts = np.array([[0.024641486289475458, 15.794078117855713],
                         [0.02578420733921399, 15.33274216119602],
                         [0.025742144466791603, 14.773086888448592],
                         [0.0272546759509536, 14.34456098541006],
                         [0.028185029522485604, 13.850414975129206],
                         [0.029135946254338727, 13.224585371260723],
                         [0.030833077839829193, 12.631454976237654],
                         [0.031500547231879165, 11.97281531874801],
                         [0.0353348021578731, 11.346209801449294],
                         [0.0365058983570556, 10.522854807199371],
                         [0.039548308292946234, 9.962423621021717],
                         [0.042347236764949954, 9.402103279619803],
                         [0.04640601043948934, 8.775719451872586],
                         [0.05024936252748312, 8.050683773710393],
                         [0.055717179941926265, 7.457109999584335],
                         [0.06321443616543099, 6.7316309423191525],
                         [0.07007956865728836, 6.0722153713992775],
                         [0.08141025206587252, 5.445277319773323],
                         [0.09239136204215868, 4.818560957698862],
                         [0.11116392492691975, 4.224211270142574],
                         [0.133763641875928, 3.662782480983193],
                         [0.16284708959137742, 3.101242847048066],
                         [0.1937924109859389, 2.7374502930458773],
                         [0.2415215022801478, 2.2086098679561608],
                         [0.31927404677936744, 1.8767406093691488],
                         [0.41228194270434737, 1.5121721419367309],
                         [0.5579829872435167, 1.2459229905920441],
                         [0.7465575911480041, 1.0456264808169249],
                         [0.9426142240692037, 0.9775677885081613],
                         [1.2617836474397963, 0.9418757707175751]])

turning_popt, turning_pcov = curve_fit(func,  turning_pts[:, 0],  turning_pts[:, 1],  p0=(4, 0.1))
milling_popt, milling_pcov = curve_fit(func,  milling_pts[:, 0],  milling_pts[:, 1],  p0=(4, 0.1))
grinding_popt, gridning_pcov = curve_fit(func,  grinding_pts[:, 0],  grinding_pts[:, 1],  p0=(4, 0.1))


plt.plot(turning_pts[:,0], func(turning_pts[:,0], *turning_popt), 'r-', label='fit: a=%5.3f, b=%5.3f' % tuple(turning_popt)) 
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

plt.plot(milling_pts[:,0], func(milling_pts[:,0], *milling_popt), 'r-', label='fit: a=%5.3f, b=%5.3f' % tuple(milling_popt)) 
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

plt.plot(grinding_pts[:,0], func(grinding_pts[:,0], *grinding_popt), 'r-', label='fit: a=%5.3f, b=%5.3f' % tuple(grinding_popt)) 
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# this part generates sample surface finishes

# Define parameters for each Gaussian distribution
# means = [0.1, 0.8, 12]  # List of mean vectors
# stdev = [0.05, 0.2, 1.2]  # List of standard deviations
# sizes = [4, 4, 4]  # Number of samples for each distribution

# # Generate data
# data = [[],[],[]]
# for i in range(len(means)):
#     data[i] = stdev[i]* np.random.randn(sizes[i]) + means[i]

# # flatten the list and randomize the entries
# flat_data = [item for inner_list in data for item in inner_list]
# np.random.shuffle(flat_data)  # shuffle entries in-place

# print(len(flat_data))

# np.round(flat_data,2)

# %% [markdown]
# ### 3.2 Extending to the full Data Set (2 points)
#
# In the cell below, you will find a data set of tolerances for a part sent to a machine ship. **Use your function** on the list to count the number of processes that can *only be completed* using grinding or milling.
#
# For example, your output may look like this:
# ```
# Only grinding         Only Milling
#         7                 11
# ```

# %%
#-------------Do not edit--------------------
# full tolerance list (in microns) 

tolerance_list = [10.784816857410622,  0.6284242401927808,  12.93574564247594,  11.12811894288246, 13.776787616827054,  0.05107017590751106,  1.0127501750972174,  11.675191297747707,  12.062884629308304,  0.16496634293111634,  12.590085712262848,  10.731140195151154,  0.045065685183655425,  11.51518692397626,  1.0418687155577828,  0.8291592892965186,  7.952897208385569,  12.438588832472773,  0.6207610683948976,  0.7528983420257483,  0.5675155635817709,  11.22386987451356,  13.023339642701792,  0.7486025733524816, 10.764849744815045,  11.745369578976508,  0.08570630717518767,  12.998961097741738,  11.828738900408295,  10.628084496275532,  0.11179193052272116,  0.7695671658260386,  9.922153972105964,  0.1169692709084147,  12.333488049446247,  1.125792754642666,  0.15322878584568517,  0.6984137044479597,  12.936398835857625,  13.313918034830612,  0.10213420843315299,  0.7865597569325863,  10.767448516372495,  10.406624904442811, 11.947019067105021,  0.12922769019058133,  0.7322069947908311, 13.49528686072342,  0.390276218528216,  0.7601984858717746, 12.628682578472825,  9.922979277692916,  12.016473959072854,  0.7145423882679505,  11.61989597384899,  0.04726044396200514,  0.10246806193431096,  0.5687861054879977,  0.11909587262102675,  0.6425321468962494, 0.21135459672999074,  0.8072720616657312,  12.887720354117628,  1.096957977232816,  13.533965673378663,  12.520124338949184,  0.06944516368385857,  10.82389986128962, 0.3830359009796972,  12.914193636031131,  0.7491712279013639,  1.055959382080717,  0.10514992993691348,  13.014680685502269,  0.8617968557764097,  0.03508747608245555, 14.552068181509526,  0.8944577980093145, 11.902207248788262, 0.1304118893082896,  0.8452501664971064, 1.2140352228779538, 11.123010545594665, 0.0789648039157834, 1.0395050730726916, 12.797943860265375, 10.138084813390835, 0.9773702715191002, 0.02558748747438859, 0.5554200433485876, 11.705145465181145, 12.584623696693342, 10.932942228395497, 10.494983558601154, 0.17938653487971756]

# %%
# Write your code for 3.2 here:

# %%
### Answer

### RUBRIC
# 2 out of 2 points for a correct answer (including any necessary citations) that uses their previous function 
# 1 out of 2 points for using the function correctly OR getting a correct answer 
# (i.e. if there was a bug in their function that yields the incorrect answer, 
# but they did the function call correctly, they get 1 our of 2)
# 0 out of 2 for an incorrect answer AND incorrect function call

# 3.2:

manufacturing_processes = ['grinding', 'turning','milling']

# initilize an array to hold the tallies for each process. Could also use a list instead.
process_tally = np.zeros(3)

# loop over manufacturing processes 
for process_ind in range(len(manufacturing_processes)):

    # loop over tolerance list
    for part_tol in tolerance_list:
        if select_process(part_tol, manufacturing_processes[process_ind]):
            process_tally[process_ind] += 1

# compute grinding only
# subtract tally for grinding from tally for grinding/turning/milling to get grinding only
grinding_only = process_tally[0] - process_tally[1]

# subtract tally for milling from tally for grinding/turning/milling to get milling only
milling_only = process_tally[2] - process_tally[1]

print("Grinding only \t Milling only \n \t{} \t {}".format(grinding_only, milling_only))
# Out:
# Grinding only 	 Milling only
#  	22.0 	 45.0

# %% [markdown]
# ### 3.3 Adding Complexity (3 points)
#
# What if you wanted to also take into account the length of time it takes to process the part? Run the cell below which has a function that estimates the time required to finish a part to a particular surface finish for each of the three basic process turning, milling, and grinding.
#
# Write a new function that takes in a desired surface finish in microns and recommends a manufacturing process (turning, milling, or grinding) based on the process's viability and ability to reach the desired surface finish in the least amount of time. Use the provided function ```estimate_time``` in your code to get the process time. You can choose to build from your previous code or start from scratch. You may find it helpful to make use of the test data again while you're debugging your function!
#
# Demonstrate that your code works by writing code that runs your function and determines the number of recommended operations for each of turning, milling, grinding in the full data set.
#
# For example, your output may look like this:
# ```
# Recommended Process Tally
# Turning    Milling    Grinding
#   37         49          21
# ```
#
# Or your may choose to store the result in a dictionary and print it according to
# ```
# {'turning': 37, 'milling': 49, 'grinding': 21}
# ```

# %%
#--------------Run this cell, but do not edit it----------------------------
# function to estimate the amount of time it would take to finish to a required tolerance using a specific machining process

def estimate_time(surface_finish, process):
    if process == 'turning':
        process_time = 8.030 * np.exp(1.031 * surface_finish)
    elif process == 'milling':
        process_time = 11.926 * np.exp(0.472 * surface_finish)
    elif process == 'grinding':
        process_time = 21.669 * np.exp(17.150 * surface_finish)
    else:
        print('incorrect input process')
        return
    
    # return the estiamted time rounded to 3 decimal places
    return np.round(process_time,3)
#-------------------Write your answer to 3.3 in the following cell---------

# %%
# write you answer to 3.3 here:

# %%
### ANSWER

# grading: there are many ways to solve this probelm
# # 1 point for choosing a viable process based on tolerance
# # 1 point for narrowing down the viable processes based on process time
# # 1 point for attempting the problem with only code from coursework (no points if they use code beyond coursework AND the answer doesn't work)

# 3.3

def process_recommender(surface_finish):
    # first, figure out viable finishing processes
    if surface_finish >= 0.025 and surface_finish < 0.4:
        viable_process = ['grinding']
    elif surface_finish >=0.4 and surface_finish <= 3.2:
        viable_process = ['grinding', 'milling', 'turning']
    elif surface_finish > 3.2 and surface_finish <= 25:
        viable_process = ['milling']        
    else:
        print("No viable process. Check surface finish range.")
        return
    
    # compute time for each viable process
    time_array = np.zeros(len(viable_process))
 
    for process_ind in range(len(viable_process)):
        time_array[process_ind] = estimate_time(surface_finish, viable_process[process_ind])

    # choose the process with the smallest time
    min_index = np.argmin(time_array)

    return viable_process[min_index]

# process_recommender(0.3)
# tally the recommendation for each tolerance in the list
# loop over tolerance list
process_dict = {'turning':0, 'milling':0, 'grinding':0}
for part_tol in tolerance_list:
    recommended = process_recommender(part_tol)
    process_dict[recommended] += 1

print(process_dict)
# Out:
# {'turning': 7, 'milling': 66, 'grinding': 22}

# %% [markdown]
# ### 3.4 Reflections (2 points)
#
# &#9989;&nbsp; In the cell below, answer the following reflection questions:
# * In Part 3.3, did you use your function from 3.1 at all?
# * In what way? (Or if you didn't, why not?)
# * This problem explored optimizing a manufacturing process using two variables: surface finish and process time. The process implicitly assumed a simple cut (i.e., a planar workpiece, no complicated geometry). Other possible considerations for finishing a part can introduce furether code complexity. Discuss the role functions can play in a more complicated scenario.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answers here.*

# %% [markdown]
# ### ANSWER
#
# Full credit for any thoughtful answer to these questions

# %% [markdown]
# ## 4. Numpy, matplotlib, and functions (18 Points)

# %% [markdown]
# ### 4.1 Making a plotting function  (6 points)
#
# In CMSE 201, you will be making plots often. To help future you save time, you are going to write a function to use when you make plots!
#
# &#9989;&nbsp; In cells below, write a function that takes in arrays of x and y values and displays a plot containing 4 subplots. Use plt.subplot() and include labels, line shapes, and colors to make the plots clear.
#
# For this exercise, you will analyze global temperature trends for four different regions over time. The anomalies represent the difference between the observed temperature and a reference period’s average temperature. In 1900, the anomaly is -0.2°C, meaning global temperatures were 0.2°C cooler than the reference period. By 2020, the anomaly reaches 1.0°C, indicating that the world is about 1°C warmer compared to the baseline.
#
# **You must also test your function with the test data to receive full credit**

# %%
# test data here
import numpy as np

years = np.array([1900, 1920, 1940, 1960, 1980, 2000, 2020])
global_temp = np.array([-0.2, -0.1, 0.0, 0.1, 0.4, 0.7, 1.0])
north_america_temp = np.array([-0.3, -0.2, 0.0, 0.2, 0.5, 0.8, 1.2])
europe_temp = np.array([-0.1, 0.0, 0.1, 0.3, 0.6, 0.9, 1.1])
asia_temp = np.array([-0.4, -0.3, -0.1, 0.2, 0.5, 0.9, 1.3])

# %%
# put your answer here

# %%
### ANSWER ###

# Rubric
# 2pts for inputs
# 1pt for labels
# 1pt for subplot
# 1pt for correctly plotting data
# 1pt for test

import matplotlib.pyplot as plt

def plot_temperature_trends(x, y, labels, xlabels, ylabels, title):
    plt.figure(figsize=(12,6))
    plt.suptitle(title)
    
    plt.subplot(2,2,1)
    plt.plot(x, y[0], color="red", linestyle="dashed", label=labels[0])
    plt.xlabel(xlabels[0])
    plt.ylabel(ylabels[0])
    plt.legend(loc='best')

    plt.subplot(2,2,2)
    plt.plot(x, y[1], color="blue", linestyle="solid", label=labels[1])
    plt.xlabel(xlabels[1])
    plt.ylabel(ylabels[1])
    plt.legend(loc='best')

    plt.subplot(2,2,3)
    plt.plot(x, y[2], color="green", linestyle="dotted", label=labels[2])
    plt.xlabel(xlabels[2])
    plt.ylabel(ylabels[2])
    plt.legend(loc='best')

    plt.subplot(2,2,4)
    plt.plot(x, y[3], color="purple", linestyle="dashdot", label=labels[3])
    plt.xlabel(xlabels[3])
    plt.ylabel(ylabels[3])
    plt.legend(loc='best')

    plt.tight_layout()

# Labels
x_label_list = ['Years','Years','Years','Years']
y_label_list = ['Temperature Anomaly (°C)'] * 4
labels = ['Global', 'North America', 'Europe', 'Asia']

# Run test
plot_temperature_trends(years, [global_temp, north_america_temp, europe_temp, asia_temp], labels, x_label_list, y_label_list, 'Temperature Trends (1900-2020)')

# %% [markdown]
# ### 4.2 Using `numpy` arrays and functions for calculations (6 points)
#
# The temperature anomalies in different regions vary significantly over time. To better compare trends between regions, we can examine the percent change in temperature anomalies rather than absolute values.
#
# We can calculate the percent change as follows:
#
# $\% \ difference = \frac{(final-initial)}{initial} \times 100$
#
# &#9989;&nbsp; In the cell below, write a function that takes in an array of temperature anomalies and calculates the percent change between each value. Demonstrate that your code works using one of the temperature anomaly arrays from the dataset.

# %%
# put your code here

# %%
### ANSWER ###

# one possible solution
import numpy as np

def pct_change(y):
    """
    Calculates the percent change between each consecutive value in an array.
    """
    percent_change_list = []
    i = 0
    print(len(y))  # Debugging: Print length of array
    while i < len(y) - 1:
        percent_change_list.append(((y[i+1] - y[i]) / y[i]) * 100)
        i += 1
    return np.array(percent_change_list)

# Test the function with global temperature anomaly data
global_temp = np.array([-0.2, -0.1, 1.0, 0.1, 0.4, 0.7, 1.0])
print("Percent change in global temperature anomalies:", pct_change(global_temp))
        
# Rubric
# 1 pt for def
# 2 pts for calculating pct diff
# 1 pt for return
# 2 pts for test
# Out:
# 7
# Percent change in global temperature anomalies: [  -50.         -1100.           -90.           300.
#     75.            42.85714286]

# %% [markdown]
# ### 4.3 Putting it all together (6 points)
#
# Along with this homework assignment, you will find a .csv file with some additional global temperature anomalies.
#
# &#9989;&nbsp; In the cell(s) below, use the data from the file (and the functions you wrote) to calculate the percent difference and generate plots for  plots for the regions in the CSV data file.
#
# **NOTE:** This homework only includes up to Day 9 content which does not include the `pandas` module. Therefore, you should use the `numpy` module for this problem. It is designed to be simpler with `numpy`!
#
#  Remember that you can open up data files in Jupyter to see what the data looks like!

# %%
# put your work here

# %%
### ANSWER ###

# Rubric
# 2 pts for loading the data
# 1 pt for pulling out the data for 4 countries
# 1 pt for percent difference
# 2 pts for writing code that uses the two functions to plot the data (partial credit for any attempt)
# Note, if students use pandas but do it correctly, you do not need to deduct points

import numpy as np

# Load temperature anomaly data from CSV
years, global_temp, north_america_temp, europe_temp, asia_temp = np.loadtxt(
    'global_temperature_anomalies.csv', skiprows=1, delimiter=',', usecols=[0,1,2,3,4], unpack=True
)

# Function to calculate percent change
def pct_change(y):
    percent_change_list = []
    i = 0
    while i < len(y) - 1:
        percent_change_list.append(((y[i+1] - y[i]) / abs(y[i])) * 100)
        i += 1
    return np.array(percent_change_list)

# Labels for the plots
x_label_list = ['Years'] * 4
y_label_list = ['Percent Change in Temperature (°C)'] * 4
labels = ['Global', 'North America', 'Europe', 'Asia']

# Generate plots for percent change in temperature anomalies
plot_temperature_trends(years[1:], [pct_change(global_temp), pct_change(north_america_temp), pct_change(europe_temp), pct_change(asia_temp)], 
         labels, x_label_list, y_label_list, 'Temperature Anomaly Trends')

# %% [markdown]
# ---
#
# ### Congratulations, you're done! ###
#
# Submit this assignment by uploading it to the course Desire2Learn web page. Go to the "Homework Assignments" section, find the submission folder link for Homework #2, and upload it there.

# %% [markdown]
# &#169; Copyright 2025,  The Department of Computational Mathematics, Science and Engineering at Michigan State University
