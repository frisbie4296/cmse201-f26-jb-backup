# %% [markdown]
# ### <p style="text-align: right;"> &#9989; **Put your name here** </p>

# %% [markdown]
# # __CMSE  201 &ndash; Spring 2021__
#
# <img src="https://cmse.msu.edu/sites/_cmse/assets/Image/image002.jpg"
#      alt="CMSE Logo"
#      align="right"
#      height="100"
#      width="100" />
#
# # Homework 2: If Statements, Functions and Modules
#
# In this homework you will practice some fundamental progamming techniques and skills using the Python programming language. This should serve as a good assessment of what you do/do not understand at this point in the course. Make sure to use Slack and help room hours if you run into issues!
#
# ___

# %% [markdown]
# ## Goals
#
# ### By the end of the homework assignment you will have practiced:
#
# 1. Writing If Statements
# 2. Writing Functions
# 3. Using math modules
# 3. Using matplotlib

# %% [markdown]
# ## Assignment instructions
#
# Work through the following assignment, making sure to follow all of the directions and answer all of the questions.
#
# **This assignment is due at 11:59pm on Friday, February 19th.** It should be uploaded into the "Homework Assignments" dropbox folder for Homework #2.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ## Grading
#
# Academic Integrity Statement (2 point)
# 1. Question 1: If Statements (6 points)
# 2. Question 2: The Bass diffusion model (6 points)
# 3. Question 3: Maximize your salary (7 points)
# 4. Question 4: Pythagorean triples (7 points)
# 5. Question 5: The Henon map (7 points)
#
#
# Total points possible: **35**
# ___

# %% [markdown]
# ---
# # Academic integrity statement (2 point)
#
# In the markdown cell below, put your personal academic integrity statement (composed during the Day04 In-Class Assignment). By including this statement, you are confirming that the work you submit in the assignment is wholly your own.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ## Question 1: If Statements (6 points)
#
# All states and municipalities accross the country are currently  deploying a massive vaccination campaing  to help address the COVID-19 epidemic. While the approved vaccines have shown to be highly effective in fighting the virus, the limited existing supply means that some prioritization is required to help the people that need it most urgently.  Ingham county (which includes Lansing, East Lansing, Williamston, etc) has outlined the following vaccination timeline:
#
# <img src="http://hd.ingham.org/portals/hd/home/Documents/cd/coronavirus/CoVVaxPrioritization.jpg"
#      alt="Cov19-Vacc"
#      align="center"
#      width= "600" />
#
# **Source:** http://hd.ingham.org/DepartmentalDirectory/CommunicableDisease/Coronavirus(COVID19).aspx#8789307-vaccine-information

# %% [markdown]
# In order to get an estimate for the size of each group, and to help schedule vaccine appointments when each priority group is reached, the county is using an online form which can be accessed through:
#
# https://forms.office.com/Pages/ResponsePage.aspx?id=APB9bkoOzkmQV8zvOU2w2BS4xo62KN1BnoBePaTOwItUQVYwTEpGTklGSzc5T01WWUMxUTJZWEdGQy4u
#
# and whose output will include data as the one shown in the table below:
#
#
# | Name | Healthcare | Age | Essential| Health Risk |
# | :----- | :----- | :------ | :--- | :--- |
# | Alice Dunn | No |36 | No  | No  |
# | Doug Hoyos | No |21 | Yes | No  |
# | Carter Hicks | No |33 | No  | Yes |
# | Clara Ortiz | Yes |52 | Yes | Yes |
# | Lin Cheng | No |18 | No  | Yes |
# | Darious Petters | Yes | 78 | No | Yes |
#
#
#
# &#9989;&nbsp; **a.** **Construct** a Python list of lists storing the data in the table above. That is,   a list `survey = [list0, list1, list2,...]` with as many entries as rows (i.e., people) in the table. Each entry in `survey` is itself a list, say for instance `list0`, whose first entry is the corresponding person's name as a string, the second entry is their Health Care status (i.e., whether or not the person is a staff member or  resident in a nursing home) also as a string, the third entry is the person's age as an integer, and the last two entries are strings indicating if the person is an esential worker and/or if they have a high risk health condition.
#
#
# &#9989;&nbsp; **b.** **Loop through** the `survey` list created in part **a** with either a `for` or a `while` loop, and using appropriate `if/elif/else` statements  determine and print  each person's priority group  (1A, 1B, 1C or 2) together with their estimated  vaccine appointment time. For instance, for _Alice Dunn_ your loop should print something like:
#
# `Alice Dunn : you are in group 2, and your vaccine appointment should be after July 2021.`
#
# and for example, for _Clara Ortiz_ your loop should print:
#
# `Clara Ortiz : you are in group 1A, you are eligible for a vaccine now.`
#
# **Important:** Your solution must use the information in Healthcare/Age/Essential/Health Risk  together with `if/elif/else` statements.
#
# **TIPS:** Remember to write pseudocode before you begin coding;  In pseudocode, write the logic (sequence of conditional statements) to determine the groups.

# %%
# Put your pseudocode and code here

# %%
#### ANSWER ####

list0 = ['Alice Dunn', 'No', 36, 'No', 'No']
list1 = ['Doug Hoyos', 'No', 21, 'Yes', 'No']
list2 = ['Carter Hicks', 'No', 33, 'No', 'Yes']
list3 = ['Clara Ortiz', 'Yes', 52, 'Yes', 'Yes']
list4 = ['Lin Cheng', 'No',18,  'No', 'Yes']
list5 = ['Darious Petters', 'Yes', 78, 'Yes', 'No', 'Yes']

survey = [list0, list1, list2, list3 , list4, list5]

print(survey)

for person in survey:
    if person[1] == 'Yes':
        print(person[0], ': you are in group 1A, and your appointment will be between December 2020 and May 2021')
    elif person[2] >= 65 or person[3] == 'Yes':
        print(person[0], ': you are in group 1B, and your appointment will be between February and July 2021')
    elif person[2] >= 16 and person[4] == 'Yes':
        print(person[0], ': you are in group 1C, and your appointment will be after May 2021')
    else:
        print(person[0], ': you are in group 2, and your appointment will be after July 2021')

        
#### Rubric ####
# +1, Set up at least one inner list correctly 
# +1, Set up the survey list correctly
# +1, Use a for/while loop, even if not successfully 
# +1, Use at least one if/elif/else statement correctly
# +2, The loop works as intended
# Out:
# [['Alice Dunn', 'No', 36, 'No', 'No'], ['Doug Hoyos', 'No', 21, 'Yes', 'No'], ['Carter Hicks', 'No', 33, 'No', 'Yes'], ['Clara Ortiz', 'Yes', 52, 'Yes', 'Yes'], ['Lin Cheng', 'No', 18, 'No', 'Yes'], ['Darious Petters', 'Yes', 78, 'Yes', 'No', 'Yes']]
# Alice Dunn : you are in group 2, and your appointment will be after July 2021
# Doug Hoyos : you are in group 1B, and your appointment will be between February and July 2021
# Carter Hicks : you are in group 1C, and your appointment will be after May 2021
# Clara Ortiz : you are in group 1A, and your appointment will be between December 2020 and May 2021
# Lin Cheng : you are in group 1C, and your appointment will be after May 2021
# Darious Petters : you are in group 1A, and your appointment will be between December 2020 and May 2021

# %% [markdown]
# ---
# ## Question 2: The Bass Diffusion Model (6 points)
#
# One of the earliest applications of modeling to marketing is Frank Bass' 1969 paper studying the spread of new products through a population. The technique is now known as the Bass diffusion model, and it  has been applied to market forecasting, advertising,  economics, and more. The   mathematical model is:
#
# $$A(t) = M\frac{1 - e^{-(p+q)t}}{1 + \frac{q}{p}e^{-(p+q)t}}$$
#
# where $A(t)$ is the expected number of adopters  after time $t$, the **coefficient of innovation**, $p$, is the effect from advertising and "influencers",  the **coefficient of imitation**, $q$, is the effect of  word-of-mouth and followers, and $M$ is the expected market cap, or maximum number of adopters that can be reached.  For this model, we expect the evolution of adopters to behave like so:
#
#
# <div align="center">
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/Bass_adopters.svg/1200px-Bass_adopters.svg.png" width=300px>
# </div>
#
#
#
# &#9989;&nbsp; **a.** Write a Python function taking as input:
# * the time $t$ after introducing a product
# * the parameters $M,p,q$
#
# and that returns the value $A(t)$ from the Bass diffusion model as output. Evaluate the function at $t = 5 $ years, and with parameters $M = 1,000$, $p = 0.03$, and $q = 0.38$.  Make sure to print the returned value (it should be around 331.199).
#
# **NOTE**: Mathematical functions like, natural log ($ln$) or an exponential (i.e. $e^x$) can be called using the Python `math` library. You may need to look up what these functions are and don't forget to include "`import math`" in your code!

# %%
# Put your pseudocode and code here

# %% [markdown]
# &#9989;&nbsp; **b.** Make a plot of the number of adopters versus time for these same parameters.  Use the code below as a starting place.  Be sure to label all of your axes.

# %%
# Put your pseudocode and code here
times = list(range(0,20))  # list of times, calculate number of adopters for each entry in times; make a plot adopters vs time

# %% [markdown]
# &#9989;&nbsp; **c.** If you keep the other parameters the same and double the coefficient of innovation (double the impact of advertising), roughly how much sooner will you reach the market cap for this product?

# %% [markdown]
# <font size="+3">&#9998;</font> *Put your answer to part **c.** here.* (approximate answer is OK)

# %%
#### ANSWER ####
import math

def bass(t, p, q, M):   
    A = M * (1 - math.exp(-t * (p + q))) / (1 + (q / p) * math.exp(-t * (p + q)))
    return  A

p = 0.03
q = 0.38
M = 1000

A = bass(5, p, q, M)

print(A)

# Part  (NOT PRESENT)

def tpeak(p,q):
    t_peak = (math.log(q) - math.log(p))/(p +q)
    return t_peak

t_peak = tpeak(p, q)

print('Time of peak sales: ',t_peak)

A_peak = bass(t_peak, p, q, M)

print('Number of adopters when sales peak: ',A_peak)


# Part B
t = list(range(0,20))

adopt = []
for t1 in t:
    adopt.append(bass(t1,p,q,M))
    
import matplotlib.pyplot as plt

plt.plot(t,adopt)
plt.xlabel('time (years)')
plt.ylabel('Adopters, A')

# Part C
t = list(range(0,20))

adopt = []
for t1 in t:
    adopt.append(bass(t1,p*2,q,M))
    
import matplotlib.pyplot as plt

plt.plot(t,adopt)
plt.xlabel('time (years)')
plt.ylabel('Adopters, A')
print('Roughly 6 years faster to reach max market')
#### Rubric ####
# +2 for reasonable pseudocode/comments, If code fully works, no pseudocode is necessary
# +1 Set up the bass function (def and inputs), even if it does not work as expected (e.g., no return)
# +1 If the bass function works as intended
# +1 for plot with correct labels
# +1 Part C, approximate answer, can be found by plotting again
# Out:
# 331.19864249137356
# Time of peak sales:  6.192619197703112
# Number of adopters when sales peak:  460.5263157894737
# Roughly 6 years faster to reach max market

# %% [markdown]
# ---
# ## Question 3: Maximize your salary (7 points)
#
# Imagine your best friend just graduated and is now on the job hunt.  They currently have 3 job offers with different benefits and are going to be interviewing for more.  Congratulations!  Here are their three offers:
#
# *General Mills: Salary pay for 100,000 dollars per year
#
# *Coca Cola: Hourly pay at 60 dollars per hour.  They work 50 weeks out of the year and work 40 hours per week
#
# *Walmart: Hourly pay at 45 dollars per hour.  They only work 30 weeks out of the year and work 80 hours per week, plus a one time 5,000 dollar signing bonus
#
# Your friend heard coding is useful and tried to code below but wasn't lucky enough to take CMSE201, so they only use python as a calculator rather than creating a function.  Below is their code:

# %%
#Friend's code

#General Mills
pay_gm = 100000

#CocaCola
pay_cc = 60*50*40

#Walmart
pay_wlmrt = 45*30*80 + 5000

# %% [markdown]
# Your friend texts you just now mentioning they're on a 5 minute break from an interview and are about to negotiate their pay for another job offer at Starbucks Corporate.  They don't have time to write out the math like above and would like an easy tool they can use on the fly that quickly calculates their take-home pay at the end of the year.
#
# &#9989;&nbsp; **Write a function** that calculates their yearly take home pay accepting any of the 3 forms from above: salary, weekly payment, or weekly payment with signing bonus.
#
# **TIP:** one of the inputs to the function should be the method of calculation; if `method='salary'` then it should execute the salary type of calculation and so on.
#
# **Run your new function** and print out the total pay from each job offer.

# %%
# Put your pseudocode and code here

# %%
### ANSWER ### Sample function for instructors
def calc_yearly_take_home(method,weeks_per_year=0,hrs_per_week=0,dollars_per_hour=0,salary=0,signing_bonus=0):
    
    if method == 'salary':
        yearly_take_home = salary
    elif method == 'weekly':
        yearly_take_home = weeks_per_year*hrs_per_week*dollars_per_hour + signing_bonus
    else:
        #This part isn't necessary
        print('Invalid payment method')
        
    return yearly_take_home


##Main
print('GM Pay = $',calc_yearly_take_home(method='salary',salary=100000))
print('CocaCola Pay = $',calc_yearly_take_home('weekly',50,40,60))
print('Walmart Pay = $',calc_yearly_take_home('weekly',30,80,45,signing_bonus=5000))


##Scoring Rubric:
# 1 pt reasonable pseudocode, If code fully works, no pseudocode is necessary
# 2 pt - They created a function that considers the three cases with salary, weekly, or weekly with bonus
# 1 pt - They printed out the 3 pays: GM ($100,000), Coke ($120,000), & WalMart ($113,000)
# Out:
# GM Pay = $ 100000
# CocaCola Pay = $ 120000
# Walmart Pay = $ 113000

# %% [markdown]
# <font size="+3">&#9998;</font> Answer the questions based on your new function:
#
# * To get more pay, how much yearly pay should they negotiate?
# * You have another friend that isn't in a time crunch but has 20 job offers.  Would writing each offer out or using a function save you more time to help them?
# * Now that you have worked a lot with functions, what kind of situations should they be used in (versus 'just writing out the math')?

# %% [markdown]
# <font size="+3"> &#9998;</font> *Put your answers here.*

# %%
#### ANSWER ####
'''
1. Negotiate higher than $120K
2. Functions will save more time
3. Instances that are repeatable, when in a time crunch, to create reproduceable work, etc...
'''

##Scoring
# 1 pt - Answer to Q1: 'Negotiate higher than $120,000'
# 1 pt - Answer to Q2: 'Functions will save more time with repeatable tasks'
# 1 pt - Answer to Q3: 'repeatable tasks, in a time crunch, more reproduceable work, etc...'
# Out:
# '\n1. Negotiate higher than $120K\n2. Functions will save more time\n3. Instances that are repeatable, when in a time crunch, to create reproduceable work, etc...\n'

# %% [markdown]
# ---
# ## Question 4: Pythagorean triples (7 points)
#
# &#9989;&nbsp; **a.** A Pythagorean triple is a list `[a, b, c]` of positive integers $ a < b < c$ so that $a^2 + b^2 = c^2$. Write a function that takes integers `a` and `b` as inputs and returns the number 1 if they are members of a pythagorean triple and the number 0 if they are not members.  (*Tip*: the function needs to check if `c` is an integer).
#
# &#9989;&nbsp; **b.**
# Write a Python function taking as input a positive integer $n$, and   returns  a list of all Pythagorean triples `[a, b, c]` with $c \leq n$. For example, if $n =13$, then the output of your function should be
#
# `[[3, 4, 5], [5, 12, 13], [6, 8, 10]]`.
#
#
# &#9989;&nbsp; **c.** How many Pythagorean triples   are there between 1 and 300? Make sure to show your work.

# %%
# Part A: Put your pseudocode and code here

# %%
# Part B: Put your pseudocode and code here

# %% [markdown]
# <font size="+3">&#9998;</font> *Put your answer to part **c.** here.*

# %%
#### ANSWER ####

import math

def pytriple_success(a,b):
    c = (a**2 + b**2)**.5
    c2 = int((a**2 + b**2)**.5)
    if c == c2:
        return 1
    else:
        return 0

    
    
    
def pytriples(n):
    trip_list=[]
    for a in range(1,n):
        for b in range(a, int((n**2 - a**2)**.5)+1):
            c = int((a**2 + b**2)**.5)
            if c**2 == a**2 + b**2:
                trip_list.append([a, b, c])
    return trip_list

# Another way
def pytriples2(n):
    trip_list=[]
    for a in range(1,n):
        for b in range(a, n):
            if pytriple_success(a,b)==1:
                c = int((a**2 + b**2)**.5)
                if c<=n:
                    trip_list.append([a, b, c])
    return trip_list


print('There are', len(pytriples(300)), 'Pythagorean triples between 1 and 300')

#### Rubric ####
# +2 for reasonable pseudocode/comments, If code fully works, no pseudocode is necessary
# +2 for part a (def statement; if used correctly)
# +2 for part b (def statement; uses loop correctly; returns list correctly)
# +1 Gets the number of Py triples using the function (even if number is incorrect)
# Out:
# There are 209 Pythagorean triples between 1 and 300

# %% [markdown]
# ---
# ## Question 5: The Henon map (7 points)
#
# Suppose you have a point with coordinates $(x_0, y_0)$ on the plane, and that you have specific values for two real numbers $a,b$.
# This information is enough to produce two sequences of numbers $x_0, x_1, x_2, \ldots$ and $y_0, y_1, y_2, \ldots$ by using the following equations:
#
# $$
# \begin{eqnarray*}
# x_{i+1} &=& 1 \;-\; a\, x_i^2 \;+\; y_i \\
# y_{i+1} &=& b\, x_i
# \end{eqnarray*}
# $$
#
# This kind of iterative process is what people call in mathematics a discrete time __Dynamical System__, where the next value of the $(x_{i+1},y_{i+1})$ coordinates depends on the current value of the $(x_{i},y_{i})$ coordinates. The specific equations shown above are known as the Henon map, and even though it appears to be very simple, the system has a lot of richness controlled by the choices of parameters $a,b$. We will attempt to visualize such complexity in what follows.
#
#
# &#9989;&nbsp; **a.** Complete the function  `henon` provided in the cell below. The function takes as inputs the starting point $(x_0,y_0)$ for the Henon map, as well as the paramters $a,b$ and the number of steps $n$ for which to run the dynamics. Your task is to compute the lists `x = [x0, x1, ..., xn]` and `y = [y0, y1, ..., yn]` with multiple calls to the Henon equations inside a loop.
#
# &#9989;&nbsp; **b.**   Use matplotlib to make a `subplot` figure with the following 3 plots **all in one row horizontally**: three  $y$ vs $x$ scatter plots of the Henon map with $n= 10,000$ points and $x_0 = y_0 =0$ for:
# - $a = 1.4$, $b = 0.3$
# - $a = 0.2$, $b = 0.9991$
# - $a = 0.2$, $b = -0.9999$
#
# Make sure to include appropriate titles and axis labels. If everything goes well, your figure should look similar to the one below:
#
# <img src="https://i.ibb.co/Qk8GTQQ/HenonMap.png"
#      alt="HenonMap"
#      align="center"
#      width= "800" />
#
#
#
# **Hint 1:** Consider using `matplotlib.pyplot.figure(figsize = (k,m))` to control the size of your figures, and `matplotlib.pyplot.tight_layout()` to add a bit of space betwen subplots.
#
# **Hint 2:** The `scatter` function in matplotlib has a parameter $s$ than can be used to change the size of the dots in each plot.

# %%
# Put your pseudocode and code here

def henon(x0, y0, a, b, n):
    x = [x0]
    y = [y0]
   
    # Complete the main for loop computing the lists x and y
       
    return x, y

# To run the function you can use:
# x, y = henon(x_0, y0, a, b, n) 
# to run the dynamics and get both lists.

# %%
#### ANSWER ####
def henon(x0, y0, a, b, n):
    x = [x0]
    y = [y0]
    for i in range(n):
        x.append(1 - a*x[i]**2 + y[i])
        y.append(b*x[i])
    return x, y

# %matplotlib inline
import matplotlib.pyplot as plt


plt.figure(figsize = (15,5))

n = 10000
a = 1.4
b = .3
x, y = henon(0, 0, a, b, n)
plt.subplot(1,3,1)
plt.scatter(x, y, s=.1)
plt.title('Henon map, a = 1.4 and b = 0.3')
plt.xlabel('x')
plt.ylabel('y')

a = .2
b = .9991
x, y = henon(0, 0, a, b, n)
plt.subplot(1,3,2)
plt.scatter(x, y, s=.1)
plt.title('Henon map, a = 0.2 and b = 0.9991')
plt.xlabel('x')
plt.ylabel('y')

a = .2
b = -.9999
x, y = henon(0, 0, a, b, n)
plt.subplot(1,3,3)
plt.scatter(x, y, s=.1)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Henon map, a = 0.2 and b = -0.9999')

plt.tight_layout()


#### Rubric #####
# +2 for reasonable pseudocode/comments
#+2 Complete the henon function correctly
#+2 Create subplots correctly
#+1 Add titles and lables

# %% [markdown]
# ---
# ## Assignment Wrap-up
#
# Please fill out the following Google Form before you submit your assignment. **You must completely fill this out in order to receive credit for the assignment!**
#
# **COMPLETE THIS SURVEY through [this link]( ) or through cell below.**

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://forms.office.com/Pages/ResponsePage.aspx?id=MHEXIi9k2UGSEXQjetVofRzD77LVqLNIpscq-NmZsrdUNVJQQ01BMElXOTlGWEJOV1pZUUZIS0tRVy4u" 
	width="80%" 
	height="1200px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://forms.office.com/Pages/ResponsePage.aspx?id=MHEXIi9k2UGSEXQjetVofRzD77LVqLNIpscq-NmZsrdUNVJQQ01BMElXOTlGWEJOV1pZUUZIS0tRVy4u"
# 	width="80%"
# 	height="1200px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the "Homework Assignments" section, find the submission folder link for Homework #2, and upload it there.

# %% [markdown]
# &#169; Copyright 2021,  Michigan State University Board of Trustees
