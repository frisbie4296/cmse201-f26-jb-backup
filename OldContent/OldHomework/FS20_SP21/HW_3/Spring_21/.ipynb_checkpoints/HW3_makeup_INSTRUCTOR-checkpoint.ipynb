# %% [markdown]
# # Homework 3: Data Analysis with Pandas, Numpy, and Matplotlib
#
# ## Learning Goals
# * **Load data into notebooks using Pandas**
# * **Determine the components of the data**
# * **Make meaningful representations of the data and draw conclusions from them**
# * **Compute statistical quantities for the given data set and draw conclusions from them**
#
# ## Introduction
# You are a sports analyst covering the International Powerlifting Federation World Championships. You've been invited to the live stream of the event to talk about who should be crowned the "best lifter" of the competition. Your task is to look at the data from previous competitions and make an argument for who is the best lifter.
#
# ### Basics of Powerlifting
# Powerlifting is a strength sport in which lifters compete for the highest total across their squat, bench press, and deadlift. Each competitor gets three attempts at each lift (squat, bench, and deadlift), and the best of the three attempts on each lift are added up to the competitor's "Total." The competitors are divided up into weight classes, and the competitor with the highest total in their weight class wins. If a lifter misses all three attempts for a squat, bench, or deadlift, they are disqualified and do not get a Total. A miss is any attempt that a competitor fails to complete as judged by the referees. For a more in depth introduction to powerlifting and description of how the squat, bench, and deadlift are executed, check out [this article](https://www.bodybuilding.com/fun/issa119.htm).
#
# ### The Open Powerlifting Project
# OpenPowerlifting is a community service project to create a permanent, open archive of the world's powerlifting data. That means that everyone's powerlifting meet data from your friendly neighborhood gym hobbyist competitor to elite strength athletes is available for anlaysis. The data you will use in this assignment can be found at https://data.openpowerlifting.org. This particular data set includes all of the worldwide powerlifting meet data from the International Powerlifting Federation for the past several years.
#
# ## Assignment Goal
# Analyze powerlifting data to determine who is the "best lifter" across all weight classes.

# %% [markdown]
# ###ANSWER###
#
# ## Note to Instructors:
# This homework is targeted towards students having their first outside of class-time experience of digging into some data. I also want to continue to build on what they have been learning so far throguhout the semester. The goals I have for this assignment are as follows:
# 1. Load, clean, and filter data with pandas
# 2. Use a couple different kinds of plots to visualize their data
# 3. Write functions to streamline their work
# 4. Compute basic statistics for the data
# 5. Draw conclusions based on their plots and calculations
# 6. Practice with writing code and making plots to justify their conclusions)
#
#
# ## Note to Graders:
# The answers I have provided are just sample answers, I do expect that students may approach things differently but should still get the same end result, and these answers should also be considered correct. There are also a couple of times when they are asked to give conclusions and justify their answers. In some cases, there is not a clear correct answer, so more weight should be given to the quality of the justification (I will indicate these places in the rubric along the way).

# %% [markdown]
# Work through the following assignment, making sure to follow all the directions and answer all the questions.
#
# **This assignment is due at 11:59 pm on March 5th.** It should be uploaded into the "Homework Assignments" submission folder for Homework #3.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ---
# ## Grading
#
# * Academic Integrity (1 points)
# * Part 1 (15 points)
# * Part 2 (16 points)
# * Part 3 (13 points) + 5 points optional extra credit
#
# Total points possible: **45**
#
# ---

# %% [markdown]
# # ---
# # Academic integrity statement (1 points)
#
# In the markdown cell below, put your personal academic integrity statement (composed during the Day04 In-Class Assignment). By including this statement, you are confirming that the work you submit in the assignment is wholly your own.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ## Part 1: Getting a Feel for the Data
#
# Before doing any data analysis, you should determine what your data looks like!
#
# ### &#9989;&nbsp; Task 1.1 (3 points)
# **Task: Write a piece of code that reads in the data file `openpowerlifting_data.csv` and prints out the descriptive information about the data (e.g., Columns, number of entries, mean values, etc.).  Write a print statement that prints the number of lifters in this dataset.**
#
# **NOTE:** From your previous work with this data, you recall the following:
# * A minus sign in front of a lift (i.e. -200.0) means a missed/failed lift
# * The weight class, best squat, best bench, best deadlift, and total measurements are in kilograms (kg)
# * The IPF weight classes for women are: 47 kg, 52 kg, 57 kg, 63 kg, 72 kg, 84 kg, 84 kg+
# * The IPF weight classes for men are: 59 kg, 66 kg, 74 kg, 83 kg, 93 kg, 105 kg, 120 kg, 120 kg+
# * Competitors are assigned to a weight class by the nearest class **above** their bodyweight (i.e. if they weigh 50.25 kg, their weight class is the 52 kg class) with the exception of competitors in the 84kg+ of 120kg+ categories where the competitors have bodyweights **greater** than the listed weight class.

# %% [markdown]
# ### Grading
# * 1.1 (3 points)
# * 1.2 (3 points)
# * 1.3 (5 points)
# * 1.4 (4 points)

# %%
####ANSWER####

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

powerlifting_data = pd.read_csv('openpowerlifting_data.csv')
powerlifting_data.tail()
powerlifting_data.describe()
# Out:
#                 Age  BodyweightKg  Best3SquatKg  Best3BenchKg  \
# count  55736.000000  76246.000000  74992.000000  74777.000000
# mean      28.711156     83.144281    170.861872    113.722694
# std        8.311594     21.464455     61.529049     45.042623
# min        9.500000     22.680000   -330.000000   -225.000000
# 25%       23.500000     67.150000    122.500000     75.000000
# 50%       27.500000     81.650000    172.500000    115.000000
# 75%       32.500000     94.450000    215.000000    145.000000
# max       81.500000    220.000000    477.500000    322.500000
#
#        Best3DeadliftKg       TotalKg          Dots
# count     74462.000000  73719.000000  73660.000000
# mean        198.497387    484.475828    357.762924
# std          61.790513    158.048925     65.782236
# min        -320.000000     60.000000     44.890000
# 25%         150.000000    347.500000    314.880000
# 50%         202.500000    497.500000    359.395000
# 75%         245.000000    600.000000    402.890000
# max         417.500000   1105.000000    582.150000

# %% [markdown]
# ### &#9989;&nbsp; Task 1.2 (3 points)
# **Choose one of the lifts (i.e., squat, bench, or deadlift) and make a scatter plot of best lift weight vs competitor bodyweight.** (Be sure to label your axes)

# %%
# Put your pseudocode and code here

# %%
####ANSWER####

# 3 exampls of acceptable plots
plt.scatter(powerlifting_data['BodyweightKg'],powerlifting_data['Best3SquatKg'])
plt.ylabel('Squat (kg)')
plt.xlabel('Bodyweight(kg)')
plt.figure()
plt.scatter(powerlifting_data['BodyweightKg'],powerlifting_data['Best3BenchKg'])
plt.ylabel('Bench (kg)')
plt.xlabel('Bodyweight(kg)')
plt.figure()
plt.scatter(powerlifting_data['BodyweightKg'],powerlifting_data['Best3DeadliftKg'])
plt.ylabel('Deadlift (kg)')
plt.xlabel('Bodyweight(kg)')
# Out:
# Text(0.5,0,'Bodyweight(kg)')

# %% [markdown]
# ### &#9989;&nbsp; Task 1.3 (3 points)
# **Examine your plot. What does the distribution of the bodyweight vs. lift data look like? How does adjusting the bin size affect what you see? Describe any features you think may be important. How does the lift you chose change with bodyweight? What is a possible explanation for what you observe?**

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> Put your answer here

# %% [markdown]
# ###ANSWER###
#
# This answer should include something about how higher weight classes tend to lift more weight, there seems to be "preferred" bodyweights, and there are some negative numbers (those are missed/failed lifts). They should notice that adjusting the bin size can smear out or emphasize structure in the data.

# %% [markdown]
# # Part 2: Data Filtering and Analysis
#
# ## 2.1 Cleaning and Filtering
#
# Often when presented with a data table, additional cleaning and filtering may be required before you can analyze the data the way you want to. There are many ways to do this, but most involve "masking" the data in some way--removing everything from your data except the values that you want, usually based on some condition.
#
# ### &#9989;&nbsp; Task 2.1.1 (2 points)
# **In your exploration in Part 1, you may have noticed some entries for competitors who did not achieve a total, create a new data frame that contains only competitors with a valid total (i.e. no negative values) using the pandas `dropna()` function.**

# %% [markdown]
# ### Grading
# * 2.1.1 (2 points)
# * 2.1.2 (2 points)
# * 2.1.3 (2 points)

# %%
# Put your pseudocode and code here

# %%
###ANSWER###
powerlifting_data_cleaned = powerlifting_data.dropna(subset=['TotalKg'])
powerlifting_data_cleaned.head()
# Out:
#                Name Sex Equipment   Age Division  BodyweightKg WeightClassKg  \
# 0   Alicia Urbaniak   F       Raw   NaN     Open          46.5            47
# 1    Patrycja Nowak   F       Raw  25.5     Open          45.4            47
# 2   Klaudia Rusztyn   F       Raw  20.5     Open          51.8            52
# 3  Ewa Mioduszewska   F       Raw  24.5     Open          51.2            52
# 4   Katarzyna Synak   F       Raw   NaN     Open          51.3            52
#
#    Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg    Dots Country  \
# 0          60.0          51.0             97.5    208.5  275.43  Poland
# 1          62.5          40.0            100.0    202.5  272.34  Poland
# 2          97.5          52.5            148.0    298.0  364.21  Poland
# 3         100.0          50.0            145.0    295.0  363.49  Poland
# 4         100.0          57.5            125.0    282.5  347.61  Poland
#
#          Date
# 0  2014-03-28
# 1  2014-03-28
# 2  2014-03-28
# 3  2014-03-28
# 4  2014-03-28

# %% [markdown]
# ### &#9989;&nbsp; Task 2.1.2 (2 points)
# The next task in this assignment will require you to do analysis on ***one*** weight class. **Create a new dataframe for the weight class that you want to work with.**
#
# Recall that the weight classes we want to focus on in this dataframe are:
#
# * Women: 47 kg, 52 kg, 57 kg, 63 kg, 72 kg, 84 kg, 84 kg+
# * Men: 59 kg, 66 kg, 74 kg, 83 kg, 93 kg, 105 kg, 120 kg, 120 kg+

# %%
###Answer goes here###

# %%
###ANSWER###
###Sample answer (multiple weight classes shown)
class_84kg_mask = powerlifting_data_cleaned["WeightClassKg"]=='84'
class_105kg_mask = powerlifting_data_cleaned["WeightClassKg"]=='105'
class_47kg_mask = powerlifting_data_cleaned["WeightClassKg"]=='47'

class_84kg = powerlifting_data_cleaned[class_84kg_mask]
class_84kg.head()
class_105kg = powerlifting_data_cleaned[class_105kg_mask]
class_105kg.head()
class_47kg = powerlifting_data_cleaned[class_47kg_mask]
class_47kg.head()
# Out:
#                  Name Sex Equipment   Age Division  BodyweightKg  \
# 0     Alicia Urbaniak   F       Raw   NaN     Open          46.5
# 1      Patrycja Nowak   F       Raw  25.5     Open          45.4
# 106  Ewa Mioduszewska   F       Raw  27.5     Open          46.8
# 107   Paulina Grzybek   F       Raw  22.5     Open          47.0
# 108      Alicja Mułyk   F       Raw  22.5     Open          46.7
#
#     WeightClassKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg  \
# 0              47          60.0          51.0             97.5    208.5
# 1              47          62.5          40.0            100.0    202.5
# 106            47         102.5          50.0            138.0    290.5
# 107            47         102.5          55.5            122.5    280.5
# 108            47          97.5          47.5            117.5    262.5
#
#        Dots Country        Date
# 0    275.43  Poland  2014-03-28
# 1    272.34  Poland  2014-03-28
# 106  381.92  Poland  2017-04-01
# 107  367.61  Poland  2017-04-01
# 108  345.66  Poland  2017-04-01

# %% [markdown]
# ### &#9989;&nbsp; Task 2.1.3 (2 points)
# **How many entries are in your cleaned dataframe? How do you know that your masking is working?**

# %% [markdown]
# <font size="+3">&#9998;</font> *Put your answer here.*

# %% [markdown]
# ###ANSWER###
#
# Answer should include something about the length of the dataframes for how many entries as well as some justification of spot-checking to confirm that they only have one weight class in the dataframe

# %% [markdown]
# ### &#9989;&nbsp; Task 2.2 Means, Medians, and Standard Deviation (7 points)
# One way to visualize the distribution of data is with one-dimensional histograms (Pandas, NumPy, and Seaborn have ways of doing this).
#
# **Plot a one-dimensional histogram of totals for the weight class you chose.**
#
# **For your weight class, calculate the mean and median of the total and plot them as a vertical lines on your histogram.**
#
# **Calculate the standard deviation and plot it as a vertical band about the mean.**

# %% [markdown]
# ### Grading
# * 2.2 (7 points)
# * 2.2.1 (3 points)

# %%
# Put your pseudocode and code here

# %%
###ANSWER###
total_mean_47kg = np.mean(class_47kg['TotalKg'])
total_mean_84kg = np.mean(class_84kg['TotalKg'])
total_mean_105kg = np.mean(class_105kg['TotalKg'])

total_median_47kg = np.median(class_47kg['TotalKg'])
total_median_84kg = np.median(class_84kg['TotalKg'])
total_median_105kg = np.median(class_105kg['TotalKg'])

total_std_47kg = np.std(class_47kg['TotalKg'])
total_std_84kg = np.std(class_84kg['TotalKg'])
total_std_105kg = np.std(class_105kg['TotalKg'])

print('47kg_mean =',total_mean_47kg,'84kg_mean =',total_mean_84kg,'105kg_mean =',total_mean_105kg,'47kg_median =',\
      total_median_47kg,'84kg_median =',total_median_84kg,'105kg_median =',total_median_105kg)

plt.figure(figsize=(10,15))
ax1 = plt.subplot(311)
ax2 = plt.subplot(312)
ax3 = plt.subplot(313)

ax1.hist(class_47kg['TotalKg'],bins=25,alpha=0.8,label='47kg')
ax1.axvline(total_mean_47kg,color='black',ls='--',lw=3,label='mean')
ax1.axvline(total_median_47kg,color='green',ls='--',lw=3,label='median')
ax1.axvspan(total_mean_47kg-total_std_47kg,total_mean_47kg+total_std_47kg,color='grey',alpha=0.3)
ax1.legend()
ax1.set_ylabel('N')
ax1.set_xlabel('Total (kg)')

ax2.hist(class_84kg['TotalKg'],bins=25,alpha=0.8,label='84kg')
ax2.axvline(total_mean_84kg,color='black',ls='--',lw=3,label='mean')
ax2.axvline(total_median_84kg,color='green',ls='--',lw=3,label='median')
ax2.axvspan(total_mean_84kg-total_std_84kg,total_mean_84kg+total_std_84kg,color='grey',alpha=0.3)
ax2.legend()
ax2.set_ylabel('N')
ax2.set_xlabel('Total (kg)')

ax3.hist(class_105kg['TotalKg'],bins=25,alpha=0.8,label='105kg')
ax3.axvline(total_mean_105kg,color='black',ls='--',lw=3,label='mean')
ax3.axvline(total_median_105kg,color='green',ls='--',lw=3,label='median')
ax3.axvspan(total_mean_105kg-total_std_105kg,total_mean_105kg+total_std_105kg,color='grey',alpha=0.3)
ax3.legend()
ax3.set_ylabel('N')
ax3.set_xlabel('Total (kg)')
plt.tight_layout()
# Out:
# 47kg_mean = 245.17983870967743 84kg_mean = 341.61410181392625 105kg_mean = 609.1178953292065 47kg_median = 247.5 84kg_median = 337.5 105kg_median = 610.0

# %% [markdown]
# ### &#9989;&nbsp; Task 2.2.1 (3 points)
#
# **What do you observe about the distribution of your weight class? Are there differences between your mean and median? Why or why not? What does the standard deviation tell you about the distribution?**

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> Write your answer here

# %% [markdown]
# ###ANSWER###
#
# Depending on the weight class, the means and medians may be virtually the same or relatively different. Their answer should connect the separation of the mean and median to the shape of the distribution. They should see that the standard deviation of the mean contains most (66%) of the data which makes sense given what they have learned about standard deviation at this point. They may also recognize that the standard deviation is larger for more spread out distributions (but we'll ask them about that later)

# %% [markdown]
# # Part 3: Putting it all Together
#
# ## 3.1 Speeding up/Automating the process
#
# For your "best lifter" analysis, you'll need the information you found in Part 2 for all weight classes.
#
# ### &#9989;&nbsp; Task 3.1.1 Expanding to all weight classes (2 points)
#
# **Step 1: Write a function to create a new dataframe(s) for a given weight class.** (Inputs should be base dataframe and weight class; Output should be a new dataframe containing only that weight class.)
#
# *Use examples to justify that your dataframes have been created correctly.*

# %% [markdown]
# ### Grading
# * 3.1.1 (2 points)
# * 3.1.2 (2 points)
# * 3.1.3 (1 point)
# * 3.1.3.1 (1 point)

# %%
# Put your pseudocode and code here

# List to help extract information from the base dataframe
weight_class_list = ['47', '52', '57', '63', '72', '84', '84+', '59', '66', '74', '83', '93', '105', '120', '120+']
frame_names_list = ['class_47kg','class_52kg','class_57kg','class_63kg','class_72kg','class_84kg','class_84pluskg',\
                    'class_59kg','class_66kg','class_74kg','class_83kg','class_93kg','class_105kg','class_120kg','class_120pluskg']

# %%
###ANSWER###
def weight_class_dataframes(frame,filter_key):
    mask = frame["WeightClassKg"]==filter_key
    weight_class_frame = frame[mask]
    return weight_class_frame

# %% [markdown]
# **Step 2: Loop through all the weight classes and store the dataframes for each weight classs in a list** (Lists can store all types of variables including Pandas dataframes!)

# %%
# Put your pseudocode and code here

# %%
###ANSWER###
# Approach using simple list of frames

frame_list =[]
for cls in weight_class_list:
    frame_list.append(pd.DataFrame(weight_class_dataframes(powerlifting_data_cleaned,cls)))

# %%
###ANSWER###
#Approach using OrderedDict()
from collections import OrderedDict ##imports Ordered dictionary functionality
weight_class_list = ['47', '52', '57', '63', '72', '84', '84+', '59', '66', '74', '83', '93', '105', '120', '120+']
frame_names_list = ['class_47kg','class_52kg','class_57kg','class_63kg','class_72kg','class_84kg','class_84pluskg',\
                    'class_59kg','class_66kg','class_74kg','class_83kg','class_93kg','class_105kg','class_120kg','class_120pluskg']
frame_names_dict = OrderedDict()
i=0
while i<len(weight_class_list):
    #print(i)
    #print(weight_class_list[i])
    #print(frame_names_list[i])
    frame_names_dict[frame_names_list[i]] = pd.DataFrame(weight_class_dataframes(powerlifting_data_cleaned,weight_class_list[i]))
    #print(frame_names_list[i].head())
    i+=1

# %% [markdown]
# ### &#9989;&nbsp; Task 3.1.2 Expanding statistics to all weight classes (2 points)
# **Write a function to calculate the mean, median, and standard deviation for a single weight class. Then, write a loop through all of the weight classes and save the results of your calculations for plotting.**

# %%
# Put your pseudocode and code here

# %%
###ANSWER###
def do_stats(dataframe):
    mean = np.mean(dataframe['TotalKg'])
    median = np.median(dataframe['TotalKg'])
    std = np.std(dataframe['TotalKg'])
    return mean,median,std


print(do_stats(frame_names_dict['class_66kg']))
print(do_stats(frame_list[8]))
# Out:
# (458.7915710068875, 460.0, 85.84342759614465)
# (458.7915710068875, 460.0, 85.84342759614465)

# %%
###ANSWER###
weight_class = []

all_means = []
all_medians = []
all_stds = []
#Approach using list of frames
for i in range(len(frame_list)):
    mn,md,st = do_stats(frame_list[i])
    all_means.append(mn)
    all_medians.append(md)
    all_stds.append(st)

# Approach using OrderedDict()    
#for i in frame_names_dict:
#    print(i)
#    weight_class.append(i)
#    all_means.append(do_stats(frame_names_dict[i])[0])
#    all_medians.append(do_stats(frame_names_dict[i])[1])
#    all_stds.append(do_stats(frame_names_dict[i])[2])
print(np.round(all_means,2),np.round(all_stds,2))
# Out:
# [245.18 273.87 288.34 306.52 324.67 341.61 371.45 398.34 458.79 503.08
#  538.93 574.73 609.12 652.4  701.64] [ 54.06  64.03  57.62  60.24  63.98  68.62  80.13  94.56  85.84  86.23
#   88.72  92.03  97.48 107.48 124.43]

# %% [markdown]
# ### &#9989;&nbsp; Task 3.1.3 Visualizing the Data (1 point)
# **Plot mean total (with error bars) versus all of the weight classes.** When successful, your plot should look something like this:
# <img src="https://raw.githubusercontent.com/roboe92/CMSE_EDR/main/functions_interview_images/TotalVClass.png">

# %%
# Put your pseudocode and code here

# %%
###ANSWER###
plt.errorbar(frame_names_list,all_means,yerr=all_stds,fmt='o')
plt.xlabel('Weight Class (kg)')
plt.ylabel('Mean Total (kg)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()
plt.savefig('TotalVClass.png')

# %% [markdown]
# ### &#9989;&nbsp; Task 3.1.3.1  Making Observations (1 point)
# **Describe any trends you see in the data and propose an explanation for what you observe**

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> Write your answer here

# %% [markdown]
# ###ANSWER###
#
# Explanation should include that heavier weight classes lift more weight on average, but this is also separated by men and women. The error bars on the men's weight classes are also generally larger. Possible explanations are that on average, men probably lift more than women, and heavier people can lift heavier weights.

# %% [markdown]
# ### &#9989;&nbsp; Task 3.2 Determining the Strongest Competitors (2 points)
#
# You may have noticed that on average, higher weight classes have higher totals. However, you know that in powerlifting, the "best lifter" award goes to the person who is strongest for their size, not just the person with the biggest total. There are many ways used in powerlifting to compare strength across weight classes, but here, we'll just use pound-for-pound strength (i.e. Total Lifted(kg)/Bodyweight(kg)).
#
# **Calculate the "pound-for-pound" mean for each weight class and plot them. Include comments in your code that explain the decisions you made.**

# %% [markdown]
# ### Grading
# * 3.2 (2 points)
# * 3.2.1 (1 point)
# * 3.2.2 (2 points)
# * 3.2.3 (1 point)

# %%
# Put your pseudocode and code here

# %%
###ANSWER###

#compute the average bodyweight for the "plus" categories and use that for the pound for pound calculation
#any way they try to account for the unlimited ceiling is fine, as long as they don't just set it to 
#84kg and 120 kg which would be identical to the next weight class down

#Alternatively, students may choose to compute pound-for-pound for every lifter's bodyweight 
#and then take the mean which is also acceptable and avoids having to deal with the "plus" weight categories

df_120pluskg = frame_names_dict['class_120pluskg']
print(np.mean(df_120pluskg['BodyweightKg']))
df_84pluskg = frame_names_dict['class_84pluskg']
print(np.mean(df_84pluskg['BodyweightKg']))

weight_class_numbers = np.array([47, 52, 57, 63, 72, 84, 106, 59, 66, 74, 83, 93, 105, 120, 141])

total_lb_for_lb = np.array(all_means)/weight_class_numbers
print(total_lb_for_lb)

plt.scatter(weight_class_numbers,total_lb_for_lb)
plt.xlabel('Weight Class (kg)')
plt.ylabel('Pound-for-Pound ratio')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()
# Out:
# 138.27540504201662
# 103.81459347915826
# [5.21659231 5.26674491 5.05863589 4.86536431 4.50933658 4.06683455
#  3.50426244 6.75155885 6.95138744 6.79831697 6.49319264 6.17992946
#  5.80112281 5.43669551 4.97614625]

# %% [markdown]
# ### &#9989;&nbsp; Task 3.2.1 (1 point)
# **Describe any similarities or differences you see in the pound-for-pound mean calculation results across weight classes and genders.**

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> Write your answer here

# %% [markdown]
# ###ANSWER###
#
# Explanation should include that there is separation between men's and women's weight classes, but the pound-for-pound curves look about the same, just offset.

# %% [markdown]
# ### &#9989;&nbsp; Task 3.2.2 (2 points)
#
# **Find the maximum total for each weight class, calculate the pound-for-pound value for each maximum. Make a single plot with the pound-for-pound ratio vs weight class (from task 3.2 above) and with the maximum pound-for-pound ratio vs weight class.**  Be sure to label all axes and include a legend.

# %%
# Put your pseudocode and code here

# %%
###ANSWER###

def strongest_lifter(weight_class_frame):
    max_total = np.max(weight_class_frame.loc[:,'TotalKg'])
    max_total_idx = np.argmax(weight_class_frame.loc[:,'TotalKg'])
    #name = weight_class_frame['Name'][max_total_idx]
    return max_total

max_total_list = []

for i in frame_names_list:
    #print(i)
    max_total_list.append(strongest_lifter(frame_names_dict[i]))
max_total_list = np.array(max_total_list)
max_lb_for_lb = max_total_list/weight_class_numbers

plt.scatter(weight_class_numbers,max_lb_for_lb,label='Max total')
plt.scatter(weight_class_numbers,total_lb_for_lb,label='Avg total')
plt.xlabel('Weight Class (kg)')
plt.ylabel('Pound-for-Pound ratio')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.grid()
# Out:
# /Users/Dustin/anaconda/lib/python3.5/site-packages/numpy/core/fromnumeric.py:61: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return bound(*args, **kwds)

# %% [markdown]
# ### &#9989;&nbsp; Task 3.2.3 (1 point)
# **Describe any similarities or differences between the pound-for-pound ratio for the means and the maximums. Is the pound-for-pound ratio sufficient to crown the "best lifter"? Why or why not?**

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> Write your answer here

# %% [markdown]
# ###ANSWER###
#
# Answer should include that the lightest lifters have the highest pound-for-pound ratio. A well reasoned argument for yes or no to "is it sufficient" is fine here.

# %% [markdown]
# ### &#9989;&nbsp; OPTIONAL EXTRA CREDIT: Task 3.3 Drawing Conclusions (5 points)
#
# It turns out that you have had powerlifting's current way of equalizing lifters across across genders and weight classes all along in the form of the DOTS Formula. Powerlifting has a long history of trying to solve the problem of who the "best lifter" is, and the current accepted metric is the [DOTS formula](https://linktr.ee/cpt_timmy).
#
# **Find the maximum DOTS score for each weight class ('Dots' in the dataframe) and the corresponding total and person who lifted that total. Compare that to the maximum total and corresponding pound-for-pound ratio (and the person who lifted that total). What do you observe in each weight class? Across all weight classes? Who will you tell your boss is the best lifter across all weight classes and by which metric? Use plots, code, and explanations to justify your answer. ** (Hint: This problem has several parts. Break this into sub-problems and use pseudocode to accomplish.)

# %% [markdown]
# ### Grading
# * 3.3 (5 points)

# %%
# Put your pseudocode and code here

# %%
###ANSWER###
def strongest_lifter(weight_class_frame):
    max_total = np.max(weight_class_frame.loc[:,'TotalKg'])
    max_total_idx = np.argmax(weight_class_frame.loc[:,'TotalKg'])
    name = weight_class_frame['Name'][max_total_idx]
    return max_total,name

def most_dots(weight_class_frame):
    max_dots = np.max(weight_class_frame.loc[:,"Dots"])
    max_dots_idx = np.argmax(weight_class_frame.loc[:,'Dots'])
    name = weight_class_frame['Name'][max_dots_idx]
    return max_dots,name

# %%
###ANSWER###
max_total_list = []
max_total_names = []
max_dots = []
max_dots_names =[]

for i in frame_names_dict:
    print(i)
    max_total_list.append(strongest_lifter(frame_names_dict[i])[0])
    max_total_names.append(strongest_lifter(frame_names_dict[i])[1])
    max_dots.append(most_dots(frame_names_dict[i])[0])
    max_dots_names.append(most_dots(frame_names_dict[i])[1])
    print(strongest_lifter(frame_names_dict[i]))
    print(most_dots(frame_names_dict[i]))
    
    
print(np.argmax(max_total_list),max_total_list[np.argmax(max_total_list)],max_total_names[np.argmax(max_total_list)])    
print(np.argmax(max_dots),max_dots[np.argmax(max_dots)],max_dots_names[np.argmax(max_dots)])    
#print(max_total_list,max_total_names)
#print(max_dots,max_dots_names)
# Out:
# class_47kg
# (407.5, 'Wei-Ling Chen')
# (537.79, 'Wei-Ling Chen')
# class_52kg
# (600.0, 'Andrzej Stanaszek')
# (582.15, 'Andrzej Stanaszek')
# class_57kg
# (473.5, 'Maria Htee')
# (553.29, 'Maria Htee')
# class_63kg
# (514.0, 'Prescillia Bavoil')
# (552.97, 'Carola Garra')
# class_72kg
# (562.5, 'Jessica Buettner')
# (560.19, 'Jessica Buettner')
# class_84kg
# (613.0, 'Amanda Lawrence')
# (567.13, 'Amanda Lawrence')
# class_84pluskg
# (671.5, 'Bonica Brown')
# (525.78, 'Bonica Brown')
# class_59kg
# (670.5, 'Sergey Fedosienko')
# (577.54, 'Sergey Fedosienko')
# class_66kg
# (705.5, 'Charles Okpoko')
# (554.34, 'Charles Okpoko')
# class_74kg
# (790.5, 'Taylor Atwood')
# (573.31, 'Taylor Atwood')
# class_83kg
# (833.0, 'Russel Orhii')
# (565.24, 'Russel Orhii')
# class_93kg
# (870.0, 'Anatolii Novopismennyi')
# (554.81, 'Anatolii Novopismennyi')
# class_105kg
# (900.5, 'Krzysztof Wierzbicki')
# (555.24, 'Krzysztof Wierzbicki')
# class_120kg
# (978.5, 'Dennis Cornelius')
# (563.57, 'Dennis Cornelius')
# class_120pluskg
# (1105.0, 'Ray Williams #1')
# (564.96, 'Ray Williams #1')
# 14 1105.0 Ray Williams #1
# 1 582.15 Andrzej Stanaszek
# /Users/Dustin/anaconda/lib/python3.5/site-packages/numpy/core/fromnumeric.py:61: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return bound(*args, **kwds)

# %%
###ANSWER###
plt.scatter(weight_class_numbers,max_lb_for_lb,label='Max total')
plt.xlabel('Weight Class (kg)')
plt.ylabel('Pound-for-Pound ratio')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.grid()

# %%
###ANSWER###
plt.scatter(weight_class_numbers,max_dots,label='Max dots')
plt.xlabel('Weight Class (kg)')
plt.ylabel('DOTS')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.grid()

# %% [markdown]
# ---
# ## Assignment Wrap-up
#
# Please fill out the following form before you submit your assignment. **You must completely fill this out in order to receive credit for the assignment!**
#
# **COMPLETE THIS SURVEY through [this link]( ) or through cell below.**

# %%
from IPython.display import HTML
HTML(
"""
<iframe
	src="https://forms.office.com/Pages/ResponsePage.aspx?id=MHEXIi9k2UGSEXQjetVofRzD77LVqLNIpscq-NmZsrdUMTE1N1hKMkFLQ05aNVpWREYzTk5NQlpYSi4u"
	width="80%"
    height="1200px"
	frameborder="0"
	marginheight="0"
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://forms.office.com/Pages/ResponsePage.aspx?id=MHEXIi9k2UGSEXQjetVofRzD77LVqLNIpscq-NmZsrdUMTE1N1hKMkFLQ05aNVpWREYzTk5NQlpYSi4u"
# 	width="80%"
#     height="1200px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# # Congratulations, you're done!
#
# Submit this assignment by uploading your notebook to the course Desire2Learn web page.  Go to the "Homework Assignments" folder, find the appropriate submission link, and upload everything there. Make sure your name is on it!
