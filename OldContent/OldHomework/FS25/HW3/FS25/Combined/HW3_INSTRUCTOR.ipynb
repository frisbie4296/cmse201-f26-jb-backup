# %% [markdown]
# ### ANSWER
#
# # Homework 3 Template (Loading, Cleaning, Analyzing, and Visualizing Data with Pandas (and using resources!))

# %% [markdown]
# ### ANSWER
#
# ## README
#
# These templates have been drafted to standardize the homework assignments to the course learning objectives and keep them of similar difficulty, length, and point values throughout the semester.
# Homework drafts are due to the Lead Instructor and Associate Instructors at least **7 days** prior to their release date in order to give instructors enough time to review the assignment, the assignment lead enough time to integrate feedback, and all staff enough time to review the final assignment prior to release.
#
# It is expected that the assignments follow the learning objectives and the general structure/point distribution provided, but the framing of the problems is left up to the assignment lead(s). A specific rubric should be included with the finished assignment to foster equity in grading across sections. It is encouraged to explore a variety of discipline areas in the problem framing, particularly those represented by our students (biology, chemistry, data science, physics, astronomy, business, etc.)! Some example questions have been provided for reference. If you have questions about your homework assignment as you develop it, they can be directed to the lead instructor.
#
# Please make sure to include "metacognition" questions along the way where students are explicitly asked to describe how they solved a problem, what external resources they used (or how they knew how to do the problem if they didn't need resources). It is critical for them to engage in this so that they know they are learning and we can see that they are learning!
#
# Finally, homework assignments are designed to assess the material covered in the Pre-class and In Class assignments and should therefore **not contain anything that is not covered in those assignments.**
#
# ## Overall Structure (Suggested - feel free to adjust order)
# 1. Academic Integrity
# 2. Loading/cleaning data
#    * Identify a robust data set that students will load and clean (ideally a csv)
#    * Ask them to do exploratory data analysis (e.g. calculate descriptive statistics, make simple line plots or histograms, etc.)
#    * Ask them to make claims supported by evidence and reasoning about what they see
#    * Metacognition: Documenting solution pathways
# 3. Making meaningful visualizations (with resources)
#    * Provide some data in the notebook (or provide them a clean data file that reads in easily)
#    * Have students identify plotting code to tinker with from an external source (not class assigments)
#    * Have students make a plot to visualize the data and then make claims (supported by evidence and reasoning) related to the data
#    * MetacognitionL Documenting solution pathways
# 4. Linear Regression (could be combine with previous parts)
#    * Using data from either part 2 or part 3, ask folks to do regression on the data
#    * Ask them to make a prediction (i.e. use the regression to project future behavior)
#    * Metacognition: Documenting solution pathways
#
# ### Learning Goals Assessed in this homework
# * Using pandas to work with data and clean it
# * Make meaningful visual representations of the data
# * Fitting curves to data and evaluating model fits
#
# Below are some questions that *loosely* follow the template (and are from Homework 3 Fall 2023) for this homework assignment, but feel free to also look at past assignments!
# **Note:** Please look at Homework 1 and Homework 2 for examples of metacognition questions! (That is new this semester)

# %% [markdown]
# # Homework 3: Loading, Cleaning, Analyzing, and Visualizing Data with Pandas (and using resources!)

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Put your name here </p>

# %% [markdown]
# ## Learning Goals
#
# * Using pandas to work with data and clean it
# * Make meaningful visual representations of the data
# * Fitting curves to data and evaluating model fits
#
# ___

# %% [markdown]
# ## Assignment instructions
#
# Work through the following assignment, making sure to follow all of the directions and answer all of the questions.
#
# **This assignment is due at 11:59pm on Friday, October 31, 2025**
#
# It should be uploaded into D2L Homework #3.  Submission instructions can be found at the end of the notebook.
#
# Total points possible: **80**

# %% [markdown]
# ---
# <a id="toc"></a>
#
# ## Table of Contents
#
# [Part 0. Academic Integrity Statement](#part_0) (2 points)
#
# [Part 1. Reading, describing, and cleaning data](#part_1)  (29 points)
#
# [Part 2. Exploratory Data Analysis and Data visualization](#part_2)  (25 points)
#
# [Part 3. Fitting curves to data.](#part_3) (24 points)

# %% [markdown]
# ---
# <a id="part_0"></a>
#
# ## Part 0. Academic integrity statement (2 points)
#
# [Back to Top](#toc)
#
# In the markdown cell below, paste your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# Before we read in the data and begin working with it, let's import the libraries that we would typically use for this task. You can always come back to this cell and import additional libraries that you need.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import curve_fit

# %% [markdown]
# ---
# <a id="part_1"></a>
#
# ## Part 1: Reading, describing, and cleaning data (29 total points)
#
# [Back to Top](#toc)

# %% [markdown]
# ### 1.0 Data Source & Context (4 points)
#
# Before analyzing any dataset, it's important to know where it came from and what that implies for the kinds of conclusions we can (and cannot) draw.
#
# The dataset we'll use in this assignment is: "Analyzing Student Academic Trends" by Saad Ali Yaseen, hosted on Kaggle (https://www.kaggle.com/datasets/saadaliyaseen/analyzing-student-academic-trends). The dataset contains 200 student records; variables include hours_studied, sleep_hours, attendance_percent, previous_scores, exam_score.
#
#
# &#9989;&nbsp; **Task**
# Write a 3-5 sentence Context Statement that addresses: (4 pts)
#
# 1. Whether the data appears to be real-world observational, experimental, or simulated/synthetic/curated (and why you think so).
#
# 2. What population the data might (or might not) represent, and any limits on generalization.
#
# 3. What kinds of claims are reasonable (e.g., associations vs. causal claims) given the dataset's provenance and size.
#
# 4. Any data quality or measurement caveats you notice (e.g., small N, unknown sampling, engineered features).

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Put your answer here:

# %%
### ANSWER ###

# Example Context Statement (model):
# This Kaggle dataset contains 200 student records with study/sleep hours, attendance, previous scores, and an exam score. 
# The page presents a compact, classroom-friendly table without documented sampling frame or study protocol, so I will treat it 
# as a curated or possibly synthetic teaching dataset rather than population-representative field data. Because the data are not 
# from a randomized experiment and the data-generating process is unclear, I’ll limit claims to descriptive patterns and 
# associations—not causation. Generalization beyond this sample is limited; results primarily illustrate methods rather than 
# produce policy conclusions. I’ll also watch for small-sample effects and potential engineered variables.

# %% [markdown]
# ### 1.1 Read the data (1 point)
#
# &#9989;&nbsp; **Task**
#
# Read in the data from `student_exam_scores.csv` into a Pandas dataframe (0.5 pt) and display the `head` of the data (0.5 pt).

# %%
## your code here

# %%
### ANSWER ###
student_df = pd.read_csv("student_exam_scores.csv")
student_df.head(20)
# Out:
#    student_id  hours_studied  sleep_hours  attendance_percent  \
# 0        S001            8.0          8.8                72.1
# 1        S002            1.3          8.6                60.7
# 2        S003            4.0          8.2                73.7
# 3        S004            3.5          4.8                95.1
# 4        S005            9.1          6.4                89.8
# 5        S006            8.4          5.1                58.5
# 6        S007           10.8          6.0                54.2
# 7        S008            2.0          4.3                75.8
# 8        S009            5.6          5.9                81.6
# 9        S010            1.3          8.9                66.8
# 10       S011            3.4          5.3                90.9
# 11       S012            6.6          7.9                87.6
# 12       S013            1.3          6.3                83.6
# 13       S014            3.2          6.1                61.2
# ...

# %%
### ANSWER ###
# 0.5 -- use read_csv to read the file
# 0.5 -- display head

# %% [markdown]
# ### 1.2 Describe the data (3 points)
#
# #### 1.2.1 &#9989;&nbsp; **Task (1 point)**
#
# Use `describe` to display several summary statistics from the data frame.

# %%
## your code here

# %%
### ANSWER ###
student_df.describe()
# Out:
#        hours_studied  sleep_hours  attendance_percent  previous_scores  \
# count     200.000000   200.000000          200.000000       200.000000
# mean        6.325500     6.622000           74.830000        66.800000
# std         3.227317     1.497138           14.249905        15.663869
# min         1.000000     4.000000           50.300000        40.000000
# 25%         3.500000     5.300000           62.200000        54.000000
# 50%         6.150000     6.700000           75.250000        67.500000
# 75%         9.000000     8.025000           87.425000        80.000000
# max        12.000000     9.000000          100.000000        95.000000
#
#        exam_score
# count  199.000000
# mean    33.951256
# std      6.806465
# min     17.100000
# 25%     29.500000
# 50%     34.000000
# 75%     38.900000
# max     51.300000

# %%
### ANSWER ###
# 1 -- use describe

# %% [markdown]
# #### 1.2.2 &#9989;&nbsp; **Task (2 points)**
# The columns in this dataset represent the following:
#
# - **student_id**: A unique identifier for each student.
# - **hours_studied**: The number of hours the student studied before the exam.
# - **sleep_hours**: The average number of hours the student slept per day.
# - **attendance_percent**: The percentage of classes attended by the student.
# - **previous_scores**: The marks obtained by the student in previous assessments.
# - **exam_score**: The final exam score, representing the student’s overall performance.
#
# Using the results from `describe` above, write in the markdown cell below:
#
# 1. The **minimum and maximum** number of hours studied among all students. (1 pt)
# 2. The **lowest and highest** exam scores observed in the dataset. (1 pt)

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Put your answer here:
#
# **Part 1 (1pt):**
#
# **Part 2 (1pt):**

# %%
### ANSWER ###
# 1 -- The minimum and maximum number of hours are 1.0 hour and 12 hours, respectively.
# 1 -- The lowest and highest exam scores are 17.1 and 51.3, respectively.

# %% [markdown]
# ### 1.3 Isolating and performing basic statistics on data (6 points)
#
# #### 1.3.1 &#9989;&nbsp; **Task (1 point)**
#
# Display the `exam_score` column on its own using the name of the column.

# %%
## your code here

# %%
### ANSWER ###

student_df['exam_score']
# Out:
# 0      30.2
# 1      25.0
# 2      35.8
# 3      34.0
# 4      40.3
#        ...
# 195    42.7
# 196    40.4
# 197    28.2
# 198    42.0
# 199    37.8
# Name: exam_score, Length: 200, dtype: float64

# %%
### ANSWER ###
# 0.5 -- use square brackets to access data frame
# 0.5 -- get "exam_score" column

# %% [markdown]
# #### 1.3.2 &#9989;&nbsp; **Task (1 points)**
#
# Using `.iloc`, display the first ten rows of just the `exam_score` column.

# %%
## your code here

# %%
### ANSWER ###

student_df.iloc[0:10,5]
# Out:
# 0    30.2
# 1    25.0
# 2    35.8
# 3    34.0
# 4    40.3
# 5    35.7
# 6    37.9
# 7    18.3
# 8     NaN
# 9    24.7
# Name: exam_score, dtype: float64

# %%
### ANSWER ###
# 0.5 -- use iloc
# 0.5 -- uses the correct indices [0:10,5]

# %% [markdown]
# #### 1.3.3 &#9989;&nbsp; **Task (4 points)**
#
# Using `mean` and `median` functions, print out the mean and median `exam_score` values for all the data **(2 pts)**.

# %%
## your code here

# %%
### ANSWER ###

print(student_df["exam_score"].mean())
print(student_df["exam_score"].median())
# Out:
# 33.951256281407034
# 34.0

# %%
### ANSWER ###
# 1 -- mean 33.951256281407034
# 1 -- median 34.0

# %% [markdown]
# Using only the mean and median you computed above, what can you infer about the shape of each variable’s distribution? For each variable you summarized, state whether the data are likely approximately [symmetric, right-skewed, or left-skewed](https://en.wikipedia.org/wiki/Skewness), and justify your choice based on the relationship between mean and median.
#
# Rule of thumb:
# - mean $\approx$ median $\rightarrow$ roughly symmetric
# - mean > median $\rightarrow$ right-skew (long right tail)
# - mean < median $\rightarrow$ left-skew (long left tail)
#
# Note: These are indicators, not proofs. A histogram is still the best check.

# %% [markdown]
# &#9989;&nbsp; **Do this (2 pts):**
# For the variable summarized in 1.3.3, write one sentence naming the likely shape and one sentence justifying it with your mean/median values.

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Put your answer here:

# %%
### ANSWER ###
# Rubric (2 pts total):
# - 1 pt: Correct identification of skew/symmetry for the variables based on the student’s own mean/median results.
# - 1 pt: Clear justification that explicitly references mean and median (e.g., “mean (x̄) slightly greater than median → mild right-skew”).
# Notes:
# - Full credit if the student concludes “approximately symmetric” when mean and median are very close (e.g., within a small absolute difference relative to the variable’s scale).
# - It’s fine if students add a caveat like “confirm with histogram,” but points come from the mean/median reasoning.

# %% [markdown]
# ### 1.4 Filter the data using masking (8 points)
#
# <!-- You want to know whether students’ study habits have changed over time, and if so, whether they tend to study **more or less** in recent years.
#  -->
# You decide to analyze the **median number of hours studied** for the following groups based on their **previous_scores** range:
#
# * 0-20
# * 21-40
# * 41-60
# * 61-80
# * 81-100
#
# **1.4.2** &#9989;&nbsp; **Task (6 pts)**
# 1. For each of the above score ranges, calculate the median value of `hours_studied`.
# 2. For each range, print a statement such as:
# > "The median number of hours studied for students with previous scores between (*insert range here*) is: x hours."
#
#
# **Hint:** You can create Boolean masks for value ranges as follows:
# ```python
# data[(data["previous_scores"] >= lower_bound) & (data["previous_scores"] <= upper_bound)]

# %%
## your code here

# %%
### ANSWER ###



median_0_20 = student_df['hours_studied'][(student_df['previous_scores'] >= 0) & (student_df['previous_scores'] <= 20)].median()
median_21_40 = student_df['hours_studied'][(student_df['previous_scores'] >= 21) & (student_df['previous_scores'] <= 40)].median()
median_41_60 = student_df['hours_studied'][(student_df['previous_scores'] >= 41) & (student_df['previous_scores'] <= 60)].median()
median_61_80 = student_df['hours_studied'][(student_df['previous_scores'] >= 61) & (student_df['previous_scores'] <= 80)].median()
median_81_100 = student_df['hours_studied'][(student_df['previous_scores'] >= 81) & (student_df['previous_scores'] <= 100)].median()

print("The median number of study hours for previous scores 0–20 is:", median_0_20)
print("The median number of study hours for previous scores 21–40 is:", median_21_40)
print("The median number of study hours for previous scores 41–60 is:", median_41_60)
print("The median number of study hours for previous scores 61–80 is:", median_61_80)
print("The median number of study hours for previous scores 81–100 is:", median_81_100)
# Out:
# The median number of study hours for previous scores 0–20 is: nan
# The median number of study hours for previous scores 21–40 is: 3.3
# The median number of study hours for previous scores 41–60 is: 5.75
# The median number of study hours for previous scores 61–80 is: 6.8
# The median number of study hours for previous scores 81–100 is: 6.85

# %%
### ANSWER ###

# 1 -- tries to mask out "previous_scores" data
# 1 -- tries to set up Boolean statements with "hours_studied"
# 1 -- correct use of Boolean statements
# 1 -- tries to get five intervals
# 1 -- correctly masks five intervals
# 1 -- prints results

# %% [markdown]
# **1.4.2** &#9989;&nbsp; **Task (2 pts)**
#
# Suppose you want to check for an association between past assignment performance and study time.
# Using your masked subsets from Task 1.4.1, report how the median hours_studied changes (if at all) across increasing values (or bins) of previous_scores. Provide a 1-2 sentence descriptive summary of the observed pattern (e.g., “the median appears higher/lower/similar for higher previous_scores”).

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Put your answer here

# %%
### ANSWER ###

# 2 - Students with **higher previous scores** tend to study **more hours**.

# %% [markdown]
# ### 1.5 Clean out the NaN values (7 points)
#
# #### 1.5.1 &#9989;&nbsp; **Task (2 points)**
# Using the `isna().sum()`function to count NaN values in each column.

# %%
# Put yoru answer here

# %%
### ANSWER ###
student_df.isna().sum()
# Out:
# student_id            0
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            1
# dtype: int64

# %%
### ANSWER ###
# 2 -- correctly count NaN values in each column.

# %% [markdown]
# #### 1.5.3 &#9989;&nbsp; **Task (2 point)**
# You observe `"NaN"` values in the `"exam_score"` column. Create a new, clean DataFrame (0.5 pt) by removing all rows where `"exam_score"` contains `"NaN"` values (0.5 pt). Use the built-in pandas function `dropna()` to accomplish this (you can look it up online to learn more).

# %%
#Put your answer here

# %%
### ANSWER###
clean_student_df = student_df.dropna()

# %%
### ANSWER ###
# 1 -- uses .dropna()
# 1 -- creates a new, clean dataframe

# %% [markdown]
# #### 1.5.4 &#9989;&nbsp; **Task (2 points)**
# Now that you have the original and clean datasets, determine the number of rows in each of them (1 pt). Print out your results (1 pt).

# %%
#Put your answer here

# %%
### ANSWER ###

print("The length of the original dataset is", len(student_df))
print("The length of the clean dataset is", len(clean_student_df))
# Out:
# The length of the original dataset is 200
# The length of the clean dataset is 199

# %%
### ANSWER ###
# 1 -- correctly determines length of each dataframe by any means: 200 and 199
# 1 -- prints out results

# %% [markdown]
# #### 1.5.5 &#9989;&nbsp; **Task (1 point)**
# Let's reflect on the cleaning process. If you hadn’t dropped the `"NaN"` data, would it have affected your results?

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Put your answer here

# %%
### ANSWER ###
# 1 -- no, because it's NaN, it wouldn't have affected if it was dropped or not
# Note they may add (based on Part 2) that NaN's interfere with fitting curves
# and from that perspective the NaNs do matter

# %% [markdown]
# ---
# <a id="part_2"></a>
#
# ## Part 2: Exploratory Data Analysis (25 total points)
#
# [Back to Top](#toc)
#
# It's time to explore our data! You’ll use basic EDA to understand distributions and relationships.

# %% [markdown]
# If you were not able to get part 1 done correctly, run the cell below to load the clean data set and use it in the rest of the assignment. You can also use this data set to check your work in part 1.

# %%
exam_scores_df = pd.read_csv("student_exam_scores_cleaned.csv")

print(exam_scores_df.head())
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %% [markdown]
# ### Part 2.1: Distributions & summary statistics (8 points)
#
# Understanding distributions helps you reason about ranges, skewness, and typical values before modeling anything.
#
# &#9989;&nbsp; **Do this (8 points):** Using matplotlib and pandas:
#
# 1. Create 3 subplots (use plt.subplot) in 1 row $\times$ 3 columns to show histograms for three numeric columns: use exam_score, hours_studied, and sleep_hours. (3 pts; 1 each)
#
# 2. Use plt.figure with figsize=(9, 3) (or similar wide aspect). (1 pt)
#
# 3. Compute and print the mean and median for each of the three plotted columns. (2 pts)
#
# 4. On each histogram, draw vertical lines for the mean and median (e.g., plt.axvline). Add clear titles and axis labels. (2 pts)
#
# > _Hints:_ Select columns by name, e.g., df["exam_score"].

# %%
# Put your code here

# %%
### ANSWER ###
bins = 25
alpha = 0.75 # optional

plt.figure(figsize=(9, 3))
plt.suptitle("Distributions of Exam Score, Study Hours, and Sleep Hours")

# exam_score
plt.subplot(1, 3, 1)
plt.hist(exam_scores_df["exam_score"], bins=bins, alpha=alpha)
plt.axvline(exam_scores_df["exam_score"].mean(), linestyle="--", label="mean")
plt.axvline(exam_scores_df["exam_score"].median(), linestyle=":", label="median")
plt.title("Exam Score")
plt.xlabel("score")
plt.ylabel("count")
plt.legend(loc="best")

# hours_studied
plt.subplot(1, 3, 2)
plt.hist(exam_scores_df["hours_studied"], bins=bins, alpha=alpha)
plt.axvline(exam_scores_df["hours_studied"].mean(), linestyle="--", label="mean")
plt.axvline(exam_scores_df["hours_studied"].median(), linestyle=":", label="median")
plt.title("Hours Studied")
plt.xlabel("hours")
plt.ylabel("count")
plt.legend(loc="best")

# sleep_hours
plt.subplot(1, 3, 3)
plt.hist(exam_scores_df["sleep_hours"], bins=bins, alpha=alpha)
plt.axvline(exam_scores_df["sleep_hours"].mean(), linestyle="--", label="mean")
plt.axvline(exam_scores_df["sleep_hours"].median(), linestyle=":", label="median")
plt.title("Sleep Hours")
plt.xlabel("hours/night")
plt.ylabel("count")
plt.legend(loc="best")

plt.tight_layout()
plt.show()
plt.savefig("student_distributions.jpg")

# %% [markdown]
# ### Part 2.2: Visualizing relationships (9 points)

# %% [markdown]
# &#9989;&nbsp; **Do this (9 points):**  Use `matplotlib` to make three _scatter plots_ showing:
#
# 1. exam_score vs. hours_studied
#
# 2. exam_score vs. attendance_percent
#
# 3. exam_score vs. sleep_hours:
#
# For full credit:
#
# - Create **3 subplots** using plt.subplot with **3 rows $\times$ 1 column**. (3 pts; 1 each)
#
# - Use `plt.figure` and `figsize=(4, 8)` (or similar tall aspect). (2 pt)
#
# - Provide an overall **title** (e.g., “Study Habits and Exam Performance”). (2 pt)
#
# - Provide **x-axis** and **y-axis** labels and subplot titles. (2 pts)

# %%
# Put your code here

# %%
### ANSWER ###
# Rubric (9 pts total):
# - 3 subplots (3x1): 3 pts (1 each)
# - figsize: 2 pt
# - overall title: 2 pt
# - labels & subplot titles: 2 pts


# Style variables
pt_size = 30
pt_alpha = 0.6 # optional
pt_color = "tab:blue"

plt.figure(figsize=(4, 8))
plt.suptitle("Study Habits and Exam Performance")

# 1) exam_score vs hours_studied
plt.subplot(3, 1, 1)
plt.scatter(exam_scores_df["hours_studied"], exam_scores_df["exam_score"],
            s=pt_size, alpha=pt_alpha, c=pt_color)
plt.title("Exam Score vs. Hours Studied")
plt.xlabel("hours_studied")
plt.ylabel("exam_score")

# 2) exam_score vs attendance_percent
plt.subplot(3, 1, 2)
plt.scatter(exam_scores_df["attendance_percent"], exam_scores_df["exam_score"],
            s=pt_size, alpha=pt_alpha, c=pt_color)
plt.title("Exam Score vs. Attendance")
plt.xlabel("attendance_percent")
plt.ylabel("exam_score")

# 3) exam_score vs sleep_hours
plt.subplot(3, 1, 3)
plt.scatter(exam_scores_df["sleep_hours"], exam_scores_df["exam_score"],
            s=pt_size, alpha=pt_alpha, c=pt_color)
plt.title("Exam Score vs. Sleep Hours")
plt.xlabel("sleep_hours")
plt.ylabel("exam_score")

plt.tight_layout()
# plt.savefig("student_relationships.jpg")

# %% [markdown]
# ### Part 2.3: Reflections (8 points)
# &#9989;&nbsp; **Answer the following:** Looking at the plots,
#
# 1. Which relationship looks strongest? Briefly justify. (2 pt)
# 2. Which plot looks the most linear? (2 pt).
# 3. Which plot do you believe would be the easiest to create a model for. Briefly justify. (2 pt)
# 4. In 3-4 sentences, compare and contrast when a histogram is useful versus when a scatter plot is useful (2 pt). Consider three scenarios:
#     - the number/type of variables each shows,
#     - the kinds of patterns each reveals,
#     - the relationship between “exam scores for one class” and “hours studied”.

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Put your answer here
#
# **Part 1 (2pt):**
#
# **Part 2 (2pt):**
#
# **Part 3 (2pt):**
#
# **Part 4 (2pt):**

# %%
### ANSWER ###

# Grading guidance (8 pts total; each answer must be justified; no partial credit per item):

# Example acceptable answers (students may differ if justified by their plots):
# 1) Strongest: Often exam_score vs hours_studied shows the clearest positive association.
# 2) Most linear: Frequently exam_score vs hours_studied appears most linear.
# 3) Easiest to model: exam_score vs hours_studied, because it shows a monotonic, roughly linear trend,
#    which suits a simple linear model; attendance and sleep may relate nonlinearly or with more spread.
# 4) First two: hitograms; Third: scatter plot.

# %% [markdown]
# ---
# <a id="part_3"></a>
#
# ## Part 3: Fitting curves to data - Predicting Exam Scores (24 points)
#
# [Back to Top](#toc)

# %% [markdown]
# Now that we've visualized our data, let's ask:
#
# What is the relationship between **exam score** and each of these variables:
#
# * **hours_studied**
#
# * **sleep_hours**
#
# Can we predict exam score for both of these variables with a simple linear model?
#
# ### Part 3.1: Model (4 points)
# In the above plots we notice that `exam_score` tends to **increase** as `hours_studied` increases in value. Specifically, we can describe this relationship with a linear model:
#
# $$ exam\_score = m \times variable + b $$
#
# Where $variable$ is the predictor variable (e.g., `hours_studied`, or `sleep_hours`), $m$ is the slope of the line, and $b$ is the intercept.
#
# &#9989;&nbsp; **Do this:**
# - Write a function called `exam_model` that calculates exam score based on a given predictor variable using the equation above.
# - The equation should be structured so that it can be used with the `curve_fit` function in the next section.

# %%
# Put your code here

# %%
### ANSWER ###

def exam_model(x, m, b):
    return  x*m +b

# 1 point for correct name
# 1 point for correct order of the inputs. No partial credit
# 1 point for correct math. No partial credit
# 1 point for return statement

# %% [markdown]
# ### Part 3.2: Fit the model (10 points)
#
# We’ll now use the `curve_fit` function from SciPy to find the best-fitting line that predicts exam scores.
#
# &#9989;&nbsp; **Do this:**
#
# Use the dataset `student_exam_scores_cleaned.csv`
#
# For each predictor variable (`hours_studied`, and `sleep_hours`):
#
# - Use the `curve_fit` with your `exam_model` function to find the slope ($m$) and intercept ($b$). (3 pts each, 6 total)
#
# - Print out the value of the slope $m$, write "The value of the slope is..." (1 pt each, 2 total)
#
# - Print out the value of the intercept $b$, write "The value of the intercept is..." (1 pt each, 2 total)

# %%
# Put your code here

# %%
### ANSWER ###

import pandas as pd
from scipy.optimize import curve_fit

# Load the data
exam_scores_df = pd.read_csv("student_exam_scores_cleaned.csv")

# Loop over predictor variables
predictors = ["hours_studied", "sleep_hours"]

for var in predictors:
    popt, pcov = curve_fit(exam_model, exam_scores_df[var], exam_scores_df["exam_score"])
    m, b = popt
    print(f"For {var}: The value of the slope is {m:.3f}, and the value of the intercept is {b:.3f}")

    
# They do NOT have to use a for loop to receive full credit here
# 2 pts for calling curve_fit (1 pt for each variable)
# 2 pts for correct placement of exam_model (1 pt for each variable)
# 2 pts for correct placement of x and y values (1 pt for each variable)

# 2 pts for printing slope (1 pt for each variable)
# 2 pts for printing intercept (1 pt for each variable)
# Out:
# For hours_studied: The value of the slope is 1.634, and the value of the intercept is 23.618
# For sleep_hours: The value of the slope is 0.854, and the value of the intercept is 28.303

# %% [markdown]
# ### Part 3.3 Check your model (10 points)
#
# &#9989;&nbsp; **Do this (8 points):**  Use matplotlib to make two plots using two predictor variables (hours_studied, and sleep_hours), to compare your model and the data.
# - Plot the actual data (1 point each, 2 total)
# - Plot your modeled data (1 point each, 2 total)
# - Use x and y axis labels and title (1 point each, 2 total)
# - Adjust the color, and size, and alpha of the datapoints. Make sure the plot of your model is a different color than the datapoints so that you can see it. (1 point each, 2 total)

# %%
# Put your code here

# %%
### ANSWER ###
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 1, figsize=(12, 12), constrained_layout=True)
# Top plot
ax = axes[0]
ax.scatter(exam_scores_df["hours_studied"], exam_scores_df["exam_score"], s=15, alpha=0.3, label="Data")
popt, pcov = curve_fit(exam_model, exam_scores_df["hours_studied"], exam_scores_df["exam_score"])
m, b = popt
x = exam_scores_df["hours_studied"]
ax.plot(x, exam_model(x, m, b), linewidth=2, label="Model")
ax.set_xlabel("Study Hours")
ax.set_ylabel("Exam Score")
ax.set_title("Exam Score vs. Study Hours")
ax.legend()

# Bottom plot
ax = axes[1]
ax.scatter(exam_scores_df["sleep_hours"], exam_scores_df["exam_score"], s=15, alpha=0.3, label="Data")
popt, pcov = curve_fit(exam_model, exam_scores_df["sleep_hours"], exam_scores_df["exam_score"])
m, b = popt
x = exam_scores_df["sleep_hours"]
ax.plot(x, exam_model(x, m, b), linewidth=2, label="Model")
ax.set_xlabel("Sleep Hours")
ax.set_ylabel("Exam Score")
ax.set_title("Exam Score vs. Sleep Hours")
ax.legend()

plt.show()

# 2 points for plotting the data (1 pt each plot)
# 2 points for plotting the fitted line (1 pt each plot)
# 1 point for title and x and y axis labels (0.5 pts each plot)
# 1 point for adjusting color/size/alpha of data and making sure line is different color (0.5 each plot, 0 points if no attempt)

# %% [markdown]
# ##### &#9989;&nbsp; **Answer the following (2 points):**
# Do you think your models are good models? Is one model better that the other? Clearly justify your answer (looking for more than a "yes" or "no" answer).

# %% [markdown]
# <font size=8 color="#009600">&#9998;</font> Put your answer here

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
# [Back to Top](#toc)
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the "Homework Assignments" section, find the submission folder link for Homework #3, and upload it there.

# %% [markdown]
# &#169; 2024 Copyright the Department of Computational Mathematics, Science and Engineering.
