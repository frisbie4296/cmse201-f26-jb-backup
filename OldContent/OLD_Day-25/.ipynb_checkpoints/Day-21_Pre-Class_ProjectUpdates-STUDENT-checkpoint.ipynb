# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # Day 21 Pre-class assignment: Making project progress!
#
# The purpose of this pre-class assignment is to make sure you're making progress with your semester project. If you haven't really started on your project yet, now is the time!
#
# ## Goals for today's pre-class assignment
#
# 1. Work on semester project
# 2. Assess where you're at with your semester project.
#
# ## Assignment instructions
#
# **This assignment is due by 11:59 p.m. the day before class**. To complete this assignment, you should **upload the current draft of the jupyter notebook you are using for the project** to D2L.

# %% [markdown]
# ---
# # Project Updates Details
#
# During the in-class activity for this day will be spending about 20 minutes where each person presents to the other members of the group to update everyone on their project progress and get feedback (~3-4 minutes each).  It's a great opportunity to give and get ideas from your classmates. Your job is to share the current draft of your Jupyter notebook for the project.  If you have not yet started and do not have a working draft, use the `CMSE201_FinalProjectTemplate.ipynb` file on D2L. If you have started, you may still want to take a look at the template notebook to remind yourself what you should be including in your notebook.
#
# Here is what you will want to consider including in notebook file and discussing with your classmates:
#
# 1. quick review of your project: what is(are) the question(s) you want to answer?
#
# 2. how have you set out to answer this?
#
# 3. show progress to date - plots, animations, code, whatever you have so far. If you don't have anything, you should spend a bit of time working on it!
#
# 4. what are the issues you have? are there stumbling blocks? does the data contain what you need to answer the question, or do you need to shift to something different? is your model too complicated to complete?
#
# 5. what is your plan in the form of a timeline to allow you be complete the project? what form will the answer take?
#
# If you're having issues coming up with project information make a note of this in your notebook!
#
# ### The primary goal of this task is to make sure you have a project that’s going somewhere before it’s too late!
# #### You'll submit the current version of your project notebook for this pre-class submission.

# %% [markdown]
# ----
# # Assignment wrap-up
#
# Please fill out the form that appears when you run the code below.  **You must completely fill this out in order to receive credit for the assignment!** If the embedded survey doesn't work, you can click this [link](https://forms.office.com/Pages/ResponsePage.aspx?id=MHEXIi9k2UGSEXQjetVofddd5T-Pwn1DlT6_yoCyuCFURFNJWVpXTktPVjA3RU81NDdXQ1cwSDA4Qi4u).

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://forms.office.com/r/6wBMXs7xH1" 
	width="800px" 
	height="600px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://forms.office.com/r/6wBMXs7xH1"
# 	width="800px"
# 	height="600px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ---------
# ### Congratulations, you're done with your pre-class assignment!
#
# Now, you just need to submit this assignment by uploading it to the course <a href="https://d2l.msu.edu/">Desire2Learn</a> web page. **For this assignment, submit the current version of your project notebook** to today's submission folder.

# %% [markdown]
# &#169; Copyright 2020,  Michigan State University Board of Trustees
