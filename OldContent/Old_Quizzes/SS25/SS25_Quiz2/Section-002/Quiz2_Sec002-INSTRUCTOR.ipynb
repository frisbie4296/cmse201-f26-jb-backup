# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 (Section 002, Spring 2025)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill.
#
# **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **You may use generative AI tools, but like all sources, we expect that you document and describe the resources you used and how you used them!**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# **Quiz duration: 35 minutes**
#
# **Total possible points:** 70

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging code

# %% [markdown]
# ---
# # Academic integrity statement (5 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.
#
# **REMINDER:** You are responsible for following the citation guidelines for code that you did not write and/or is from outside CMSE 201 content.
# **(From Day 4, edited slightly) Guidelines for Using Code You Didn't Write:**
# If you are using content to solve problems that has not been covered in our pre-class or in class assignments, you **MUST** cite your work. This includes any use of the resources reviewed in class (e.g. Stack Overflow, Google, LearnPython, etc.). If you use generative AI tools **besides HiTA**, you must indicate which tool you used (e.g. chatGPT, Co-Pilot, Claude, etc.) and what lines of code were produced by generative AI and which ones were produced by you. If you use only HiTA, you are expected to cite use of HiTA for each part of each problem you use it for. Failure to sufficiently cite your work may result in loss of points on the problem.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ### ANSWER
#
# # TEMPLATE INSTRUCTIONS
#
# This quiz should assess functions, numpy, and matplotlib. Specifically, we want to assess if students can load in a data file, explore it with some basic calculations, and visualize it in  a meaningful way. Use of numpy and matplotlib implicitly includes functions, but we also want to assess students' understanding of how to write and use their own functions.
#
# **Note:** Please make sure that your instructions for expectations on metacognition questions are explicit. If at all possible, use context clues and visual aids to help students for whom English is not their first language. Please also ensure that students are reminded of the citation guidelines for using HiTA vs. other GenAI resources.
#
# Use Homework 2 questions as a guide for what they can be expected to know for this quiz (though the quiz will be shorter and simpler than a homework assignment)
#
# To that end, my suggested overarching structure for this Quiz is:
# * Write a function that takes in data and outputs a calculation and/or a plot (provide some "test" data to demonstrate that their function works (Note: This question can/should have the flexibility for them to write one or multiple functions, depending on how they see the solution to the problem).
# * Documenting Solution Pathway Question
# * Choose a data set (presented as a .csv file) with more than two columns of data (make sure they use numpy for this, not pandas)
# * Documenting Solution Pathway Question
# * Visualize the data in a simple manner (i.e. ask them to make a line plot or histogram, can include use of subplots)
# * Use a given function on the data file for calculations
#
# **Note:** While you can have the quiz have students explore a single thread of a problem, rather than disjointed problems, be attentive to places where students can earn partial credit throughout the quiz. For example, even if they can't get their function to work from the beginning of the quiz, they can still show you that they can load and plot data. If they can't load and plot the data, they could plot the test data. You can also include questions (as I have in the examples) where they can qualitatively discuss what they are doing.
#
# Below is an example of how this quiz could be written. If you use this structure, make sure to choose your own data set and make your quiz unique to your section!

# %% [markdown]
# # Part 1a) (20 points) Writing and Testing a Function
#
# According to [popular medical practice](https://openoregon.pressbooks.pub/nutritionscience/chapter/7b-bmi-body-comp-metabolic-health/), a person's _body mass index_ (BMI) is a calculated measure of a person's body weight (in pounds) divided by the square of their height (in inches) times $703$. That is,
# \begin{equation}
# \mathrm{BMI} = \frac{\mathrm{weight(lb)}}{\mathrm{height(in^2)}} * 703
# \end{equation}
# where the radius is the radius of the tree in feet, and the height is the height of the tree in feet.
#
# **NOTE:** Keep in mind that in Part 1b), you will be asked to document your solution pathway for both Task 1a) and Task 1b).
#
# ### Task 1a):
# Using the equation above, write a function that takes in a person's height (in inches, _not squared inches!_) and weight (in pounds) and returns their BMI.

# %%
# put your code here!

# %%
### ANSWER
### RUBRIC

## 10/10 for a function that runs/will run and produce correct output
## 5/10 for a function that runs/will run but has errors (mathematical or otherwise)
## 0/10 for a function that will not run AND has error(s)
import numpy as np
def BMI(height, weight):
    return (weight/(height**2))*703

#Test function
BMI(60, 50)
# Out:
# 9.763888888888888

# %% [markdown]
# ### Task 1b):
# A household of 5 people visits the doctor's office for their annual medical check-up. Their vitals are recorded in the table below. Using the function you wrote in Task 1 and the list of weights and height, calculate the total BMI in the household.
#
# | Name        | Weight (lb) | Height (inches)
# |----------------|-------------------|-----   |
# | Jane    | 35.7             | 37     |
# | Kayla     | 67.3              | 45    |
# | Rick      | 112.6              | 60     |
# | Jack |155.8               | 66     |
# | Bela | 138.4               | 56     |

# %%
# put your code here!
weight_list = [35.7,67.3,112.6,155.8,138.4]
height_list = [37,45,60,66,56]

# %%
### ANSWER

total_BMI = 0
weight_list = [35.7,67.3,112.6,155.8,138.4]
height_list = [37,45,60,66,56]


for i in range(len(weight_list)):
    total_BMI+=BMI(height_list[i],weight_list[i])
print(total_BMI)
### RUBRIC
## 10/10 for an answer that runs, produces the correct answer, and uses function arguments correctly (no variable scope problems)
## 5/10 for an answer that runs but has errors (with variable scope, final answer, etc.)
## 0/10 for an answer that does not run AND has errors
# Out:
# 119.85389776812288

# %% [markdown]
# ## Part 1b) Documenting Your Solution Pathway (10 points)
#
# Answer the following questions in detail:
# 1. Did you use any external resources (e.g. generative AI, past assignments, Code Portfolio, Stack Overflow, Google, etc.) to help you?
#     - If you DID use external resources, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include prompts and outputs.
#     - If you DID NOT use external resources, what prior knowledge did you recall to solve the problem?
# 2. Does your solution work?
#     - If your solution works, how do you know it works?  Include any calculations you made, tests you ran, etc.
#     - If your solution does not work, how do you know it does not work?  What approaches would you use to verify a correct solution?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# #### Rubric
# 5 points for each question:
# 1 point for answering the outer overall question and 4 points for the details with the inner questions.

# %% [markdown]
# ---
#
# # Part 2: Using `numpy` and `matplotlib` to Analyze Data
#
# Suppose you have decided to examine [Forecasted water temperature in offshore Lake Michigan](https://www.sciencebase.gov/catalog/item/66b78f02d34eebcf8bb3da75) to gain insights into the severity of underwater temperatures on the lake in the next 20 years. You found this dataset of simulated offshore temperatures for the year 2014, as observed from one site in the northern basin where the National Oceanic Atmospheric Administration (NOAA) has been maintaining a weather buoy since 1979.
#
# This dataset is a record of average daily offshore temperatures, and each column represents one of 20 vertical depths (ranging 4 to 159 m below the surface) at which the measurement is taken.

# %% [markdown]
# ## Part 2a) (15 points)
#
# It's time to load in some data!  The file, `Quiz2_dataset.csv` has temperature data for **20** different vertical depths under water. The first column is the "Day of Year" of the measurements while the remaining columns are measurements taken at each depth (with the depths given by the negative values in the first row). Open the file in a editor of your choosing and **looking at the different columns, choose one column of data (other than "Day of Year") to explore.**
#
# **Using numpy (not pandas!), load the `Quiz2_dataset.csv` file into your notebook.** Inspect the data file and ensure that you only read in the columns you are interested in for full credit (i.e. "Day of Year" and your column of choice).
#
# **Using matplotlib, make a basic plot that visualizes the data of your choice on the y-axis and the Index on the x-axis.** Make sure to include appropriate labels for full credit!

# %%
# PUT YOUR CODE HERE

# %%
### ANSWER

# Rubric
# 5 points for reading in only the desired columns of data and defining variables
# 5 points for plotting the data
# 5 points for axis labels
import matplotlib.pyplot as plt
day_of_the_year, temp = np.loadtxt('Quiz2_dataset.csv',usecols=(0,3),skiprows=1,delimiter=',',unpack=True)
print(np.min(temp), np.max(temp))#recover range of values of temperature

#OR
print(temp[0:4])

plt.plot(temp)
#plt.ylim(0,550000)
plt.xlabel('Day of the Year')
plt.ylabel('Temperature at depth')
# Out:
# 2.537 18.5639
# [7.3035 7.2977 7.291  7.2692]
# Text(0, 0.5, 'Temperature at depth')

# %% [markdown]
# ## Part 2b) (10 points)
# To share your insight, you want to create a summary plot of your data and the descriptive statistics. In the cell below, create this summary plot. It should include the following:
#
# * The column of data you chose
# * The mean of that column
# * The +/- standard deviation from the mean
#
# You may choose to plot your descriptive statistics as horizontal or vertical lines (depending on the plot), or you can print them out as part of the plot (i.e. in the legend, title, as an annotation, etc. NOT)
#
# Adjust your x and y ranges as needed in order for all of your information to be visible. You can choose to use a histogram, line plot, scatter plot, etc.
#
# #### Note: If you are unable to load data from the provided csv file, use the test data `test_x` and `test_y` below to generate your plot for partial credit.

# %%
# Test data
test_x = np.arange(0,10,1.0) # day of the year test data
test_y = [7.2813, 7.2782, 7.2564, 7.2185, 7.0878, 6.8292, 6.7631, 6.8228, 6.8514, 6.8182] # Offshore temperature test data

# %%
## Put your answer here

# %%
### ANSWER ###

mean = np.mean(temp)
stan=np.std(temp)
plt.hist(temp)
plt.axvline(mean,color = 'k')
plt.axvline(mean+stan,color= 'pink',ls='--')
plt.axvline(mean-stan,color = 'pink',ls='--')

plt.xlabel('temperature')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
### ANSWER ###

mean = np.mean(temp)
stan=np.std(temp)

plt.plot(day_of_the_year, temp)
plt.axhline(mean,color = 'k')
plt.axhline(mean+stan,color= 'pink',ls='--')
plt.axhline(mean-stan,color = 'pink',ls='--')

plt.xlabel('Day of the year')
plt.ylabel('temperature')
# Out:
# Text(0, 0.5, 'temperature')

# %%
## ANSWER using test data
mean = np.mean(test_y)
stan=np.std(test_y)
plt.hist(test_y)
plt.axvline(mean,color = 'red')
plt.axvline(mean+stan,color= 'purple',ls='--')
plt.axvline(mean-stan,color = 'purple',ls='--')

plt.xlabel('temperature')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# ### Rubric ###
# Full credit for any response that includes all three components
#
# 4 points for base plot,
#
# 2 point each for mean/median, std above and std below line plots (total of 6)

# %% [markdown]
# ## Part 2c) Documenting Your Solution Pathway (10 points)
#
# Answer the following questions in detail:
# 1. Did you use any external resources (e.g. generative AI, past assignments, Code Portfolio, Stack Overflow, Google, etc.) to help you?
#     - If you DID use external resources, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include prompts and outputs.
#     - If you DID NOT use external resources, what prior knowledge did you recall to solve the problem?
# 2. Does your solution work?
#     - If your solution works, how do you know it works?  Include any calculations you made, tests you ran, etc.
#     - If your solution does not work, how do you know it does not work?  What approaches would you use to verify a correct solution?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# #### Rubric
# 5 points for each question:
# 1 point for answering the outer overall question and 4 points for the details with the inner questions.

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
