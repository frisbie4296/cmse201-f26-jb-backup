# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 (Section 003)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill.
#
# **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **You may use generative AI tools, but like all sources, we expect that you document and describe the resources you used and how you used them!**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging code

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.
#
# **NOTE: Guidelines for Using Code You Didn't Write**
#
# If you are using content to solve problems that has not been covered in our pre-class or in class assignments, you **MUST** cite your work. If you use generative AI tools, you must indicate which tool you used (e.g. chatGPT, Co-Pilot, Claude, etc.) and what lines of code were produced by generative AI and which ones were produced by you. If you used generative AI to prduce text (or other output), include the tool, the prompt, and the output. Failure to properly cite your work may result in loss of points on the problem.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # Part 1: Defining a function
#
# ## Part 1a) (20 points)
# **Write a function that takes an array of values as input and returns the mean, minimum, and maximum of those values.**  (You can use numpy functions inside the function you make.)
#
# **Demonstrate that your function works by calling it using the test data.** We are going to use this to analyze the data from the data file later in the quiz!
#
# Note: You are provided with both x and y data. You can use either to test your function.

# %%
# test data
import numpy as np
test_x = np.arange(1980,1990) # indices test data
test_y = [12.5, 14.3, 16.4, 9.3, 10.9, 14.7, 8.7, 9.8, 11.7, 12.2] # Stream time (minutes) test data

# PUT YOUR FUNCTION HERE

# %% [markdown]
# ## Part 1b) Documenting Your Solution Pathway (10 points)
#
# **Answer the following questions in detail:**
# 1. Did you use any external resources (e.g. generative AI, past assignments, Code Portfolio, Stack Overflow, Google, etc.) to help you? (1 point)
#     1. *If you DID use external resources*, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. (4 points)
#     2. *If you DID NOT use external resources*, what prior knowledge did you recall to solve the problem? (4 points)
# 2. Does your solution work? (1 point)
#     1. *If your solution works*, how do you know it works?  Include any calculations you made, tests you ran, etc. (4 points)
#     2. *If your solution DOES NOT work*, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# # Part 2: Using `numpy` and `matplotlib` to Analyze Data
#
# You have decided to examine data on [apple production in the United States](https://www.ers.usda.gov/data-products/fruit-and-tree-nuts-data/fruit-and-tree-nuts-historical-data).  This data is compiled in `AppleProduction.csv`.  The first column contains the year and the remaining columns indicate the total utilized apple production (in millions of pounds) for different states in the U.S.

# %% [markdown]
# ## Part 2a) (5 points)
#
# **Looking at the different columns in `AppleProduction.csv`, choose one state to explore.**
#
# **Using numpy (not pandas!), load the `AppleProduction.csv` file into your notebook.** Inspect the data file and ensure that you only read in the columns you are interested in for full credit (i.e. "Year" and your state of choice).

# %%
# PUT YOUR CODE HERE

# %% [markdown]
# ## Part 2b) (5 points)
#
# **Use the function you made in Part 1a to calculate the mean, minimum, and maximum values for your dataset and print them out.**  (If you were unable to make the function, you can calculate these using another method for half-credit.)

# %%
# Your code here!

# %% [markdown]
# ## Part 2c) (20 points)
#
# Using matplotlib, do the following:
# 1. (5 pts) **Make a basic line plot that visualizes the Apple Production for the state of your choice on the y-axis and the Year on the x-axis.**  (If you were unable to load in the data, you can use the test data given in Part 1.)
# 2. (5 pts) **Include horizontal lines (`axhline`) indicating the minimum, maximum, and mean** that you calculated in Part 2b.  Use different colors and linestyles to make these distinct.
# 3. (5 pts) **Include appropriate axis labels**
# 4. (5 pts) **Give the plot a title** indicating which state you used (or if you used the test data)

# %%
# PUT YOUR CODE HERE

# %% [markdown]
# ## Part 2d) Documenting Your Solution Pathway (10 points)
#
# **Answer the following questions in detail:**
# 1. Did you use any external resources (e.g. generative AI, past assignments, Code Portfolio, Stack Overflow, Google, etc.) to help you? (1 point)
#     1. *If you DID use external resources*, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. (4 points)
#     2. *If you DID NOT use external resources*, what prior knowledge did you recall to solve the problem? (4 points)
# 2. Does your solution work? (1 point)
#     1. *If your solution works*, how do you know it works?  Include any calculations you made, tests you ran, etc. (4 points)
#     2. *If your solution DOES NOT work*, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
