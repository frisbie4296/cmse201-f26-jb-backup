# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 1 (Spring 2025)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# *Important note about using online resources*: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. You are expected to cite all of your sources and indicate how you used them. *However, the use of any person-to-person communication software is absolutely not acceptable.*
#
# *You may use generative AI tools, but like all sources, we expect that you document and describe the resources you used and how you used them!*
#
# *Do your own work.* This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ---
# # Academic integrity statement [5 points]
#
# *NOTE: Guidelines for Using Code You Didn't Write*
#
# If you are using content to solve problems that has not been covered in our pre-class or in class assignments, you **MUST** cite your work. If you use generative AI tools, you must indicate which tool you used (e.g. chatGPT, Co-Pilot, Claude, etc.) and what lines of code were produced by generative AI and which ones were produced by you. If you used generative AI to prduce text (or other output), include the tool, the prompt, and the output. Failure to properly cite your work may result in loss of points on the problem.
#
# **In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# # 1. Problem Context: Converting between `for` loops and `while` loops
#
# ### &#9989;&nbsp; Question (10 points)
# ## Part 1a)
# You are organizing a fundraising event for the charity of your choice.  Your goal is to raise 100 dollars, so you offer a small prize to the contributor who pushes the total over 100 dollars.  Fortunately for you, you have some very generous friends and you end up raising more than 500 dollars.  You need to figure out which friend pushed the total over your 100 dollar goal.
#
# **Task: Change the `for` loop to a `while` loop, making sure the output remains the same.**

# %%
# list of contributions (DO NOT CHANGE!)
contribution_list = [7, 3, 9, 5, 4, 10, 8, 4, 6, 6, 4, 1, 5, 3, 4, 5, 3, 2, 7, 9, 2, 5, 5, 3, 6, 10, 7, 8, 3, 9, 3, 3, 9, 4, 7, 6, 9, 7, 3, 9, 5, 5, 5, 1, 2, 7, 7, 3, 6, 5, 4, 9, 2, 6, 10, 9, 9, 6, 7, 1, 2, 5, 6, 5, 9, 7, 9, 9, 5, 9, 5, 8, 8, 7, 1, 4, 3, 8, 1, 10, 9, 7, 2, 3, 8, 6, 5, 8, 10, 7, 2, 10, 5, 5, 7, 8, 7, 7, 6, 4]

# %%
# for loop (DO NOT CHANGE!)
total = 0
for i in range(len(contribution_list)):
    if total < 100:
        total = total + contribution_list[i]
        print('Friend number',i,'raised the total to',total,'dollars.')
# Out:
# Friend number 0 raised the total to 7 dollars.
# Friend number 1 raised the total to 10 dollars.
# Friend number 2 raised the total to 19 dollars.
# Friend number 3 raised the total to 24 dollars.
# Friend number 4 raised the total to 28 dollars.
# Friend number 5 raised the total to 38 dollars.
# Friend number 6 raised the total to 46 dollars.
# Friend number 7 raised the total to 50 dollars.
# Friend number 8 raised the total to 56 dollars.
# Friend number 9 raised the total to 62 dollars.
# Friend number 10 raised the total to 66 dollars.
# Friend number 11 raised the total to 67 dollars.
# Friend number 12 raised the total to 72 dollars.
# Friend number 13 raised the total to 75 dollars.
# Friend number 14 raised the total to 79 dollars.
# Friend number 15 raised the total to 84 dollars.
# Friend number 16 raised the total to 87 dollars.
# Friend number 17 raised the total to 89 dollars.
# Friend number 18 raised the total to 96 dollars.
# ...

# %%
# Put your while loop here!

# %% [markdown]
# ### &#9989;&nbsp; Metacognition (10 points)
# ## Part 1b) Documenting Your Solution Pathway
#
# **Describe in detail how you solved the problem** including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?
#
# If you were unable to complete this problem, describe how you know it does not work, how you would approach the problem, and how you would verify that your code works.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# # 2. Problem Context: Using if/else Statements to Control Flow
#
# ### &#9989;&nbsp; Question (10 points)
# ## Part 2a)
# In boxing, athletes compete in weight classes.  A (simplified) list of classifications is below:
# * "Heavyweight": 175.1 pounds and above
# * "Middleweight": 135.1 to 175 pounds
# * "Lightweight": 118.1 to 135 pounds
# * "Flyweight": 118 pounds and below
#
# In the cell below, you will see a list of 12 weights. **Using `if`, `elif`, and `else` statements, print which weight class each athlete will compete in.** Some starter code for navigating the list (and formatting the output) is given!

# %%
# Example starter code
weights = [111, 113, 182, 164, 120, 122, 143, 102, 223, 174, 158, 143] #pounds

for weight in weights:
    print(weight,"competes in","[example class]")
# Out:
# 111 competes in [example class]
# 113 competes in [example class]
# 182 competes in [example class]
# 164 competes in [example class]
# 120 competes in [example class]
# 122 competes in [example class]
# 143 competes in [example class]
# 102 competes in [example class]
# 223 competes in [example class]
# 174 competes in [example class]
# 158 competes in [example class]
# 143 competes in [example class]

# %% [markdown]
# ### &#9989;&nbsp; Metacognition
# ## Part 2b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail how you solved the problem** including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?
#
# If you were unable to complete this problem, describe how you know it does not work, how you would approach the problem, and how you would verify that your code works.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# # 3. Using Loops for Calculations
#
# ### &#9989;&nbsp; Question (10 points)
# ## Part 3a)
# You have a collection of coins, each worth a separate amount.  The number and value of the coins correspond to the lists given below.  **Write some code to find the total value of the coins that you have.**  Your code should do the following:
# * Use a loop to iterate through the lists
# * Multiply the value of the coin by the quantity of that coin
# * Compute the total value of all the coins you have
# * Print the total value

# %%
# Example starter code
value_of_coins = [0.01, 0.05, 0.10, 0.25, 0.50, 1.00] #in dollars
number_of_coins = [8, 3, 5, 14, 2, 1] #quantity of coins for each value amount

# write your code here

# %% [markdown]
# ### &#9989;&nbsp; Metacognition
# ## Part 3b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail how you solved the problem** including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?
#
# If you were unable to complete this problem, describe how you know it does not work, how you would approach the problem, and how you would verify that your code works.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #1, and upload it there.
