# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 3 (Sec 008, Spring 2025)
#
# The goal of this quiz is to give you the opportunity to test out more of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your more recently acquired programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **You also must use the tools and commands that we learned to answer the questions.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# **Each part of the quiz can be done independently. If you get stuck _move on to another part of the quiz to earn some points there!_**
#
# **Quiz Duration:** 40 minutes
#
# **Total possible points:** 80

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.
#
# ****GenAI use: If you use generative AI, you must copy/paste into a cell in this quiz (1) your prompt, (2) the output from generative AI, and (3) Write your answer in separate cells. Failure to include this level of detail will result in a deduction of points.**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # 1. Analyzing marijuana/cannabis consumption (40 points)
#
# The Substance Abuse and Mental Health Services Administration ([SAMHSA](https://www.samhsa.gov/))
# regualry publishes National Survey on Drug Use and Health ([NSDUH](https://nsduhweb.rti.org/respweb/homepage.cfm)) data related to drug and substane use such as alcohol, tobacco, marijuana, and opioids. In this part of the quiz you will be analyzing data related to marijuana/cannbais monthly use adapted from the 2023 NSDUH.
#
# The data has the following columns:
#
# __IRSEX__:  Sex at birth
# 	1 = Male
# 	2 = Female
#
# __MJDAY30A__: Number of days used Marijuana/Cannabis products during the last 30 days.
# 	Range = 1-30
# 	91 = Never used marijuana
#     93 = did not use Marijuana/Cannabis in the past 30 days
#     94 = don’t know
#     97 = refused
#     98 = blank (no answer)
#
# __MJAGE__: Age when first used Marijuana/cannabis.
# 	Range = 1-85
# 	985 = bad data
# 	991 = never used marijuana
# 	994 = don’t know
# 	997 = refused
# 	998 = blank (no answer)
#
# __MJMONSMOKE__: Marijuana use – smoking – past 30 days
#     1 = Yes
#     2 = No
#     991 = never used marijuana
# 	994 = don’t know
# 	997 = refused
# 	998 = blank (no answer)
#
# __MJMONVAPE__: Marijuana use – vaping – past 30 days
#     1 = Yes
#     2 = No
#     991 = never used marijuana
# 	994 = don’t know
# 	997 = refused
# 	998 = blank (no answer)
#
# __MJMONEAT__: Marijuana use – eating or drinking – past 30 days
#     1 = Yes
#     2 = No
#     991 = never used marijuana
# 	994 = don’t know
# 	997 = refused
# 	998 = blank (no answer)
#
#
#
#
# #### &#9989;&nbsp; **Question 1.1 (5 points)**
# Load the `marijuana_data_for_quiz3.csv` file provided on D2L **using Pandas** and display the first 10 rows.

# %%
# Let's make sure pandas is imported
import pandas as pd

# Put your code here

# %% [markdown]
# #### &#9989;&nbsp; **Question 1.2 (15 points)**
# You want to narrow down your analysis to just one age group corresponding to first use of Marijuana/cannabis as described by the column __MJAGE__ in the data in the age range 17-23 years old including the end points, i.e., 17 and 23 are included.
#
# Create a mask that filters the data to show only the rows that match the age range 17-23 years old (including the end points 17 and 23), __and__ that only contain entries in the column __MJDAY30A__ that are less than or equal to 30 (i.e., entries with proper values for the number of days used Marijuana/Cannabis products during the last 30 days).
#
# **Display that dataframe once you've created it**, to confirm that you did it correctly.
#
# **Note**: if you didn't get the dataset loaded correctly, try your best to write the code that **should** appropriately mask the data for partial credit.

# %%
# Put your code here

# %% [markdown]
# #### &#9989;&nbsp; **Question 1.3 (10 points)**
#
# Finally, you are curious about the average number of days for using Marijuana/Cannabis products during the last 30 days (the ___MJDAY30A___ column) for the age range you specified. **Write some code to calculate and display the mean** for the ___MJDAY30A___ column of your masked dataframe.
#
# **Note #1**: there's more than one way you could do this.
#
# **Note #2**: if you didn't get the dataset loaded correctly, try your best to write the code that **should** calculate and display the mean for partial credit.

# %%
# Put your code here

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> From the output of your code, what is the mean for the number of days of using marijuana/cannabis products during the last 30 days (column __MJDAY30A__ in the data)?
# *Put your answer here*

# %% [markdown]
# ### &#9989;&nbsp; Metacognition
# ## Question 1.4 Documenting Your Solution Pathway (10 points)
#
# 1. Did you use any external resources (e.g. generative AI, past assignments, Code Portfolio, Stack Overflow, Google, etc.) to help you?
#     * If you DID use external resources, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include prompts and outputs.
#     * If you DID NOT use external resources, what prior knowledge did you recall to solve the problem?
# 2. Does your solution work?
#     * If your solution works, how do you know it works?  Include any calculations you made, tests you ran, etc.
#     * If your solution does not work, how do you know it does not work?  What approaches would you use to verify a correct solution?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
# # 2. Fitting a model to data with `curve_fit` and visualizing the results (30 points)
#
# You recently took up a job at a prominent car company in Detroit, and you want to assess the efficiency of their suspension system (the part that connects the wheels to body of the car and isolates the passenger compartment from vibraiton and shock due to wavy roads, potholes, etc.). You know from the senior engineers that the suspension system successfully attenuates the road vibration according to a known function with some constants. Your job is to identify the corresponding constants.

# %%
# RUN THIS CELL to make sure you have the dataset loaded
import numpy as np
import pandas as pd

vibration_data = pd.DataFrame({'time': np.linspace(0, 10, 250), 'vibration':
        [ 1.08270409e-01,  9.41621263e-02,  1.17275172e-01,  1.09444396e-01,
        1.17947748e-01,  1.04040803e-01,  9.27111681e-02,  7.90029916e-02,
        7.63305568e-02,  4.50581504e-02,  2.28746910e-02,  1.01760710e-02,
        2.39969131e-03, -2.72302788e-02, -4.71794596e-02, -4.55453139e-02,
       -5.46724577e-02, -7.55161274e-02, -8.40246863e-02, -8.42646549e-02,
       -8.18515343e-02, -8.97192048e-02, -8.05316526e-02, -7.53010846e-02,
       -6.71153696e-02, -5.01581298e-02, -5.21451003e-02, -2.90543002e-02,
       -3.14596889e-02, -1.24998313e-02,  1.33648587e-02,  1.35670152e-02,
        3.45210514e-02,  3.55116688e-02,  6.76543721e-02,  7.25562910e-02,
        7.01438192e-02,  7.12977793e-02,  6.80193181e-02,  7.06267538e-02,
        6.11446002e-02,  6.21533078e-02,  4.64063697e-02,  5.27988433e-02,
        3.42394549e-02,  1.99815594e-02,  2.83601386e-02,  1.08671604e-03,
       -1.07174458e-02, -3.14605436e-02, -2.35783749e-02, -3.00814158e-02,
       -4.13686370e-02, -6.47223610e-02, -5.70874854e-02, -5.15043215e-02,
        8.49606343e-03,  9.92768021e-03, -6.65689860e-03, -1.19724878e-02,
       -9.75145525e-03,  3.61280496e-03, -1.34510801e-02, -5.13793314e-03,
       -1.40933744e-02, -1.07397916e-02, -4.03999398e-03, -7.54444993e-03,
        1.47808178e-04, -2.28951929e-03, -1.01144323e-02, -8.36706406e-05,
        1.46148479e-02, -1.07397214e-02,  4.24489883e-03, -5.34344602e-03,
        1.92653807e-02,  7.22574917e-03,  5.21862370e-03,  1.15057961e-02,
        9.59087387e-04,  1.09690288e-02,  1.48845474e-02,  1.93511015e-02,
        9.41354652e-03,  2.76139657e-03,  2.75143788e-03,  5.69911283e-03,
        2.56766899e-03,  1.02066198e-02, -2.11437658e-03, -1.25830599e-03,
       -1.77063504e-03, -7.16769408e-03, -1.43441286e-02, -8.56489362e-03,
       -1.92384273e-02, -9.82052418e-03, -1.93013537e-02, -7.86642819e-03,
       -8.19734388e-03, -2.22226970e-03,  3.31632172e-03, -1.29111219e-02,
       -3.97171364e-03, -1.22602007e-03, -1.80766205e-03, -3.51849049e-03,
       -8.35957249e-03,  8.63595820e-03, -1.15095472e-02,  5.13083993e-04,
        1.58141352e-02,  1.03784242e-02]})

vibration_data.head()

# %% [markdown]
# ---
#
# #### &#9989;&nbsp; **Question 2.1 (10 points):**
#
# Using the data and provided model below, use `curve_fit` to find best fit parameters for *a, b,* and *c*. make sure you give `curve_fit` a good starting point for finding the best fit parameters using the `p0` argument and these starting values/guidelines:
# * C = 0.1
# * zeta any value between 0 and 1
# * omega_d = 1.75
# * phi = 0.5
#
# Once you've found the best values, **print them out**. You should find that they are not far off from, but not the same as, the starting values above.

# %%
# Run this cell before you proceed. Do not edit!

# Will need to use NumPy for the function
import numpy as np

# Will need to import curve_fit from SciPy
from scipy.optimize import curve_fit

# This function calculates the vibration of a suspension system corresponding to time
def vibration_function(t, C, zeta, omega_d, phi):
    return C * np.exp(-zeta * t) * np.cos(omega_d * t - phi)

# %%
# Put your code here

# %% [markdown]
# #### &#9989;&nbsp; **Question 2.2 (10 points)**
#
# Now that you have a set of best fit parameters, **use those parameters to calculate the expected model values and plot the expected model values on top of the actual data values**. Make sure to label your axes and include a legend to communicate what parts of the plot correspond to the model versus the data.

# %%
# Make sure we import matplotlib
import matplotlib.pyplot as plt

# Put your code here

# %% [markdown]
# ### &#9989;&nbsp; Metacognition
# ## Question 2.3 Documenting Your Solution Pathway (10 points)
#
# 1. Did you use any external resources (e.g. generative AI, past assignments, Code Portfolio, Stack Overflow, Google, etc.) to help you?
#     * If you DID use external resources, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include prompts and outputs.
#     * If you DID NOT use external resources, what prior knowledge did you recall to solve the problem?
# 2. Does your solution work?
#     * If your solution works, how do you know it works?  Include any calculations you made, tests you ran, etc.
#     * If your solution does not work, how do you know it does not work?  What approaches would you use to verify a correct solution?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #3, and upload it there.
#
# **Double check your submission on D2L!**
