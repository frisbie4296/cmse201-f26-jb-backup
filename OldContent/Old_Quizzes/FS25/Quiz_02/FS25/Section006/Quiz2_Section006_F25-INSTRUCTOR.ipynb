# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 (Section 006, Fall 2025)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill.
#
# **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **You may use generative AI tools, but like all sources, we expect that you document and describe the resources you used and how you used them!**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
#
# **Quiz duration: 40 minutes**
#
# **Total possible points:** 75

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging code

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.
#
# **NOTE: Guidelines for Using Code You Didn't Write**
#
# If you are using content to solve problems that has not been covered in our pre-class or in class assignments, you **MUST** cite your work. If you use generative AI tools, you must indicate which tool you used (e.g. chatGPT, Co-Pilot, Claude, etc.) and what lines of code were produced by generative AI and which ones were produced by you. If you used generative AI to prduce text (or other output), include the tool, the prompt, and the output. Failure to properly cite your work may result in loss of points on the problem.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ### ANSWER
#
# # TEMPLATE INSTRUCTIONS
#
# This quiz should assess functions, numpy, and matplotlib. Specifically, we want to assess if students can load in a data file, explore it with some basic calculations, and visualize it in  a meaningful way. Use of numpy and matplotlib implicitly includes functions, but we also want to assess students' understanding of how to write and use their own functions.
#
# **Note:** Please make sure that your instructions for expectations on metacognition questions are explicit. If at all possible, use context clues and visual aids to help students for whom English is not their first language. Please also ensure that students are reminded of the citation guidelines for using HiTA vs. other GenAI resources.
#
# Use Homework 2 questions as a guide for what they can be expected to know for this quiz (though the quiz will be shorter and simpler than a homework assignment)
#
# To that end, my suggested overarching structure for this Quiz is:
# * Write a function that takes in data and outputs a calculation and/or a plot (provide some "test" data to demonstrate that their function works (Note: This question can/should have the flexibility for them to write one or multiple functions, depending on how they see the solution to the problem).
# * Documenting Solution Pathway Question
# * Choose a data set (presented as a .csv file) with more than two columns of data (make sure they use numpy for this, not pandas)
# * Documenting Solution Pathway Question
# * Visualize the data in a simple manner (i.e. ask them to make a line plot or histogram, can include use of subplots)
# * Use a given function on the data file for calculations
#
# **Note:** While you can have the quiz have students explore a single thread of a problem, rather than disjointed problems, be attentive to places where students can earn partial credit throughout the quiz. For example, even if they can't get their function to work from the beginning of the quiz, they can still show you that they can load and plot data. If they can't load and plot the data, they could plot the test data. You can also include questions (as I have in the examples) where they can qualitatively discuss what they are doing.
#
# Below is an example of how this quiz could be written. If you use this structure, make sure to choose your own data set and make your quiz unique to your section!

# %% [markdown]
# ## Part 1a) Writing and Testing a Function (20 points)
#
# In statistics, the Pearson correlation coefficient (PCC) is a correlation coefficient that measures linear correlation between two sets of data. It has a value between −1 and 1 and the formula is defined as:
#
# $$ r = \frac{\sum\limits_{i=1}^{N} (x_{i}-\overline{x})(y_{i}-\overline{y})}{\sqrt{\sum\limits_{i=1}^{N} (x_{i}-\overline{x})^2 \sum\limits_{i=1}^{N} (y_{i}-\overline{y})^2}}$$
#
# where the symbols in this equation represent the following:
#
# * $r$: Pearson correlation coefficient
# * $\overline{x}$: Mean of the value of x-variable
# * $\overline{y}$: Mean of the value of y-variable
# * $x_{i}$: The value of x-variable at position $i$
# * $y_{i}$: The value of y-variable at position $i$
#
# **Task 1a) Write a function (10 points)**
#
# - Write a function called `Corr_coeff` (**5 points**).
# - Your function should take the following inputs: `x_value`,`y_value` (**3 point**).
# - The function should return the PCC value (**2 points**).
#
# > Hint: In your defined `Corr_coeff` function, you can implement functions from Numpy to calculate the PCC value.
#
# **Note:** You are provided with both **x** and **y** data for testing your defined function in part 1b).

# %%
import numpy as np
# Define your function here

# %%
### ANSWER
import numpy as np

# Pearson's correlation coefficient function
#Solution #1
def Corr_coeff(x_value, y_value):
    mu = np.mean(x_value)
    nu = np.mean(y_value)
    num1 = []
    num2 = []
    for jj in range(len(x_value)):
        num1.append(x_value[jj] - mu)
        num2.append(y_value[jj] - nu)
    
    return sum(np.array(num1)*np.array(num2))/np.sqrt(sum(np.array(num1)**2)*(sum(np.array(num2)**2)))

# print(Corr_coeff(x_values,y_values))

#Solution #2
def Corr_coeff2(x_value, y_value):
    return np.corrcoef(x_value,y_value)[0,1]

# print(Corr_coeff2(x_values,y_values))

### RUBRIC
## 10/10 for a function that runs/will run and produce correct output
## 5/10 for a function that runs/will run but has errors (mathematical or otherwise)
## 0/10 for a function that will not run AND has error(s)

# %% [markdown]
# **Task 1b) Test your function (10 points)**
#
# Now, you have the following **x_values** and **y_values** data to test your function and calculate the Pearson Correlation Coefficient (PCC) between them.

# %%
# Test data
import numpy as np

np.random.seed(123)
x_values = np.random.normal(5, 2, 100)# 100 sample poitns from normal distribution with mean 5 and standard deviation 2.
y_values = np.linspace(1,3,100)# 100 evenly distributed points between 1 and 3.

# put your code here!

# %%
### ANSWER
print(Corr_coeff(x_values,y_values))

# or
print(Corr_coeff2(x_values,y_values))

### RUBRIC
## 10/10 for an answer that runs, produces the correct answer, and uses function arguments correctly (no variable scope problems)
## 5/10 for an answer that runs but has errors (with variable scope, final answer, etc.)
## 0/10 for an answer that does not run AND has errors
# Out:
# 0.00725365673808658
# 0.007253656738086591

# %% [markdown]
# ## Part 1b) Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 1 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# # Part 2: Using `numpy` and `matplotlib` to Analyze Data
#
# You are given a public dataset: the **Palmer Penguins** dataset. It contains measurements for penguins observed on islands in the Palmer Archipelago, Antarctica (*source: Gorman KB, Williams TD, Fraser WR (2014). Ecological sexual dimorphism and environmental variability within a community of Antarctic penguins (genus Pygoscelis). PLoS ONE 9(3):e90081.*).
#
# Among them, three important traits are:
# - `body_mass_g` — Penguin’s body mass at the time of measurement, in grams (a proxy for overall size/condition).
# - `bill_length_mm` — Length of the upper bill (culmen) from tip toward the base, in millimeters (useful for species ID and feeding ecology).
# - `flipper_length_mm` — Straight-line length of a flipper, in millimeters (relates to body size and swimming ability).
#
#
# **Data access in this quiz:** The CSV file `penguins_clean.csv` (with no missing values) is provided to you on the course site.

# %% [markdown]
# ## Part 2a) (10 points)
#
# It’s time to load data and do some analysis!
#
# **YOUR TASK:** Using **NumPy** (not pandas), load the file `penguins_clean.csv` into your notebook. For full credit:
# - Read **only** the columns `body_mass_g`, `bill_length_mm`, and `flipper_length_mm`.
# - Store them in arrays named `body_mass_g`, `bill_length_mm`, and `flipper_length_mm`.
# - Briefly verify your load (e.g., print the arrays’ shapes or the first few values).
#
# *(If you can’t figure out NumPy, you may use pandas for partial credit.)*

# %%
# Put your code here

# %%
### ANSWER
# Rubric
# 6 points for loading the data
# 4 points for defining variables

penguins = np.loadtxt('penguins_clean.csv',delimiter=',',skiprows=1,usecols=[2,4,5]) # 6 points

bill_length_mm = penguins[:,0] 
flipper_length_mm = penguins[:,1] 
body_mass_g = penguins[:,2] # 4 points

print(bill_length_mm[0:5])
print(flipper_length_mm[0:5])
print(body_mass_g[0:5])
# Out:
# [39.1 39.5 40.3 36.7 39.3]
# [181. 186. 195. 193. 190.]
# [3750. 3800. 3250. 3450. 3650.]

# %% [markdown]
# ## Part 2b) (10 points)
#
# Now that you have a tool and some data, it’s time to analyze relationships in the Penguins dataset.
#
# Suppose you are hired as a data scientist to assess whether **flipper length** and **bill length** are informative about a penguin’s **body mass**.
#
# **YOUR TASK:** Using `matplotlib`, create **two** simple scatter plots:
# 1. `body_mass_g` (y-axis) **vs.** `flipper_length_mm` (x-axis)
# 2. `body_mass_g` (y-axis) **vs.** `bill_length_mm` (x-axis)
#
# **Requirements (for full credit):**
# - Use **subplots** (both plots in one figure).
# - Provide **correct axis labels with units** (grams, millimeters).
# - Add **clear titles** indicating which variables are plotted.
# - Use the arrays from Part 2a: `body_mass_g`, `flipper_length_mm`, `bill_length_mm`.

# %%
# Put your code here

# %%
### ANSWER ###
# Rubric
# 6 points for plotting the data
# 2 points for subplots
# 2 points for axis labels

import matplotlib.pyplot as plt

plt.figure(figsize=(8,10))

# (1) body_mass_g (y) vs flipper_length_mm (x)
plt.subplot(2, 1, 1)  # 2 points
plt.scatter(flipper_length_mm, body_mass_g)  # 2 points
plt.xlabel('Flipper length (mm)')            # 1 point
plt.ylabel('Body mass (g)')                  # 1 point
plt.title('Body mass vs Flipper length')

# (2) body_mass_g (y) vs bill_length_mm (x)
plt.subplot(2, 1, 2)  # 2 points
plt.scatter(bill_length_mm, body_mass_g)     # 2 points
plt.xlabel('Bill length (mm)')               # 1 point
plt.ylabel('Body mass (g)')                  # 1 point
plt.title('Body mass vs Bill length')
# Out:
# Text(0.5, 1.0, 'Body mass vs Bill length')

# %% [markdown]
# ## Part 2c) (5 points)
#
# Using your defined function, compute the **Pearson correlation coefficient** between `body_mass_g` and each of `flipper_length_mm` and `bill_length_mm`.  **Report both coefficients** and indicate which length(s) has a correlation with `body_mass_g` **greater than 0.8** (justify with the numeric values).

# %%
## Put your code here

# %%
### ANSWER
# Rubric
# 3 points for calculating the correlation
# 2 points for the correct answer
cor_rs = Corr_coeff(body_mass_g,flipper_length_mm)
cor_ts = Corr_coeff(body_mass_g,bill_length_mm) 
print('The correlation coefficients between body mass and flipper/bill lengths are as follows:',cor_rs,cor_ts)
print('The correlation between body mass and flipper length is greater than 0.8')
# Out:
# The correlation coefficients between body mass and flipper/bill lengths are as follows: 0.8712017673060112 0.5951098244376296
# The correlation between body mass and flipper length is greater than 0.8

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*
#
# - r(body_mass_g, flipper_length_mm) = ______
# - r(body_mass_g, bill_length_mm) = ______
# - Length(s) with r > 0.8: ______

# %% [markdown]
# ## Part 2d) Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 1 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
