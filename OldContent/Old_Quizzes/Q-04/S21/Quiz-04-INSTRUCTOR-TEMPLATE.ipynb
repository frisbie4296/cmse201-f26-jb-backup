# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 4 (Section 001 - Spring 2021)
#
# The quiz is set up so that even if you get stuck on one question there are opportunities to get points on the other questions, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time.  Also, you will receive partial credit for pseudocode, even if your python code does not function correctly.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity will result in you receiving a zero on the quiz.
#
# **Total points possible: 20**

# %% [markdown]
# ---
# ## Academic integrity statement (1 point)
#
# In the markdown cell below, put your personal academic integrity statement (composed during Day04 In-Class Assignment). By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# ## Part 1: Fitting and Describing Trends in Arbitrary Data (19 pts)

# %% [markdown]
# ###ANSWER### (for making sure this gets removed)
#
# **Note to instructors:** In this section, the goal provide students with the opportunity to showcase their ability to write code given what they've had the opportunity to practice in the fourth homework assignment. This means that this question should ideally only involve the following concepts:
# * loading data using Pandas or Numpy (I am just giving the data below to save student's time)
# * Fitting some sort of model to the data using either NumPy's `polyfit` or SciPy's `curve_fit`
# * visualizing the data and the best fit model
# * answering conceptual questions based on the model results
#
# For this quiz, I'm stepping away from trying to get the to pseudocode a solution first (as was used in the first two quizzes), since it's less clear how beneficial it would be for these questions. I may return to this style of questioning in the future.

# %%
### ANSWER ###
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Generate some arbitrary data--Feel free to make your own arbitrary data with this!!
x = np.arange(0,30, 1)

def arb_func(x):
    y = 4*x**2 + 3*x + 5
    return y

y = arb_func(x)

yn = y + np.random.normal(0,500,x.size)
yn[yn<0] =0
plt.plot(x,yn,'.')
yn = yn.astype(np.int)
yn
# Out:
# array([   0,    0,    0,   88,    0,  464,  133,  152,  339,  499,    0,
#           0,    0, 1566,  561,  710,  569,  317, 1747, 1358, 2111, 2589,
#        2581, 2980, 2238, 1778, 3074, 3632, 3586, 3374])

# %% [markdown]
# You conduct an online public experiment for 30 days.  You asked people to like to your facebook post about your new adorable cat. You record the number of likes per day and store the amount in `likes_per_day.`
#
#
# ### Display Data
#
# &#9989;&nbsp; **Question 1 [3 points]:** Make a plot of the number of 'likes per day' versus day.  Label all of your axes.

# %%
import numpy as np
likes_per_day= np.array([   0,    0,  760,  430,  363,    0,  636,    0,  427,  231, 1077,
        150,  303, 1158,  867, 1384,  489,  707, 1430, 1986, 1420, 1923,
       1570, 2487, 2751, 3192, 2948, 2869, 3871, 4346])  # number of likes per day

day = np.arange(0,30, 1)  # each day data is recorded

# %%
# Put your pseudocode and  code here

# %%
### ANSWER
plt.plot(day,likes_per_day,'.')
plt.xlabel('day')
plt.ylabel('# of likes per day')
# Out:
# Text(0, 0.5, '# of likes per day')

# %% [markdown]
# ### Fitting Data
# &#9989;&nbsp; **Question 2 [5 points]:** Fit the `likes_per_day` versus `day` with a 1st order polynomial.  Make a plot of the original data and the results from the fitted function.

# %%
# Put your pseudocode and  code here

# %%
### ANSWER ####

fit1 = np.polyfit(day,likes_per_day,1)
f1 = np.poly1d( fit1 )
plt.plot(day,likes_per_day,'.')
plt.plot(day,f1(day),'g-')
plt.xlabel('day')
plt.ylabel('# of likes per day')
# Out:
# Text(0, 0.5, '# of likes per day')

# %% [markdown]
# &#9989;&nbsp; **Question 3 [2 points]:** Write the equation of the fitted 1st order polynomial function below.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your equation here *

# %%
### ANSWER ###
print('y = ', f1[1],'* x + ',f1[0] )
# Out:
# y =  124.15639599555062 * x +  -474.43440860215026

# %% [markdown]
# &#9989;&nbsp; **Question 4 [1 points]:** Based on this 1st order fitted model, complete this sentence:
#
# **Each day, the number of likes per day is increasing by on average `_____`.**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here *

# %% [markdown]
# &#9989;&nbsp; **Question 5 [4 points]:** Fit the `likes_per_day` versus `day` with a 2nd order polynomial.  Which model, a 1st order or 2nd order polynomial, fits this data better?  Justify your answer with an explanation.  (Potentially use plot to help with explanation)

# %%
# Put your pseudocode and  code here

# %%
### ANSWER ####

# 2nd order fits better, could argue that MSE is lower; Plot visually shows 2nd order looks like a better fit
fit1 = np.polyfit(day,likes_per_day,1)
f1 = np.poly1d( fit1 )
plt.plot(day,likes_per_day,'.')
plt.plot(day,f1(day),'g-',label='1st order')

fit2 = np.polyfit(day,likes_per_day,2)
f2 = np.poly1d( fit2 )
plt.plot(day,f2(day),'r--',label='2st order')


plt.xlabel('day')
plt.ylabel('# of likes per day')
# Out:
# Text(0, 0.5, '# of likes per day')

# %% [markdown]
# &#9989;&nbsp; **Question 6 [4 points]:** Part 1: Using the 1st or 2nd order model, assuming the trends, continue what would you expect to be the number of likes on day 40?  Use python code to `print()` the exact answer to this question.
#
# Part 2: Considering this is the popularity of your cat, should you plan for making a fortune on your cat?  Briefly justify your answer.

# %%
# Put your pseudocode and  code here

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your part 2 answer here.*
#
# 2.

# %%
### ANSWER ####

print('Number on day 40, 1st order: ', f1(40))
print('Number on day 40, 2nd order: ', f2(40))
# Out:
# Number on day 40, 1st order:  4491.821431219875
# Number on day 40, 2nd order:  8128.318594072779

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #4, and upload it there.

# %% [markdown]
# &#169; Copyright 2021,  Michigan State University Board of Trustees
