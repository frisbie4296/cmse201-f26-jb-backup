# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 (Sec 004)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging codeg code

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else..

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # Introduction
#
# Suppose you have decided to examine [Forecasted water temperature in offshore Lake Michigan](https://www.sciencebase.gov/catalog/item/66b78f02d34eebcf8bb3da75) to gain insights into the severity of underwater temperatures on the lake in the next 20 years. You found this dataset of simulated offshore temperatures for the year 2014, as observed from one site in the northern basin where the National Oceanic Atmospheric Administration (NOAA) has been maintaining a weather buoy since 1979.
#
# This dataset is a record of average daily offshore temperatures, and each column represents one of 20 vertical depths (ranging 4 to 159 m below the surface) at which the measurement is taken.

# %% [markdown]
# ---
# ## Part 1a) (20 points)
# **Using the test data below, write a function that takes an array of values as input and returns the mean, standard deviation, and median of those values. Demonstrate that your function works by calling it using the test data.** We are going to use this to analyze the data from the data file later in the quiz!
#
# Note: You are provided with both $x$ and $y$ data. You can use either to test your function.

# %%
# test data
import numpy as np
test_x = np.arange(0,10,1.0) # day of the year test data
test_y = [7.2813, 7.2782, 7.2564, 7.2185, 7.0878, 6.8292, 6.7631, 6.8228, 6.8514, 6.8182] # Offshore temperature test data


# PUT YOUR FUNCTION HERE

# %% [markdown]
# ## Part 1b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
# ## Part 2a) (10 points)
#
# Now that you have a function to learn about the data, it's time to load in some data! The file, `Quiz2_dataset.csv` has temperature data for **20** different vertical depths under water. The first column is the "Day of Year" of the measurements while the remaining columns are measurements taken at each depth (with the depths given by the negative values in the first row). Open the file in a editor of your choosing and **looking at the different columns, choose one column of data (other than "Day of Year") to explore.**
#
# **Using numpy (not pandas!), load the `Quiz2_dataset.csv` file into your notebook.** Inspect the data file and ensure that you only read in the columns you are interested in for full credit (i.e. "Day of Year" and your column of choice).

# %%
# PUT YOUR CODE HERE

# %% [markdown]
# ## Part 2b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
# ## Part 3 (8 points)
# Now that you have some data read in, it's time to do some analysis! **Using your function from Part 1**, calculate the mean, median, and standard deviation (using numpy) of your data column of choice. If you were unable to either write the function for part 1 or load the data in part 2, use the originally provided `test_x` and `test_y` data provided in question 1 for your data, and calculate the values without the function here for partial credit.

# %%
# Put your code here

# %% [markdown]
# ---
# ## Part 4a) (12 points)
# To share your insight, you want to create a summary plot of your data that includes the descriptive statistics. In the cell below, **use matplotlib to make a basic plot that visualizes the data column of your choice on the y-axis and the "Day of Year" on the x-axis.**
#
# **Your summary plot should also include the following:**
#
# * The mean
# * The median
# * The +/- standard deviation from the mean
#
# The mean, median, and standard deviations should be different linestyles and colors to differentiate them from each other
#
# Adjust your x and y ranges as needed in order for all of your information to be visible. You can choose to use a histogram, line plot, scatter plot, etc. Make sure to include appropriate labels for full credit!
#
# If you are unable to load data from the provided csv file, use the test data `test_x` and `test_y` to generate your plot for partial credit.

# %%
# Put your code here

# %% [markdown]
# ## Part 4b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Assignments" section, find the submission folder link for Quiz #2, and upload it there.
