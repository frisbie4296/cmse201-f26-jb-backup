# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 (Section 002)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging code

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # Introduction
# ## Analyzing Athletic Performance in Powerlifting
#
# You have landed your first data science internship at the Center for Obscure Sports. Your first assignment is to explore how overall performance in powerlifting changes with age. Your team lead has given you a datafile called `Quiz2_data_FS24-002.csv` that you are going to explore with Python to see what you can learn and share with your team.
#
# #### Background Information on Powerlifting for the Curious
# Powerlifting is a strength sport in which lifters compete for the highest total across their squat, bench press, and deadlift. Each competitor gets three attempts at each lift (squat, bench, and deadlift), and the best of the three attempts on each lift are added up to the competitor's "Total." The competitors are divided up into weight classes, and the competitor with the highest total in their weight class wins. If a lifter misses all three attempts for a squat, bench, or deadlift, they are disqualified and do not get a Total. A miss is any attempt that a competitor fails to complete as judged by the referees.
#
# The data is structured as follows:
# * Column 0: Competitor Age (in years)
# * Column 1: Competitor Bodyweight (in kilograms)
# * Column 2: Best Squat Attempt (in kilograms)
# * Column 3: Best Bench Press Attempt (in kilograms)
# * Column 4: Best Deadlift Attempt (in kilograms)

# %% [markdown]
# ## Part 1a) (20 points)
# **Using the test data below, write a function that takes an array of values as input and returns the mean, standard deviation, and median of those values. Demonstrate that your function works by calling it using the test data.** We are going to use this to analyze the data from the data file later in the quiz!
#
# Note: You are provided with both x and y data. You can use either to test your function.

# %%
# test data
import numpy as np
test_x = [ 7.5,  7.5,  7.5,  8.5,  9. ,  9.5,  9.5, 10. , 10. , 10.5, 10.5, 10.5, 11. , 11.5, 11.5, 11.5, 11.5, 11.5, 12. , 12.5] # Ages test data
test_y = [30.4, 34.8, 47.5, 60.2, 35., 34.8, 27.8, 58.06, 28.12, 77., 54., 44.5, 45.56, 57., 72.9, 69., 48., 78.4, 49.7, 50.5] # Competitor Bodyweight in kilograms


# PUT YOUR FUNCTION HERE

def my_function(values):
    return np.std(values), np.mean(values),np.median(values)

my_function(test_x)
# Out:
# (1.5022899187573615, 10.175, 10.5)

# %% [markdown]
# ## Part 1b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*
#
# I remembered that numpy has functions for computing those descriptive statistics. I remembered the structure of a function and used that to start writing the function. I formetted my function to take in one input and return the three values in order. I know my solution works because I did the calculations by hand and they match the output I got

# %% [markdown]
# ## Part 2a) (10 points)
#
# Now that you have a function to learn about the data, it's time to load in some data! The file, `Quiz2_data_FS24-002.csv` has data for all of the powerlifting meets held in Michigan that are present in the OpenPowerlifting dataset. **Looking at the different columns, choose one column of data (other than "Age") to explore.**
#
# **Using numpy (not pandas!), load the `Quiz2_data_FS24-002.csv` file into your notebook.** Inspect the data file and ensure that you only read in the columns you are interested in for full credit (i.e. "Age" and your column of choice).
#
# **Using matplotlib, make a basic plot that visualizes the data column of your choice on the y-axis and "Age" on the x-axis.** Make sure to include appropriate labels for full credit!
#
# Here is an example of a plot you could create (but yours should not be identical to this one):
# ![Example Part 2](part2a.png)

# %%
# PUT YOUR CODE HERE
import matplotlib.pyplot as plt
age, squat = np.loadtxt('Quiz2_data_FS24-002.csv',skiprows=1,usecols=[0,2],delimiter=',',unpack=True)
print(age,squat)
plt.plot(age,squat)
plt.xlabel('age')
plt.ylabel('squat weight (kg)')
# Out:
# [ 7.5  7.5  7.5 ... 77.  77.  77.5] [ 30.   17.5  35.  ... 170.  165.   75. ]
# Text(0, 0.5, 'squat weight (kg)')

# %% [markdown]
# ## Part 2b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*
# I did not use resources. I knew first I had to read in the file using loadtxt from the great lakes assignment. Then I got errors messages when I hit shift enter because I forgot to set the delimiter and the unpack arguments. After that, I was able to plot the age vs. the squat weight and add labels. I had to recall how to make plots and read in data, and I used my knowledge of the great lakes assignment for that. I know my solution works because the ages match human ages, and there is a squat weight for every age. I don't know what squat weights are reasonable, but they seem fine.

# %% [markdown]
# ## Part 3 (10 points)
# Now that you have some data read in, it's time to do some analysis! **Using your function from Part 1**, calculate the mean, median, and standard deviation (using numpy) of your data column of choice. If you didn't get your function in Part 1 to work, you can calculate the values without the function here for partial credit.

# %%
# Put your code here
std_sq,mean_sq,med_sq = my_function(squat)

# %% [markdown]
# ## Part 4a) (10 points)
# To share your insight, you want to create a plot of your data and the descriptive statistics. In the cell below, create this plot. It should include the following:
#
# * The column of data you chose
# * The mean
# * The median
# * The +/- standard deviation from the mean
# * The mean, median, and standard deviations should be different linestyles and colors to differentiate them from each other
#
# Adjust your x and y ranges as needed in order for all of your information to be visible. You can choose to use a histogram, line plot, scatter plot, etc.
#
# Here is an example of one kind of plot (but yours should **not** be identical to this one):
# ![Example Part 4](part_4a_example.png)

# %%
# Put your code here
plt.hist(squat)
plt.axvline(mean_sq,color='black')
plt.axvline(mean_sq+std_sq,color='springgreen')
plt.axvline(mean_sq-std_sq,color='springgreen')

# %% [markdown]
# ## Part 4b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
