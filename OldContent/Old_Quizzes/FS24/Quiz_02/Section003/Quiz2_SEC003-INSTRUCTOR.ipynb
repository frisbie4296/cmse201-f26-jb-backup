# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 Section 003
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging code

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ### ANSWER

# %% [markdown]
# ---
#
# # Introduction
#
# You have decided to examine the statistic data for [Women in STEM major](https://github.com/fivethirtyeight/data/blob/master/college-majors/women-stem.csv). You have found the following dataset.
#
# The data is structured as follows:
# * Column 0: `Rank` (Rank by median earnings)
# * Column 1: `Major_code` (Major code, FO1DP in ACS PUMS)
# * Column 2: `Major` (Major description)
# * Column 3: `Major_category` (Category of major)
# * Column 4: `Total` (Total number of people with major)
# * Column 5: `Men` (Male graduates)
# * Column 6: `Women` (Female graduates)
# * Column 7: `ShareWomen` (Women as share of total)
# * Column 8: `Median` (Median earnings of full-time, year-round workers)

# %% [markdown]
# ## Part 1a) (20 points)
# **Using the test data below, write a function that takes an array of values as input and returns the mean, standard deviation, and median of those values. Demonstrate that your function works by calling it using the test data.** We are going to use this to analyze the data from the data file later in the quiz!
#
# Note: You are provided with both x and y data. You can use either to test your function.

# %%
# test data
import numpy as np
index = np.arange(0,10,1.0) # indices for test data
temps = [282, 77, 131, 135, 373, 11021, 960, 10907, 2105, 16016] # Female student number


# PUT YOUR FUNCTION HERE

# %%
### ANSWER ###
index = np.arange(0,10,1.0) # indices for test data
temps = [282, 77, 131, 135, 373, 11021, 960, 10907, 2105, 16016] # Female student number

def do_stats(my_yvals):
    mean = float(np.mean(my_yvals))
    std_dev = float(np.std(my_yvals))
    median = float(np.median(my_yvals))
    return mean, std_dev, median

print(do_stats(temps))

#Rubric:
# 10 points for defining the function and having it return values
# 5 points for calculating the statistics
# 5 points for testing the function
# Out:
# (4200.7, 5710.438985752321, 666.5)

# %% [markdown]
# ## Part 1b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ## Part 2a) (10 points)
#
# Now that you have a function to learn about the data, it's time to load in some data! The file, `women-stem.csv` has data for one full year. **Looking at the different columns, choose two columns (not date) to import.**
#
# **Using numpy (not pandas!), load the `women-stem.csv` file into your notebook.** Inspect the data file and ensure that you only read in the columns you are interested in for full credit (i.e. your two column choices).
#
# **Using matplotlib, make a plot that visualizes the "correlation" of the two columns, one of the columns should appear on the x-axis and the other on the y-axis.** Make sure to include appropriate labels for full credit!

# %%
# PUT YOUR CODE HERE

# %%
### ANSWER

# Rubric
# 5 points for reading in the desired columns of data and defining variables
# 5 points for plotting the data
# 5 points for axis labels
import matplotlib.pyplot as plt
women, median = np.loadtxt('women-stem.csv',usecols=(6,8),skiprows=1, delimiter=',',unpack=True)

plt.scatter(women, median)
plt.xlabel('Female student number')
plt.ylabel('Median income')
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 2b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ## Part 3 (10 points)
# Now that you have some data read in, it's time to do some analysis! **Using your function from Part 1**, calculate the mean, median, and standard deviation (using numpy) of your data column of choice. If you didn't get your function in Part 1 to work, you can calculate the values without the function here for partial credit.
#
# You should store your results in variables, and print them out in a human-readable way. For example,
#
# The mean of my data is _____, the median is _____, and the standard deviation is _____.

# %%
# Put your code here

# %%
### ANSWER
medianmean, medianstddev, medianmedia = do_stats(median)

print('The mean median income is', medianmean, ', the median of median income is', medianmedia, ', and the standard deviation is', medianstddev)

# Rubric
# 5 points for calculating the statistics
# 5 points for printing the statistics
# Out:
# The mean median income is 45534.05263157895 , the median of median income is 43000.0 , and the standard deviation is 14048.64931501165

# %% [markdown]
# ## Part 4a) (10 points)
# To share your insight, you want to create a summary plot of your data and the descriptive statistics. In the cell below, create this summary plot. It should include the following:
#
# * The column of data you chose
# * The mean
# * The median
# * The +/- standard deviation from the mean
# * The mean, median, and standard deviations should be different linestyles and colors to differentiate them from each other
#
# Adjust your x and y ranges as needed in order for all of your information to be visible. You can choose to use a histogram, line plot, scatter plot, etc.

# %%
# Put your code here

# %%
### ANSWER ###

mean,stan,med = do_stats(median)
plt.hist(median)
plt.axvline(mean,color = 'k')
plt.axvline(mean+stan,color= 'pink',ls='--')
plt.axvline(mean-stan,color = 'pink',ls='--')

plt.xlabel('median income')
plt.ylabel('frequency')

# Rubric
# 2 points for plot
# 2 points for axis labels
# 2 points for mean line
# 2 points for standard deviation lines
# 2 points for median line
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# ### ANSWER ###
# Full credit for any response that includes all three components

# %% [markdown]
# ## Part 4b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
