# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 Section 005
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging code

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ### ANSWER
#
# # TEMPLATE INSTRUCTIONS
#
# This quiz should assess functions, numpy, and matplotlib. Specifically, we want to assess if students can load in a data file, explore it with some basic calculations, and visualize it in  a meaningful way. Use of numpy and matplotlib implicitly includes functions, but we also want to assess students' understanding of how to write and use their own functions.
#
# **Note:** One thing I noticed in grading Quiz 1 is that folks need a bit more time and a bit more scaffolding for answering questions about their solution pathways. Therefore, I recommend you allow **40 minutes** for the quiz, and make sure that your instructions for expectations on metacognition questions are explicit. If at all possible, use context clues and visual aids to help students for whom English is not their first language.
#
# Use Homework 2 questions as a guide for what they can be expected to know for this quiz (though the quiz will be shorter and simpler than a homework assignment)
#
# To that end, my suggested overarching structure for this Quiz is:
# * Write a function that takes in data and outputs a calculation and/or a plot (provide some "test" data to demonstrate that their function works (Note: This question can/should have the flexibility for them to write one or multiple functions, depending on how they see the solution to the problem).
# * Documenting Solution Pathway Question
# * Choose a data set (presented as a .csv file) with more than two columns of data (make sure they use numpy for this, not pandas)
# * Documenting Solution Pathway Question
# * Visualize the data in a simple manner (i.e. ask them to make a line plot or histogram, can include use of subplots)
# * Use a given function on the data file for calculations
#
# **Note:** While you can have the quiz have students explore a single thread of a problem, rather than disjointed problems, be attentive to places where students can earn partial credit throughout the quiz. For example, even if they can't get their function to work from the beginning of the quiz, they can still show you that they can load and plot data. If they can't load and plot the data, they could plot the test data. You can also include questions (as I have in the examples) where they can qualitatively discuss what they are doing.
#
# Below is an example of how this quiz could be written. If you use this structure, make sure to choose your own data set and make your quiz unique to your section!

# %% [markdown]
# ---
#
# # Introduction
#
# You have decided to investigate air quality in the United States.  You have found a [dataset from the World Health Organization](https://www.who.int/data/gho/data/themes/air-pollution/who-air-quality-database) which contains a variety of parameters.
#
# The data is structured as follows:
# * Column 0: `city` (the city where the observation occured)
# * Column 1: `pm10_concentration` (concentration of particulate matter smaller than 10 micrometers)
# * Column 2: `pm25_concentration` (concentration of particulate matter smaller than 2.5 micrometers)
# * Column 3: `no2_concentration` (concentration of nitrogen dioxide)
# * Column 4: `population` (the population of the city)
# * Column 5: `latitude` (the latitude of the city)
# * Column 6: `longitude` (the longitude of the city)
#
# (Note: The dataset provided has been cleaned to only include cities in the United States and data from the year 2021.  Rows where data is missing have been dropped.  The full dataset is MUCH bigger!)

# %% [markdown]
# ## Part 1a) (10 points)
# **Using the test data below, write a function that takes an array of values as input.  The function should return three values as output: the mean, standard deviation, and median of the input array. These values should be found using numpy functions. Demonstrate that your function works by calling it using the test data.** We are going to use this to analyze the data from the data file later in the quiz!
#
# Note: You are provided with two sets of test data. You can use either to test your function.

# %%
# STARTER CODE

# import numpy
import numpy as np
# population test data
test_pop = np.array([10256, 250453, 58634, 3859378, 194729, 20478, 4638273])
# pm25 test data
test_pm25 = np.array([6.37, 7.29, 10.68, 15.63, 7.84, 8.25, 4.31])


# PUT YOUR FUNCTION HERE

# %%
### ANSWER ###

# population test data
test_pop = np.array([10256, 250453, 58634, 3859378, 194729, 20478, 4638273])
# pm25 test data
test_pm25 = np.array([6.37, 7.29, 10.68, 15.63, 7.84, 8.25, 4.31])

def do_stats(my_yvals):
    return np.mean(my_yvals),np.std(my_yvals),np.median(my_yvals)

print(do_stats(test_pm25))

#Rubric:
# 2.5 points for defining a function
# 2.5 points for having it return values
# 2.5 points for calculating the statistics
# 2.5 points for testing the function
# Out:
# (8.624285714285715, 3.3708068433996936, 7.84)

# %% [markdown]
# ## Part 1b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?
#
# If you were unable to complete this problem, describe how you know it does not work, how you would approach the problem, and how you would verify that your code works.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ## Part 2a) (10 points)
#
# Now that you have a function to learn about the data, it's time to load in some data! The file, `who_ambient_air_quality_cleaned.csv` has data for 70 US cities. **Looking at the different columns, choose two columns of data (other than `city`, `latitude`, or `longitude`) to explore.**
#
# **Using numpy (not pandas!), load the `who_ambient_air_quality_cleaned.csv` file into your notebook.** Inspect the data file and ensure that you only read in the two columns you are interested in for full credit.
#
# **Using matplotlib, make a scatter plot that visualizes the "correlation" of the data you chose. One column should be on the x-axis and the other column should be on the y-axis.** *Make sure to include appropriate axis labels for full credit!*

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# PUT YOUR CODE HERE

# %%
### ANSWER

# Rubric
# 4 points for reading in the data
# 4 points for plotting the data
# 2 points for axis labels
import matplotlib.pyplot as plt
# %matplotlib inline
pop,pm25 = np.loadtxt('who_ambient_air_quality_cleaned.csv',usecols=(4,2),skiprows=1,delimiter=',',unpack=True)

plt.scatter(pop,pm25)
# plt.ylim(0,550000)
plt.xlabel('Population')
plt.ylabel('Concentration of pm 2.5')
# Out:
# Text(0, 0.5, 'Concentration of pm 2.5')

# %% [markdown]
# ## Part 2b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?
#
# If you were unable to complete this problem, describe how you know it does not work, how you would approach the problem, and how you would verify that your code works.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ## Part 3 (10 points)
# Now that you have some data read in, it's time to do some analysis! **Using your function from Part 1**, calculate the mean, median, and standard deviation (using numpy) of one of the columns you chose in Part 2.
#
# If you didn't get your function in Part 1 to work, you can calculate the values without the function here for partial credit.
#
# If you couldn't read in the data in Part 2, you can use the test data from Part 1 for partial credit.

# %%
# Put your code here

# %%
### ANSWER
do_stats(pm25)
# Out:
# (8.48537142857143, 2.055208235340703, 8.15)

# %% [markdown]
# ## Part 4a) (10 points)
# To share your insight, you want to create a summary plot of your data and the descriptive statistics. In the cell below, create this summary plot. The summary plot can be a **histogram, line plot, scatter plot, or other type of plot**, as long as it can convey the relevant information.  It should include the following:
#
# * The column of data you chose
# * Axis labels
# * The mean
# * The median
# * Mean + standard deviation
# * Mean - standard deviation
# * The mean, median, and standard deviations should be different linestyles and colors to differentiate them from each other
#
# If needed, adjust your x and y ranges in order for all of your information to be visible.

# %%
# Put your code here

# %%
### ANSWER ###

mean,stan,med = do_stats(pm25)
plt.hist(pm25)
plt.axvline(mean,color = 'r')
plt.axvline(mean+stan,color= 'pink',ls='--')
plt.axvline(mean-stan,color = 'pink',ls='--')
plt.axvline(med, color = 'k')

plt.xlabel('Concentration of PM2.5')
plt.ylabel('frequency')

# Rubric
# 2 points for plot
# 2 points for axis labels
# 2 points for mean line
# 2 points for standard deviation lines
# 2 points for median line
# Out:
# Text(0, 0.5, 'frequency')

# %%
### ANSWER ###

mean,stan,med = do_stats(pm25)
plt.plot(pm25)
plt.axhline(mean,color = 'r')
plt.axhline(mean+stan,color= 'pink',ls='--')
plt.axhline(mean-stan,color = 'pink',ls='--')
plt.axhline(med, color = 'k')

plt.xlabel('index')
plt.ylabel('Concentration of PM2.5')

# Rubric
# 2 points for plot
# 2 points for axis labels
# 2 points for mean line
# 2 points for standard deviation lines
# 2 points for median line
# Out:
# Text(0, 0.5, 'Concentration of PM2.5')

# %% [markdown]
# ### ANSWER ###
# Full credit for any response that includes all three components

# %% [markdown]
# ## Part 4b) Documenting Your Solution Pathway (10 points)
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start?
# 2. What prior knowledge did you recall to solve the problem?
# 3. How do you know that your solution works?
#
# If you were unable to complete this problem, describe how you know it does not work, how you would approach the problem, and how you would verify that your code works.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
