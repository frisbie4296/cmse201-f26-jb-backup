# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 3 (Sec 006 Fall 2024)
#
# The goal of this quiz is to give you the opportunity to test out more of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your more recently acquired programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of <font color="red">**90**</font> points possible on this quiz and each part of the quiz can be done independently. **If you get stuck _move on to another part of the quiz to earn some points there!_**

# %% [markdown]
# ### ANSWER (for making sure this gets removed) ###
#
# ## Template Guidelines
#
# **Learning Objectives from Homework 3:**
# - Using pandas to work with data and clean it
# - Make meaningful visual representations of the data
# - Fitting curves to data and evaluating model fit
#
# **Learning Objectives the Quiz will assess:**
# * Loading and manipulating (e.g. filtering, calculating basic statistics) data using Pandas
# * Using curve_fit to fit models to data and find best fit model parameters
# * Using best fit parameters to calculate expected model values
# * Visualizing data and models using matplotlib
#
# **Quiz Duration:** 30 minutes (ideally, time can be extended slightly if needed)
# * This means your TAs/LAs should be able to complete the quiz in at most 10 minutes (if TA/LA completion time is closer to 15, consider extending quiz to 40 minutes)
#
# **Notes:**
# * The structure and rubric provided here is a suggestion and an example of the difficulty level expected. However, as long as your quiz assesses the learning objectives listed under "Learning Objectives the Quiz will assess" section above, you can differ from this structure. If you aren't sure that your quiz does that, run it by another instructor (lead isntructor, other faculty, TA, or LA)
# * The examples provided are examples and **should not be used directly without changes in any quizzes**
# * These quizzes are important for students to assess how well they understand the material independent of their groups, so when grading, be sure to provide feedback on where points were deducted. **You should also have a clear rubric with clearly stated point values, but you do not need to follow the point values included in this template**.
# * Quizzes should be written with ample time for TAs/LAs to review! **Your TA and LAs should have at least 48 hours to review the quiz before it is given**.
# * Quizzes (and instructor solution with point-by-point rubrics) should be **pushed to the GitHub repo for record-keeping**. Put your section's version in a sub-folder with the name `Section-###` where "###" is your section number.
#
# **Overall Structure:**
#
# 1. A section that focuses on assessing if students correctly load a CSV file (that they haven't seen before) using Pandas and then explores if they have mastered the ability to mask data for the purposes of filtering the data and can calculate basic statistical values.
# 2. A section that uses some provided data (so as not to penalize them again for not having mastered loading data) and a model function to find the best fit parameters for the model using curve_fit. This question should also assess if they can use those best fit parameters to produce the expected model values and then use matplotlib to visualize their model and compare it to the data.
# 3. It is also strongly recommended that you include documenting solution pathways questions!

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.
#
# **NOTE: If you use generative AI, you must copy/paste into a cell in this quiz (1) your prompt, (2) the output from chatGPT, and (3) Write your answer in separate cells. Failure to include this level of detail will result in a deduction of points.**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # 1. Analyzing Mobile Phone Usage (50 points)
#
# You have landed your first data science internship at a form focused on reducing mobile phone use. Your first assignment is to explore how folks are using their phones. Your team lead has given you a datafile called `user_behavior_dataset.csv` that you are going to explore with `pandas` and other python modules to see what you can learn and share with your team.
#
# #### Background Information on the Data
#
# These [data come from real phone usage](https://www.kaggle.com/datasets/valakhorasani/mobile-device-usage-and-user-behavior-dataset?resource=download), but have been de-identified. The data includes the following columns:
# * Device Model: The model of the phone
# * Operating System: The operating system of the phone
# * App Usage Time (min/day): The average time spent using apps on the phone per day
# * Screen On Time (hours/day): The average time the screen is on per day
# * Battery Drain (mAh/day): The average battery drain per day
# * Number of Apps Installed: The number of apps installed on the phone
# * Data Usage (MB/day): The average data usage per day
# * Age: The age of the user
# * Gender: The binary gender of the user
# * User Behavior Class: Classification of user behavior based on usage patterns (1 to 5)
#
# #### &#9989;&nbsp; **Question 1.1 (5 points)**
# Load the `user_behavior_dataset.csv` file provided on D2L **using Pandas** and display the first 10 rows.

# %%
# Let's make sure pandas is imported
import pandas as pd

# Put your code here

# %%
### ANSWER
import pandas as pd

pl = pd.read_csv("user_behavior_dataset.csv")
pl.head(10)

## Rubric
# 2 points for reading the data
# 2 points for displaying the read data
# 1 point for displaying only the first 10 rows of the data
## Possible Scores
# 5 -Completely correct
# 4 - Printing the first 10 rows is missing
# 2 - Read the data but did not display it
# 0 - No attempt
# Out:
#    User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0        1      Google Pixel 5          Android                       393
# 1        2           OnePlus 9          Android                       268
# 2        3        Xiaomi Mi 11          Android                       154
# 3        4      Google Pixel 5          Android                       239
# 4        5           iPhone 12              iOS                       187
# 5        6      Google Pixel 5          Android                        99
# 6        7  Samsung Galaxy S21          Android                       350
# 7        8           OnePlus 9          Android                       543
# 8        9  Samsung Galaxy S21          Android                       340
# 9       10           iPhone 12              iOS                       424
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# ...

# %% [markdown]
# #### &#9989;&nbsp; **Question 1.2 (15 points)**
# You want to narrow down your analysis to just one age group. Choose a range of ages (including at least 5 years - e.g. 30-34). **You get to choose the age range**.
#
# Create a mask that filters the data to show only the rows that match the age range you chose.
#
# **Display that dataframe once you've created it**, to confirm that you did it correctly.
#
# **Note**: if you didn't get the dataset loaded correctly, try your best to write the code that **should** appropriately mask the data for partial credit. Or explain what you would do with pseudocode.

# %%
# Put your code here

# %%
### ANSWER
df_young = pl[(pl["Age"] >= 18) & (pl['Age'] <=25) ]
df_young.head(10)

# Rubric
# 5 points for any masking attempt
# 5 points for a correct mask
# 5 points for display
## Possible Scores
# 15 - Completely correct
# 10 - Masking attempt but no incorrect mask
# 10 - Masking attempt but no display, correct mask
# 5 - Masking attempt but no display, incorrect mask
# 0 - No attempt
# Out:
#     User ID        Device Model Operating System  App Usage Time (min/day)  \
# 3         4      Google Pixel 5          Android                       239
# 6         7  Samsung Galaxy S21          Android                       350
# 11       12           OnePlus 9          Android                       215
# 22       23  Samsung Galaxy S21          Android                       423
# 29       30  Samsung Galaxy S21          Android                       412
# 31       32        Xiaomi Mi 11          Android                       197
# 32       33      Google Pixel 5          Android                       278
# 35       36  Samsung Galaxy S21          Android                        32
# 37       38  Samsung Galaxy S21          Android                       522
# 39       40  Samsung Galaxy S21          Android                       398
#
#     Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 3                          4.8                     1676
# ...

# %% [markdown]
# #### &#9989;&nbsp; **Question 1.3 (10 points)**
#
# Finally, you are curious about the average (mean) app usage, number of apps, and data usage. Write a function that takes in your filtered data frame and relevant columns and returns the mean of those data. Use your function to calculate and display the mean of the app usage, number of apps, and data usage for the age group you chose. You can store the means in variables or print them directly.
#
# **Note #1**: there's more than one way you could do this.
#
# **Note #2**: if you didn't get the dataset loaded correctly, try your best to write the code that **should** calculate and display the mean for partial credit.
#
# **Note #3**: If you are having trouble writing the function, you can calculate the means directly in the code cell for partial credit.

# %%
# Put your code here

# %% [markdown]
# From the output of your code, what is the average (mean) app usage, number of apps, and data usage?

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here*

# %%
### ANSWER

def computeMean(dataframe, column):
    return dataframe[column].mean()

meanAppUseYoung = computeMean(df_young, 'App Usage Time (min/day)')
meanNumberAppsYoung = computeMean(df_young, 'Number of Apps Installed')
meanDataUsageYoung = computeMean(df_young, 'Data Usage (MB/day)')

print(f"Mean App Usage Time for young people: {meanAppUseYoung} min/day")
print(f"Mean Number of Apps Installed for young people: {meanNumberAppsYoung} apps")
print(f"Mean Data Usage for young people: {meanDataUsageYoung} MB/day")

# Rubric
# 4 points for a correct function
# 1 point for each correct mean
# 1 point for each correct print
## Possible Scores
# 10 - Completely correct
# 9, 8, 7, 6, 5 - depending on the number of correct means and prints
# 6 - no function, but correct means and prints
# 4 - Correct function but no correct means or prints
# 0 - No attempt
# Out:
# Mean App Usage Time for young people: 288.2442748091603 min/day
# Mean Number of Apps Installed for young people: 54.213740458015266 apps
# Mean Data Usage for young people: 976.7251908396946 MB/day

# %% [markdown]
# #### &#9989;&nbsp; **Question 1.4 Documenting Your Solution Pathway (20 points)**
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start? (10 points for solution pathway)
# 2. What prior knowledge did you recall to solve the problem? (5 points for prior knowledge and resources)
# 3. How do you know that your solution works? (5 points for how you can check your work)
#
# **If you did not use external resources, you still must answer the three questions above to receive full credit.**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %%
### ANSWER:
# Will vary based on student response.

## Rubric
# 10 points for solution pathway
# 5 points for prior knowledge and tools
# 5 points for how you know your solution works

# %% [markdown]
# ---
# # 2. Fitting a model to data with `curve_fit` and visualizing the results (40 points)
#
# You are taking a course on signal analysis and have been given a dataset the represents a signal to fit. The data are stored in two arrays appearing below and these are combined into a data frame.
#
# * `signal['time']` is the time in seconds for the signal
# * `signal['voltage']` is the voltage of the signal
#
# **Run the cell below to load and plot the data.**

# %%
# RUN THIS CELL to make sure you have the dataset loaded
# Make sure of imports
import pandas as pd
import matplotlib.pyplot as plt

time = [0.0, 1.5, 3.0, 4.5, 6.0, 7.5, 9.0, 10.5, 12.0, 13.5, 15.0, 16.5, 18.0, 19.5, 21.0, 22.5, 24.0, 25.5, 27.0, 28.5, 30.0, 31.5, 33.0, 34.5, 36.0, 37.5, 39.0, 40.5, 42.0, 43.5, 45.0, 46.5, 48.0, 49.5, 51.0, 52.5, 54.0, 55.5, 57.0, 58.5, 60.0, 61.5, 63.0, 64.5, 66.0, 67.5, 69.0, 70.5, 72.0, 73.5, 75.0, 76.5, 78.0, 79.5, 81.0, 82.5, 84.0, 85.5, 87.0, 88.5, 90.0, 91.5, 93.0, 94.5, 96.0, 97.5, 99.0, 100.5, 102.0, 103.5, 105.0, 106.5, 108.0, 109.5, 111.0, 112.5, 114.0, 115.5, 117.0, 118.5, 120.0, 121.5, 123.0, 124.5, 126.0, 127.5, 129.0, 130.5, 132.0, 133.5
ig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(signal['time'], signal['voltage'], 'o')  
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# #### &#9989;&nbsp; **Question 2.1 (10 points):**
#
# Using the data and provided model below, use `curve_fit` to find best fit parameters for *a, b,* and *c*. Based on the shape of the data, we are fitting with a sine curve:
#
# $$a*\sin(b*t)+c$$
#
# Make sure you give `curve_fit` a good starting point for finding the best fit parameters using the `p0` argument and these starting values:
# * $a$ = 4
# * $b$ = 0.2
# * $c$ = 1
#
# Once you've found the best values, **print them out**. You should find that they are not far off from, but not the same as, the original values that your friend gave you.

# %%
# Will need to use NumPy for the function
import numpy as np

# Will need to import curve_fit from SciPy
from scipy.optimize import curve_fit

# This function calculates volts corresponding to time for a sound wave
def sine_wave(t,a,b,c):
    return a*np.sin(b*t)+c

# %%
# Put your code here

# %%
### ANSWER
params,ignore = curve_fit(sine_wave,signal['time'],signal['voltage'],p0=[4,0.20,1])
print(params)

# rubric
# 2 pts for using model function correctly
# 2 pts for using data correctly
# 3 pts for p0 correct
# 3 pts for printing
## Possible Scores
# 10 - Completely correct
# 7 - correct call no print; or incorrect call (i.e., p0) but printed
# 4 - basic call; no p0 and no print
# 2 - for any effort
# 0 - No attempt
# Out:
# [3.11107621 0.20320463 0.5392182 ]

# %% [markdown]
# #### &#9989;&nbsp; **Question 2.2 (10 points)**
#
# Now that you have a set of best fit parameters, **use those parameters to calculate the expected model values and plot the expected model values on top of the actual data values**. Make sure to label your axes and include a legend to communicate what parts of the plot correspond to the model versus the data.

# %%
# Make sure we import matplotlib
import matplotlib.pyplot as plt

# Put your code here

# %%
### ANSWER ###

# Make sure we import matplotlib
import matplotlib.pyplot as plt

plt.scatter(signal['time'], signal['voltage'], label='data')
plt.plot(signal['time'],sine_wave(signal['time'],params[0],params[1],params[2]), 'C1', label='fit')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.grid()
plt.legend()
plt.tight_layout()

# Rubric
# 2 points for scatter plot
# 2 points for line plot
# 2 points for correct parameters for line plot
# 2 points for labels
# 2 points for legend
## Possible Scores
# 10 - Completely correct
# 8 - missing one of the above
# 6 - missing two of the above
# 4 - missing three of the above
# 2 - missing four of the above
# 0 - No attempt

# %% [markdown]
# #### &#9989;&nbsp; **Question 2.3 Documenting Your Solution Pathway (20 points)**
#
# **Describe in detail** how you solved the problem including any external resources you consulted (e.g. generative AI **prompts and outputs**, past assignments, Code Portfolio, Stack Overflow, Google, etc.) and how they informed your approach. You must also describe how you know your solution works (e.g. and calculations you made, tests you ran, etc.)
#
# If you did not use external resources, describe your thought process for solving the problem by answering the following questions:
# 1. How did you know where to start? (10 points for solution pathway)
# 2. What prior knowledge did you recall to solve the problem? (5 points for prior knowledge and resources)
# 3. How do you know that your solution works? (5 points for how you can check your work)
#
# **If you did not use external resources, you still must answer the three questions above to receive full credit.**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %%
### ANSWER:
# Will vary based on student response.

## Rubric
# 10 points for solution pathway
# 5 points for prior knowledge and tools
# 5 points for how you know your solution works

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #3, and upload it there.
