# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 4 (SEC 006 Fall 2024)
#
# The goal of this quiz is to give you the opportunity to test out more of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your more recently acquired programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of <font color="red">**110**</font> possible on this quiz. **If you get stuck any particular question, do you your best to provide what your solution *might* look like for later parts of the exam in order to create opportunities for partial credit.**
#
# <font color="violet">**THERE IS A 10 POINT BONUS QUESTION AT THE END QUESTION 1 OF THE QUIZ!**</font>

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# ## Part 1: Modeling a system using `solve_ivp` (40 points)

# %% [markdown]
# #### Objective:
#
# We will model and visualize the [Rössler attractor](https://en.wikipedia.org/wiki/R%C3%B6ssler_attractor), which is a set of three coupled nonlinear ordinary differential equations (ODEs). The Rössler system is a prime example of a chaotic dynamical system, where small variations in initial conditions can lead to vastly different outcomesâa phenomenon known as the [Butterfly Effect](https://en.wikipedia.org/wiki/Butterfly_effect). This makes it an invaluable tool for understanding the fundamental principles underlying complex systems and [chaos theory](https://en.wikipedia.org/wiki/Chaos_theory).
#
# The insights gained from studying the Rössler attractor can contribute to broader scientific understanding. Chaos theory has applications in various fields, including physics, engineering, biology, and economics. Understanding chaotic systems like the Rössler attractor also enhances our ability to analyze real-world phenomena that exhibit similar characteristics, from weather patterns and financial markets to biological processes. By exploring these systems, researchers can better predict and control complex behaviors, which is crucial for developing more accurate models and making informed decisions.
#
# Knowledge about chaotic systems like the Rössler attractor can foster a greater appreciation of the beauty and complexity inherent in nature. It demonstrates how even simple mathematical equations can give rise to intricate patterns and behaviors that are both mesmerizing and profound.
#
# #### Mathematical Model:
# The Rössler equations are given by:
#
# $$
# \begin{align*}
# \frac{dx}{dt} &= -y - z \\
# \frac{dy}{dt} &= x + ay \\
# \frac{dz}{dt} &= b + xz - cz
# \end{align*}
# $$
#
# where \(a = 0.2\), \(b = 0.2\), and \(c = 5.7\) are parameters that can be adjusted to explore different behaviors of the system. Another common set of parameters is \(a = 0.1\), \(b = 0.1\), and \(c = 14\).
#
# #### Initial Conditions:
#
# When we start the modeling process, we will use the following initial conditions for each variable:
# - $x(0) = 0.1$
# - $y(0) = 0.1$
# - $z(0) = 0.1$
#
# #### Time Range and Timestep:
# - Evolve the model for 100 time units.
# - Use a timestep of $\Delta t = 0.01$ time units.
#
# #### Tasks:
# 1. **Write a Python function that calculates the derivatives for the Rössler equations** using these parameters.
# 2. **Set up the initial conditions and time range**.
# 3. **Use `solve_ivp` from SciPy to solve the system of ODEs**.
# 4. **Unpack the solution and plot the attractor in 2D** to visualize its behavior.
# 5. (BONUS) **Plot the attractor in 3D** to explore its structure further.
#
# ### Code you need to write to solve this problem:
# * A function that takes in a set of time values as well as the current values for $x$, $y$, and $z$ and **returns** the derivatives for each variable, $\frac{dx}{dt}$, $\frac{dy}{dt}$, and $\frac{dz}{dt}$. This would be your "derivatives" function that `solve_ivp` needs.
# * A set of variables for storing your initial conditions, $x_0$, $y_0$, and $z_0$, set to the correct initial values.
# * A variable that stores all the times for which you want to solve the system of ODEs, you can generate these times using `np.arange()`. The times should match the time range and timestep size specified above.
# * Code that calls `solve_ivp` using all of the appropriate arguments and stores the result.
# * Code that unpacks the solution so that you can plot it.
#
# **Note**: you will not need the "`args`" argument for `solve_ivp` for this case because any model parameters that might be needed for this system are provided directly as numbers in the set of  ODEs include above.

# %% [markdown]
# &#9989;&nbsp; **Question 1 (30 points)**:
#
# For 50 time units, solve the RÃ¶ssler equations using the parameters \(a = 0.2\), \(b = 0.2\), and \(c = 5.7\). Your code should use a function for the derivatives, set up the initial conditions and time range, use `solve_ivp` to solve the system of ODEs, and unpack the solution.
#
# **Show that you can print the first few values of the solution to demonstrate that you have successfully solved the system of ODEs.**

# %%
# The import commands you need are provided here
from scipy.integrate import solve_ivp
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D ## Only for the BONUS question

# Put your code here

# %% [markdown]
# &#9989;&nbsp; **Question 2 (5 points)**:
# Now that you have a solution to the model, make a single plot that displays the spatial evolution of two of the variables. Let's focus on $x$ and $y$. Make a plot of the solution $x$ vs. $y$. You should select a color and your plot should contain a $x$-axis label, a $y$-axis label, and a legend.
#
# If all goes well, you should end up with something that looks like this:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f5/RosslerAttractor.svg/640px-RosslerAttractor.svg.png" alt="Rossler X-Y" border="0" width=500>
#
# <font color="violet">**Due to the sensitivity to initial conditions and integration method (i.e., the starting conditions and the precision of the integrator), the plot of the Rössler attractor you make might look different from the one shown above. But it should be qualitatively similar.**</font>

# %%
# put your code here

# %% [markdown]
# &#9989;&nbsp; **Question 3 (5 points)**:
#
# Great! Now make a plot of two other different variables, either $x$ vs. $z$ or $y$ vs. $z$. Make sure to include axes labels. **You only need to make one plot for this question.**

# %%
# put your code here

# %% [markdown]
# &#9989;&nbsp; **BONUS Question 4 (10 points)**:
#
# Using the solution you have, make a 3D plot of the RÃ¶ssler attractor. You can use the `mpl_toolkits.mplot3d` module to create a 3D plot. Make sure to include axes labels and a title. **You only need to make one plot for this question.**
#
# If you've done everything correctly, you should end up with something that looks like this:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/75/Roessler_attractor.png/480px-Roessler_attractor.png" alt="Rossler XYZ" border="0" width=480>
#
# <font color="violet">**Due to the sensitivity to initial conditions and integration method (i.e., the starting conditions and the precision of the integrator), the plot of the Rössler attractor you make might look different from the one shown above. But it should be qualitatively similar.**</font>

# %%
# put your code here

# %% [markdown]
# ## Part 2: Data Visualization (50 points)
#
# Below are several different data visualizations. Using what you have learned in class and in the homework about what makes a data visualization good, bad, or somewhere in between, choose **three** visualizations to assess through the following questions.
#
# &#9989;&nbsp; **Question 1 (10 points per visualization - 30 points total)**:
#
# Examine the visualization (and any accompanying text). In your own words, articulate your interpretation of the story the visualization is trying to convey.
#
# &#9989;&nbsp; **Question 2 (20 points total)**: Grade the visualization using the rubric and provide justification for your scores for each category.
#
# 1. **Does the plot tell a story? (4 Points)**
# 2. **No wasted space (2 points)**
# 3. **Labels, legend, and title are informative without cluttering (1 points)**
# 4. **Presenting multi-variable data (1 points)**

# %% [markdown]
# ### Visualizations to Choose From
#
# <style>
#   .visualization-container {
#     display: flex;
#     flex-wrap: wrap;
#     justify-content: space-around;
#   }
#   .visualization-item {
#     flex: 0 1 45%;
#     margin: 10px;
#     padding: 10px;
#     border: 1px solid #ddd;
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
#     text-align: center;
#   }
#   .visualization-item img {
#     max-width: 100%;
#     border-radius: 8px;
#   }
#   .visualization-item h3 {
#     margin-bottom: 10px;
#   }
# </style>
#
# <div class="visualization-container">
#   <div class="visualization-item">
#     <h3>Visualization 1</h3>
#     <img src="https://github.com/msu-cmse-courses/cmse201-supplemental/blob/main/bad_data_viz/Picture2.jpg?raw=true" alt="Visualization 1">
#   </div>
#
#   <div class="visualization-item">
#     <h3>Visualization 2</h3>
#     <img src="https://github.com/msu-cmse-courses/cmse201-supplemental/blob/main/bad_data_viz/Screenshot 2023-11-29 at 4.32.57â¯PM.png?raw=true" alt="Visualization 2">
#   </div>
#
#   <div class="visualization-item">
#     <h3>Visualization 3</h3>
#     <img src="https://github.com/msu-cmse-courses/cmse201-supplemental/blob/main/bad_data_viz/badGraphic.png?raw=true" alt="Visualization 3">
#   </div>
#
#   <div class="visualization-item">
#     <h3>Visualization 4</h3>
#     <img src="https://github.com/msu-cmse-courses/cmse201-supplemental/blob/main/bad_data_viz/image (7).png?raw=true" alt="Visualization 4">
#   </div>
#
#   <div class="visualization-item">
#     <h3>Visualization 5</h3>
#     <img src="https://github.com/msu-cmse-courses/cmse201-supplemental/blob/main/bad_data_viz/image (2).png?raw=true" alt="Visualization 5">
#   </div>
#
#   <div class="visualization-item">
#     <h3>Visualization 6</h3>
#     <img src="https://github.com/msu-cmse-courses/cmse201-supplemental/blob/main/bad_data_viz/image (6).png?raw=true" alt="Visualization 6">
#   </div>
#
#   <div class="visualization-item">
#     <h3>Visualization 7</h3>
#     <img src="https://github.com/msu-cmse-courses/cmse201-supplemental/blob/main/bad_data_viz/image (9).png?raw=true" alt="Visualization 7">
#   </div>
#
#   <div class="visualization-item">
#     <h3>Visualization 8</h3>
#     <img src="https://github.com/msu-cmse-courses/cmse201-supplemental/blob/main/bad_data_viz/whimsical_squid.png?raw=true" alt="Visualization 8">
#   </div>
# </div>

# %% [markdown]
# **QUESTION 1 RESPONSES HERE**

# %% [markdown]
# **QUESTION 2 RESPONSES HERE**
