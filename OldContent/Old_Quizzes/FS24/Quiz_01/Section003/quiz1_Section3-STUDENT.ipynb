# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201 Section 3: Quiz 1
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. You are expected to cite all of your sources and indicate how you used them. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **You may use generative AI tools, but like all sources, we expect that you document and describe the resources you used and how you used them!**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ---
# # Academic integrity statement [10 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # 1. Manipulating Lists with Loops (10 points)
# Problem Context: Choose an engaging scenario that involves lists!
#
# Example: You are cleaning the kitchen to move various items around.
#
# ### &#9989;&nbsp; Write a `for` loop to filter out only the vegetables from a list of food and store them in a new list.
#
# ### &#9989;&nbsp; Metacognition
# Describe how your solution correctly identifies the target vegetables and why the loop method you chose is effective.
#
# What resources did you consult, and how did they inform your approach? Include any past assignments, urls, generative AI prompts/outputs, as well as how you used them.

# %%
# put your code here!

foods = ["Bread", "Beef", "Lettuce", "Tomato", "Carrot"]
vegetables = []

# %%
### ANSWER


# RUBRIC
# 5 pts for correctly creating a creating a new list with vegetables using a loop
# 5 pts for providing resources and describing approach in detail

# %% [markdown]
#  <font size=6 color="#009600">&#9998;</font> YOUR EXPLANATION GOES HERE

# %% [markdown]
# ---
# # 2. Problem Context: Converting between `for` loops and `while` loops (10 points)
#
# ### &#9989;&nbsp; Watering Plants and Checking for Extra Water
# You are a gardener responsible for taking care of four different plants. You have a list of plants, and your task is to water each plant. Additionally, for some plants, you need to check if they require extra water.
#
# Here are the specific tasks:
#
# Water each plant: You will iterate over a list of plant names and print out a message saying you are watering each one.
# Check for extra water needs: If a plant is at an index = 2, print a message indicating that this plant needs extra water.
#
# You must implement this solution using both a for loop and a while loop.
#
# ### &#9989;&nbsp; Metacognition
# Explain the differences between using a for loop and a while loop in this context. What made your while loop achieve the same result?
#
# What resources did you consult, and how did they inform your approach? Include any past assignments, urls, generative AI prompts/outputs, as well as how you used them.

# %%
# put your code here

plants = ["Aloe Vera", "Spider Plant", "Cactus", "Fern"]

# %%
### ANSWER

# RUBRIC
# 5 pts for correctly converting the for loop to a while loop with the same output
# 5 pts for providing resources and describing approach in detail

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> PUT YOUR ANSWER HERE

# %% [markdown]
# ---
#
# # 3. Problem Context: Using if/else Statements to Control Flow (10 points)
#
# ### &#9989;&nbsp; Problem Description: Categorizing Animals by Age for Treatment
# You're working as a veterinarian at a wildlife rescue center, and your task is to categorize animals based on their age into "Young," "Adult," or "Senior" categories for treatment purposes.
#
# Animals are categorized as:
#
# Young: Animals younger than 2 years.
# Adult: Animals between 2 and 8 years.
# Senior: Animals older than 8 years.
#
# ### &#9989;&nbsp; Metacognition
# How do you know that your code is working?
#
# What resources did you consult, and how did they inform your approach? Include any past assignments, urls, generative AI prompts/outputs, as well as how you used them.

# %%
# put your code here

age = 5  # Example age of the animal

# %%
### ANSWER
        
# RUBRIC
# points for correctly formatted if/elif else statements
# points for reasoning about how they know code works
# points for including resources

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# # 4. Using Loops for Calculations (10 points)
#
# ### &#9989;&nbsp; Calculating Total Revenue at an Electronics Store
# You sell smartphones, laptops, headphones, and tablets. Each has a different price, and you know how many units of each were sold. Your task is to compute the total revenue for each item and the overall revenue for the day.
#
# ### &#9989;&nbsp; Metacognition
# How do you know that your code is working?
#
# What resources did you consult, and how did they inform your approach? Include any past assignments, urls, generative AI prompts/outputs, as well as how you used them.

# %%
# put your code here

device_prices = [699.99, 1299.99, 199.99, 349.99]  # Prices for smartphones, laptops, headphones, and tablets
device_quantities = [15, 7, 25, 10]  # Quantities sold for each device
device_names = ["Smartphones", "Laptops", "Headphones", "Tablets"]

# %%
### ANSWER

# RUBRIC
# points for code that runs and produces the appropriate output
# points for reasoning
# points for resources

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #1, and upload it there.
