# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 Section 006
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging code

# %% [markdown]
# ---
# # Academic integrity statement [10 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ### ANSWER
#
# # TEMPLATE INSTRUCTIONS
#
# This quiz should assess functions, if/else, numpy, and matplotlib. Specifically, we want to assess if students can load in a data file, explore it with some basic calculations, and visualize it in  a meaningful way. Use of numpy and matplotlib implicitly includes functions, but we also want to assess students' understanding of how to write and use their own functions.
#
# Use Homework 2 questions as a guide for what they can be expected to know for this quiz (though the quiz will be shorter and simpler than a homework assignment)
#
# To that end, my suggested overarching structure for this Quiz is:
# * Write a function that takes in data and outputs a calculation and/or a plot (provide some "test" data to demonstrate that their function works (Note: This question can/should have the flexibility for them to write one or multiple functions, depending on how they see the solution to the problem). You can use if/else statements in this function or later in the quiz with function calls.
# * Choose a data set (presented as a .csv file) with more than two columns of data (make sure they use numpy for this, not pandas)
# * Visualize the data in a simple manner (i.e. ask them to make a simple line or scatterplot)
# * Use the function from part 1 on the data
#
# **Note:** While it is helpful to have the quiz have students explore a single thread of a problem, rather than disjointed problems, be attentive to places where students can earn partial credit throughout the quiz. For example, Even if they can't get their function to work from the beginning of the quiz, they can still show you that they can load and plot data. If they can't load and plot the data, they could plot the test data. You can also include questions (as I have in the examples) where they can qualitatively discuss what they are doing.
#
# Below is an example of how this quiz could be written. If you use this structure, make sure to choose your own data set and make your quiz unique to your section!

# %% [markdown]
# ---
#
# # Introduction
#
# You are a zoologist exploring data from the International Union for Conservation of Nature's (IUCN) Red List, a tool that leverages research and data to provide a comprehensive assessment of an organism's extinction risk. Put simply, the Red List provides a status on nearly all species on Earth as to whether it is doing ok, Vulnerable to extinction, Endangered, or even Extinct ([Source](https://data.world/project-data-viz/iucn-redlist-changes-2002-to-2022-pdv-10-2022/workspace/project-summary?agentid=project-data-viz&datasetid=iucn-redlist-changes-2002-to-2022-pdv-10-2022)). Your job is to analyze the data to find out what percentages of different animal categories are critically endangered, endangered, or vulnerable over the years of data collected.
#
# The structure of the data is as follows:
# * Column 0: Year (ranging from 2002-2022)
# * Column 1: Total Bird Species assessed in that year
# * Column 2: Total Reptile Species assessed in that year
# * Column 3: Bird Species Critically Endangered
# * Column 4: Reptile Species Critically Endangered
# * Column 5: Bird Species Endangered
# * Column 6: Reptile Species Endangered
# * Column 7: Bird Species Vulnerable
# * Column 8: Reptile Species Vulnerable
#
# ## Part 1 [30 points]
#
# In the cell below, there is a function that calculates the percentage between all of the values in two arrays, plots the percentages, and returns those percentages.
#
# * On each line, add a brief comment to describe what the code is doing.
# * Demonstrate that the function works by writing a function call using the test data.
#
# We are going to use this to analyze the data from the data file later in the quiz!

# %%
import numpy as np

# TEST DATA
# an array of time (in years)
time = np.array([1980,1990,2010,2020])
# an array of total species numbers
total_species = np.array([1500,1554,1350,1467])
# an array of number of species endangered
endangered_species = np.array([300,312,340,323])

def species_pct(time_array,total_array,fraction_array): # add a comment here
    pct = (fraction/total_array)*100 # add a comment here
    plt.plot(time_array,pct) # add a comment here
    return pct # add a comment here

# %%
# Write your function call here

# %%
### ANSWER ###
#Rubric:
# 15 points for correctly describing each line of code
# 15 points for testing the function

import numpy as np

def species_pct(time_array,total_array,fraction):
    pct = (fraction/total_array)*100
    plt.plot(time_array,pct)
    return pct
species_pct(time,total_species,endangered_species)
# Out:
# array([20.        , 20.07722008, 25.18518519, 22.01772324])

# %% [markdown]
# ## Part 2 [25 points]
#
# Now that you have a function to learn about the data, it's time to load in some data! The file, `endangered_species_cleaned.csv` has the total species assessed and endangered category data for mammals and amphibians. **Choose one species category (i.e. mammals or amphibians) to explore.**
#
# **Using np.loadtxt(), load the `endangered_species_cleaned.csv` file into your notebook.** Inspect the data file and ensure that you only read in the columns you are interested in for full credit. Note: You may use pandas if you like, but pandas is Quiz 3 content and you are not expected to know it for a quiz yet.
#
# **Using matplotlib, make a basic plot that visualizes the endangered category data on the y-axis and the years on the x-axis.** Make sure to include appropriate labels and a legend for full credit!

# %%
# PUT YOUR CODE HERE

# %%
### ANSWER ###
# Rubric
# 10 points for reading in the desired columns of data and defining variables
# 10 points for plotting the data
# 5 points for axis labels and a legend

import matplotlib.pyplot as plt
year,mammals_tot,mammals_crit_end,mammals_end,mammals_vuln = np.loadtxt('/Users/rache/OneDrive/Documents/GitHub/cmse201-F22-jb/Quizzes/Quiz_2/endangered_species_cleaned.csv',usecols=[0,1,3,5,7],skiprows=1,delimiter=',',unpack=True)
#plt.plot(year,mammals_tot,label='total')
plt.plot(year,mammals_crit_end,label='crit end')
plt.plot(year,mammals_end,label = 'end')
plt.plot(year,mammals_vuln, label='vuln')
plt.xlabel('years')
plt.ylabel('animal number')
plt.legend()

# %% [markdown]
# ## Part 3 [35 points]
#
# Now that you have a tool and some data, it's time to do some analysis!
#
# **Using the function from Part 1, calculate and plot the percentages for each endangered category of data you have (you should have at least 3).**
#
# Visualization is helpful, but we also want some output that flags if the percentage of endangered species in a category is getting high. What is high you ask? You decide!
#
# **Based on your percentage plots, determine your threshold for a high percentage. Then, write an if statement that checks if a percentage is above that threshold. If the percentage is above the threshold, it should print out a statment indicating that results (i.e. 'The percentage of critically endangered species is high this year').** For full credit, justify your threshhold based on the data you present!
#
# **NOTE:** You can choose to write your if statement inside the function, or you can write it separately. As long as you successfully check out the threshold, you will get full credit!

# %%
# PUT YOUR CODE HERE

# %%
### ANSWER ###
# Rubric:
# 10 points for function call that plots
# 5 points for plotting all three data
# 5 points for labels/legend
# 10 points for if statement
# 5 points for print statement


def species_pct(time_array,total_array,fraction,label):
    pct = (fraction/total_array)*100
    for i in range(len(pct)):
        if pct[i] > 10:
            print('whoa this is high',time_array[i])
    plt.plot(time_array,pct,label=label)
    plt.xlabel('years')
    plt.ylabel('animals number')
    plt.legend()
    return pct
label_names=['crit end','end','vuln']
count=0

for i in (mammals_crit_end,mammals_end,mammals_vuln):
    pct_plot = species_pct(year,mammals_tot,i,label_names[count])
    count+=1
# Out:
# whoa this is high 2002.0
# whoa this is high 2007.0
# whoa this is high 2006.0
# whoa this is high 2004.0
# whoa this is high 2003.0
# whoa this is high 2002.0

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.

# %%
### ANSWER
### Data Preparation
import pandas as pd

species = pd.read_csv('/Users/rache/OneDrive/Documents/GitHub/cmse201-F22-jb/Quizzes/Quiz_2/endangered_species.csv',thousands=',')
'''species = species.drop(columns = [ 'Bird Species Assessed',
       'Reptile Species Assessed',
       'Fish Species Assessed', 'Insect Species Assessed',
       'Mollusc Species Assessed', 'Other Invertebrate Species Assessed',
       'Plant Species Assessed', 'Fungus & Protist Species Assessed',
       'Bird Species Critically Endangered',
       'Reptile Species Critically Endangered',
       'Fish Species Critically Endangered',
       'Insect Species Critically Endangered',
       'Mollusc Species Critically Endangered',
       'Other Invertebrate Species Critically Endangered',
       'Plant Species Critically Endangered',
       'Fungus & Protist Species Critically Endangered', 'Bird Species  Endangered',
       'Reptile Species  Endangered',
       'Fish Species  Endangered', 'Insect Species  Endangered',
       'Mollusc Species  Endangered', 'Other Invertebrate Species  Endangered',
       'Plant Species  Endangered', 'Fungus & Protist Species  Endangered', 'Bird Species Vulnerable',
       'Reptile Species Vulnerable',
       'Fish Species Vulnerable', 'Insect Species Vulnerable',
       'Mollusc Species Vulnerable', 'Other Invertebrate Species Vulnerable',
       'Plant Species Vulnerable', 'Fungus & Protist Species Vulnerable'])'''

species = species.drop(columns=['Mammal Species Assessed', 'Amphibian Species Assessed',
       'Fish Species Assessed', 'Insect Species Assessed',
       'Mollusc Species Assessed', 'Other Invertebrate Species Assessed',
       'Plant Species Assessed', 'Fungus & Protist Species Assessed',
       'Mammal Species Critically Endangered',
       'Amphibian Species Critically Endangered',
       'Fish Species Critically Endangered',
       'Insect Species Critically Endangered',
       'Mollusc Species Critically Endangered',
       'Other Invertebrate Species Critically Endangered',
       'Plant Species Critically Endangered',
       'Fungus & Protist Species Critically Endangered',
       'Mammal Species  Endangered', 'Amphibian Species Endangered',
       'Fish Species Endangered', 'Insect Species  Endangered',
       'Mollusc Species Endangered', 'Other Invertebrate Species Endangered',
       'Plant Species Endangered', 'Fungus & Protist Species  Endangered',
       'Mammal Species Vulnerable', 'Amphibian Species Vulnerable',
       'Fish Species Vulnerable', 'Insect Species Vulnerable',
       'Mollusc Species Vulnerable', 'Other Invertebrate Species Vulnerable',
       'Plant Species Vulnerable', 'Fungus & Protist Species Vulnerable'])
species.keys()
# Out:
# Index(['Year', 'Bird Species Assessed', 'Reptile Species Assessed',
#        'Bird Species Critically Endangered',
#        'Reptile Species Critically Endangered', 'Bird Species Endangered',
#        'Reptile Species Endangered', 'Bird Species Vulnerable',
#        'Reptile Species Vulnerable'],
#       dtype='object')

# %%
### ANSWER

species.to_csv('/Users/rache/OneDrive/Documents/GitHub/cmse201-F22-jb/Quizzes/Quiz_2/Sect_006/endangered_species_cleaned_makeup.csv',index=False)

# %%
### ANSWER
import numpy as np
import matplotlib.pyplot as plt
year,mammals_tot,mammals_crit_end = np.loadtxt('/Users/rache/OneDrive/Documents/GitHub/cmse201-F22-jb/Quizzes/Quiz_2/Sect_006/endangered_species_cleaned_makeup.csv',usecols=[0,1,3],skiprows=1,delimiter=',',unpack=True)
plt.plot(year,mammals_crit_end/mammals_tot)
#plt.plot(year,mammals_crit_end)

# %%
### ANSWER
test = pd.read_csv('endangered_species_cleaned_makeup.csv')
test.head()
# Out:
#    Year  Bird Species Assessed  Reptile Species Assessed  \
# 0  2022                  11162                     10150
# 1  2021                  11162                     10148
# 2  2020                  11158                      8492
# 3  2019                  11147                      7829
# 4  2018                  11126                      7127
#
#    Bird Species Critically Endangered  Reptile Species Critically Endangered  \
# 0                                 231                                    433
# 1                                 225                                    433
# 2                                 223                                    324
# 3                                 225                                    309
# 4                                 224                                    287
#
#    Bird Species Endangered  Reptile Species Endangered  \
# 0                      423                         787
# ...
