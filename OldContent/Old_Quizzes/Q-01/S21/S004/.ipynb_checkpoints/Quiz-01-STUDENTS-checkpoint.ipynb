# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 1 (Section 004 - Fall 2020)
#
# The goal of this quiz is to test some of the skills you've developed thus far. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# You are encouraged to look through the entire quiz before you get started so that you can appropriately budget your time.
#
# Even if you get stuck on one question you can still get points on  later problems. Consider jumping ahead if you aren't making progress and  come back later if time allows.
#
# **Important note about using online resources**: This exam is "open internet". That is, you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you can exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on this quiz.

# %% [markdown]
# ---
# ## Part 1: Reviewing Python concepts (6 points)

# %% [markdown]
# &#9989;&nbsp; **Question 1 (3 points):** *In your own words*, explain what a  `for` loop and a `while` loop are, and when you would use one versus the other. In your explanation, provide an example problem that you could solve using each type of loop.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*
#
# ## Rubric
#
# +1 point : articulate what a foor/while loop is
#
# +1 point : say something to the effect of "for loops is when we known how many instances we want to iterate over", " while
# loops is for when we want to run the iteration until certain condition is satisfied"
#
# +1 point : provide at least one example

# %% [markdown]
# &#9989;&nbsp; **Question 2 (3 points):** *In your own words*, explain what a  Python "list" and a Python "dictionary" are, and when you would use one versus the other.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*
#
# ## Rubric
#
# +1 point: say what a list is
#
# +1 point: say what a dictionary is (in particular mention keys)
#
# +1 point: say something to the effect of "lists when we want to iterate over indices or elements", "dictionary, to iterate over keys"...

# %% [markdown]
# ---
# ## Part 2: Writing Python code (9 points)

# %% [markdown]
# &#9989;&nbsp; **Question 3:** You've recently been hired by a local bank and your first task is to check the health of their member's checking accounts. Specifically, they'd like to know what the current **average** blance is  and how much money **total** is held by the bank.
#
# Here are their members names and current checking account balances:
#
# * Luis - $\$6,000$
# * Dan - $\$71,000$
# * Lorie - $\$200,100$
# * Charles - $\$150,000$
# * Steve - $\$3$
# * Paula - $\$222$
#
# This question has three parts:
#
# 1. Write a plan for your code using plain language and/or **pseudocode**.
# 2. Implement your plan by writing **actual Python code**.
# 3. Check that your code is working as intended.
#
# &#9989;&nbsp; First, **explain how you would write a bit of code that uses *at least one list and at least one loop* to determine the average checking account balance and what the total amount held by the bank is. (3 points)**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*
#
# ## Rubric
#
# +1 point: If they tried something
#
# +1 point: If the thing they tried makes sense, though may be incomplete/incorrect
#
# +1 point: If the pseudocode is correct

# %% [markdown]
# &#9989;&nbsp; Second, **write a solution to solve this problem using Python. Your solution should involve at least *one list* and at least *one loop*. (3 points)**

# %% [markdown]
# ## Rubric
#
# +1 point: If they put the numbers in a list or dictionary (keys = names)
#
# +1 point: If they used a loop
#
# +1 point: If the solution is correct

# %%
# Put your code here

# %% [markdown]
# &#9989;&nbsp; Finally, **how do you know that your code is working correctly?** Explain how you know your code is working. Feel free to use a bit of code to support your argument. **(3 points)**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ## Rubric
#
# +1 point: If they tried something
#
# +1 point: if what they tried makes sense, though may be incomplete/incorrect
#
# +1 point: If what they tried is correct

# %%
# Put any code that supports your claim here

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #1, and upload it there.

# %% [markdown]
# &#169; Copyright 2020,  Michigan State University Board of Trustees
