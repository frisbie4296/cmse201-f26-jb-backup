# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 1 (Section 001 - Spring 2021)
#
# The quiz is set up so that even if you get stuck on one question there are opportunities to get points on the other questions, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ---
# # Academic integrity statement (1 point)
#
# In the markdown cell below, put your personal academic integrity statement (composed during Day04 In-Class Assignment). By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# ## Part 1: Reviewing Python concepts (6 points)

# %%
###ANSWER### (for making sure this gets removed)

# **Note to instructors:** In this section, the goal is to ask a 
# conceptual question to probe student understanding of the content covered so far 
# in the course. These are free response questions, so student answers may very, 
# but should be written in their own words.

# Recommend only asking one of the three questions below!

# %% [markdown]
# &#9989;&nbsp; **Question X (6 points):** *In your own words*, explain what a Python "list" is and how you create one in Python. In your explanation, make sure you indicate what type(s) of Python variables can be stored in a list.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER
# I'm looking for them to say something along the lines of "a list is a python object for storing information that can be accessed and changed as necessary" (the "changing" part gets at the idea that lists are mutable, but they might miss this). They should also indicate that a list can hold any Python variable type (e.g integers, floats, lists, strings, etc) for full points.

# %% [markdown]
# &#9989;&nbsp; **Question 2 (6 points):** *In your own words*, explain the difference between a `for` loop and a `while` loop and when you would use one versus the other. In your explanation, provide an example problem that you could solve using each type of loop.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER
# Fundamentally, it should be clear that a `for` loop is used when we want to iterate for a predetermined number of times either by loops over a range of values or by iterating through a Python object (e.g. list or dictionary). In contrast a `while` loop is used when we want to run the code until a particular condition is met. They should provide an reasonable example of using each loop for full points.

# %% [markdown]
# &#9989;&nbsp; **Question X (6 points):** *In your own words*, explain what each of the following lines (lines A, B, C) of code are doing:
# ```
# -----------
# animals = ['tigers','sparrows','rabbits','pandas']    # LINE A
#
# for v in range(4):
#     print('I like ' + animals[v])   # LINE B
#
# animals.append('gophers')   # LINE C
#
# --------------
#     ```

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your explanation for line A,B, and C here.*
#
# LINE A is ________
#
# LINE B is ________
#
# LINE C is ________

# %% [markdown]
# ### ANSWER
#
# LINE A is assigns a list of different animals to variable `animals`
#
# LINE B is prints to the screen the phrase `I like a specific animal`.  Pulls a single entry from the list and appends to 'I like'
#
# LINE C is add the string `gophers` to the list `animals`

# %% [markdown]
# ---
# ## Part 2: Writing Python code (13 points)

# %% [markdown]
# ###ANSWER### (for making sure this gets removed)
#
# **Note to instructors:** In this section, the goal provide students with the opportunity to showcase their ability to write code given what they've had the opportunity to practice in the first homework assignment. This means that this question should ideally only involve working with either a `for` loop or a `while` loop and perhaps a list or dictionary. Since it is still early in the semester and we want them to get into the habit of thinking through their solution before writing it, so this question includes a pseudocoding component before the actual coding.
#
# Please modify this question for your sections!

# %% [markdown]
# &#9989;&nbsp; **Question 3:** You've recently been hired by a small company and one of the first things they've asked you to do is to check on the state of their finances. Specifically, they'd like to know what the current **average** salary is for their employees and how much money **total** the company is spending on their employee salaries. (You don't bother to ask why they don't already know these things!)
#
# Here are the employee names and yearly salaries that they've provided for you:
#
# * Wei - $\$86000$
# * Lucien - $\$71000$
# * Maegan - $\$78000$
# * Jonie - $\$95000$
#
# This question has three parts:
#
# 1. Writing a plan for your code using plain language and/or **pseudocode**.
# 2. Implementing your plan by writing **actual Python code**.
# 3. Checking that your code is working as intended.
#
# First, **explain how you would write a bit of code that uses *at least one list and at least one loop* to determine the average yearly salary at this company and what the total amount of money the company is spending each year on employee salaries. (4 points)**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER
# Example response:
# * store all of the salaries in a list
# * initialize a "total" variable that starts out equal to 0
# * loop through the list
#     * for each iteration, add the current salary to the "total"
# * after the loop runs take the total and divide by the total number of elements to get the average
# * print both

# %% [markdown]
# Second, **write a solution to solve this problem using Python. Your solution should involve at least *one list* and at least *one loop*. (7 points)**

# %%
# Put your code here

# %%
### ANSWER

salaries = [86000,71000,78000,95000]

total = 0
for s in salaries:
    total += s
print("The average is:", total/len(salaries))
print("The total is:", total)
# Out:
# The average is: 82500.0
# The total is: 330000

# %% [markdown]
# Finally, **how do you know that your code is working correctly?** Explain how you know your code is working. Feel free to use a bit of code to support your argument. **(2 points)**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER
# One possible response:
# I would create a simpler list with just two salaries so that the average and told would be obvious and then run that test.

# %%
# Put any code that supports your claim here

# %%
### ANSWER

# The average for these should be 75000 and the total should be 150000
salaries = [50000,100000]

total = 0
for s in salaries:
    total += s
print("The average is:", total/len(salaries))
print("The total is:", total)

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #1, and upload it there.

# %% [markdown]
# &#169; Copyright 2020,  Michigan State University Board of Trustees
