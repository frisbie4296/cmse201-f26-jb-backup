# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 (Section 006)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging code

# %% [markdown]
# ---
# # Academic integrity statement [10 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ### ANSWER
#
# # TEMPLATE INSTRUCTIONS
#
# This quiz should assess functions, if/else, numpy, and matplotlib. Specifically, we want to assess if students can load in a data file, explore it with some basic calculations, and visualize it in  a meaningful way. Use of numpy and matplotlib implicitly includes functions, but we also want to assess students' understanding of how to write and use their own functions.
#
# Use Homework 2 questions as a guide for what they can be expected to know for this quiz (though the quiz will be shorter and simpler than a homework assignment)
#
# To that end, my suggested overarching structure for this Quiz is:
# * Write a function that takes in data and outputs a calculation and/or a plot (provide some "test" data to demonstrate that their function works (Note: This question can/should have the flexibility for them to write one or multiple functions, depending on how they see the solution to the problem). You can use if/else statements in this function or later in the quiz with function calls.
# * Choose a data set (presented as a .csv file) with more than two columns of data (make sure they use numpy for this, not pandas)
# * Visualize the data in a simple manner (i.e. ask them to make a simple line or scatterplot)
# * Use the function from part 1 on the data
#
# **Note:** While it is helpful to have the quiz have students explore a single thread of a problem, rather than disjointed problems, be attentive to places where students can earn partial credit throughout the quiz. For example, Even if they can't get their function to work from the beginning of the quiz, they can still show you that they can load and plot data. If they can't load and plot the data, they could plot the test data. You can also include questions (as I have in the examples) where they can qualitatively discuss what they are doing.
#
# Below is an example of how this quiz could be written. If you use this structure, make sure to choose your own data set and make your quiz unique to your section!

# %% [markdown]
# ---
#
# # Introduction
#
# You have decided to examine some [Twitch Streaming Data](https://www.kaggle.com/datasets/aayushmishra1512/twitchdata/) to gain insights into viewer behavior. You have found a dataset with a variety of parameters related to viewer engagement with different streamers.
#
# The data is structured as follows:
# * Column 0: Index (representing streamer username)
# * Column 1: Watch time(Minutes)
# * Column 2: Stream time(minutes)
# * Column 3: Peak viewers
# * Column 4: Average viewers
# * Column 5: Followers
# * Column 6: Followers gained
# * Column 7: Views gained
#
#
# ## Part 1 [10 points]
#
# You remember learning in CMSE 201 that the context of a dataset is critical to understanding what claims you can or cannot make about the data. In the cell below, briefly describe the context of this dataset (using the source provided).
#
# **Note:** You may notice that some of the columns mentioned on the source are not present in the provided data, that is to simplify your lives for this quiz!

# %% [markdown]
# **PUT YOUR CONTEXT HERE**

# %% [markdown]
# ## Part 2 [20 points]
# **Using the test data below, write a function that takes an array of values as input and returns the mean, standard deviation, and median of those values. Demonstrate that your function works by calling it using the test data.** We are going to use this to analyze the data from the data file later in the quiz!
#
# Note: You are provided with both x and y data. You can use either to test your function.

# %%
# test data
import numpy as np
test_x = np.arange(0,10,1.0) # indices test data
test_y = [215250., 211845., 515280., 517740., 123660.,  82260., 136275., 147885., 122490., 92880.] # Stream time (minutes) test data


# PUT YOUR FUNCTION HERE

# %%
### ANSWER ###
test_x = np.arange(0,10,1.0) # indices test data
test_y = [215250., 211845., 515280., 517740., 123660.,  82260., 136275., 147885., 122490., 92880.] # Stream time (minutes) test data

def do_stats(my_yvals):
    return np.mean(my_yvals),np.std(my_yvals),np.median(my_yvals)

print(do_stats(test_y))

#Rubric:
# 10 points for defining the function and having it return values
# 5 points for calculating the statistics
# 5 points for testing the function
# Out:
# (216556.5, 155544.75952358535, 142080.0)

# %% [markdown]
# ## Part 3 [15 points]
#
# Now that you have a function to learn about the data, it's time to load in some data! The file, `Quiz2_dataset.csv` has data for 1000 different streamers. **Looking at the different columns, choose one column of data (other than "Index") to explore.**
#
# **Using numpy (not pandas!), load the `Quiz2_dataset.csv` file into your notebook.** Inspect the data file and ensure that you only read in the columns you are interested in for full credit (i.e. "Index" and your column of choice).
#
# **Using matplotlib, make a basic plot that visualizes the data of your choice on the y-axis and the Index on the x-axis.** Make sure to include appropriate labels for full credit!

# %%
# PUT YOUR CODE HERE

# %%
### ANSWER

# Rubric
# 5 points for reading in the desired columns of data and defining variables
# 5 points for plotting the data
# 5 points for axis labels
import matplotlib.pyplot as plt
index,stream_time = np.loadtxt('Quiz2_dataset.csv',usecols=(0,3),skiprows=1,delimiter=',',unpack=True)

plt.plot(index,stream_time)
plt.ylim(0,550000)
plt.xlabel('index')
plt.ylabel('minutes')
# Out:
# Text(0, 0.5, 'minutes')

# %% [markdown]
# ## Part 4 [10 points]
# Now that you have some data read in, it's time to do some analysis! Using your function from Part 2, calculate the mean, median, and standard deviation (using numpy) of your data column of choice.

# %%
# Put your code here

# %% [markdown]
# ## Part 5 [15 points]
# To share your insight, you want to create a summary plot of your data and the descriptive statistics. In the cell below, create this summary plot. It should include the following:
#
# * The data
# * The mean (as a vertical line)
# * The median (as a vertical line)
# * The +/- standard deviation from the mean (as vertical lines)
# * The mean, median, and standard deviations should be different linestyles and colors to differentiate them from each other
#
# Adjust your x and y ranges as needed in order for all of your information to be visible.

# %%
# Put your code here

# %%
### ANSWER ###

mean,stan,med = do_stats(stream_time)
plt.plot(index,stream_time)
plt.axhline(mean,color = 'k')
plt.axhline(mean+stan,color= 'pink',ls='--')
plt.axhline(mean-stan,color = 'pink',ls='--')
plt.ylim(-50000,550000)
plt.xlabel('index')
plt.ylabel('minutes')
# Out:
# Text(0, 0.5, 'minutes')

# %% [markdown]
# ## Part 6 [10 points]
#
# (1) In the cell below, make one claim about the data and calculations shown in the plot. Make sure to include your evidence for the claim and your reasoning for the claim.
#
# (2) Identify one improvement that you could make to your plot

# %% [markdown]
# **PUT YOUR ANSWER HERE**

# %% [markdown]
# ### ANSWER ###
# Full credit for any response that includes all three components

# %% [markdown]
# ## Part 7 [5 points]
# Now that you have done some work with one column of data, you realize it would be great if you could do the analysis on the rest of the data too. Based on the code you have written so far, provide a detailed plan for how you would accomplish this.

# %% [markdown]
# **PUT YOUR ANSWER HERE**

# %%
### ANSWER ####
data = np.loadtxt('Quiz2_dataset.csv',skiprows=1,delimiter=',',unpack=True)
def do_stats_and_plot(my_xvals,my_yvals):
    mean,stan,med = do_stats(my_yvals)
    plt.plot(my_xvals,my_yvals)
    plt.axhline(mean,color = 'k')
    plt.axhline(mean+stan,color= 'pink',ls='--')
    plt.axhline(mean-stan,color = 'pink',ls='--')
    #plt.ylim(0,550000)
    plt.xlabel('index')
    plt.ylabel('minutes')
    
#for i in range(1,8):
#    do_stats_and_plot(data[0,:],data[i,:])
#    plt.show()

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
