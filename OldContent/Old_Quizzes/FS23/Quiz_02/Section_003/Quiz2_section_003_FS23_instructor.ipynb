# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201 Section 003: Quiz 2 (43 points total)
#
#
# The goal of this quiz is to give you the opportunity to test out more of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your more recently acquired programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### ANSWER (for making sure this gets removed) ###
#
# ## Template Guidelines
#
# **Learning Objectives from Homework 2:**
# - Review how to define and use functions in Python (including using the `return` statement and default arguments)
# - Use functions to calculate statistical values and build computational models
# - Load data using NumPy
# - Visualize models and data using matplotlib
# - Compare models to data to understand assumptions and limitations
#
# **Learning Objectives the Quiz will assess:**
# * Writing functions, including using the return statement and defaul arguments
# * Using pre-written functions that create model values
# * Loading a dataset using NumPy
# * Using matplotlib to visualize a model or data
#
# **Learning objectives that we don't have time/space for**:
#
# * Statistical analysis of data (or looking as distributions)
#
# **Quiz Duration:** 30 minutes
# * This means your TAs/LAs should be able to complete the quiz in at most 10 minutes
#
# **Notes:**
# * The structure and rubric provided here is a suggestion and an example of the difficulty level expected. However, as long as your quiz assesses the learning objectives listed under "Learning Objectives the Quiz will assess" section above, you can differ from this structure. If you aren't sure that your quiz does that, run it by another instructor (lead isntructor, other faculty, TA, or LA)
# * The examples provided are examples and **should not be used directly without changes in any quizzes**
# * These quizzes are important for students to assess how well they understand the material independent of their groups, so when grading, be sure to provide feedback on where points were deducted. **You should also have a clear rubric with clearly stated point values, but you do not need to follow the point values included in this template**.
# * Quizzes should be written with ample time for TAs/LAs to review! **Your TA and LAs should have at least 48 hours to review the quiz before it is given**.
# * Quizzes (and instructor solution with point-by-point rubrics) should be **pushed to the GitHub repo for record-keeping**. Put your section's version in a sub-folder with the name `Section-###` where "###" is your section number.
#
# **Overall Structure:**
#
# 1. Basic question that checks to see if student can write a function from scratch, ideally probing if they can implement a return statement and a default argument value
# 2. Question that checks their ability to use a provided function and their ability to make a plot with matplotlib
# 3. Question that checks if they can load data using NumPy and then visualize it.

# %% [markdown]
# ---
# # Academic integrity statement (1 point)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# # Read in modules that we will need
#
# Before we get started, read in the modules you might use on this quiz:

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ---
#
# # 1. Writing a function (6 points)
#
# In statistics, **arithmatic mean** or just **mean** or **average** is an important factor in calculating the Pearson correlation coefficient (PCC) which is a correlation coefficient that measures linear correlation between two sets of data. The PCC has a value between −1 and 1.
#
# Mathematically,the equation for mean is
# ### $$\overline{x} =\frac{\sum_{i=1}^N x_i}{N} = \frac{x_1 + x_2 +\cdots + x_N}{N} $$
#
#
# ✅ **Write a function (6 points)**
#
# - Write a function called `average` (**2 points**).
# - Your function should take the following inputs: `x_value` (**2 point**).
# - The function should return the mean value (**2 points**).

# %%
# write your function average() here

# %%
### ANSWER ###
def average(x_value):
    return sum(x_value)/len(x_value)

# %% [markdown]
# ## Part 1.2  [6 points]
#
# Using the test data below and the defined function to calculate the average or mean **x_values, y_vaules**. **Demonstrate that your function works by using `np.mean()`.
#
# We are going to use this to calculate Pearson correlation coefficient of data from the data file later in the quiz!

# %%
# PUT YOUR CODE HERE (3 points)
import numpy as np
x_values = np.random.normal(2, 2, 200)# 200 sample poitns from normal distribution with mean 2 and standard deviation 2.
y_values = np.linspace(1,4,200)# 200 evenly distributed points between 1 and 4.

# %%
### ANSWER ###
print(average(x_values)) #  1 point
print(np.mean(x_values)) # 1 point
print(average(y_values)) #  1 point
print(np.mean(y_values)) # 1 point
# Out:
# 2.070061151253253
# 2.070061151253254
# 2.5
# 2.5

# %% [markdown]
# Pearson's correlation coefficient is the covariance of the two variables divided by the product of their standard deviations and the formula is:
# ### $$ r = \frac{\sum\limits_{i=1}^{N} (x_{i}-\overline{x})(y_{i}-\overline{y})}{\sqrt{\sum\limits_{i=1}^{N} (x_{i}-\overline{x})^2(y_{i}-\overline{y})^2}}$$
#
# where the symbols in this equation represent the following:
#
# * $r$: Pearson correlation coefficient
# * $\overline{x}$: Mean of the value of x-variable
# * $\overline{y}$: Mean of the value of y-variable
# * $x_{i}$: The value of x-variable at position $i$
# * $y_{i}$: The value of y-variable at position $i$

# %%
# Pearson's correlation coefficient function
def Corr_coeff(x_value, y_value):
    mu = average(x_value)
    nu = average(y_value)
    num1 = []
    num2 = []
    for jj in range(len(x_value)):
        num1.append(x_value[jj] - mu)
        num2.append(y_value[jj] - nu)
    
    return sum(np.array(num1)*np.array(num2))/np.sqrt(sum(np.array(num1)**2)*(sum(np.array(num2)**2)))

# %% [markdown]
# Using the test data above and the defined Pearson correlation coefficient function to calculate the Pearson correlation coefficient between **x_values,y_vaules**. Demonstrate that your function works by using `np.corrcoef()`.

# %%
# Calculate Pearson's correlation coefficient (2 points)
cor =Corr_coeff(x_values,y_values) #1 point
print(cor)
np.corrcoef(x_values,y_values) #1 point
# Out:
# 0.059694858402856696
# array([[1.        , 0.05969486],
#        [0.05969486, 1.        ]])

# %% [markdown]
# ## Part 2 [10 points]
#
# Now that you have a function to learn about the data, it's time to load in some data! The file, `Advertising.csv` consists of the `sales`, *in thousand of units*, of that product in 200 diferent markets, along with advertising budgets for the product in each of those markets for three diferent media: `TV, radio, and newspaper`, *in thousands of dollars*.
#
# **Using numpy (not pandas!), load the `Advertising.csv` file into your notebook.** Inspect the data file and ensure that you only read in the columns you are interested in for full credit.

# %%
# PUT YOUR CODE HERE

# %%
### ANSWER ###
advertising = np.loadtxt('Advertising.csv',delimiter=',',skiprows=1,usecols=range(1,5)) # 6 points


TV = advertising[:,0] # 1 point
Radio = advertising[:,1] # 1 point
Newspaper = advertising[:,2] # 1 point
Sales = advertising[:,3] # 1 point

# %% [markdown]
# ## Part 3 [20 points]
#
# Now that you have a tool and some data, it's time to do some analysis!
#
# Suppose that you are hired as data scientist to suggest,
# on the basis of this data, a marketing plan for next year that will result in
# high product sales. First, **draw simple scatter plots between Sales, TV, Radio, and Newspaper**, then answer the following question: **Which of the media have a correlation with the sales higher than 0.5?**
#
# **NOTE:** You may want to make small adjustments to your function. Make sure to indicate where you do!

# %%
# Draw simple scatter plots between Sales, TV, Radio, and Newspaper. (10 points)
# Sales in y-axis
# PUT YOUR CODE HERE

# %%
### ANSWER ###
plt.figure(figsize=(8,10))
#plt.subplot(3,1,1)

plt.subplot(3,1,1)  # 1 point

plt.scatter(TV,Sales,color ='b') # 3 points
plt.xlabel('TV')
plt.ylabel("Sales")

plt.subplot(3,1,2)
plt.scatter(Radio,Sales,color = 'g')# 3 points
plt.xlabel('Radio')
plt.ylabel("Sales")

plt.subplot(3,1,3)
plt.scatter(Newspaper,Sales, color = 'r')# 3 points
plt.xlabel('Newspaper')
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
# Which of the media have a correlation with the sales higher than 0.5 ? (10 points)
# PUT YOUR CODE HERE

# %%
### ANSWER ###

cef1 = Corr_coeff(TV,Sales) # 2 point
cef2 = Corr_coeff(Radio,Sales) # 2 point
cef3 = Corr_coeff(Newspaper,Sales) # 2 point1

print('The PCC between TV and Sales is', cef1) # 1 point
print('The PCC between Radio and Sales is', cef2) # 1 point
print('The PCC between Newspaper and Sales is',cef3) # 1 point
# Out:
# The PCC between TV and Sales is 0.782224424861606
# The PCC between Radio and Sales is 0.5762225745710553
# The PCC between Newspaper and Sales is 0.22829902637616525

# %% [markdown]
# ### ANSWER ###
#
# TV and Radio # 3 points ( 1 point)

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
