# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201.007: Quiz 2

# %% [markdown]
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester.
#
# **Do your own work:** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. There is zero tolerance for violations of academic integrity.
#
# You're allowed to reference your code portfolio as described on the course website. **No other materials online or elsewhere can be referenced.**
#
# **Quiz duration:** 50 minutes.

# %% [markdown]
# ---
#
# # 1. Functions [5 points]

# %% [markdown]
# Write a function to determine if a point, given by its $x$ and $y$ coordinates, lies inside a circle of radius $r$ (centered at the origin).
#
# Reminder: The equation for a circle with radius $r$ is $x^2 + y^2 = r^2$. Examples:
#
# - The point with $(x, y)$ coordinates $(0.3, 0.4)$ is inside the circle with radius $r = 1.0$ because $0.3 ^ 2 + 0.4 ^ 2 = 0.25$ which is less than $r ^ 2 = 1 ^ 2 = 1$.
# - The point with $(x, y)$ coordinates $(0.3, 0.4)$ is *not* inside the circle with radius $r = 0.1$ because $0.3 ^ 2 + 0.4 ^ 2 = 0.25$ which is greater than $r ^ 2 = 0.1 ^ 2 = 0.01$.
#
# Your function should have three arguments:
#
# - The $x$ coordinate,
# - The $y$ coordinate,
# - The radius $r$ with a default value of `1.0`,
#
# and should return `True` if the point lies within the circle of radius $r$, else `False`. Consider points exactly on the boundary to be inside the circle.

# %%
# Your code here.

# %% [markdown]
# ---
# # 2. Data visualization [5 points]

# %% [markdown]
# The file `points.txt` (also on D2L under Quiz 2) contains $x$ and $y$ coordinates of dart throws from an (amateur) competition. There are two columns labeled $x$ and $y$ giving the coordinates for $50$ throws. The first few lines of the file are

# %% [markdown]
# |x y|
# |:---:|
# |-0.50 0.14|
# |0.39 0.32|
# |0.17 -0.03|
# |-0.60 0.02|
# |0.19 -0.21|

# %% [markdown]
# - Load in the data using `NumPy`.
# - Visualize the data by making a scatter plot with the $x$ values on the horizontal axis and the $y$ values on the vertical axis using `Matplotlib`.
#   - Set the limits on the horizontal and vertical axes to be between $-1$ and $1$.
#   - Label the horizontal axis `x-coordinate` and the vertical axis `y-coordinate`.
#
# If you're unable to load in the data, you can use the points from the above table to get partial credit for plotting and for the next question.

# %%
# Your code here.

# %% [markdown]
# ---
#
# # 3. Data analysis [15 points]

# %% [markdown]
# For each radius in the provided array of radii (plural of radius), determine the percentage of dart throws inside a circle of that radius using your function from Question 1, then make a plot of the percentages (vertical axis) vs. radii (horizontal axis).
#
# *Hint*: `0%` of throws should be within the first radius (`0.0`) and `100%` of throws should be within the last radius (`1.0`).

# %%
radii = np.linspace(0.0, 1.0, 10)  # This makes an array of 10 linearly (equally) spaced radii between 0.0 and 1.0; np refers to numpy.

# Your code here.

# %% [markdown]
# ---
# ## Code portfolio [5 points]
#
# Turn in your code portfolio along with your quiz to D2L.

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
#
# **Make sure the quiz you submit is the quiz you want me to grade,** for example by downloading your submission and checking it contains your completed work.
