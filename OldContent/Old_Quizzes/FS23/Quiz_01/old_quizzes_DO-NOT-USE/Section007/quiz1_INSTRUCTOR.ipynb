# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 1 - Section 007 (Spring 2023)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### ANSWER (for making sure this gets removed) ###
#
# ## Template Guidelines
#
# **Learning Objectives from Assignments:**
# * Work with number, string, and list data types
# * Learn how to do order of magnitude approximations
# * Write for and while loops
# * Combine lists and loops to compute new values
# * Use python lists to store values
# * Use loops to iterate over a specified range, over a list of values, or until a condition is met
# * Use conditional statements to control code flow
# * Basic debugging
#
# **Learning Objectives the Quiz will assess:**
# * When should students use a For loop vs. while loop
# * What problems can we solve with Loop by index vs. loop by value
# * Calculating and Storing values in lists (within loops)
# * Basic debugging (potentially involving: lists, loops, variables; **this was an implicit learning goal that we didn't work on to explicitly, so don't get carried away with this one**)
#
# **Learning objectives that we don't have time/space for**:
#
# * Using conditional statements, we can try to integrate this into a future quiz.
#
# **Quiz Duration:** 30 minutes
# * This means your TAs/LAs should be able to complete the quiz in at most 10 minutes
#
# **Notes:**
# * The structure and rubric provided here is a suggestion and an example of the difficulty level expected. However, as long as your quiz assesses the learning objectives listed under "Learning Objectives the Quiz will assess" section above, you can differ from this structure. If you aren't sure that your quiz does that, run it by another instructor (lead isntructor, other faculty, TA, or LA)
# * The examples provided are examples and **should not be used directly without changes in any quizzes**
# * These quizzes are important for students to assess how well they understand the material independent of their groups, so when grading, be sure to provide feedback on where points were deducted. **You should also have a clear rubric with clearly stated point values, but you do not need to follow the point values included in this template**.
# * Quizzes should be written with ample time for TAs/LAs to review! **Your TA and LAs should have at least 48 hours to review the quiz before it is given**.
# * Quizzes (and instructor solution with point-by-point rubrics) should be **pushed to the GitHub repo for record-keeping**. Put your section's version in a sub-folder with the name `Section-###` where "###" is your section number.
#
# **Overall Structure:**
#
# * Basic question that assess variable type and scope
# * Basic question about a list (and indexing)
# * Question that probes students knowledge an ability to use for loop by index vs. by value and an opportunity to do some debugging
# * Question with a while loop that has them take an awkward for loop and rewrite it as a while loop

# %% [markdown]
# ---
# # Academic integrity statement [10 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # 1. Variables (10 points)
#
# In the first cell below, define a variable, `course`, that holds a string that is the name of the course you are taking this semester(for example, CMSE201), and define another variable, `year`, that is the current year.
#
# In the second cell below, write a print statement (using your two variables defined in the first cell) that prints a complete sentence like below.
#
# "`I am taking <course> in Spring <year>.`" (where \<course\> is filled in using your `course` variable value, and \<year\> is filled in using the `year` variable value)

# %%
# define your variables here

# %%
# write your print statement here

# %%
### ANSWER

course = "CMSE201"
year = 2023

# 2 points for string of name
# 2 points for number of dogs

# %%
### ANSWER

print('I am taking',course,'in Spring', year)


# 1 point for using print()
# 1 point for calling the name variable
# 1 point for calling the dogs variable
# 3 point for a complete sentence
# Out:
# I am taking CMSE201 in Spring 2023

# %% [markdown]
# ---
# # 2. List (25 points)
#
# Do the following.
#
# 1. Create a **list** called `colors` that contains the **strings**: `"red"`, `"green"`, `"yellow"`, `"blue"` and `"purple"`, in that order.
# 2.  Replace the string `"green"` with the string `"spartan"`.
# 3. Use a command to find the length of the list `colors`, and print it out.
# 4. Use the method of looping by values to print out each item in the list.
# 5. Use the method of looping by index to print out each item in the list.

# %%
# put your code here

# %%
### ANSWER

colors = ["red", "green", "yellow", "blue", "purple"]
colors[1]="spartan"
print("The length of colors is", len(colors))

for color in colors:
    print(color)
    
for i in range(len(colors)):
    print(colors[i])

# 5 points for defining the list
# 5 points for replacing the list item
# 5 points for printing the length of the list
# 5 points for looping by value 
# 5 points for looping by index
# Out:
# The length of colors is 5
# red
# spartan
# yellow
# blue
# purple
# red
# spartan
# yellow
# blue
# purple

# %% [markdown]
# ---
#
# # 3. For Loops and Debugging (40 points)
#
# We are trying to create a squared integer list, namely a sequence of number like the following
#
# 0, 1, 4, 9, 16, 25, 36, 49, 64, 81
#
# Below is the code written for that purpose.

# %%
my_list = ()

for i in range(10)
    a = i*2
    my_list.append(a)
    
Print(my_list)
# Out:
#   Input In [29]
#     for i in range(10)
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# The code above is buggy. Your job now is to debug the code, so that it does what it is supposed to do.

# %% [markdown]
# &#9989;&nbsp; **Part 1 (20 points):** In the cell below, describe the bugs in the code. Specifically, for each bug you found, provide the following information:
# 1. The line of code that caused the error(s)
# 2. A plain english description of the error(s) in the code
#
# Hint: there are total of 4 bugs.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER ###
#
# Bug 1, wrong initialization of list
#
# Bug 2, missing : after the for
#
# Bug 3, Print should not be capitalized
#
# Bug 4, instead of square, it is now calculating multiply by 2
#
# Grading, 5 points for each bug.

# %% [markdown]
# &#9989;&nbsp; **Part 2 (20 points):** In the empty code cell below, fix the buggy code according to the bugs you found so that it works properly to print
#
# 0, 1, 4, 9, 16, 25, 36, 49, 64, 81

# %%
# Put your modified code here

# %%
#### ANSWER ###

my_list = [] #bug 1

for i in range(10):  #bug 2
    a = i**2 #bug 4
    my_list.append(a)
    
print(my_list) #error3
# 5 points each for fixing each bug
# Note, we give half credit if a student choose to completely rewrite the code.
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# # 4. While Loops (15 points)
#
# The code below uses for loop to print all odd numbers between 100 to 140.

# %%
for i in range(101,140,2):
    print(i)
# Out:
# 101
# 103
# 105
# 107
# 109
# 111
# 113
# 115
# 117
# 119
# 121
# 123
# 125
# 127
# 129
# 131
# 133
# 135
# 137
# 139

# %% [markdown]
# Now, write a code below using `while` loop to achieve the same objective, i.e. print all odd numbers between 100 to 140.

# %%
#put your code here

# %%
### ANSWER ###
i=101
while i<140:
    print(i)
    i=i+2
    
#4 points for line 1 (correct starting point)
#4 points for line 2 (correct while loop condition)
#3 points for printing
#4 points for line 4 (correct adding statements)
# there may be alternative ways to line 4, as long as the final list is correct, full points can be given
# Out:
# 101
# 103
# 105
# 107
# 109
# 111
# 113
# 115
# 117
# 119
# 121
# 123
# 125
# 127
# 129
# 131
# 133
# 135
# 137
# 139

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #1, and upload it there.
