# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 (Section 001 - Fall 2020)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# You are encouraged to look through the entire quiz before you get started so that you can appropriately budget your time and understand the broad goals of the exam.
#
# The quiz is set up so that even if you get stuck on one question there are opportunities to get points on the other questions, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# **Total points possible: 22**

# %% [markdown]
# ---
# # Academic integrity statement [1 point]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# ## Part 1: Reviewing concepts [9 points]

# %% [markdown]
# &#9989;&nbsp; **Questions [3 points]:** In a new cell write if each statement is `True` or `False`:
# 1. Functions can make a program smaller by eliminating repetitive code. Later, if you make a change, you only have to make it in one place.
#
# 2. A function must always return a variable
#
# 3. A function can only return one variable
#
# 4. Dividing a long program into functions allows you to debug the parts one at a time and then assemble them into a working whole.
#
# 5. Well-designed functions are often useful for many programs. Once you write and debug one, you can reuse it.
#
# 6. The following function takes in a list and multiplies each element by the value of `const` and it returns a new list
#
#         def lux_func(input_list, const):
#             for i in range(len(input_list)):
#                 input_list[i] *= const
#             pass
#
# 7. Loops and `if` statements cannot be inside functions.
#
# 8. A function can call another function within itself.
#
# 9. Any variable defined in the body of the function will be lost when outside the function if not returned.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
# 7.
# 8.
# 9.

# %% [markdown]
# ---
# ## Part 2: Writing Python code [12 points]

# %% [markdown]
# &#9989;&nbsp; **Question 2:** Your job is to create **function** that takes in a **number** and figures out which one is the biggest between its sine and cosine values.
#
# Once you've created your function, you are going to call the function on a provided list of angles (included below), store the output of the function in a new **list**, and then **print the following for each item** on the list.
#
#     blank1 is bigger for angle = blank2
#
# where `blank1` can be sine, cosine, or none and `blank2` is the angle from the list
#
# **NOTE:** Few things to keep in mind:
#
# 1. You can use either `numpy` 's or `math` 's `sin` and `cos` functions, but both of them accept angles in radians while the provided list of angles is in degrees. Both the `numpy` and `math` module have a function to convert degrees to radians or you can convert it yourself. Recall that $\pi$ radians = 180 degrees.
#
# 2. The sine and cosine of 45 degrees ( or $\pi/4$) are equal. Python does not know this and will always calculate cosine to be bigger. So you need to account for this possibility.
#
#
# This question has two parts:
#
# 1. Writing a plan for your code using plain language and/or **pseudocode**. [3 points]
# 2. Implementing your plan by writing **actual Python code**. [6 points]
# 3. Test for the 45 degree case. [3 points]

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your **pseudocode** here.*

# %% [markdown]
# Second, **write a solution to solve this problem using Python.**
#
# Your solution should include **the function you described above**, should be called **using the provided list**, should store the returned output by your function into a **new list**, and should **print the new list**. **[6 points]**

# %%
# Write your function here
# remember to import the correct module

# %%
import numpy as np

# Write your APID inside the parenthesis without the Initial A or initial 0 (zeros)
np.random.seed(123456789)

# The command below creates a list of 10 elements with numbers between 0 and 90 
angle_list = np.random.randint(0, 90, 10)

print(angle_list)

# Call your function here


# Print the new list here
# Out:
# [56 28 50 89 29  7 79 83 60 84]

# %%
# Now test for the 45 degree case
print('{} is bigger for angle = {}'.format( put_your_function_call_here, 45))

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.

# %% [markdown]
# &#169; Copyright 2020,  Michigan State University Board of Trustees
