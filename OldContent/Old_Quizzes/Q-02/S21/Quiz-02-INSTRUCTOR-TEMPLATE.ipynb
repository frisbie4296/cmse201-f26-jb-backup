# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 (Section 001 - Spring 2021)
#
# The quiz is set up so that even if you get stuck on one question there are opportunities to get points on the other questions, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time.  Also, you will receive partial credit for pseudocode, even if your python code does not function correctly.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# **Total points possible: 22**

# %% [markdown]
# ---
# # Academic integrity statement (1 point)
#
# In the markdown cell below, put your personal academic integrity statement (composed during Day04 In-Class Assignment). By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# ## Part 1: Reviewing concepts [9 points]

# %% [markdown]
# ###ANSWER### (for making sure this gets removed)
#
# **Note to instructors:** In this section, the goal is to ask some number of conceptual questions to probe student understanding of the content covered so far in the course.

# %% [markdown]
# &#9989;&nbsp; **ALTERNATE Questions 1 [3 points]:** In a new cell write if each statement is `True` or `False`: (perhaps pick up to six T/F questions)
# 1. Functions can make a program smaller by eliminating repetitive code. Later, if you make a change, you only have to make it in one place.
#
# 2. A function must always return a variable
#
# 3. A function can only return one variable
#
# 4. Well-designed functions are often useful for many programs. Once you write and debug one, you can reuse it.
#
# 5. matplotlib `plot(x,y)` function will display the values of `x` on the horizontal axis and the values of `y` on the vertical axis.
#
# 6. The following function requires one input list and multiplies each element by the value of `const` and it returns a new list
#
#         def my_func(input_list, const=1):
#             for i in range(len(input_list)):
#                 input_list[i] *= const
#             return input_list
#
# 7. For the above function, if it is called with `my_func([0,1,2,3])` will return `[1,2,4,6]`
#
# 8. Loops and `if` statements cannot be inside functions.
#
# 9. A function can call another function within itself.
#
# 10. Any variable defined in the body of the function will be lost when outside the function if not returned.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*
# 1. True
#
# 2.
#
# 3.
#
# 4.
#
# 5.
#
# 6.
#
# 7.
#
# 8.
#
# 9.

# %% [markdown]
# ### ANSWER
# 1. True
# etc

# %% [markdown]
# &#9989;&nbsp; **ALTERNATE Question 1 [3 points]:** *In your own words*, explain the following:
# 1. what a Python "function" is and why functions can be useful when writing code.
# 2. what the required components are when writing a function in Python.

# %% [markdown]
# &#9989;&nbsp; **ALTERNATE Question 1 [4 points]:** *In your own words*, explain the following:
# 1. What do the commands `def` and `return` do in a Python function?
# 2. When and how would you use the commands `else`  and `elif` in a Python conditional statement?

# %% [markdown]
# ---
# ## Part 2: Writing Python code [12 points]

# %% [markdown]
# ###ANSWER### (for making sure this gets removed)
#
# **Note to instructors:** In this section, the goal provide students with the opportunity to showcase their ability to write code given what they've had the opportunity to practice in the second homework assignment. This means that this question should ideally only involve the following new concepts:
# * if statements
# * functions
# * making plots
#
# We also want them to continue with the habit of thinking through their solution before writing it, so this question includes a pseudocoding component before the actual coding.

# %% [markdown]
# &#9989;&nbsp; **Question 2.1:** Create **function** that takes in a numpy array and prints the mean +/- std of the array and returns the mean of the array. In addition, if the mean of the array is greater than 20, it prints a warning that this array has a high mean (you can use numpy functions to calculate these terms).
#
# The results of the function should look something like:
#
# `The mean+/-std is 250 +/- 10`
#
# `Warning: The mean is greater than 20`
#
# This question has two parts:
#
# 1. Writing a plan for your code using plain language and/or **pseudocode**. [3 points]
# 2. Implementing your plan by writing **actual Python code**. [6 points]

# %%
# Put your pseudocode and code here

# %%
### ANSWER ###

def myfunc(a1):
    print('The mean+/-std is ',np.mean(a1),' +/- ',np.std(a1))
    if(np.mean(a1)>20):
        print('Warning: The mean is high')
    return np.mean(a1)

# %% [markdown]
# &#9989;&nbsp; **Question 2.2:** Test your function on the arrays `a1` and `a2` below.

# %%
a1 = np.arange(0,50,0.3)  # Angles from 0 to 50 in Radians
a2 = np.sin(a1)
a3 = np.cos(a1)

# Put your pseudocode and code here

# %%
### ANSWER ###
import numpy as np
a1 = np.arange(0,100,0.3)
a2 = np.sin(a1)
a3 = np.cos(a1)
myfunc(a1)
myfunc(a2)
# Out:
# The mean+/-std is  49.949999999999996  +/-  28.925118841588187
# ...
# The mean+/-std is  0.0010240168392554887  +/-  0.7080452827042896
# 0.0010240168392554887

# %% [markdown]
# &#9989;&nbsp; **Question 2.3:** Make a plot of the sin() and cos() of the angles versus the angles from 0 to 50. (angles are in radians).  Label your axes and include a legend.

# %%
# Put your pseudocode and code here

# %%
### ANSWER ###
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(a1,a2,label="Sin()")
plt.plot(a1,a3,label="Cos()")

plt.xlabel("angle (radians)")
plt.ylabel("Y")
plt.title("Sin vs Angle")
plt.grid()
plt.legend()

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.

# %% [markdown]
# &#169; Copyright 2021,  Michigan State University Board of Trustees
