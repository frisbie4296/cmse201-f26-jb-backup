# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 3 (Section 001 - Fall 2020)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# You are encouraged to look through the entire quiz before you get started so that you can appropriately budget your time and understand the broad goals of the exam.
#
# The quiz is set up so that even if you get stuck on one question there are opportunities to get points on the other questions, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. **Being able to effectively use the internet for computational modeling and data science is a very important skill**, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# **Total points possible: 30**

# %% [markdown]
# ![Moira](https://media.giphy.com/media/26gs78HRO8sOuhTkQ/giphy.gif)

# %% [markdown]
# ---
# # Part 1. Academic integrity statement
#
# ## Write your statement  [1 point]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.
#
# Keep it simple.

# %% [markdown]
# *Put your statement here*

# %% [markdown]
# ---
# # Part 2. Stocks [29 points]
#
# Welcome today you will be looking at some stock prices. Firstly run the following code cell to import the necessary libraries

# %% [markdown]
# ###ANSWER### (for making sure this gets removed)
#
# **Note to instructors:** In this section, the goal is to provide students with the opportunity to showcase their ability to write code given that they've had the opportunity to practice in the third homework assignment. This means that this question should ideally only involve the following new concepts:
# * loading data using primarily Pandas (though a carefully supported question might also use NumPy)
# * calculating some basic statistics or extracting information from the data in some way
# * visualizing the data
# * reading documentations
#
# For this quiz, I'm stepping away from trying to get the to pseudocode a solution first, since it's less clear how beneficial it would be for these questions. May return to this style of questioning in the future.

# %%
# Import the plotting library 
# %pylab
# %matplotlib inline

import seaborn as sns
import pandas as pd

print("Seaborn version: ",sns.__version__)
print("Matplotlib version: ",mpl.__version__)
print("Pandas version: ",pd.__version__)
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# Seaborn version:  0.10.1
# Matplotlib version:  3.1.3
# Pandas version:  1.0.3

# %% [markdown]
# ## Part 2.1: Collection [6 points]
#
# The file `stocks_data.csv` contains the closing price of several companies over the past 5 years (as of 2020-10-15). Read the dataset with the first column as the index.
#
# - Read the dataset **[2 points]**.
# - Use the date column as the **index** of the `DataFrame` **[2 points]**. _Hint:_ read the documentation of [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
# - Print the last 5 days **[2 points]**.

# %%
# Put your answer here

# %%
### ANSWER ###
stocks = pd.read_csv('stocks_data.csv', index_col = 0)
stocks.tail(5)
# Out:
#                   AAPL         AMZN    GE        GOOGL       INTC         IBM  \
# Date
# 2020-10-08  114.970001  3190.550049  6.65  1483.430054  53.369999  131.490005
# 2020-10-09  116.970001  3286.649902  6.84  1510.449951  52.820000  127.790001
# 2020-10-12  124.400002  3442.929932  6.83  1564.589966  53.880001  127.209999
# 2020-10-13  121.099998  3443.629883  6.72  1567.069946  53.830002  125.099998
# 2020-10-14  121.190002  3363.709961  6.82  1563.439941  53.549999  125.940002
#
#                   MSFT        NFLX        NVDA          T        TSLA  \
# Date
# 2020-10-08  210.580002  531.789978  553.549988  28.610001  425.920013
# 2020-10-09  215.809998  539.440002  550.510010  28.320000  434.000000
# 2020-10-12  221.399994  539.809998  569.039978  28.129999  442.299988
# 2020-10-13  222.860001  554.090027  569.929993  27.750000  446.649994
# 2020-10-14  220.860001  541.450012  563.809998  27.490000  461.299988
#
#                    VZ        ^GSPC
# Date
# 2020-10-08  59.189999  3446.830078
# 2020-10-09  59.330002  3477.139893
# 2020-10-12  59.549999  3534.219971
# 2020-10-13  59.360001  3511.929932
# 2020-10-14  58.430000  3488.669922

# %% [markdown]
# - Print quick statistical summary of your data (e.g. the mean, standard deviation, min, max, etc) **[2 points]**.

# %%
# Put your answer here

# %%
### ANSWER ###
stocks.describe()
# Out:
#               AAPL         AMZN           GE        GOOGL         INTC  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean     46.633253  1448.575488    16.602968  1058.175322    42.395060
# std      22.312370   683.155003     7.838000   234.818527    10.434312
# min      21.202499   482.070007     5.472735   671.799988    25.068556
# 25%      28.405820   828.884979     9.709012   826.425018    32.523386
# 50%      41.859478  1517.859985    13.193615  1070.849976    43.929394
# 75%      53.161896  1838.309998    25.519071  1207.039978    49.914127
# max     134.179993  3531.449951    28.555582  1717.390015    67.294716
#
#                IBM         MSFT         NFLX         NVDA            T  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean    128.094883   100.739135   256.035584   178.963304    30.245276
# std      11.053036    47.740999   124.474452   111.543496     2.810370
# min      92.307220    42.722469    82.790001    24.683723    24.092373
# 25%     122.800610    59.423771   133.074997    99.701023    28.081206
# 50%     129.366455    91.175034   276.820007   169.094727    29.875042
# 75%     134.313881   134.362831   354.864990   240.058937    32.015100
# max     155.360657   231.649994   556.549988   573.859985    37.092419
#
#               TSLA           VZ        ^GSPC
# count  1259.000000  1259.000000  1259.000000
# mean     82.144858    47.527861  2619.943294
# std      78.690618     6.822623   397.639353
# min      28.733999    35.420033  1829.079956
# 25%      45.982000    41.995319  2271.035034
# 50%      60.167999    45.753677  2663.679932
# 75%      69.686001    53.928276  2896.244995
# max     498.320007    59.971466  3580.840088

# %% [markdown]
# ## Part 2.2: Plotting [16 points]
#
# - Make **one** plot with every stock price as a function of time except the last column (_i.e._ ^GSPC)  **[2 points]**.
# - Make the plot 12 inches wide and 9 inches tall **[2 points]**.
# - Make the $y$-axis **log** scaled **[2 points]**.
# - Label the $y$-axis as **Price (USD)** **[2 points]**.
# - Label the $x$-axis as **Date** **[2 points]**.
# - Make the ticks size equal to **14 pts** **[2 points]**.
# - Rotate the $x$-ticks by **30 degrees** **[2 points]**.
# - Make the $x$ and $y$ label size equal to **16 pts** **[2 points]**.
#
# Most of the above can be done using pandas plotting function [`plot`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html)

# %%
# Put your answer here

# %%
### ANSWER ###
stocks.iloc[:,:-1].plot(figsize=(12,9), rot = 30, fontsize = 14, logy=True)
plt.ylabel('Price (USD)', fontsize = 16)
plt.xlabel('Date', fontsize = 16)
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## Part 2.3: Questions [7 points]
#
#  By looking at the quick statistical data and the above plot answer these questions
#
# 1. How many days of data you have ? **[1 point]**
# 2. What is the highest price reached by TSLA and on what date? (_Hint:_ you might need to use code for this. This could be a very simple command if you remember HW 3) **[3 points]**.
# 3. Looking at the plot, are the `mean` and `std` from your statistical analysis an accurate representation of the data? Explain why or why not. (_Hint:_ You want to look at the trend of the curves. This can be seen easily if you make the y-axis linear. Try make the linear plot in the code space below.). **[3 points]**

# %%
# Put any code that you might need here

# %%
### ANSWER ###
stocks["TSLA"].idxmax()
# Out:
# '2020-08-31'

# %% [markdown]
# ---
#
# # Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #3, and upload it there.

# %% [markdown]
# ![Moira2](https://media.giphy.com/media/d1E2HnwywoTkES08/giphy.gif)

# %% [markdown]
# If you wish to look at other companies here is the code I used to create the data set

# %%
# Create the data from stocks
# Note that you need to have yfinance package
# If you get module not found error the run !pip install yfinance from your Jupyter notebook 

# import yfinance as yf

#stocks_list = ['AAPL', 'AMZN', 'GE', 'GOOGL', 'INTC', 'IBM', 'MSFT', 'NFLX', 'NVDA', 'T', 'TSLA', 'VZ', '^GSPC']

#stocks = pd.DataFrame()

#for company in stocks_list:
#    stock = yf.Ticker(company)
#    symbol = stock.info["symbol"]
#    price = stock.history(start = '2015-10-15', end='2020-10-15')
#    stocks["{}".format(symbol)] = price.Close
#    print(symbol, ' done')

# Save the data to a csv file
#stocks.to_csv('stocks_data_2.csv', encoding='utf-8')

# %% [markdown]
# # Part 3. Correlations [20 points]
#
# ![correlations](https://c1.staticflickr.com/5/4195/34878771446_3d1e5a1173_o.jpg)

# %% [markdown]
# ### ANSWER ###
#
# ***Note to Instructors:*** The following is not part of the Quiz due to time limitation, however, it is still interesting and could be given to students as extra work.

# %% [markdown]
# ## Part 3.1 Heatmap [10 points]
#
# Create a correlation matrix of your dataset. You might want to look up [`pandas.DataFrame.corr`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html) **[2 points]**.
#
# _Note_ that `corr` is a function and as such it does not store changes!

# %%
# Put your answer here

# %%
### ANSWER ###
scorr = stocks.corr()

# %% [markdown]
# Now using `seaborn` make a [heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html) using the correlation matrix you just calculated.
#
# - Make the heatmap **[2 points]**.
# - Make the figure 12 in wide and 9 in tall **[2 points]**.
# - Set the **lower limit** of the colorbar to be -1 and the **upper limit** to be 1 **[2 points]**
# - Use the `RdBu` colormap **[2 points]**. ( _Hint_ : [Colormap Matplotlib](https://matplotlib.org/gallery/color/colormap_reference.html#sphx-glr-gallery-color-colormap-reference-py) )

# %%
# Put your code here

# %%
### ANSWER ###
# Set up the matplotlib figure
plt.figure(figsize=(12, 9))

# Draw the heatmap
sns.heatmap(scorr, vmin = -1, vmax = 1, cmap = 'RdBu')

# %% [markdown]
# ## Part 3.2: Questions [8 points]
#
# By looking at the above plot answer these questions
#
# 1. Which three companies stand out in this plot ? **[3 point]**
# 2. Is GE positively or negatively correlated with other companies **[1 points]**.
# 3. Looking at the Image in Part 3. Markdown cell how you would you say does ^GSPC correlate with TSLA and GOOGL? **[4 points]**
#
# PS. ^GSPC is the S&P 500 index.

# %% [markdown]
# ## Part 3.3 Pair plot [2 points]
#
# Make a pairplot of your entire dataset **[2 points]**. (_Note:_ This might take a while on your computer so jump ahead while this is working!)
#
# Which do you think better represents the correlation data, `heatmap` or `pairplot`?

# %%
# Put your code here

# %%
### ANSWER ### 
sns.pairplot(data = stocks)

# %% [markdown]
# &#169; Copyright 2020,  Michigan State University Board of Trustees
