# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 3 (Section 008 - Fall 2020)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# You are encouraged to look through the entire quiz before you get started so that you can appropriately budget your time and understand the broad goals of the exam.
#
# The quiz is set up so that even if you get stuck on one question there are opportunities to get points on the other questions, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# **Total points possible: 16**

# %% [markdown]
# ---
# ## Academic integrity statement [1 point]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# ---
# ## Writing Python code [15 points]

# %% [markdown]
# ###ANSWER### (for making sure this gets removed)
#
# **Note to instructors:** In this section, the goal provide students with the opportunity to showcase their ability to write code given what they've had the opportunity to practice in the third homework assignment. This means that this question should ideally only involve the following new concepts:
# * loading data using primarily Pandas (though a carefully supported question might also use NumPy)
# * calculating some basic statistics or extracting information from the data in some way
# * visualizing the data
#
# For this quiz, I'm stepping away from trying to get the to pseudocode a solution first, since it's less clear how beneficial it would be for these questions. May return to this style of questioning in the future.

# %%
###ANSWER
# Grab the data I'm using for this question
# !curl -O https://raw.githubusercontent.com/fivethirtyeight/data/master/candy-power-ranking/candy-data.csv

# %% [markdown]
# ### Which halloween candy is best?
#
# With Halloween right around the corner, grocery stores are stocked with a myriad of halloween candy, but which candy is "best"?
#
# In this part of the quiz you are asked to load, manipulate, and visualize data using Pandas. Specifically, you'll be working with data from this article on Five Thirty Eight:
#
# [The Ultimate Halloween Candy Power Ranking](https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/)

# %% [markdown]
# &#9989;&nbsp; **Question 1 [2 points]:** Load the data from `candy-data.csv` into your notebook **using Pandas** and then use Pandas to display the first 15 rows of the data.

# %%
# Put your code here

# %%
### ANSWER
import pandas as pd

candy = pd.read_csv("candy-data.csv")
candy.head(15)

# %% [markdown]
# **Question 2 [4 points]**: What built-in Pandas function can you use to get a quick statistical summary of your data (e.g. the mean, standard deviation, min, max, etc)? **Use this function to summarize the data and then answer the following questions**:
#
# 1. How many different types of candy are included in this dataset?
# 2. Are the mean and standard deviation values for the "chocolate", "fruity", and "caramel" columns useful? Defend your answer!

# %%
# Put your code here

# %%
### ANSWER
candy.describe()

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER
# They can choose either option as long as they defend it. Argument for mean: a low value for the mean means there aren't many candies of that type. Argument against standard deviation: doesn't really tell you anything other than the fact that there are a mix of ones and zeros.

# %% [markdown]
# **Question 3 [6 points]**: The original article claimed that there was no correlation in either of these two combination of parameters:
# * sugar content and win percentage
# * price and win percentage
#
# **What is your assessment?** Make plots of the data to determine if you agree or disagree with the article on these claims. Using your plots to support your argument, **state the conclusion you reach**.

# %%
# Put your code here

# %%
### ANSWER
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

sns.jointplot(candy['sugarpercent'],candy['winpercent'],kind="reg",height=4)
sns.jointplot(candy['pricepercent'],candy['winpercent'],kind="reg",height=4)

# %% [markdown]
# <font size=+3>&#9998;</font> *State your conclusion as to whether the sugar content or price are correlated with the win percentage.*

# %% [markdown]
# ### ANSWER
# They should find that the values are not clearly correlated as both quantities show a large degree of scatter at all prices.

# %% [markdown]
# **Question 4 [3 points]:** *Got a real sweet tooth?* **Using a mask**, extract only those candies that where the value in the "sugarpercent" column is *greater than 0.5*. Use this information to print out the overall percentage of candies in the dataset that are more sugar than not.
#
# If you can't figure out how to use a mask to do this, feel free use whatever other means necessary for a loss of 1/2 of a point.

# %%
# Put your code here

# %%
### ANSWER
mask = candy['sugarpercent'] > 0.5
sugary = candy[mask]
print((100*len(sugary)/len(candy)),"percent of the candies are very sugary!")

# %%
sugary.head(5)

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #3, and upload it there.

# %% [markdown]
# &#169; Copyright 2020,  Michigan State University Board of Trustees
