# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 3 (Section 004 - Fall 2020)
#
# The goal of this quiz is to test some of the skills you've developed thus far. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# You are encouraged to look through the entire quiz before you get started so that you can appropriately budget your time.
#
# Even if you get stuck on one question you can still get points on  later problems. Consider jumping ahead if you aren't making progress and  come back later if time allows.
#
# **Important note about using online resources**: This exam is "open internet". That is, you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you can exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on this quiz.
#
# **Total points possible: 16**

# %% [markdown]
# ---
# # Academic integrity statement [2 points]
#
# By including your personal academic integrity  statement in the cell below, you are confirming that  the submitted work is your own.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# ## Writing Python code [14 points]

# %% [markdown]
# ### Which halloween candy is best?
# In this part of the quiz you are asked to load, manipulate, and visualize data using Pandas. Specifically, you'll be working with data from this article on Five Thirty Eight:
#
# [The Ultimate Halloween Candy Power Ranking](https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/)

# %% [markdown]
# &#9989;&nbsp; **Question 1 [2 points]:** Load the data from `candy-data.csv` into your notebook **using Pandas** and then use Pandas to display the last 10 rows of the data.

# %%
# Put your code here

# %%
### ANSWER
import pandas as pd

candy = pd.read_csv("candy-data.csv")
candy.tail(10)
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 75        Tootsie Roll Juniors          1       0        0               0
# 76        Tootsie Roll Midgies          1       0        0               0
# 77     Tootsie Roll Snack Bars          1       0        0               0
# 78           Trolli Sour Bites          0       1        0               0
# 79                        Twix          1       0        1               0
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        WelchÕs Fruit Snacks          0       1        0               0
# 83  WertherÕs Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# ...

# %% [markdown]
# **Question 2 [4 points]**: What  Pandas function can you use to get a quick statistical summary of your data (e.g. the mean, standard deviation, min, max, etc)? **Use this function to summarize the data and answer the following questions**:
#
# 1. How many different types of candy are included in this dataset?
# 2. What is the most popular ingredient out of *chocolate*,	*caramel* and *nougat*? **Justify your answer?**

# %%
# Put your code here

# %%
### ANSWER
candy.describe()
# Out:
#        chocolate     fruity    caramel  peanutyalmondy     nougat  \
# count  85.000000  85.000000  85.000000       85.000000  85.000000
# mean    0.435294   0.447059   0.164706        0.164706   0.082353
# std     0.498738   0.500140   0.373116        0.373116   0.276533
# min     0.000000   0.000000   0.000000        0.000000   0.000000
# 25%     0.000000   0.000000   0.000000        0.000000   0.000000
# 50%     0.000000   0.000000   0.000000        0.000000   0.000000
# 75%     1.000000   1.000000   0.000000        0.000000   0.000000
# max     1.000000   1.000000   1.000000        1.000000   1.000000
#
#        crispedricewafer       hard        bar   pluribus  sugarpercent  \
# count         85.000000  85.000000  85.000000  85.000000     85.000000
# mean           0.082353   0.176471   0.247059   0.517647      0.478647
# std            0.276533   0.383482   0.433861   0.502654      0.282778
# min            0.000000   0.000000   0.000000   0.000000      0.011000
# ...

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### Answer:
# 1. There are 85 different types of candi (the first row is 0,  the last is 84)
# 1. Chocolate. The mean of each column = percentage of candi with that ingredient (bc entires = 0 or 1)

# %% [markdown]
# **Question 3 [5 points]**: Do you observe any strong correlations between the quantities *sugarpercent*, *pricepercent* or *winpercent*?

# %%
# Put your code here

# %%
### ANSWER
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

sns.jointplot(candy['sugarpercent'],candy['winpercent'] )
sns.jointplot(candy['pricepercent'],candy['winpercent'] )
sns.jointplot(candy['pricepercent'],candy['sugarpercent'] )

# %%
candy.loc[ :, ['sugarpercent','winpercent','pricepercent'] ].corr()
# Out:
#               sugarpercent  winpercent  pricepercent
# sugarpercent      1.000000    0.229151      0.329706
# winpercent        0.229151    1.000000      0.345325
# pricepercent      0.329706    0.345325      1.000000

# %% [markdown]
# <font size=+3>&#9998;</font> *State your conclusions here.*

# %% [markdown]
# ### ANSWER
# They should find that the values are not clearly correlated.

# %% [markdown]
# **Question 4 [3 points]:** *Where's the chocolate?* **Using a mask**, extract only those candies that contain chocolate. How many of those also contain nougat?

# %%
# Put your code here

# %%
### ANSWER
mask = (candy['chocolate'] == 1)

chocolate = candy[mask]

chocolate

print(chocolate['nougat'].sum(), 'candies contain nougat')
# Out:
# 6 candies contain nougat

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #3, and upload it there.

# %% [markdown]
# &#169; Copyright 2020,  Michigan State University Board of Trustees
