# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 1 (Section 005 - Spring 2022)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ---
# # Academic integrity statement [10 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# # For and while loops [30 points]
#
# *In your own words*, explain what a  `for` loop and a `while` loop are, and when you would use one versus the other.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# Now, write a code below using `for` loop to print all odd numbers between 100 to 130.

# %%
#put your code here

# %%
### ANSWER ###
for i in range(101,130,2):
    print(i)
# Out:
# 101
# 103
# 105
# 107
# 109
# 111
# 113
# 115
# 117
# 119
# 121
# 123
# 125
# 127
# 129

# %% [markdown]
# Now, write a code below using `while` loop to print all odd numbers between 100 to 130.

# %%
#put your code here

# %%
### ANSWER ###
i=101
while i<130:
    print(i)
    i=i+2
# Out:
# 101
# 103
# 105
# 107
# 109
# 111
# 113
# 115
# 117
# 119
# 121
# 123
# 125
# 127
# 129

# %% [markdown]
# ---
#
# # List [60 points]
# This part will have multiple steps. Please write each new step in a new cell to facilitate grading.
#
# 1. Create a **list** called `colors` that contains the **strings**: `"red"`, `"green"`, `"yellow"`, `"blue"` and `"purple"`, in that order.
# 2. Using a **for loop**, **print** all of the elements that are in the list `colors`.
# 3. Replace the string `"green"` with the string `"spartan"`.  Then, print the new list.
# 4. Replace the string `"purple"` with the list of integers `[5,1,7,8,8,4]`, and print the new list.
# 5. Use a command to find the length of the list `color`. Then, write a loop that finds the length of __*each element*__ in the list. Include print statements to specify what you are finding the length of. For example, `"The length of red is: 3"` or `"The length of colors is: 5"`.

# %%
#question 1
#put your code here

# %%
#question 2
#put your code here

# %%
#question 3
#put your code here

# %%
#question 4
#put your code here

# %%
#question 5
#put your code here

# %%
### ANSWER ###
colors = ["red", "green", "yellow", "blue", "purple"]
for color in colors:
    print(color)
colors[1]="spartan"
print(colors)
colors[-1]=[5,1,7,8,8,4]
print(colors)
print("The length of colors is", len(colors))
for color in colors:
    print("The length of", color, "is",len(color))
# Out:
# red
# green
# yellow
# blue
# purple
# ['red', 'spartan', 'yellow', 'blue', 'purple']
# ['red', 'spartan', 'yellow', 'blue', [5, 1, 7, 8, 8, 4]]
# The length of colors is 5
# The length of red is 3
# The length of spartan is 7
# The length of yellow is 6
# The length of blue is 4
# The length of [5, 1, 7, 8, 8, 4] is 6

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #1, and upload it there.
