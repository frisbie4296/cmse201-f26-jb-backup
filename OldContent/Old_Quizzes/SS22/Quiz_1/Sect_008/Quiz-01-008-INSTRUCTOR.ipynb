# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 1 (Section 008 - Spring 2022)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ---
# # Academic integrity statement [10 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# # Calculating Paint Costs
#
# You are working for a contractor who paints houses, specifically helping them calculate the cost of paint of different colors they need to buy for a job. For each painting job, the system stores three lists:
# - One with the paint color/type
# - One with the gallons needed for each color/type
# - One with the cost of the paint color/type

# %%
paint_color_type = ["Raucous Orange semi-gloss","Resolute Blue flat","Lagoon semi-gloss","Gris Eggshell","Wisteria flat","Adriatic Sea flat"]
paint_quantity = [0.5,2,1,3,0.75,1.5]
paint_cost = [53.62,49.87,64.87,81.49,53.62,61.12]

# %% [markdown]
# **Your company needs a piece of code that will calculate the total cost of materials for each job, so they can make up the budget.** To calculate the total cost *for one color*, the price must be multiplied by the quantity needed (E.g., the total cost of Raucous Orange semi-gloss is \\$53.62 per gallon $\times$ 0.5 gallons $=$ \\$26.81.) The total cost of materials is the sum of the costs of each paint color/type.
#
# Your boss started to write this bit of code (below), but part way through they **ran into an error** they couldn’t figure out.

# %%
all_colors_total_cost = []

for jj in range(paint_quantity):
    total_color_cost = paint_quantity[jj]*paint_cost[jj]
    all_colors_total_cost.append(total_color_cost)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_79268/681386722.py in <module>
#       1 all_colors_total_cost = []
#       2
# ----> 3 for jj in range(paint_quantity):
#       4     total_color_cost = paint_quantity[jj]*paint_cost[jj]
#       5     all_colors_total_cost.append(total_color_cost)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %% [markdown]
# &#9989;&nbsp; **Part 1 (25 points):** In the cell below, describe the bug in the code and how you solved it. Specifically, provide the following information:
# 1. The line of code that caused the error(s)
# 2. (Where appropriate) The error code
# 3. A plain english description of the error(s) in the code
# 4. How you solved the error(s)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER ###
#
# 1. **(5 Points)** Line 3 threw the error
# 1. **(5 Points)** TypeError: 'list' object cannot be interpreted as an integer
# 1. **(10 Points)** It was trying to take the `range` of a list, not a number
# 1. **(5 Points)** We needed to include `len` in line 3 so that we were acting on a number.

# %% [markdown]
# &#9989;&nbsp; **Part 2 (15 points):** In the empty code cell below, rewrite the buggy code so that it works properly.

# %%
# Put your modified code here

# %%
#### ANSWER ###

#Basically full points (15) for getting it running.

all_colors_total_cost = []

for jj in range(len(paint_quantity)):
    total_color_cost = paint_quantity[jj]*paint_cost[jj]
    all_colors_total_cost.append(total_color_cost)

# %% [markdown]
# &#9989;&nbsp; **Part 3 (25 points):** Is this code looping by index or looping by value? Could you solve the problem using the other kind of `for` loop?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER ###
#
# - **(10 Points)** It is looping by index.
# - **(15 Points)** No we couldn't solve this problem by looping by value, since we need to access two lists.

# %% [markdown]
# &#9989;&nbsp; **Part 4 (25 points):** The purpose of this code is to calculate the total cost of materials. In the cell below, modify the code above so that it calculates the total cost of all of the materials. Your code should also print out the total cost.

# %%
# Put your modified code that calculates total cost here

# %%
#### ANSWER ###

#Lots of ways to do this
#Full points (25) if it's working. 
#(I might take off a few if they do something like create an entirely new loop.)

all_colors_total_cost = []

for jj in range(len(paint_quantity)):
    total_color_cost = paint_quantity[jj]*paint_cost[jj]
    all_colors_total_cost.append(total_color_cost)

print(sum(all_colors_total_cost))
# Out:
# 567.785

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #1, and upload it there.
