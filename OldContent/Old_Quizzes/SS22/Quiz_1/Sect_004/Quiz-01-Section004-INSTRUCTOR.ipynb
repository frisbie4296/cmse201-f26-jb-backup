# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 1 (Section 004 - Spring 2022)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ---
# # Academic integrity statement [10 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # Calculating Omicron Cases [90 points]
#
# You work for Centers for Disease Control and Prevention (CDC), and recently you are monitoring the Omicron variant of COVID-19 in the US. Some data from previous weekly reports are already collected for you, and are stored in the following three lists:
# - One with the date each data was collected, i.e., the week ending day
# - One with the number of 7-day average cases of all variants in that week
# - One with the percentage of Omicron variant (among all cases) occurs in that week

# %%
collecting_date = ['Dec 4th, 2021', 'Dec 11th, 2021', 'Dec 18th, 2021', 'Dec 25th, 2021', 'Jan 1st, 2022', 'Jan 8th, 2022', 'Jan 15th, 2022']
averaging_cases = [109000, 119000, 132000, 208000, 417000, 694000, 804000]
omicron_percentage = [0.6, 7.4, 37.8, 74.1, 88.9, 96.2, 99.4] # in percentage

# Reference:
# https://covid.cdc.gov/covid-data-tracker/#trends_dailycases
# https://covid.cdc.gov/covid-data-tracker/#variant-proportions
# The figures are modified for simplicity.

# %% [markdown]
# **Your department needs a piece of code that will calculate the total cases of Omicron variant for each week.** To calculate the total cases of Omicron variant *for one week*, the total cases of the week must be multiplied by the corresponding percentage of Omicron variant (E.g., the total cases of Omicron variant during the week ending on Dec 4th, 2021 is about 109000 (cases / day) $\times$ 7 (days / week) $\times$ 0.6 % = 4578.) The total cases of Omicron variant in that period is the sum of the cases of each week.
#
# Your teammates started to write this bit of code (below), but part way through they **ran into errors** they couldn’t figure out.

# %%
omicron_cases_each_week = []
days_per_week = 7
percentage = 1 / 100

for jj in range(omicron_cases_each_week):
    current_omicron_cases \
        = int(omicron_cases_each_week[jj] * days_per_week * omicron_percentage[jj])
omicron_cases_each_week.append(current_omicron_cases)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-8126df39da71> in <module>()
#       3 percentage = 1 / 100
#       4
# ----> 5 for jj in range(omicron_cases_each_week):
#       6     current_omicron_cases         = int(omicron_cases_each_week[jj] * days_per_week * omicron_percentage[jj])
#       7 omicron_cases_each_week.append(current_omicron_cases)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %% [markdown]
# &#9989;&nbsp; **Part 1 (36 points):** In the cell below, describe the errors in the code and how you solved it. Specifically, provide the following information:
#
# 1. Identify the lines of the given script which cause errors.
# 1. For each error, use a plain english to describe it.
# 1. How will you solve the errors?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER ###
#
# 1. **(12 Points)** Line 5, 7, and 8.
# 1. **(12 Points)** Line 5: It was trying to take the `range` of a list, not a number, and the variable is an empty list. Line 7: The formula is not correct, and the variable `omicron_cases_each_week` is used incorrectly. Line 8: The total number is updated only once outside of the loop.
# 1. **(12 Points)** Line 5: We needed to include `len` in line 5 so that we were acting on a number, and modify `omicron_cases_each_week` to `omicron_cases`. Line 7: Again, modify `omicron_cases_each_week` to `omicron_cases`, and the `percentage` should be multiplied on. Line 8: Align this line to line 6.

# %% [markdown]
# &#9989;&nbsp; **Part 2 (20 points):** In the empty code cell below, rewrite the buggy code so that it works properly.

# %%
# Put your modified code here

# %%
#### ANSWER ###

#Basically full points (20) for getting it running.

omicron_cases_each_week = []
days_per_week = 7
percentage = 1 / 100

for jj in range(len(averaging_cases)):
    current_omicron_cases \
        = int(averaging_cases[jj] * days_per_week * omicron_percentage[jj] * percentage)
    omicron_cases_each_week.append(current_omicron_cases)
print(omicron_cases_each_week)
# Out:
# [4578, 61642, 349272, 1078895, 2594991, 4673396, 5594232]

# %% [markdown]
# &#9989;&nbsp; **Part 3 (18 points):** Is this code looping by index or looping by value? Could you solve the problem using the other kind of `for` loop? If so, rewrite the code (in the code cell below) using the other form of looping. If not, rewrite the code using the `while` loop.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %%
# Rewrite the code using the other form of looping here

# %% [markdown]
# ### ANSWER ###
#
# - **(4 Points)** It is looping by index.
# - **(4 Points)** No we couldn't solve this problem by looping by value. You may say you can, if you define a list [0, 1, 2, 3, 4, 5, 6] and loop by value of that list.
# - **(10 Points)**The `while` loop is shown as following.

# %%
### ANSWER ###

omicron_cases_each_week = []
days_per_week = 7
percentage = 1 / 100

jj = 0
while jj < len(averaging_cases):
    current_omicron_cases \
        = int(averaging_cases[jj] * days_per_week * omicron_percentage[jj] * percentage)
    omicron_cases_each_week.append(current_omicron_cases)
    jj += 1
print(omicron_cases_each_week)
# Out:
# [4578, 61642, 349272, 1078895, 2594991, 4673396, 5594232]

# %% [markdown]
# &#9989;&nbsp; **Part 4 (16 points):** The purpose of this code is to calculate The total cases of Omicron variant in that period (all those weeks). In the cell below, modify the code above so that it calculates the total Omicron cases. Your code should also print out the total Omicron cases.

# %%
# Put your modified code that calculates total Omicron cases here

# %%
#### ANSWER ###

#Lots of ways to do this
#Full points (16) if it's working. 
#(I might take off a few if they do something like create an entirely new loop.)
# take off (1) if printing out just a number

#Example 1 (simplest)
omicron_cases_each_week = []
days_per_week = 7
percentage = 1 / 100
for jj in range(len(averaging_cases)):
    current_omicron_cases \
        = int(averaging_cases[jj] * days_per_week * omicron_percentage[jj] * percentage)
    omicron_cases_each_week.append(current_omicron_cases)
print(sum(omicron_cases_each_week))
# Out:
# 14357006

# %%
#### ANSWER ###

#Example 2
total_omicron_cases = 0
days_per_week = 7
percentage = 1 / 100
for jj in range(len(averaging_cases)):
    current_omicron_cases \
        = int(averaging_cases[jj] * days_per_week * omicron_percentage[jj] * percentage)
    total_omicron_cases += current_omicron_cases
print(total_omicron_cases)
# Out:
# 14357006

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page. Go to "Quizzes" -> "Quiz 1" -> "Please drop your Quiz 1 notebook here", and upload your notebook there.
