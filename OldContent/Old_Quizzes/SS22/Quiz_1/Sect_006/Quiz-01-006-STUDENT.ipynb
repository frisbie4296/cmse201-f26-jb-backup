# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 1 (Section 006 - Spring 2022)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ---
# # Academic integrity statement [10 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # Calculating Zoo Animal Food Amounts
#
# You landed an internship working for the Philadelphia Zoo, and your job is to keep track of how much food the animals are eating. For each type of animal, there are three lists:
# - One with the type of animal
# - One with the number animals of each type
# - One with the amount of food (in pounds) one animal eats

# %%
animal_types = ['African Lion','Amur Tiger','Flamingo','Cheetah','Giraffe','Golden lion tamarin','Hippopotamus','Red panda']
animal_numbers = [4,1,15,1,5,3,2,3]
food_amount = [7,14,0.25,6.2,75,2,90,3]

# %% [markdown]
# **Your boss has asked you to write a piece of code to calculate the amount of food consumed each day by each type of animal.** To calculate the total amount *for one animal*, the number of animals must be multiplied by the amount of food eaten per day (E.g., the total food eaten by the African lions is 7 pounds per Lion $\times$ 4 lions $=$ 28.) The total amount of food eaten is the sum of the amount of food eaten by each animal.
#
# Your boss started to write this bit of code (below), but part way through they **ran into an error** they couldn’t figure out.

# %%
all_animals_food_amounts = []

for index in range(animal_types):
    total_food_amount = animal_numbers[index]*food_amount[index]
    all_animals_food_amounts.append(total_food_amount)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_89300/3204528446.py in <module>
#       1 all_animals_food_amounts = []
#       2
# ----> 3 for index in range(animal_types):
#       4     total_food_amount = animal_numbers[index]*food_amount[index]
#       5     all_animals_food_amounts.append(total_food_amount)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %% [markdown]
# &#9989;&nbsp; **Part 1 (25 points):** In the cell below, describe the bug in the code and how you solved it. Specifically, provide the following information:
# 1. The line of code that caused the error(s)
# 2. (Where appropriate) The error code
# 3. A plain english description of the error(s) in the code
# 4. How you solved the error(s)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# &#9989;&nbsp; **Part 2 (15 points):** In the empty code cell below, rewrite the buggy code so that it works properly.

# %%
# Put your modified code here

# %% [markdown]
# &#9989;&nbsp; **Part 3 (25 points):** Is this code looping by index or looping by value? Could you solve the problem using the other kind of `for` loop?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# &#9989;&nbsp; **Part 4 (25 points):** The purpose of this code is to calculate the total amount of food eaten by the animals. In the cell below, modify the code above so that it calculates the total amount of food eaten by all animals combined. Your code should also print out the total amount.

# %%
# Put your modified code that calculates total cost here

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #1, and upload it there.
