# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 3 (Section 002 - Spring 2022)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ---
#
# # Finding Birthday Anomalies
#
# You work for the US census bureau, and you’ve been tasked with analyzing data regarding the frequency of births for different days of the year. If there are trends, the government might consider redistributing resources to deal with surges in births more effectively. You’ve been given a data set to conduct your analysis on.

# %% [markdown]
# &#9989;&nbsp; **Part 1 (1 point):** Import all the modules that you use in the cell below.

# %%
# Put your code here! 
import matplotlib.pyplot as plt 
# %matplotlib inline
import pandas as pd

# %% [markdown]
# &#9989;&nbsp; **Part 2 (2 points):** Read in the data from _US_births_2000-2014_SSA.csv_ into a DataFrame. Remove from your data the column associated with the day of the week.

# %%
# Write any code you need here
df = pd.read_csv("US_births_2000-2014_SSA.csv")
df = df.drop(columns=['day_of_week'])
df
# Out:
#       year  month  date_of_month  births
# 0     2000      1              1    9083
# 1     2000      1              2    8006
# 2     2000      1              3   11363
# 3     2000      1              4   13032
# 4     2000      1              5   12558
# ...    ...    ...            ...     ...
# 5474  2014     12             27    8656
# 5475  2014     12             28    7724
# 5476  2014     12             29   12811
# 5477  2014     12             30   13634
# 5478  2014     12             31   11990
#
# [5479 rows x 4 columns]

# %% [markdown]
# &#9989;&nbsp; **Part 3 (3 points):**  Extract the minimum, maximum and mean values of births contain in the data. You need to show the code that allows you to extract these information.
#
# Below, there are two cells. In the first one, you will put your code. In the second one, you will put the wanted information.

# %%
# Write any code you need here
df.describe()
# Out:
#               year        month  date_of_month        births
# count  5479.000000  5479.000000    5479.000000   5479.000000
# mean   2006.999270     6.522723      15.730243  11350.068261
# std       4.321085     3.449075       8.801151   2325.821049
# min    2000.000000     1.000000       1.000000   5728.000000
# 25%    2003.000000     4.000000       8.000000   8740.000000
# 50%    2007.000000     7.000000      16.000000  12343.000000
# 75%    2011.000000    10.000000      23.000000  13082.000000
# max    2014.000000    12.000000      31.000000  16081.000000

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*
#
# mean = 11350.07
#
# min = 5728
#
# max = 16081

# %% [markdown]
# &#9989;&nbsp; **Part 4 (3 points):** Select all the data for the third of the month (i.e., where the date_of_month=3). Print out the minimum, maximum and mean values of *births* that occurred on the third of the month. You need to show the code that allows you to extract these information.
#
# Below, there are two cells. In the first one, you will put your code. In the second one, you will put the wanted information.

# %%
# Write any code you need here
df_third = df[df['date_of_month']==3]
df_third['births'].describe()
# Out:
# count      180.000000
# mean     11346.894444
# std       2291.615142
# min       6876.000000
# 25%       8716.750000
# 50%      12313.500000
# 75%      13089.250000
# max      14814.000000
# Name: births, dtype: float64

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*
#
# average = 11346.894444
#
# min = 6876
#
# max = 14814

# %% [markdown]
#  &#9989;&nbsp; **Part 5 (3 points):** Make a scatter plot showing the number of births vs the date of the month. Your figure should contain a title, a $x$-axis label, a $y$-axis label.

# %%
# Write any code you need here
plt.scatter(df['date_of_month'],df['births'])
plt.xlabel('date of the month')
plt.ylabel('number of births')
plt.title('number of births in function of the date of the month')
# Out:
# Text(0.5, 1.0, 'number of births in function of the date of the month')

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #3, and upload it there.

# %% [markdown]
# &#169; Copyright 2021,  Michigan State University Board of Trustees
