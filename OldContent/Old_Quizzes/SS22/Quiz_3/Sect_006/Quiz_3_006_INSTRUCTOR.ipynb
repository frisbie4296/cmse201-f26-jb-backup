# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 3 (Section 006 - Spring 2022)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ---
# # Academic integrity statement [10 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # Analyzing Average Precipitation in the United States
#
# You are working for NOAA, and your boss has asked you to investigate weather data from weather stations all over the United States. You want to see if there are overall changes in the average precipitation amounts throughout the year among these weather stations. Fortunately, you have learned to use the `pandas` package in Python, and you are pretty sure you can use it to explore the data and do calculations.

# %% [markdown]
# #### &#9989;&nbsp; **Part 1 (15 points):** Examine the data file and describe the columns of data it contains.

# %%
# Write any code you need here

# %%
### ANSWER ###

import pandas as pd

df = pd.read_csv("weather.csv")
df
# Out:
#        Date_Month  Date_Year Station_City Station_State  Data_Temperature  \
# 0               1       2016   Birmingham       Alabama                39
# 1               1       2016   Huntsville       Alabama                39
# 2               1       2016       Mobile       Alabama                46
# 3               1       2016   Montgomery       Alabama                45
# 4               1       2016    Anchorage        Alaska                34
# ...           ...        ...          ...           ...               ...
# 16738           1       2017       Casper       Wyoming                23
# 16739           1       2017     Cheyenne       Wyoming                32
# 16740           1       2017       Lander       Wyoming                17
# 16741           1       2017      Rawlins       Wyoming                23
# 16742           1       2017     Sheridan       Wyoming                21
#
#        Data_Precipitation
# 0                    0.00
# 1                    0.00
# 2                    0.16
# 3                    0.00
# 4                    0.01
# ...                   ...
# 16738                0.08
# 16739                0.00
# 16740                0.00
# 16741                0.06
# 16742                0.10
#
# [16743 rows x 6 columns]

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### ANSWER ###
#
# Data file contains six columns: year, monh, date_of_month, day_of_week, and births. There are 5479 rows, and it contains information about the number of births in the US for every day of the year between January 1st, 2000 and December 31st, 2014.

# %% [markdown]
# #### &#9989;&nbsp; **Part 2 (20 points):** Select all the data for January (i.e., where the Date_Month=1). Print out the mean (average) amount of *precipitation* that occurred in January.

# %%
# Write any code you need here

# %%
### ANSWER ###

df_jan = df[df['Date_Month'] == 1]
df_jan.head()
jan_mean = df_jan['Data_Precipitation'].mean()
print(jan_mean)
# Out:
# 0.4664693446088787

# %% [markdown]
# #### &#9989;&nbsp; **Part 3 (40 points):** Calculate the mean amount of precipitation for every month of the year. Make a plot showing the average amount of precipitation for each month of the year.

# %%
# Write any code you need here

# %%
### ANSWER ###

import matplotlib.pyplot as plt

all_months_mean = []
for month in range(0,12):
    df_temp = df[df['Date_Month'] == month]
    all_months_mean.append(df_temp['Data_Precipitation'].mean())
plt.plot(range(0,12),all_months_mean)

# %% [markdown]
# #### &#9989;&nbsp; **Part 4 (15 points):** Use the figure you just created to answer the following question: how does the average amount of precipitation vary throughout the year in the United States?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #3, and upload it there.

# %% [markdown]
# &#169; Copyright 2021,  Michigan State University Board of Trustees
