# %% [markdown]
# # Day 16: In-class Assignment: Introduction to Modeling with ODEs

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Put your name here.</p>
#
# #### <p style="text-align: right;"> &#9989; Put your group member names here.</p>

# %% [markdown]
# ### Goals for Today's In-Class Assignment
# By the end of this assignment, you should be able to:
# * Use Python to numerically solve an ordinary differential equation (ODE)
# * Apply numerical integration to model population growth over time
# * Visualize how the population changes over time by making plots
# * Explore other ODE models
#
# ### Assignment instructions
#
# Today, **with your group**, you're going to try to apply what you've learned in the pre-class assignment to explore modeling with ordinary differential equations.
#
# **This assignment is due at the end of class** and should be uploaded into the appropriate "In-class Assignments" submission folder.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ## Part 1: Reviewing Observations from the Pre-class
# -------------------
# ### Task
#
# As a group, discuss your answers to Parts 3 and 4 of the pre-class. Summarize your discussion below. What parameters are changing and which are not? What differences did you have in your responses?

# %% [markdown]
# <font size="+3">&#9998;</font> **Put your answer here**

# %% [markdown]
# ### Task
#
# As a group, compare your `derivs` functions and your pseudocode for update equations. Determine how you as a group would combine `derivs` and the update equations loop to solve an ODE. In the cell below, summarize your discussion.

# %% [markdown]
# <font size="+3">&#9998;</font> **Put your answer here**

# %% [markdown]
# ## STOP
#
# Discuss your pseudocode for with an instructor before moving on!

# %% [markdown]
# ## Part 2: Coding Update Equations
# -------------------
# ### Task
#
# In the cell below, fill in the `derivs` function with the code you agreed upon as a group.

# %%
# Define a function that computes the derivatives
def derivs(# PUT YOUR INPUT(S) HERE):
    # Define any important constants here

    # Define the differential equation for population
    
    #return the derivative
    return ### ANSWER ###
# Out:
#   File "C:\Users\rache\AppData\Local\Temp/ipykernel_138260/4187508386.py", line 8
#     return ### ANSWER ###
#     ^
# SyntaxError: invalid syntax

# %%
### ANSWER ###
# Define a function that computes the derivatives
def derivs(P):
    # Define any important constants
    k=0.01
    C=12e9
    # Define how pop changes
    dPdt = k*P*(1-(P/C))
    #return the derivatives
    return dPdt

# %% [markdown]
# ### Task
#
# To actually solve the ODE, you will need to code the update equations. In the cell below, fill in the missing lines of code. Use your pseudocode from Part 1 as a reference. The code below is only one suggestion for a solution, and you can alter it (or start fresh) based on your pseudocode from Part 1.
#
# Your code should result in a list (or array) of population values for the time interval from 0 to 500 years in steps of 50 years. Your initial value should be $P_0 = 1$ billion and you can assume $k = 0.01$ and $C=12$ billion.

# %%
# Define initial conditions
P0 = # your initial value for population here
t0 = # your initial value for time here

# Define the final time and the time step
final_time = # your final time value here
delta_t = # your time step size here

# Define some lists to store values
time_list = []
population = []


# Store the initial state of the system in the lists
time_list.append(t0)
population.append(P0)

# STOP!! What just happened in the lines above? Comment each line so you remember!

# Write a loop for evolving the system
t = t0 # Comment this line!!
p = P0 # Comment this line!!
while t < final_time:
    # Call our function to compute the values of the derivatives
    # We need to make sure we catch the values it returns!
    dpdt = # your derivs function call here
    
    # Use our "update equations" to compute new values
    p_new = # your update equation here
    
    # Store the new values
    population.append(p_new)
    
    # Set the old values to be the new values
    # FILL IN THIS LINE

    
    # Update the time and store that as well
    t += delta_t
    time_list.append(t)
# Out:
#   File "C:\Users\rache\AppData\Local\Temp/ipykernel_138260/3110404961.py", line 2
#     P0 = # your initial value for population here
#          ^
# SyntaxError: invalid syntax

# %%
### ANSWER ###

# Define initial conditions
P0 = 1e9
t0 = 0

# Define the final time and the time step
final_time = 500 # your final time value here
delta_t = 50 # your time step size here

# Define some lists to store values
time_list = []
population = []


# Store the initial state of the system in the lists
time_list.append(t0)
population.append(P0)

# STOP!! What just happened in the lines above? Comment each line so you remember!

# Write a loop for evolving the system
t = t0 # Comment this line!!
p = P0 # Comment this line!!
while t < final_time:
    # Call our function to compute the values of the derivatives
    # We need to make sure we catch the values it returns!
    dpdt = derivs(p)# your derivs function call here
    
    # Use our "update equations" to compute new values
    p_new = p + dpdt * delta_t # your update equation here
    
    # Store the new values
    population.append(p_new)
    
    # Set the old values to be the new values
    # FILL IN THIS LINE
    p = p_new
    
    # Update the time and store that as well
    t += delta_t
    time_list.append(t)

# %% [markdown]
# ### Question
#
# How do you know your code is working? Put any tests you ran in the cell below.

# %%
# put your tests here

# %% [markdown]
# --------------
# ## Part 3: Visualizing your Results
#
# Now that you have a solution to our differential equation from numerical integration, it is time to visualize your numerical solution along with the exact solution. The exact solution as a Python function is given in the cell below.

# %%
def population_func(time,pinitial,bigc,littlek):
    a = (bigc - pinitial)/pinitial
    pop = bigc/(1 + a*np.exp(-1.0*littlek*time))
    return pop

# %% [markdown]
# ### Task
#
# In the cell below, plot the exact solution population function for the time interval from 0 to 500 years in steps of 1 year.

# %%
# put your code here

# %%
### ANSWER ###
import numpy as np
import matplotlib.pyplot as plt

smooth_time = np.arange(0,500,1)
plt.plot(smooth_time,population_func(smooth_time,1e9,12e9,0.01),label='exact')
plt.xlabel("Time [years]")
plt.ylabel("Population")
# Out:
# Text(0, 0.5, 'Population')

# %% [markdown]
# ### Task
#
# Now we want to compare the exact solution to the numerical solution for each time step **of the numerical solution**. Using the start code below, add your code to plot the exact solution and the numerical solution in the indicated place. If you did not use the starter code in Part 2, use your Part 2 code here!

# %%
# To get the plot to display the plot to your screen at each timestep as the loop runs,
# we need these libraries
from IPython.display import display, clear_output
import time 

# Define initial conditions
P0 = 1e9
t0 = 0

# Define the final time and the time step
final_time = 500 # your final time value here
delta_t = 50 # your time step size here

# Define some lists to store values
time_list = []
population = []


# Store the initial state of the system in the lists
time_list.append(t0)
population.append(P0)

# STOP!! What just happened in the lines above? Comment each line so you remember!

# Write a loop for evolving the system
t = t0 # Comment this line!!
p = P0 # Comment this line!!

# setting up the plot
fig = plt.figure(figsize=(10,10))

while t < final_time:
    # Call our function to compute the values of the derivatives
    # We need to make sure we catch the values it returns!
    dpdt = # your derivs function call here
    
    # Use our "update equations" to compute new values
    p_new = p + dpdt * delta_t # your update equation here
    
    # Store the new values
    population.append(p_new)
    
    # Set the old values to be the new values
    # FILL IN THIS LINE
    p = p_new
    
    # Update the time and store that as well
    t += delta_t
    time_list.append(t)
    
    # visualize the exact solution with the numerical solution
    plt.scatter(# code for plotting your numerical solution)
    plt.plot(# code for plotting your numerical solution goes here too)
    plt.plot(# Code for plotting your exact solution goes here)
    plt.xlabel("Time [years]")
    plt.ylabel("Population")
    plt.legend()
    
    # These 4 lines display the plot as the loop iterates!
    time.sleep(0.1)  # 
    clear_output(wait=True)
    display(fig)
    fig.clear()
# Out:
#   File "C:\Users\rache\AppData\Local\Temp/ipykernel_138260/2612981771.py", line 35
#     dpdt = # your derivs function call here
#            ^
# SyntaxError: invalid syntax

# %%
### ANSWER ###
# To get the plot to display the plot to your screen at each timestep as the loop runs,
# we need these libraries
from IPython.display import display, clear_output
import time 


# Define initial conditions
P0 = 1e9
t0 = 0

# Define the final time and the time step
final_time = 500 # your final time value here
delta_t = 50 # your time step size here

# Define some lists to store values
time_list = []
population = []


# Store the initial state of the system in the lists
time_list.append(t0)
population.append(P0)

# STOP!! What just happened in the lines above? Comment each line so you remember!

# Write a loop for evolving the system
t = t0 # Comment this line!!
p = P0 # Comment this line!!

# setting up the plot
fig = plt.figure(figsize=(10,10))

while t < final_time:
    # Call our function to compute the values of the derivatives
    # We need to make sure we catch the values it returns!
    dpdt = derivs(p)# your derivs function call here
    
    # Use our "update equations" to compute new values
    p_new = p + dpdt * delta_t # your update equation here
    
    # Store the new values
    population.append(p_new)
    
    # Set the old values to be the new values
    # FILL IN THIS LINE
    p = p_new
    
    # Update the time and store that as well
    t += delta_t
    time_list.append(t)
    
    # visualize the exact solution with the numerical solution
    plt.scatter(time_list,population, color="orange",label='Euler')
    plt.plot(time_list,population, color="orange")
    plt.plot(smooth_time,population_func(smooth_time,1e9,12e9,0.01),label='exact')
    plt.xlabel("Time [years]")
    plt.ylabel("Population")
    plt.legend()
    
    # These 4 lines display the plot as the loop iterates!
    time.sleep(0.1)  # 
    clear_output(wait=True)
    display(fig)
    fig.clear()

# %% [markdown]
# --------------
# ## Part 4: Changing the Time Step
#
# Your numerical solution is using a time step of 50 years. In the cell below, use your previous code but change the timestep to 10 years and 100 years. Visualize your solutions with the exact solution.

# %%
# put your code here

# %%
### ANSWER ###
# To get the plot to display the plot to your screen at each timestep as the loop runs,
# we need these libraries
from IPython.display import display, clear_output
import time 


# Define initial conditions
P0 = 1e9
t0 = 0

# Define the final time and the time step
final_time = 500 # your final time value here
delta_t = 10 # your time step size here

# Define some lists to store values
time_list = []
population = []


# Store the initial state of the system in the lists
time_list.append(t0)
population.append(P0)

# STOP!! What just happened in the lines above? Comment each line so you remember!

# Write a loop for evolving the system
t = t0 # Comment this line!!
p = P0 # Comment this line!!

# setting up the plot
fig = plt.figure(figsize=(10,10))

while t < final_time:
    # Call our function to compute the values of the derivatives
    # We need to make sure we catch the values it returns!
    dpdt = derivs(p)# your derivs function call here
    
    # Use our "update equations" to compute new values
    p_new = p + dpdt * delta_t # your update equation here
    
    # Store the new values
    population.append(p_new)
    
    # Set the old values to be the new values
    # FILL IN THIS LINE
    p = p_new
    
    # Update the time and store that as well
    t += delta_t
    time_list.append(t)
    
    # visualize the exact solution with the numerical solution
    plt.scatter(time_list,population, color="orange",label='Euler-10yr')
    plt.plot(time_list,population, color="orange")
    plt.plot(smooth_time,population_func(smooth_time,1e9,12e9,0.01),label='exact')
    plt.xlabel("Time [years]")
    plt.ylabel("Population")
    plt.legend()
    
    # These 4 lines display the plot as the loop iterates!
    time.sleep(0.1)  # 
    clear_output(wait=True)
    display(fig)
    fig.clear()

# %%
### ANSWER ###
# To get the plot to display the plot to your screen at each timestep as the loop runs,
# we need these libraries
from IPython.display import display, clear_output
import time 


# Define initial conditions
P0 = 1e9
t0 = 0

# Define the final time and the time step
final_time = 500 # your final time value here
delta_t = 100 # your time step size here

# Define some lists to store values
time_list = []
population = []


# Store the initial state of the system in the lists
time_list.append(t0)
population.append(P0)

# STOP!! What just happened in the lines above? Comment each line so you remember!

# Write a loop for evolving the system
t = t0 # Comment this line!!
p = P0 # Comment this line!!

# setting up the plot
fig = plt.figure(figsize=(10,10))

while t < final_time:
    # Call our function to compute the values of the derivatives
    # We need to make sure we catch the values it returns!
    dpdt = derivs(p)# your derivs function call here
    
    # Use our "update equations" to compute new values
    p_new = p + dpdt * delta_t # your update equation here
    
    # Store the new values
    population.append(p_new)
    
    # Set the old values to be the new values
    # FILL IN THIS LINE
    p = p_new
    
    # Update the time and store that as well
    t += delta_t
    time_list.append(t)
    
    # visualize the exact solution with the numerical solution
    plt.scatter(time_list,population, color="orange",label='Euler-100yr')
    plt.plot(time_list,population, color="orange")
    plt.plot(smooth_time,population_func(smooth_time,1e9,12e9,0.01),label='exact')
    plt.xlabel("Time [years]")
    plt.ylabel("Population")
    plt.legend()
    
    # These 4 lines display the plot as the loop iterates!
    time.sleep(0.1)  # 
    clear_output(wait=True)
    display(fig)
    fig.clear()

# %% [markdown]
# ### Question
#
# What effect does changing the time step have on your numerical solution?

# %% [markdown]
# <font size="+3">&#9998;</font> **Put your answer here**

# %% [markdown]
# ## Part 5 (Time Permitting): Exploring Another Model
#
# There are several other simple ordinary differential equations that have solutions we can obtain similarly to the population growth model. [This website](http://sites.science.oregonstate.edu/math/home/programs/undergrad/CalculusQuestStudyGuides/ode/first/examples/examples.html#population) mentions a few of them.
#
# ### Question
#
# Research one of the models on the website, and answer the following questions:
# 1. Describe the model and the system it is modeling.
# 2. What are the parameters that are changing?
# 3. What are the parameters that are constant?
# 4. What derivatives would you calculate in your `derivs` function?

# %% [markdown]
# <font size="+3">&#9998;</font> **Put your answer here**

# %% [markdown]
# ### Task
#
# Write a new `derivs` function for your new model. Test it in the same way you tested the population growth model in the pre-class.

# %%
# put your code here

# %% [markdown]
# ---
# ## Assignment wrapup
#
# Please fill out the form that appears when you run the code below. **You must completely fill this out in order to receive credit for the assignment!**

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://cmse.msu.edu/cmse201-ic-survey" 
	width="800px" 
	height="600px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)

# %% [markdown]
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the "In-Class Assignments" folder, find the appropriate submission link, and upload it there.

# %% [markdown]
# &#169; Copyright 2022,  Michigan State University Board of Trustees
