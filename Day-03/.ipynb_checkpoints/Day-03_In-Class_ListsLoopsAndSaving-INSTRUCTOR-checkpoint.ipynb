# %% [markdown]
# # Day 3 In-class Assignment: The power of compound interest
# <img src="https://g.foolcdn.com/image/?url=https%3A//g.foolcdn.com/editorial/images/463624/retirement-savings-jar-full-of-coins-and-alarm-clock.jpg&w=2000&op=resize" width=400px>

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Put your name here.
# <p style="text-align: right;"> &#9989; Put your group member names here.

# %% [markdown]
# ## Learning Goals:
#
# By the end of this assignment you should be able to:
#
# * Use Python lists to store values
# * Use loops to iterate over a specified range or until a condition is met.
# * Compute the best retirement savings plan.

# %% [markdown]
# ---
# ## The Problem
#
# You are working for a bank, writing code to calculate the revenue and expenses for the company. A person can deposit money in a retirement account at your bank, and the bank pays interest every year on the money in the retirement account. The mathematical expression for calculating the amount of money in the retirement account every year is:
#
# $\mathrm{New~Retirement~Total} = (\mathrm{Old~Retirement~Total}) + [(\mathrm{Old~Retirement~Total})*(\mathrm{Interest~Rate})] + (\mathrm{Money~Added~to~Retirement})$
#
# Or, if we simplify this a bit, we can re-write it as:
#
# $\mathrm{New~Retirement~Total} = [(\mathrm{Old~Retirement~Total})*(\mathrm{1 + Interest~Rate})] + (\mathrm{Money~Added~to~Retirement})$
#
# **Your job is to write a piece of code that calculates and stores (in a list) the total amount of money in the retirement account *every year* for some number of years** (your boss is going to make a plot of it, so make sure you have the value for each year!).
#
# Your boss tells you to model the total retirement savings for a ***range*** of different parameters (*e.g.* interest rates and annual contributions).
#
# **You can assume that the person saving for retirement starts when they're 18 and continues until they're 65. Also assume that the interest rate and annual contributions are fixed.**

# %% [markdown]
# ---
# ## 1. Planning your solution and pseudo-coding
#
# Before you start writing any code you should come up with a plan for how you've going to solve the problem. During this phase you should identify and define the variables that are revelant to the problem, the equations you're going to need to model, the overall structure of the program that you will write, and how you will make sure the code is running correctly.
#
# #### You and your group members are expected to use the white board at your table (or a virtual whiteboard app like [Office Whitebaord](https://whiteboard.office.com/)) to write out your ideas to ensure that everyone is on the same page and allow your instructors to see your progress.
#
# Part of this planning process should involve writing "**pseudo-code**", a plain language description of the steps in your code (sort of like writing out in your code in form of a cooking recipe). **You actually already did a version of this on Day 1 when you and your group came up with an _algorithm_ for sorting people by their birthday.**
#
# As a reminder, **an algorithm is**: a procedure for solving a problem in terms of the actions to be executed and the order in which those actions are to be executed. In other words, an algorithm is merely the sequence of steps taken to solve a problem. [[source](https://www.unf.edu/~broggio/cop2221/2221pseu.htm) of this definition]
#
# You can see some examples of pseudocode [here](https://www.unf.edu/~broggio/cop2221/2221pseu.htm) and [here](https://www.geeksforgeeks.org/how-to-write-a-pseudo-code/).
#
# Things you should decide on during your planning and psuedo-coding:
#
# 1. What quantities in your model are "variables" that will change as a function of time? What are the initial values of these variables?
# 2. What quantities in your model are "parameters" that are constant over time? What are reasonable ranges for each parameter?
# 4. How will you go about solving this problem for a given set of inputs?
# 5. How will you check to make sure your code is running correctly.
#
#
# You should be able to justify your choices.
#
# ### &#9989;&nbsp; 1.1 Record the details of you plan in the Markdown cell below.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your plan details here!*

# %% [markdown]
# ### ANSWER ###
#
# 1. Variables of importance are the retirement total.
# 2. Parameters of importance are the interest rate and the money added. If you look up average retirement account interest rate, it's between 0.05-0.08. So let's say 0.065. They may need help with the money added every year... A good ball park is 300-500/month, which translates to about 3500-6000/year.
# 3. IMPORTANT BITS
#   - Need to have a `for` loop and store the values in a list.
#   - If they want to get fancy, they can use the -1 index to grab the previous value. Otherwise, they're going to need to hold on to the current value.
#   - Hopefully they'll recognize that everything needs to be defined outside of the loop.
# 4. Few ways to answer this. I'll let you use your discretion to decide if what they're doing is adequate. One example: Use print statement. Check the code calculations against the by-hand calculations, to make sure getting the same results.

# %% [markdown]
# ## &#128721; STOP AND ASK YOUR INSTRUCTOR TO COME OVER AND CHECK YOUR PSEUDOCODE
#
# ---
# ## 2. Coding up your solution
#
# Now that you and your group have come up with a plan for your code, it's time to put your plan into action.
#
# ### &#9989;&nbsp; 2.1 Writing Code
# **Write your code for calculating the total retirement savings in the cell below. Start by writing code for a single set of parameter values (i.e., not a range).** It is simpler, and you can also add to it later.
#
# **Hint: Remember to update the value of $\mathrm{Old~Retirement~Total}$ in your loop!**

# %%
# Put your code for calculating the total amount of retirement savings here

# %%
### ANSWER ###


money_added = 10000.0 #we'll say they add 5000 dollars to their savings every year
interest_rate = 0.065
years_of_investment = 65-18

total_savings = []
current_savings = 0
old_savings = 0

for jj in range(years_of_investment):
    current_savings = old_savings + old_savings*interest_rate + money_added
    total_savings.append(current_savings)
    old_savings = current_savings

# %% [markdown]
# ---
# ### &#128721; STOP
#
# **Check to make sure your code is working correctly.**

# %%
# If your method for checking your results involves writing code, put it here

# %%
### ANSWER ###

for val in total_savings:
    print(val)
# Out:
# 10000.0
# 20650.0
# 31992.25
# 44071.74625
# 56936.409756249996
# 70637.27639040624
# 85228.69935578265
# 100768.56481390852
# 117318.52152681258
# 134944.22542605537
# 153715.60007874898
# 173707.11408386767
# 194998.07649931905
# 217672.95147177478
# 241821.69331744013
# 267540.10338307376
# 294930.21010297356
# 324100.67375966685
# 355167.2175540452
# 388253.08669505815
# 423489.5373302369
# 461016.3572567023
# 500982.42047838797
# 543546.2778094832
# 588876.7858670997
# 637153.7769484611
# 688568.7724501111
# 743325.7426593683
# 801641.9159322273
# 863748.6404678221
# 929892.3020982306
# 1000335.3017346156
# 1075357.0963473655
# 1155255.3076099444
# 1240346.9026045906
# 1330969.451273889
# 1427482.4656066918
# 1530268.8258711267
# 1639736.29955275
# 1756319.1590236789
# 1880479.904360218
# 2012711.098143632
# 2153537.319522968
# 2303517.245291961
# 2463245.8662359384
# 2633356.8475412745
# 2814525.0426314576

# %% [markdown]
# *Explain how you know your code is working correctly.*

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your explanation here!*

# %% [markdown]
# ### ANSWER ###
#
# It starts at 5000 dollars, as it should.
#
# The next value should be 5000*(1.065) + 5000, which is 10325
#
# the third value should be 10325*(1.065) + 5000 = 15996.12, which is correct.
#
# I'm happy after three checks.

# %% [markdown]
# ## 3. Coding up your solution (Range of Values)
#
# ### &#9989;&nbsp; 3.1 Putting in a Range of Values
# **Take the code you wrote in Part 2 and experiment with a range of different input parameters and record your observations of the results.** For example, try running your loop with a couple different interest rates while keeping everything else the same. Then, try running your loops with different values for money added while keeping everything else the same.
#
# **Note:** If your group is feeling confident about loops, try to use a "nested" loop (a loop inside a loop) to explore multiple values of interest rate or money added all at once! Look back at the pre-class assignment challenge problem for an example!

# %%
# Put your code for calculating the total amount of retirement savings for a range of values here

# %%
### ANSWER ###
# Code for savings per year from Part 2
# Students should change money_added and/or interest_rate and record what they observe below!
# If folks finish early or feel really confident about loops, they can try to explroe multiple values at once with a nested loop

money_added = 10000.0 #we'll say they add 5000 dollars to their savings every year
interest_rate = 0.065
years_of_investment = 65-18

total_savings = []
current_savings = 0
old_savings = 0

for jj in range(years_of_investment):
    current_savings = old_savings + old_savings*interest_rate + money_added
    total_savings.append(current_savings)
    old_savings = current_savings

### Nested Loop Version
money_added_list = [2500,5000.0,10000.0] #we'll say they add 5000 dollars to their savings every year
interest_rate_list = [0.025, 0.05, 0.075, 0.1]
years_of_investment = 65-18



for pp in range(len(money_added_list)):
    money_added = money_added_list[pp]
    
    for ii in range(len(interest_rate_list)):
        interest_rate = interest_rate_list[ii]
        total_savings = []
        current_savings = 0
        old_savings = 0
        
        for jj in range(years_of_investment):
            current_savings = old_savings + old_savings*interest_rate + money_added
            total_savings.append(current_savings)
            old_savings = current_savings

        print("For annual money added of ",money_added,", and interest rate of ",interest_rate, ", final savings were ", current_savings/1.0e6, " (in millions)")
# Out:
# For annual money added of  2500 , and interest rate of  0.025 , final savings were  0.21916971323838497  (in millions)
# For annual money added of  2500 , and interest rate of  0.05 , final savings were  0.4452985546162911  (in millions)
# For annual money added of  2500 , and interest rate of  0.075 , final savings were  0.9645426381946933  (in millions)
# For annual money added of  2500 , and interest rate of  0.1 , final savings were  2.179937131474367  (in millions)
# For annual money added of  5000.0 , and interest rate of  0.025 , final savings were  0.43833942647676993  (in millions)
# For annual money added of  5000.0 , and interest rate of  0.05 , final savings were  0.8905971092325822  (in millions)
# For annual money added of  5000.0 , and interest rate of  0.075 , final savings were  1.9290852763893866  (in millions)
# For annual money added of  5000.0 , and interest rate of  0.1 , final savings were  4.359874262948734  (in millions)
# For annual money added of  10000.0 , and interest rate of  0.025 , final savings were  0.8766788529535399  (in millions)
# For annual money added of  10000.0 , and interest rate of  0.05 , final savings were  1.7811942184651643  (in millions)
# For annual money added of  10000.0 , and interest rate of  0.075 , final savings were  3.8581705527787733  (in millions)
# For annual money added of  10000.0 , and interest rate of  0.1 , final savings were  8.719748525897469  (in millions)

# %% [markdown]
# ### &#9989;&nbsp; 3.2 Recording Observations
#
# What did you notice about the growth of the savings amount when you changed the interest rate? What about money added?

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your observations here!*

# %% [markdown]
# ### ANSWER
# Ask students to pay attention to how the numbers change with dofferent interest rates vs. money added. Which one has a bigger impact on the final number? We want them to make primarily qualitative observations that will set them up for Part 4.

# %% [markdown]
# ## 4. Bringing in new customers
#
# Your boss says the bank is trying to attract customers that don't start saving for retirement until later in life, and they're trying to find a good way to do this. You suggest offering **double the usual interest rate** for people that don't start saving until they're 30.
#
# Your boss likes the idea and wants you to run the numbers.
#
# ### &#9989;&nbsp; 4.1 Answering your Boss' Question, Code
# **Who would end up with more money saved: someone that starts saving at 18 with a normal interest rate, or someone that starts saving at 30 with double the interest rate?**

# %%
# Put your code here

# %%
### ANSWER ###
money_added = 5000.0 #we'll say they add 5000 dollars to their savings every year
interest_rate = 0.065
years_of_investment = 65-18

total_savings = []
current_savings = 0
old_savings = 0

for jj in range(years_of_investment):
    current_savings = old_savings + old_savings*interest_rate + money_added
    total_savings.append(current_savings)
    old_savings = current_savings


regular_savings = current_savings



years_of_investment = 65-30
interest_rate = 0.065*2.0

total_savings = []
current_savings = 0
old_savings = 0

for jj in range(years_of_investment):
    current_savings = old_savings + old_savings*interest_rate + money_added
    total_savings.append(current_savings)
    old_savings = current_savings

later_savings = current_savings

print("Regular savings are: ",regular_savings/1.0e6)
print("Starting late savings are: ",later_savings/1.0e6)
# Out:
# Regular savings are:  1.4072625213157288
# Starting late savings are:  2.733404094865977

# %% [markdown]
# ### &#9989;&nbsp; 4.2 Answering your Boss' Question, Answer
#
# **Who would end up saving more money for retirement?**

# %% [markdown]
# *Write your answer here*

# %% [markdown]
# ### ANSWER ###
# The person that started later with the higher interest rate.

# %% [markdown]
# ---
# ## Assignment wrap-up
#
# Please fill out the form that appears when you run the code below. ***For today's assignment, ignore the part about pre-class assignment.*  You must completely fill this out in order to receive credit for the assignment!**

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://cmse.msu.edu/cmse201-ic-survey" 
	width="800px" 
	height="600px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://cmse.msu.edu/cmse201-ic-survey"
# 	width="800px"
# 	height="600px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ## Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the "In-class assignments" folder, find the appropriate submission link, and upload it there.
#
# See you next class!

# %% [markdown]
# &#169; Copyright 2023,  Department of Computational Mathematics, Science and Engineering at Michigan State University.
