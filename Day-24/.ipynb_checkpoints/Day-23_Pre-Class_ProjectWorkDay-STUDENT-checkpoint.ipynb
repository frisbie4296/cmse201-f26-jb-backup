# %% [markdown]
# For this pre-class, prepare 1-2 slides with a project update for your group memebers
# You should share your research question, progress so far, what challenges you have faced, and your plan for completion
