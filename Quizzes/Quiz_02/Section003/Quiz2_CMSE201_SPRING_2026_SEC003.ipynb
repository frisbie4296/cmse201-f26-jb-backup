# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 2 (Spring 2026)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging code

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # Introduction
#
# In this assignment, you will analyze a dataset containing information about [student academic performance and factors that may influence exam scores](https://www.kaggle.com/datasets/ayeshasiddiqa123/student-perfirmance). The dataset includes variables such as study hours, attendance, sleep hours, tutoring sessions, and exam scores. Using Python tools, you will compute descriptive statistics and create visualizations to better understand relationships within the data.

# %% [markdown]
# ## Part 1a) (20 points)
#
# Using the test data below, **write a function that takes two arrays of values as input and returns the following statistics**:
#
# - The **mean** of the first array
# - The **standard deviation** of the first array
# - The **median** of the first array
# - The **Pearson correlation coefficient** between the two arrays
#
# Demonstrate that your function works by calling it using the test data provided below.
#
# We will use this function later in the quiz to analyze the relationship between different variables in the dataset.
#
# **Note:**
# The first three statistics (mean, standard deviation, and median) should be calculated using the **first array only**, while the **correlation coefficient should be calculated using both arrays**.
#
# You are provided with both `x` and `y` test data to demonstrate that your function works correctly.

# %%
import numpy as np

# test data
test_x = np.arange(0,10,1.0)

test_y = np.array([
    14., 78., 98., 56., 75.,
    67., 84., 63., 45., 31.
])

# PUT YOUR FUNCTION HERE

# %% [markdown]
# #### &#9989;&nbsp; **Question 1b Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 1 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> PUT YOUR ANSWER FOR 1b) HERE!

# %% [markdown]
# ## Part 2a) (10 points)
#
# Now that you have a function to help analyze the data, it's time to load in some real data!
#
# The file `StudentPerformanceFactors.csv` contains data for **6607 students**, including both **categorical and numerical variables** related to student performance.
#
# **Using NumPy (not pandas!), load the `StudentPerformanceFactors.csv` file into your notebook.**
#
# Choose **one numerical column other than `Exam_Score`** to explore.
#
# Using **matplotlib**, create a **scatter plot** that visualizes the relationship between your chosen variable and `Exam_Score`.
#
# Your plot should include:
#
# - Your chosen numerical variable on the **x-axis**
# - `Exam_Score` on the **y-axis**
# - Proper **axis labels**
# - A **descriptive title**
#
# This plot will help you visually explore whether there appears to be a relationship between the selected factor and students' exam performance.

# %%
import matplotlib.pyplot as plt
# PUT YOUR CODE HERE

# %% [markdown]
# #### &#9989;&nbsp; **Question 2b Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 2 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ## Part 3a) (10 points)
#
# Now that you have visualized the relationship between the variables, it is time to compute some descriptive statistics.
#
# Using **your function from Part 1**, calculate the following statistics for the **`Exam_Score`** variable:
#
# - The **mean**
# - The **standard deviation**
# - The **median**
#
# Also calculate the **correlation coefficient between `Exam_Score` and the numerical variable you selected in Part 2**.
#
# Print all computed values clearly.
#
# If your function from Part 1 does not work, you may compute these values directly using **NumPy** for partial credit.

# %%
# Put your code here

# %% [markdown]
# ## Part 4a) (10 points)
#
# To share your insight, you want to create a summary plot of your data and the descriptive statistics.
#
# In the cell below, create a plot that visualizes the relationship between **`Exam_Score` and the variable you selected in Part 2**, along with the descriptive statistics of **`Exam_Score`**.
#
# Your plot should include the following:
#
# - A **scatter plot** of your chosen variable (x-axis) versus **`Exam_Score` (y-axis)**
# - A horizontal line showing the **mean of `Exam_Score`**
# - A horizontal line showing the **median of `Exam_Score`**
# - Horizontal lines showing **± one standard deviation from the mean of `Exam_Score`**
#
# The **mean, median, and standard deviation lines should use different colors and linestyles** so they can be clearly distinguished.
#
# Make sure your plot includes:
#
# - Proper **axis labels**
# - A **title**
# - A **legend** identifying the plotted statistics
#
# Adjust the x and y ranges if necessary so that all elements of your plot are clearly visible.

# %%
# Put your code here

# %% [markdown]
# #### &#9989;&nbsp; **Question 4b Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 4 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
