# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201 Section 750 "Coding across Cultures": Quiz 2
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Reading in data from files
# * Making informative plots of data
# * Using functions to repeat the same operation multiple times
#
# #### Skills/Practices:
# * Debugging code
#
# # 90 points total

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # Introduction
#
# You have decided to examine some more data from the [Food and Agriculture Organization of the United Nations](https://www.fao.org/statistics/en) to gain insights into the production of dry chilli (overall, China, India, Mexico and Turkey are the top producers of chilli in the world). The dataset `quiz2_chilli.csv` you will be analyzing has the following parameters:
#
# The data is structured as follows:
# * Column 0: `year` (the year the data was collected from)
# * Column 1: `china` dry chilli production by year for China in tonnes
# * Column 2: `india` dry chilli production by year for India in tonnes
# * Column 3: `mexico` dry chilli production by year for Mexico in tonnes
# * Column 4: `turkey` dry chilli production by year for Türkiye in tonnes

# %% [markdown]
# ## Part 1a) (20 points)
# **Using the test data below, write a function that takes an array of values as input and returns the mean, standard deviation, and median of those values. Demonstrate that your function works by calling it and printing the results using the test data.** We are going to use this to analyze the data from the data file later in the quiz!

# %%
# test data
import numpy as np

# dry chilli production in Mexico 1961 to 2024 in tonnes
test_data = [17177,16533,18534,20633,22403,22494,20968,23170,22833,20811,20806,28362,32626,34695,29300,29132,37480,41439,37212,28125,
             28727,41002,17939,36259,23499,37659,46709,49677,65345,43324,32002,81560,68848,44154,53797,44825,77466,55000,56273.93,
             56539.65,56896.6,57305.94,56500,57000,58000,58200,60000,59236.57,59509.05,59786.08,60059.83,60000,60000,60140.22,60382.34,
             60383.57,60372.43,60611.36,60737.88,60922.83,61241.37,61037.37,61188.99,61340.61]

# PUT YOUR FUNCTION HERE

# %% [markdown]
# #### &#9989;&nbsp; **Question 1b Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 1 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> PUT YOUR ANSWER FOR 1b) HERE!

# %% [markdown]
# ## Part 2a) (10 points)
#
# Now that you have a function to learn about the data, it's time to load in some data! The file, `quiz2_chilli.csv` has data for production from 1961 to 2024 in tonnes. **Looking at the different columns, choose one or multiple columns of data (other than `year`) to explore. You only need to use one column, but you can choose to look at multiple if you like.**
#
# **Using numpy (not pandas!), load the `quiz2_chilli.csv` file into your notebook.** Inspect the data file and ensure that you only read in the columns you are interested in for full credit (i.e. "year" and your column(s) of choice).
#
# **Using matplotlib, make a basic plot that visualizes the data of your choice on the y-axis and the `year` on the x-axis.** Make sure to include appropriate labels for full credit!

# %%
# PUT YOUR CODE HERE

# %% [markdown]
# #### &#9989;&nbsp; **Question 2b Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 2 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ## Part 3 (10 points)
# Now that you have some data read in, it's time to do some analysis! **Using your function from Part 1**, calculate the mean, median, and standard deviation (using numpy) of your data column of choice. **Use just one column of your choice!!** If you didn't get your function in Part 1 to work, you can calculate the values without the function here for partial credit.

# %%
# Put your code here

# %% [markdown]
# ## Part 4a) (10 points)
# To share your insight, you want to create a summary plot of your data and the descriptive statistics. In the cell below, create this summary plot. It should include the following:
#
# * The column of data you chose
# * The mean
# * The median
# * The +/- standard deviation from the mean
# * The mean, median, and standard deviations should be different linestyles and colors to differentiate them from each other
#
# Adjust your x and y ranges as needed in order for all of your information to be visible. You can choose to use a histogram, line plot, scatter plot, etc.

# %%
# Put your code here

# %% [markdown]
# #### &#9989;&nbsp; **Question 4b Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 4 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #2, and upload it there.
