# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 1 (Section 002 Spring 2026)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. You are expected to cite all of your sources and indicate how you used them. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **You may use generative AI tools, but like all sources, we expect that you document and describe the resources you used and how you used them!**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ---
# # Academic integrity statement [5 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.
#
# **NOTE: Guidelines for Using Code You Didn't Write**
#
# If you are using content to solve problems that has not been covered in our pre-class or in class assignments, you **MUST** cite your work. If you use generative AI tools, you must indicate which tool you used (e.g. chatGPT, Co-Pilot, Claude, etc.) and what lines of code were produced by generative AI and which ones were produced by you. If you used generative AI to prduce text (or other output), include the tool, the prompt, and the output. Failure to properly cite your work may result in loss of points on the problem.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
# # 1. Problem Context: Converting between `for` loops and `while` loops
#
# ### &#9989;&nbsp; Question (10 points)
# ## Part 1a)
# You are visiting a cat cafe, and you want to make sure you pet all of the cats. Fortunately, you brought your computer with you with Python installed, so you've got this. You need to loop over the list of cats and print out a string that says which cat you just pet. You start by writing a `while` loop to accomplish this task, but after thinking about it for a moment, you decide to rewrite it as a `for` loop.
#
# **Rewrite the provided `while` loop as a `for` loop, maintaining the same output.**

# %%
# while loop

cats = ["Buster", "Splat", "Splash", "Bootsie", "Bear","Jeep", "Harriet", "Marian", "Heimdall", "Loki", "Legolas", "Skadi", "BearBear", "Jasper"] # list of cats in Dr. Frisbie's family (past and present)

curr_cat = 0
while curr_cat<len(cats):
    print("I pet",cats[curr_cat]+"!")
    curr_cat+=1
# Out:
# I pet Buster!
# I pet Splat!
# I pet Splash!
# I pet Bootsie!
# I pet Bear!
# I pet Jeep!
# I pet Harriet!
# I pet Marian!
# I pet Heimdall!
# I pet Loki!
# I pet Legolas!
# I pet Skadi!
# I pet BearBear!
# I pet Jasper!

# %%
# put your answer here

# %% [markdown]
# #### &#9989;&nbsp; **Question 1b Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 1 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI (e.g. HiTA, ChatGPT, Co-pilot), be sure to include *prompts and outputs* (screenshots or copy-paste are both fine!). **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# ---
#
# # 2. Problem Context: Using if/else Statements to Control Flow
#
# ### &#9989;&nbsp; Question (10 points)
# ## Part 2a)
# As a college student in Michigan, you are tired of deciding if you should wear a coat or not, so you are going to write some Python code to make those decisions for you. You decide that for temperatures below 32$^\circ$F, you will wear a winter coat, for temperatures between 32$^\circ$F and 50$^\circ$F, you will wear a light jacket, and for temperatures greater than 50$^\circ$F, you won't wear a jacket.
#
# In the cell below, you will see a list of 10 temperatures. Using `if`, `elif`, and `else` statements, determine what kind of jacket you should wear for each day (and print it out!). Some starter code for navigating the list (and formatting the output) is given!

# %%
# Example starter code
temperatures = [42,28,31,40,45,48,48,53,56,49]

for temp in temperatures:
    
    print("You need to wear a winter jacket today!")

    print("You need to wear a light jacket today!")

    print("You don't need to wear jacket today!")
# Out:
# You need to wear a winter jacket today!
# You need to wear a light jacket today!
# You don't need to wear jacket today!
# You need to wear a winter jacket today!
# You need to wear a light jacket today!
# You don't need to wear jacket today!
# You need to wear a winter jacket today!
# You need to wear a light jacket today!
# You don't need to wear jacket today!
# You need to wear a winter jacket today!
# You need to wear a light jacket today!
# You don't need to wear jacket today!
# You need to wear a winter jacket today!
# You need to wear a light jacket today!
# You don't need to wear jacket today!
# You need to wear a winter jacket today!
# You need to wear a light jacket today!
# You don't need to wear jacket today!
# You need to wear a winter jacket today!
# You need to wear a light jacket today!
# You don't need to wear jacket today!
# You need to wear a winter jacket today!
# You need to wear a light jacket today!
# You don't need to wear jacket today!
# You need to wear a winter jacket today!
# You need to wear a light jacket today!
# You don't need to wear jacket today!
# You need to wear a winter jacket today!
# You need to wear a light jacket today!
# You don't need to wear jacket today!

# %% [markdown]
# #### &#9989;&nbsp; **Question 2b Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 2 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# # 3. Using Loops for Calculations
#
# ### &#9989;&nbsp; Question (10 points)
# ## Part 3a)
# You have been watching figure skating at the Olympics, and you decide that you want to keep track of the scores as each skater completes their program.
#
# You have one list that holds all of the "base values" for a skater's short program and another list (of equal length) that holds the "grade of execution" scores for each element (assume that the 0-th element of the base values list goes with the 0-th element of the grade of exection list, and so on).
#
# Write a program that:
# 1. Sets up an empty list to fill with each element score (i.e. base value + grade of execution)
# 2. Initializes a variable to keep track of the total score
# 3. Loops over the lists and:
#    * Adds the base value and grade of execution scores together and appends them to the element score list
#    * Adds the total score for the element to the total score variable
# 4. Prints out the total technical score

# %%
# Example starter code
# Ilia Malinin's Olympic individual short program scores (https://skatingscores.com/2526/oly/sr/men/i/short/usa/ilia_malinin/)
base_values = [11.00,8.00,3.20,17.27,2.60,3.30,3.50]
grades_of_execution = [3.77,1.60,0.23,4.76,0.56,1.56,1.00]

# %% [markdown]
# #### &#9989;&nbsp; **Question 3b Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 3 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #1, and upload it there.
