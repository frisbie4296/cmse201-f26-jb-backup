# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 3 (Section 007, Spring 2026)
#
# The goal of this quiz is to give you the opportunity to test out more of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your more recently acquired programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of **100 points** possible on this quiz and each part of the quiz can be done independently. **If you get stuck _move on to another part of the quiz to earn some points there!_**

# %% [markdown]
# ### INSTRUCTOR NOTES (REMOVE IN STUDENT VERSION) ###
#
# **Learning Objectives this Quiz assesses:**
# * Loading and manipulating (e.g. filtering, calculating basic statistics) data using Pandas
# * Using curve_fit to fit models to data and find best fit model parameters
# * Using best fit parameters to calculate expected model values
# * Visualizing data and models using matplotlib
#
# **Point Breakdown:**
# - Academic Integrity Statement: 10 pts
# - Part 1 (Pandas - Weather Data): 50 pts (5 + 15 + 10 + 20)
# - Part 2 (curve_fit - Cooling Data): 40 pts (15 + 15 + 10)
# - **Total: 100 pts**
#
# **Quiz Duration:** 40 minutes

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.
#
# **NOTE: If you use generative AI, you must copy/paste into a cell in this quiz (1) your prompt, (2) the output from generative AI, and (3) Write your answer in separate cells. Failure to include this level of detail will result in a deduction of points.**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # 1. Analyzing Campus Weather Data in East Lansing (50 points)
#
# You have been hired as a student data analyst by the MSU Sustainability Office. Your first task is to explore daily weather patterns recorded at a campus weather station throughout 2025. Your supervisor has given you a datafile called `campus_weather_2025.csv` that you are going to explore with `pandas` and other Python modules.
#
# #### Background Information on the Dataset
# The dataset contains daily weather observations for East Lansing, MI during 2025. Each row represents one day and includes columns for the date, month, average/max/min temperatures (in °F), precipitation (in inches), wind speed (in mph), and humidity (as a percentage).
#
# #### &#9989;&nbsp; **Question 1.1 (5 points)**
# Load the `campus_weather_2025.csv` file provided on D2L **using Pandas** and display the first 10 rows.

# %%
# Let's make sure pandas is imported
import pandas as pd

# Put your code here

# %%
### ANSWER
import pandas as pd

weather = pd.read_csv("campus_weather_2025.csv")
weather.head(10)
# Out:
#          Date  Month  AvgTemp_F  MaxTemp_F  MinTemp_F  Precipitation_in  \
# 0  2025-01-01      1       27.2       34.4       20.4              0.00
# 1  2025-01-02      1       23.9       38.5       13.9              0.00
# 2  2025-01-03      1       27.7       32.8       18.5              0.00
# 3  2025-01-04      1       32.0       46.7       17.9              0.00
# 4  2025-01-05      1       23.1       28.6       14.5              0.00
# 5  2025-01-06      1       23.1       37.0       12.3              0.01
# 6  2025-01-07      1       32.1       42.4       20.8              0.00
# 7  2025-01-08      1       28.0       42.9       22.8              0.10
# 8  2025-01-09      1       21.7       27.5       10.1              0.00
# 9  2025-01-10      1       26.8       37.3       20.0              0.03
#
#    WindSpeed_mph  Humidity_pct
# 0            4.9          70.2
# 1            4.5          56.8
# 2            6.8          60.9
# 3           10.9          60.4
# ...

# %% [markdown]
# #### &#9989;&nbsp; **Question 1.2 (15 points)**
# You want to narrow down your analysis to only the **comfortable temperature days**. Choose a range of average temperatures spanning at least 10°F (e.g. 60°F to 80°F).
#
# Create a mask that filters the data to show only the rows where `AvgTemp_F` falls within the temperature range you chose.
#
# **Display the filtered dataframe once you've created it**, to confirm that you did it correctly.
#
# **Note**: if you didn't get the dataset loaded correctly, try your best to write the code that **should** appropriately mask the data for partial credit.

# %%
# Put your code here

# %%
### ANSWER

comfortable = weather[(weather["AvgTemp_F"] >= 60) & (weather["AvgTemp_F"] <= 80)]
comfortable.head()

# Rubric
# 5 points for any masking attempt
# 5 points for a correct mask (both conditions with & operator)
# 5 points for displaying the filtered dataframe
# Out:
#     Age  BodyweightKg  Best3SquatKg  Best3BenchKg  Best3DeadliftKg  TotalKg
# 0  37.0          51.8          92.5          66.0            125.0    283.5
# 1  25.0          71.9         102.5          72.5            135.0    310.0
# 2  68.0          65.3         120.0          65.0            210.0    395.0
# 3  71.0          81.4         150.0          85.0            180.0    415.0
# 4  50.0          82.0         200.0         110.0            220.0    530.0

# %% [markdown]
# #### &#9989;&nbsp; **Question 1.3 (10 points)**
#
# Your supervisor wants to know the average wind speed on comfortable temperature days. **Write some code to calculate and display the mean** for the `WindSpeed_mph` column of your filtered dataframe.
#
# **Note #1**: there's more than one way you could do this.
#
# **Note #2**: if you didn't get the dataset loaded correctly, try your best to write the code that **should** calculate and display the mean for partial credit.

# %%
# Put your code here

# %% [markdown]
# From the output of your code, what is the mean wind speed on comfortable temperature days?

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here*

# %%
### ANSWER
# Option 1: Using "describe"
comfortable['WindSpeed_mph'].describe()
# The mean will be shown in the describe output
# Out:
# count    64667.000000
# mean       471.966525
# std        155.724271
# min         72.600000
# 25%        344.730000
# 50%        475.000000
# 75%        587.500000
# max       1112.500000
# Name: TotalKg, dtype: float64

# %%
### ANSWER
# Option 2: Using .mean() or np.mean()
import numpy as np
print(comfortable['WindSpeed_mph'].mean())
# For 60-80F filter: approximately 9.41 mph
# Out:
# 471.9665248117278

# %% [markdown]
# ### ANSWER
#
# The mean wind speed (for 60-80°F filter) is approximately **9.41 mph**. Accept any reasonable answer consistent with their chosen temperature range.

# %% [markdown]
# #### &#9989;&nbsp; **Question 1b) Documenting Your Solution Pathway (20 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 1 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (2 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (8 points)
# 3. Does your solution work? (2 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (8 points)

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> PUT YOUR ANSWER FOR Question 1b) HERE!

# %% [markdown]
# ### ANSWER ###
#
# RUBRIC
# * 1 point indicating which portions were solved with prior knowledge and which portions were solved with outside resources
# * 2 points documenting external sources usage
# * 2 points indicating what prior knowledge helped
# * 1 point answering if code worked
# * 4 points for any well-thought out answer about how they know it does or does not work.  2 points for a superficial answer.  0 points for a blank or an answer that does not match the results

# %% [markdown]
# ---
# # 2. Fitting a model to data with `curve_fit` and visualizing the results (40 points)
#
# You just brewed a fresh cup of coffee in the Engineering Building, but it's way too hot to drink! Being a good scientist, you decide to measure the temperature of the coffee over time as it cools down. You recall from physics that the cooling process follows **Newton's Law of Cooling**, which can be modeled as an exponential decay function. Your goal is to fit this model to your temperature data.

# %%
# RUN THIS CELL to make sure you have the dataset loaded

import pandas as pd

cooling_data = pd.read_json('{"time_min": [0.0, 0.76, 1.52, 2.28, 3.04, 3.8, 4.56, 5.32, 6.08, 6.84, 7.59, 8.35, 9.11, 9.87, 10.63, 11.39, 12.15, 12.91, 13.67, 14.43, 15.19, 15.95, 16.71, 17.47, 18.23, 18.99, 19.75, 20.51, 21.27, 22.03, 22.78, 23.54, 24.3, 25.06, 25.82, 26.58, 27.34, 28.1, 28.86, 29.62, 30.38, 31.14, 31.9, 32.66, 33.42, 34.18, 34.94, 35.7, 36.46, 37.22, 37.97, 38.73, 39.49, 40.25, 41.01, 41.77, 42.53, 43.29, 44.05, 44.81, 45.57, 46.33, 47.09, 47.85, 48.61, 49.37, 50.13, 50.89, 51.65, 52.41, 53.16, 53.92, 54.68, 55.44, 56.2, 56.96, 57.72, 58.48, 59.24, 60.0], "temperature_F": [94.83, 96.75, 93.14, 87.45, 87.26, 89.73, 79.65, 81.77, 83.35, 77.32, 75.99, 75.51, 77.07, 71.25, 70.13, 68.68, 72.54, 71.12, 67.42, 64.88, 64.32, 64.61, 58.57, 61.64, 55.67, 55.82, 57.86, 52.17, 53.76, 51.35, 51.64, 45.65, 46.83, 48.12, 50.55, 47.55, 47.13, 47.75, 43.88, 45.5, 42.64, 40.13, 42.16, 43.46, 42.38, 41.09, 45.33, 40.81, 41.41, 43.4, 35.83, 35.85, 40.94, 35.39, 36.6, 38.24, 37.47, 38.78, 37.87, 36.63, 32.57, 35.35, 34.03, 30.41, 35.57, 34.02, 32.19, 31.33, 29.11, 31.62, 31.88, 29.01, 32.74, 27.97, 25.67, 31.76, 28.65, 28.98, 27.34, 25.59]}')
cooling_data.head()
# Out:
# /var/folders/h6/jyzrtdjx2kqbl7wz1ts99_dw0000gn/T/ipykernel_37544/515917451.py:5: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
# ...

# %% [markdown]
# ---
#
# #### &#9989;&nbsp; **Question 2.1 (15 points):**
#
# Using the data and provided model below, use `curve_fit` to find best fit parameters for *a, b,* and *c*. Make sure you give `curve_fit` a good starting point for finding the best fit parameters using the `p0` argument and these starting values:
# * a = 80  (initial temperature difference)
# * b = 0.05  (cooling rate)
# * c = 20  (room temperature)
#
# Once you've found the best values, **print them out**. You should find that the values are close to, but not exactly, the starting guesses.

# %%
# Will need to use NumPy for the function
import numpy as np

# Will need to import curve_fit from SciPy
from scipy.optimize import curve_fit

# This function models Newton's Law of Cooling:
# T(t) = a * exp(-b * t) + c
# where a is the initial temperature difference, b is the cooling rate,
# and c is the ambient (room) temperature
def cooling_model(t, a, b, c):
    return a * np.exp(-b * t) + c

# %%
# Put your code here

# %%
### ANSWER
params, ignore = curve_fit(cooling_model, cooling_data['time_min'], cooling_data['temperature_F'], p0=[80, 0.05, 20])
print(params)
# Expected: a ≈ 75, b ≈ 0.04, c ≈ 22

# Rubric
# 5 pts for using the model function correctly in curve_fit
# 5 pts for passing the correct data columns
# 5 pts for providing p0 and printing the result
# Out:
# [7.51520922e+01 3.86911063e-02 2.12564169e+01]

# %% [markdown]
# #### &#9989;&nbsp; **Question 2.2 (15 points)**
#
# Now that you have a set of best fit parameters, **use those parameters to calculate the expected model values and plot the expected model values on top of the actual data values**. Make sure to label your axes and include a legend to communicate what parts of the plot correspond to the model versus the data.

# %%
# Make sure we import matplotlib
import matplotlib.pyplot as plt

# Put your code here

# %%
### ANSWER ###
plt.scatter(cooling_data['time_min'], cooling_data['temperature_F'], label='Measured Data')
plt.plot(cooling_data['time_min'], cooling_model(cooling_data['time_min'], params[0], params[1], params[2]), color='red', label='Best Fit Model')
plt.xlabel('Time (minutes)')
plt.ylabel('Temperature (°F)')
plt.title('Coffee Cooling Over Time')
plt.legend()

# Rubric
# 5 pts for correctly plotting the data (scatter)
# 5 pts for correctly computing and plotting the best fit model (line)
# 5 pts for labels, legend, and readable plot

# %% [markdown]
# #### &#9989;&nbsp; **Question 2b Documenting Your Solution Pathway (10 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 2 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (1 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (4 points)
# 3. Does your solution work? (1 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (4 points)

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> PUT YOUR ANSWER FOR 2b) HERE!

# %% [markdown]
# ### ANSWER ###
#
# RUBRIC
# * 1 point indicating which portions were solved with prior knowledge and which portions were solved with outside resources
# * 2 points documenting external sources usage
# * 2 points indicating what prior knowledge helped
# * 1 point answering if code worked
# * 4 points for any well-thought out answer about how they know it does or does not work.  2 points for a superficial answer.  0 points for a blank or an answer that does not match the results

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #3, and upload it there.
