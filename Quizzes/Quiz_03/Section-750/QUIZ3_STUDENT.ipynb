# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201: Quiz 3 (Coding across Cultures, Section 750)
#
# The goal of this quiz is to give you the opportunity to test out more of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your more recently acquired programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.
#
# There are a total of <font color="red">**100**</font> possible on this quiz and each part of the quiz can be done independently. **If you get stuck _move on to another part of the quiz to earn some points there!_**

# %% [markdown]
# ---
# # Academic integrity statement (10 points)
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.
#
# **NOTE: If you use generative AI, you must copy/paste into a cell in this quiz (1) your prompt, (2) the output from generative AI, and (3) Write your answer in separate cells. Failure to include this level of detail will result in a deduction of points.**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your personal academic integrity statement here.*

# %% [markdown]
# ---
#
# # 1. Analyzing Indigenous nations within the US  (50 points)
#
# Let's analyze some data related to the class project. The file `state_nation_acres.csv` has three columns:
# - `name`: the name of the US state or Indigenous nation
# - `state_or_nation`: whether the name represents a state or nation
# - `acres`: the number of acres owned by Indigenous people in the state or nation
#
# #### &#9989;&nbsp; **Question 1.1 (5 points)**
# Load the `state_nation_acres.csv` file provided **using Pandas** and display the first 10 rows.

# %%
# Let's make sure pandas is imported
import pandas as pd

# Put your code here

# %% [markdown]
# #### &#9989;&nbsp; **Question 1.2 (15 points)**
# You want to narrow down your analysis to just ***Indigenous nations***.
#
# Create a mask that filters the data to show only the rows that correspond to ***Indigenous nations***. Use the `state_or_nation` column in order to mask. You want to mask for `nation` (not `state`).
#
# **Display that dataframe once you've created it**, to confirm that you did it correctly.
#
# **Note**: if you didn't get the dataset loaded correctly, try your best to write the code that **should** appropriately mask the data for partial credit.

# %%
# Put your code here

# %% [markdown]
# #### &#9989;&nbsp; **Question 1.3 (10 points)**
#
# Finally, you are curious about the maximum number of acres that are present within any Indigenous nation. **Write some code to calculate and display the max acres** for your masked dataframe with only Indigenous nations listed.
#
# **Note #1**: there's more than one way you could do this.
#
# **Note #2**: if you didn't get the dataset loaded correctly, try your best to write the code that **should** calculate and display the mean for partial credit.

# %%
# Put your code here

# %% [markdown]
# From the output of your code, what is the maximum number of acres in an Indigneous nation?

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here*

# %% [markdown]
# #### &#9989;&nbsp; **Question 1.4 Documenting Your Solution Pathway (20 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 1 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (2 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (8 points)
# 3. Does your solution work? (2 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (8 points)

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> PUT YOUR ANSWER FOR 1b) HERE!

# %% [markdown]
# ---
# # 2. Fitting a model to data with `curve_fit` and visualizing the results (40 points)
#
# We are studying the relationship between the US and Mexico for the class project, with respect to agriculture, labor, and immigration. To explore this further, let's look at the value of agricultural imports from Mexico to the US from 1967 to 2026.
#
# ***Execute the cell below*** to create the dataframe `imports_df`. Note that year starts in $1967$ but that $1967$ is converted to $0$ for easier modeling.

# %%
year = [1967,1968,1969,1970,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,
        1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,
        2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025,2026]

value = [71932,82779,93052,158103,131321,186298,369769,871837,592247,378401,673590,916327,1030603,2472732,2438082,1160364,
         1941078,1996048,1436766,1082346,1201332,2225527,2763788,2589625,3036997,3839901,3686849,4674079,3556365,5495563,
         5239195,6211164,5668512,6467667,7464072,7300916,7954091,8545224,9485577,10964764,12820073,15640186,13024233,14699793,
         18544708,19112085,18319767,19591645,17899369,17983548,18815667,19303349,19398666,18343372,25465718,28466210,28316411,
         30191274,30615151]

imports = {'year': year, 'value': value}
imports_df = pd.DataFrame(imports)
imports_df['year'] = imports_df['year'] - imports_df['year'].min()

imports_df.head()
# Out:
#    year   value
# 0     0   71932
# 1     1   82779
# 2     2   93052
# 3     3  158103
# 4     5  131321

# %% [markdown]
# ---
#
# #### &#9989;&nbsp; **Question 2.1 (10 points):**
#
# Using the data you just created above and ***provided model below***, use `curve_fit` to find best fit parameters for $A$ and $k$. Make sure you give `curve_fit` a good starting point for finding the best fit parameters using the `p0` argument and these starting values:
#
# * $A = 1e5$
# * $k = 0.05$
#
# Once you've found the best values, **print them out**. You should find that they are not far off from, but not the same as, the original values that your friend gave you.

# %%
# Will need to use NumPy for the function
import numpy as np

# Will need to import curve_fit from SciPy
from scipy.optimize import curve_fit

# This function calculates value as a function of year assuming exponential growth
def exponential(x, A, k):
    return A * np.exp(k * x)

# %%
# Put your code here

# %% [markdown]
# #### &#9989;&nbsp; **Question 2.2 (10 points)**
#
# Now that you have a set of best fit parameters, **use those parameters to calculate the expected model values and plot the expected model values on top of the actual data values**. Make sure to label your axes and include a legend to communicate what parts of the plot correspond to the model versus the data.
#
# For full points:
# - Add a legend with `data` and `fit`
# - Add x and y labels
# - Add a title
#
# Your plot should look like:

# %% [markdown]
# ![download.png](attachment:67a54f8b-6e37-4abc-9cc2-2542cf1bfdef.png)

# %%
# Make sure we import matplotlib
import matplotlib.pyplot as plt

# Put your code here

# %% [markdown]
# #### &#9989;&nbsp; **Question 2b Documenting Your Solution Pathway (20 points)**
#
# **Answer the following questions in detail:**
# 1. Indicate which portions of Part 2 you answered with prior knowledge, and also indicate which portions of Part 1 you answered with the help of outside sources (e.g. generative AI, past assignments, Stack Overflow, Google, etc.) to help you? (2 point)
# 2. **For the parts were you DID use external resources**, document what sources you used and how they informed your approach.  If you used generative AI, be sure to include *prompts and outputs*. **For the parts where you DID NOT use external resources**, what prior knowledge did you recall to solve the problem? (8 points)
# 3. Does your solution work? (2 point)
# 4. **If your solution works**, how do you know it works?  Include any calculations you made, tests you ran, etc. **If your solution DOES NOT work**, how do you know it does not work?  What approaches would you use to verify a correct solution? (8 points)

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> PUT YOUR ANSWER FOR 2b) HERE!

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this quiz by uploading it to the course Desire2Learn web page.  Go to the "Quizzes" section, find the submission folder link for Quiz #3, and upload it there.
