# %% [markdown]
# # Using return vs. print statements

# %%
def my_function(float1,float2):
    add_func = float1+float2
    #print(add_func)
    return float1+float2

# %%
# let's explore variable scope
print(add_func)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # let's explore variable scope
# ----> 2 print(add_func)
#
# NameError: name 'add_func' is not defined

# %%
add = my_function(2.3,5.6)
print(add)
# Out:
# 7.8999999999999995

# %% [markdown]
# # "Global" vs. "Local" variables in Functions

# %%
print(add)
# Out:
# 7.8999999999999995

# %%
add
# Out:
# 7.8999999999999995
