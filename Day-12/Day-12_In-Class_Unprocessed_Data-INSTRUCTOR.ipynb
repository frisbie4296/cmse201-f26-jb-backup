# %% [markdown]
# # Day 12 In-Class: Data Contextualization and Wrangling

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; **Put your name here** </p>
# #### <p style="text-align: right;"> &#9989; Put your group member names here</p>

# %% [markdown]
# ### Learning Goal:
# Search for, locate, and contextualize data sets from the internet and develop troubleshooting methods for loading data sets into Jupyter notebook.
#
# ### Practices:
#
# * Articulate the context for a data set
# * Experiment with some of the ways you can load data into a Jupyter notebook
# * Identify the arguments needed for different ways to load data
# * Practice loading a data file in need of wrangling

# %% [markdown]
# ## Part 1: Pre-class Review/Discussion (15 minutes)
#
# #### &#9989;&nbsp; Questions
#
# In the pre-class, you explored two main ideas: data contextualization and data wrangling.
#
# As a group, discuss and answer the following questions about the *Data Feminism* chapter (and record your notes below):
# 1. Summarize the main ideas of data contextualization and data wrangling.
# 2. Thinking about your personal ethics as someone developing data analysis skills, what ideas would you want to carry forward from this reading into your approach to data analysis?
# 3. What did you discover (or not discover) when you went to find the context for your data sets in the pre-class?

# %% [markdown]
# <font size=+3>&#9998;</font> *Summarize your discussion here.*

# %% [markdown]
# #### &#9989;&nbsp; Task
# After you have talked through data contextualization from the pre-class, discuss as a group the tools you needed to load your data into your notebooks in the pre-class and record a list of the tools/arguments below. Include specific examples from each of your group members' experiences.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your tools here!*

# %% [markdown]
# ## Part 2: Practice with Loading Data
#
# #### &#9989;&nbsp;  Question
# Below are the links to three different data sets. Work together as a group to:
#
# 1. Obtain the data.
# 2. Load the data into your notebook.
# 3. Make at least one change to make the data more usable.
#
# Links:
# 1. [World Bank Population Data](https://databank.worldbank.org/source/population-estimates-and-projections)
# 2. [1995 MLB Season Data](https://www.retrosheet.org/gamelogs/gl1995.zip)
# 3. [AskAManager Survey Data](https://www.askamanager.org/2021/04/how-much-money-do-you-make-4.html)
#
# **As you work, take notes on what tools/advice you used from Part 1 (you'll want it to answer the discussion questions)!**

# %%
# put your code here

# %%
### ANSWER
import pandas as pd
data = pd.read_table('Data_Files//gl1995.txt',delimiter = ',')
data.head()
# Out:
#    19950425  0  Tue  LAN  NL  1  FLO NL.1  1.1  8  ...  Charles Johnson  2.5  \
# 0  19950426  0  Wed  MIN  AL  1  BOS   AL    1  0  ...  Mike Macfarlane    2
# 1  19950426  0  Wed  DET  AL  1  CAL   AL    1  5  ...        J.T. Snow    3
# 2  19950426  0  Wed  BAL  AL  1  KCA   AL    1  1  ...       Greg Gagne    6
# 3  19950426  0  Wed  CHA  AL  1  MIL   AL    1  3  ...      Turner Ward    9
# 4  19950426  0  Wed  TEX  AL  1  NYA   AL    1  6  ...  Bernie Williams    8
#
#    carrc001      Chuck Carr 8.6  burkj001.2  John Burkett.2  1.8  \
# 0  naeht001    Tim Naehring   5    tinsl001     Lee Tinsley    8
# 1  allaa001   Andy Allanson   2    disag001  Gary Disarcina    6
# 2  maynb001     Brent Mayne   2    lindj002       Jose Lind    4
# 3  olivj001      Joe Oliver   2    valej003   Jose Valentin    6
# 4  fernt001  Tony Fernandez   6    kellp001       Pat Kelly    4
#
#    Unnamed: 159  Y
# 0           NaN  Y
# 1           NaN  Y
# 2           NaN  Y
# 3           NaN  Y
# ...

# %%
### ANSWER
data= pd.read_excel("Data_Files//Ask A Manager Salary Survey 2021 (Responses).xlsx")
data.head()
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0 2021-04-27 11:02:09.743            25-34   Education (Higher Education)
# 1 2021-04-27 11:02:21.562            25-34              Computing or Tech
# 2 2021-04-27 11:02:38.125            25-34  Accounting, Banking & Finance
# 3 2021-04-27 11:02:40.643            25-34                     Nonprofits
# 4 2021-04-27 11:02:41.793            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
### ANSWER
data = pd.read_csv('Data_Files//d991abca-0eb8-468a-8b14-2402e501e5a5_Data.csv')
data.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 1                          Age dependency ratio, old     SP.POP.DPND.OL
# 2                        Age dependency ratio, young     SP.POP.DPND.YG
# 3       Age population, age 00, female, interpolated  SP.POP.AG00.FE.IN
# 4         Age population, age 00, male, interpolated  SP.POP.AG00.MA.IN
#
#       2015 [YR2015]     2016 [YR2016]     2017 [YR2017]     2018 [YR2018]  \
# 0  93.0424476640396  92.0121249200047  90.5430941060045  89.0914511265535
# 1   4.6442456380075  4.60635088670088  4.57268660954771  4.55160703424134
# 2  88.3982020260321  87.4057740333038  85.9704074964568  84.5398440923121
# ...

# %% [markdown]
# #### &#9989;&nbsp; Question
#
# In the cell below, talk about the strategies you used and describe the challenges you encountered.

# %% [markdown]
# <font size=+3>&#9998;</font> *Summarize your challenges here!*

# %% [markdown]
# ## Part 3: Finding Data to Answer an Exploratory Question
#
#
# #### &#9989;&nbsp;  Task
# Below are several questions that require data (and your expert Python skills) to answer them. Your task is to choose one of the following questions and use internet resources to find a dataset that could answer the question. You can use the sites from the pre-class to get started, but you should also try a broader search as well.
#
# **Q1:** Which New York City neighborhoods have seen the largest changes in death due to Air Pollution?
#
# **Q2:** For a single US state, what is the distribution of Powerball lottery numbers over the last ~10 years?
#
# **Q3:** How has National Park Usage/Visitation changed over time?
#
# **Q4:** In the 2015 Major League Baseball season, how many games did each team win/lose?
#
# **Q5:** How many exoplanets are discovered each year (since the first discovery in 1992)?

# %% [markdown]
# <font size=+3>&#9998;</font> *Write the exploratory question you chose here!*

# %% [markdown]
# ## Part 4: Putting it All Together
#
# #### &#9989;&nbsp;  Task
# Now that you have some practice articulating data context and finding data, it's time to combine your skills (much like you will be asked to in the context of your semester projects!)
#
# Obtain a dataset that will (hopefully) answer your group's chosen exploratory question.
#
# Then, do your best to answer the data contextualization questions (as you did in the pre-class):
#
# 1. Who collected/generated the data?
# 2. How was the data collected/generated?
# 3. Who/what is included in the data?
# 4. Who/what is **not** included in the data?
# 5. What are the limitations or biases of the data?

# %% [markdown]
# <font size=+3>&#9998;</font> *Write your answers to the questions above here and **include the link to your dataset***

# %% [markdown]
# #### &#9989;&nbsp;  Task
# Now, load the dataset into your notebook in the cell(s) below. If you need to clean up your data to be usable, put those steps here! Remember that you can also open the data file(s) in Jupyter if you are having trouble with loading/cleaning.
#
# **Make sure everyone in your group is able to get the data loaded and cleaned**

# %%
# put your code here!

# %% [markdown]
# #### &#9989;&nbsp;  Task
# Looking at your dataset, answer the following questions:
# 1. What columns do you think will be most helpful for answering your question?
# 2. What do those columns mean/stand for?
# 3. Why do you think they might answer your question?

# %% [markdown]
# <font size=+3>&#9998;</font> *Write your answers here*

# %% [markdown]
# #### &#9989;&nbsp;  Task
# Now that your data is loaded and cleaned, you are going to make a plot (e.g. scatter plot, line plot, histogram, bar plot, etc.).

# %%
# put your code here

# %% [markdown]
# #### &#9989;&nbsp;  Reflection
# Answer the following questions about your plot:
# 1. What is your plot showing?
# 2. What part of your exploratory question does it answer?
# 3. What information might be missing or incomplete?
# 4. How does the context of the data you articulated affect your interpretation of the plot?

# %% [markdown]
# <font size=+3>&#9998;</font> *Write your data answers here!*

# %%
### ANSWER

'''The cells below contain data files and read in statements for the exploratory questions. These are examples
to help y'all as instructors to troubleshoot what students might run into, not "correct" answers that the students should be steered to. 
Allow them the agency to explore!''';

# %%
### ANSWER

# Example link to data for Air Pollution -  https://a816-dohbesp.nyc.gov/IndicatorPublic/data-explorer/health-impacts-of-air-pollution/?id=2122#display=summary

# They should be able to download and read in as csv

# %%
### ANSWER
# For the Lottery question - students should find data fairly easily, but they will likely need to do data cleaning. We give an example for the New York data
# https://catalog.data.gov/dataset/lottery-powerball-winning-numbers-beginning-2010

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Lottery_Powerball_Winning_Numbers__Beginning_2010.csv')
#we need to split the winning numbers in to 6 columns
df[['1','2','3','4','5','6']] = df['Winning Numbers'].str.split(' ', expand=True) #point the students here
print(type(df['1'][0])) #note, still strings!
df[['1','2','3','4','5','6']] = df[['1','2','3','4','5','6']].astype(int) #convert to integers
print(type(df['1'][0])) #note, now integers!
#Students can then plot accordingly - looking at specific columns or across all of them
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 9
#       6 import numpy as np
#       7 import matplotlib.pyplot as plt
# ----> 9 df = pd.read_csv('Lottery_Powerball_Winning_Numbers__Beginning_2010.csv')
#      10 #we need to split the winning numbers in to 6 columns
#      11 df[['1','2','3','4','5','6']] = df['Winning Numbers'].str.split(' ', expand=True) #point the students here
#
# ...

# %%
### ANSWER

# Example dataset and read-in for National Parks data
# https://www.responsible-datasets-in-context.com/posts/np-data/ 
df = pd.read_csv('US-National-Parks_RecreationVisits_1979-2023.csv')
#students can plot the data as is, or they can group by year and sum the visits
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 5
#       1 ### ANSWER
#       2
#       3 # Example dataset and read-in for National Parks data
#       4 # https://www.responsible-datasets-in-context.com/posts/np-data/
# ----> 5 df = pd.read_csv('US-National-Parks_RecreationVisits_1979-2023.csv')
#
# ...

# %%
### ANSWER

# For MLB, students can change the year on the website linked for Part 2 and hence can be read in the same way
# Google is more likely to point them here (https://www.baseball-reference.com/leagues/majors/2015-standings.shtml) which has easily viewable data, but is harder to download and might take some data cleaning

# %%
### ANSWER

# For exoplanets
# Link to example dataset: https://exoplanetarchive.ipac.caltech.edu/index.html (click on "Confirmed exoplanets under TESS)
df = pd.read_csv('Data_Files/PS_2025.02.20_08.33.11.csv',skiprows=96)

# students can do this in a variety of ways, sort the data by year and plot it, mask by year and sum
# create a histogram that is binned in years, etc.
import matplotlib.pyplot as plt
plt.hist(df['disc_year'])


# You can encourage folks to dig a little deeper into the data to explore more things about exoplanets as well!
# Out:
# (array([1.3000e+01, 8.4000e+01, 2.1600e+02, 5.6500e+02, 8.0500e+02,
#         2.1140e+03, 1.2803e+04, 1.4837e+04, 4.3240e+03, 2.3340e+03]),
#  array([1992. , 1995.3, 1998.6, 2001.9, 2005.2, 2008.5, 2011.8, 2015.1,
#         2018.4, 2021.7, 2025. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Part 5: Sharing your Work
#
# As a group, prepare ~3 slides showing the steps you took to answer your research question.
# You should have:
# * 1 slide on your research question and data context
# * 1 slide on the steps you took to make your data usable
# * 1 slide with your completed plot(s).
#
# Make sure to explicitly discuss what choices you made in your data cleaning and plot making process and how this affects the representation of the data and the associated claims you can make (e.g. what is your data showing? Who/what is missing from the data? What information does the plot not capture?). You will be asked to do this on your final project, so this is great practice! When you are making slides, also consider what your classmates might find helpful if they encountered similar data.
#
# Each group member is responsible for presenting some component of your group’s process to the class. As you listen to other students, you are responsible for taking notes on the things that each group needed to do to get their data usable!

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your notes here!*

# %% [markdown]
# Acknowledgements: This assignment originally designed by Dr. Rachel L.S. Frisbie as part of the MSU STEM Teaching and Learning Fellowship and updated for broad implementation with CMSE Graduate Students Emily Bolger and Rachel Roca.

# %% [markdown]
# ---
# ## Assignment wrapup
#
# Please fill out the form that appears when you run the code below. **You must completely fill this out in order to receive credit for the assignment!**

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://cmse.msu.edu/cmse201-ic-survey" 
	width="800px" 
	height="600px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://cmse.msu.edu/cmse201-ic-survey"
# 	width="800px"
# 	height="600px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ---

# %% [markdown]
# ## Congratulations, you're done!
#
# Submit this assignment by uploading your notebook to the course Desire2Learn web page.  Go to the "In-Class Assignments" folder, find the appropriate submission link, and upload everything there. Make sure your name is on it!

# %% [markdown]
# Copyright &#169; 2025, [Department of Computational Mathematics, Science and Engineering](https://cmse.msu.edu/) at Michigan State University, All rights reserved.
