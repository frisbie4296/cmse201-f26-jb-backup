# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Put your name here</p>

# %% [markdown]
# # CMSE 201 Final
# ## Section 005 - Fall 2021
#
# The goal of this final is to give you the opportunity to test out some of the skills that you've developed this semester. You are encouraged to look through the entire exam before you get started so that you can appropriately budget your time and understand the broad goals of the exam. The exam is set up so that even if you get stuck on one part there are opportunities to get points on the other parts, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. **However, the use of any person-to-person communication software is absolutely not acceptable.** If you are seen accessing your email, using a chat program (e.g. Slack), or any sort of collaborative cloud storage or document software (e.g. Google Documents), you will be at risk for receiving a zero on the exam.
#
# **Keep your eyes on your screen!** Unfortunately, there isn't enough space in the room for everyone to sit at their own table so please do your best to keep your eyes on your own screen. This exam is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. If any of the instructors observe suspicious behavior, you will, again, risk receiving a zero.
#
# **Part 1: 13 points**
# **Part 2: 20 points**
# **Part 3: 27 points**
# **Part 4: 16 points**
#
# **Total: 76 points**

# %% [markdown]
# ---
# ## Part 1: Short questions (13 points)

# %% [markdown]
# ### Question 1a (4 points)
#
# The list below contains 50 random numbers from a normal distribution generated using the `np.random.normal`function, with `mean = 0` and `standard deviation = 1`.
#
# Loop through the list `my_list` below by value and append the outputs to a list called `my_answer`. If the value is less than 0 and negative, then append the square (`val**2`) of its value to `my_answer`. If the value is greater than 0 and positive, then append the string `positive` to `my_answer`.
#
# ***Print your list*** `my_answer` ***after your loop***

# %%
my_list = [ 0.09120472,  1.09128273, -1.94697031, -1.38634953, -2.29649157,  2.4098343,
  1.72783617,  2.20455628,  0.79482764,  0.9764211,  -1.18342715,  1.91636361,
 -1.1233268,  -0.66403547, -0.37835857, -0.79161527,  0.85954811, -0.230789,
 -0.06566103, -0.20863623,  1.34686857, -0.6069528,  -0.17424821,  0.42405142,
 -1.6459901,  -0.48354095,  0.53546825,  1.16614049,  0.16168311, -0.67283393,
  1.44252413, -0.22148061,  0.03126431,  0.18192959, -0.06292873, -0.54156846,
  0.47451842, -1.16459117, -0.50090939, -0.40856096, -0.93434836,  0.08451015,
  0.14369102,  0.07554944, -0.1556451,   0.55085006,  1.70202996,  1.0060937,
 -3.13491977,  1.1395335 ]

# %%
# Put your answer here

# %% [markdown]
# ### Question 1b (4 points)
#
# Now, create a function called `negative_squared`. The function should take a list as an input. Like above, if the value in the list is negative, return it's squared value. If the value in the list is positive, then return the string `positive`.
#
# Your function should return a list with the modified values.
#
# ***After you write your function, test it on*** `my_list` ***and print the returned list.*** ***Your answer should be identical to that above in Question 1a.***

# %%
# Put your answer here

# %% [markdown]
# ### Question 1c (5 points)
#
# Now, you create a list of random numbers from a normal distribution!
#
# Using the `np.random.normal` function, create a list of 50 random numbers with `mean = 0` and `standard deviation = 1`. Call your new list `y_vals`.
#
# Below, `my_list` has been relabeled as `x_vals`.
#
# ***Plot the list of 50 random*** `y_vals` ***from a normal distribution you created against the provided*** `x_vals` ***as a scatter plot. The axes and aspect ratio of your plot should be equal using the*** `plt.gca().set_aspect()` ***function.***
#
# Your plot should look something like that below. Remember, you are using a random function, so your plot will not look exactly like this. Use a reasonable color and point size of your choice.

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
x_vals = [ 0.09120472,  1.09128273, -1.94697031, -1.38634953, -2.29649157,  2.4098343,
  1.72783617,  2.20455628,  0.79482764,  0.9764211,  -1.18342715,  1.91636361,
 -1.1233268,  -0.66403547, -0.37835857, -0.79161527,  0.85954811, -0.230789,
 -0.06566103, -0.20863623,  1.34686857, -0.6069528,  -0.17424821,  0.42405142,
 -1.6459901,  -0.48354095,  0.53546825,  1.16614049,  0.16168311, -0.67283393,
  1.44252413, -0.22148061,  0.03126431,  0.18192959, -0.06292873, -0.54156846,
  0.47451842, -1.16459117, -0.50090939, -0.40856096, -0.93434836,  0.08451015,
  0.14369102,  0.07554944, -0.1556451,   0.55085006,  1.70202996,  1.0060937,
 -3.13491977,  1.1395335 ]

# %%
# Put your answer here

# %% [markdown]
# ---
# ## Part 2: Loading and manipulating data with pandas 🐼 (20 points)

# %% [markdown]
# In this part of the exam, you will be asked to load, manipulate, and visualize data using pandas. Specifically, the data set contains information about grapevine harvests in different regions of Europe from 1655 to 2007. The dataset contains the columns `year`, `region`, `harvest` (which is days after 31 August, a positive number if the harvest is after this date and a negative number if before it), and `anomaly` (the global temperature anomaly for that year).
#
# You'll be working with the `grape_harvest.csv` file to see how the harvest date of grapevines in Europe are affected by changes in global temperature.

# %% [markdown]
# ### Question 2a (3 points)
#
# ***1) Load the data into your notebook.*** Use a pandas function to ***2) display the first 5 rows of data*** and ***3) another function to summarize the continuous variables of year, harvest, and anomaly,*** displaying their count, mean, standard deviation, min, max, etc.
#
# (If you can not figure out how to read in the dataset, you can use the following code below for partial credit and to continue with this question. If you download the dataset from the link below, ***you will not get full credit***, so try to load in the data using the provided file first.)
#
# (Use the following line of code for partial credit only if you can not read in the data from the file:)
#
# `df = pd.read_csv("https://raw.githubusercontent.com/DanChitwood/PlantsAndPython/master/grape_harvest.csv")`

# %%
# Read in the dataset and display the first 5 rows of data here

# %%
# Use a function to display the count, mean, standard deviation and other statistics here

# %% [markdown]
# ### Question 2b (5 points)
#
# ***1) Determine how many rows of data are in this dataset. Print*** `There are X rows in this dataset`
#
# ***2) Determine how many rows there are for the regions in the list below called*** `some_regions` ***using a loop. Print*** `There are X data points for region X` ***for each region in the list.***
#
# **Hint:** the `len()` function is your friend for this problem! Also, remember masking and think about how you can use it in a loop to print out the number of data points for each region!

# %%
some_regions = ["switzerland_leman_lake", "burgundy", "southern_rhone_valley", 
                "jura", "ile_de_france", "bordeaux", "alsace", "languedoc", 
                "spain", "low_loire_valley", "champagne_2", "germany", 
                "northern_italy"]

# %%
# Put your answer here

# %% [markdown]
# ### Question 2c (8 points)
#
# Loop through each year from 1655 to 2007. In your loop, use each `year` value as a mask and calculate the following values and store them in their own lists.
#
# ***1) For each year, determine the average*** `harvest`***date value. Store the average*** `harvest` ***date values in a list.***
#
# ***2) For each year, determine the average temperature*** `anomaly` ***value. Store the average temperature*** `anomaly` ***values in a list.***
#
# **Hint:** use a loop! The start year value is 1655 and the end year value is 2007. Again, remember masking and think about how you can use masking in a loop! Remember, you should create two lists: one for average harvest date values and one for average temperature anomaly values for each year. If you are unable to get the code to work, explain your logic of how your code would have worked using pseudocode for partial credit.

# %%
# Put your answer here

# %% [markdown]
# ### Question 2d (2 points)
#
# Using the lists of average `harvest` and `anomaly` values for each year, ***plot the mean*** `harvest` ***values for each year against the mean*** `anomaly` ***values for each year as a scatter plot.***
#
# ***Your plot should:***
# 1) Have x and y axis labels
# 2) Have a title
#
# ***For partial credit:*** If you were not able to calculate average `harvest` and `anomaly` values in the previous Question 2c, you can simply plot all the values in the `harvest` column against the `anomaly` column in the dataset for partial credit. If you use this option for partial credit, be sure to set `alpha = 0.1` to prevent overplotting.
#
# Your plot of the averages should look like the one below:

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
# Put your answer here

# %% [markdown]
# ### Question 2e (2 points)
#
# Do you see correlation in your plot? As the average temperature anomaly rises, what happens to average harvest date? Is the harvest date earlier or later as the temperature rises? (remember, `harvest` is the date of harvest measured as days after 31 August, where positive values are after 31 August and negative values are earlier than 31 August)

# %% [markdown]
# ***Write your answer in this markdown cell***

# %% [markdown]
# ---
# ## Part 3: Fit data using NumPy and/or SciPy (27 points)

# %% [markdown]
# In this part of the exam, you will use curve and polynomial fitting functions to model `harvest` dates as a function of `year` using the grapevine dataset you loaded in above. You will compare the fit of each function by comparing its deviation from the data.

# %% [markdown]
# ### Question 3a (3 points)
#
# ***Make a scatter plot of*** `harvest` ***on the y axis vs*** `year` ***on the x axis.***
#
# Use axis labels and give your plot a title. Use `alpha = 0.1` to avoid overplotting.
#
# Your plot should look like the one below with axis labels and title.

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
# Put your answer here

# %% [markdown]
# ### Question 3b (6 points)
#
# ***Using the*** `curve_fit()` ***function, fit a linear function to the data using the formula:*** $y = mx + b$.
#
# Where $y = harvest$ and $x = year$
#
# ***Plot your fitted line from*** `curve_fit()` ***on top of the data.***
#
# Your plot should look like the one below.

# %% [markdown]
# ![download-1.png](attachment:download-1.png)

# %%
# Put your answer here

# %% [markdown]
# ### Question 3c (10 points)
#
# ***Use numpy's*** `polyfit()` ***and*** `poly1d()` ***functions to generate first-, second-, and third-order polynomial functions to the data.***
#
# ***Plot each of these functions on top of the data using labels and a legend.***
#
# Your plot should resemble the one below and have axis labels and a title.

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
# Put your answer here

# %% [markdown]
# ### Question 3d (6 points)
#
# In this question, you compare the ***fit*** of each of your polynomials by measuring the mean difference and the mean of the differences squared between the model values and the corresponding actual data. Do the following:
#
# 1) For your first-, second-, and third-order functions, ***subtract fitted curve values from actual data values and store in separate arrays, one for each function***
#
# 2) ***Then, for each array, print the average of the differences from the arrays above and***
#
# 3) ***for each array square the differences and take the means of these values. Print the average of the squared differences as well***
#
# The greater the mean squared difference, the more the model deviates from the data. The less the mean squared difference, the closer the model fits the data.

# %%
# Put your answer here

# %% [markdown]
# ### Question 3e (2 points)
#
# Based on the average of the squared difference values you calculated for each function, which function is the best fit for the data? Which is has the worst fit? Explain your answer.

# %% [markdown]
# ***Write your answer in this markdown cell***

# %% [markdown]
# ---
# ## Part 4: Compartmental modeling (16 points)

# %% [markdown]
# In this section you will come up with a real-world system and describe how a compartmental model can be used to model its behavior.

# %% [markdown]
# ### Question 4a (4 points)
#
# Give a brief definition of a compartmental model in your own words.

# %% [markdown]
# ***Write your answer in this markdown cell***

# %% [markdown]
# ### Question 4b (4 points)
#
# Choose a question that can be solved using compartmental modeling. Why is a compartmental model appropriate for your question? ***Your answer can not include any of the examples from class.***

# %% [markdown]
# ***Write your answer in this markdown cell***

# %% [markdown]
# ### Question 4c (4 points)
#
# What are the compartments and their associated variables in your model?

# %% [markdown]
# ***Write your answer in this markdown cell***

# %% [markdown]
# ### Question 4d (4 points)
#
# How does flow between compartments work in your model? Describe the exchanges and their associated rates between compartments in your model.

# %% [markdown]
# ***Write your answer in this markdown cell***

# %% [markdown]
# ---
# ## You're done! Congrats on finishing your CMSE 201 Final!
#
# Upload a copy of this notebook to the submission folder on D2L and make sure your name is on it! Thank you for a great semester!
