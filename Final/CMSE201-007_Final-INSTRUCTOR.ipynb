# %%
### ANSWER
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %% [markdown]
# # CMSE 201 Final Exam (Section 007 - Fall 2021)
#
# The exam is set up so that even if you get stuck on one part there are opportunities to get points on the other parts, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, access old notebooks, etc. **However, the use of any person-to-person communication software is absolutely not acceptable.** If you are seen accessing your email, using a chat program (e.g. Slack), or any sort of collaborative cloud storage or document software (e.g. Google Documents), you will be at risk for receiving a zero on the exam.
#
# **Keep your eyes on your screen!** Unfortunately, there isn't enough space in the room for everyone to sit at their own table so please do your best to keep your eyes on your own screen. This exam is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. If any of the instructors observe suspicious behavior, you will, again, risk receiving a zero.
#
# ___
# ## Overview:
#
# **0) Academic honesty statement (1 point)**
# **1) Short Answer (28 points)**
# **2) Pandas (28 points)**
# **3) Curve Fitting (28 points)**
# **4) Plotting (15 points)**
#
# **Total: 100 points**

# %% [markdown]
# ___
# ## Part 0: Academic Honesty Statement (1 point)
#
# **Insert your personalized academic honesty statement here.**

# %% [markdown]
# / your statement here /

# %% [markdown]
# ## Part 1: Short Answer (28 points)

# %% [markdown]
# ### 1.1 (7 points)
# In your own words, describe how masking works as if you were describing it to a new CMSE 201 student.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### 1.2 (7 points)
#
# * Mean vs. median question
#     * Given these two distributions, which one is better described by median or mean and why?

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### 1.3 (7 points)
# Choose one of the compartmental or agent-based models we explored in class (for example, SIZR, Forest Fire, Predator-Prey, etc.). In your own words, describe the model including important parameters, assumptions, and limitations.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### 1.4 (7 points)
#
# Pick any function from Homeworks 3-6 (or your Semester Project), and copy and paste it into the cell below. List the inputs and outputs of the function and summarize what the function does. The function cannot be a built-in function. *If you aren't sure that your chosen function is suitable, ask Dr. Frisbie before proceeding.*

# %%
# put your function here

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ## Part 2: Pandas (28 points)

# %% [markdown]
# Download the data file groundhog_dayta.csv (included on the D2L Exam Submission).
#
# ### 2.1 Reading in the Data File (4 points)
# In the cell below, read in the data file and display the first several rows of the data table using `.head()`.
#
# **Note:** If you do not know how to do this or are having trouble, you can have the code provided to you in exchange for not receiving any points on this part of the problem (but you will be able to continue the rest of Part 2 for credit).

# %%
# put your code here

# %%
### ANSWER
groundhog_dayta = pd.read_csv('groundhog_dayta.csv')
groundhog_dayta.head(n=8)
# Out:
#    Year Punxsutawney Phil  February Average Temperature  \
# 0  1895         No Record                         26.60
# 1  1896         No Record                         35.04
# 2  1897         No Record                         33.39
# 3  1898       Full Shadow                         35.37
# 4  1899         No Record                         25.50
# 5  1900       Full Shadow                         30.76
# 6  1901       Full Shadow                         29.86
# 7  1902         No Record                         31.46
#
#    March Average Temperature
# 0                      39.97
# 1                      38.03
# 2                      38.79
# 3                      41.05
# 4                      37.63
# 5                      41.27
# 6                      40.71
# 7                      41.58

# %% [markdown]
# ### 2.2 Manipulating your dataframe
#
# The data file contains 4 columns, "Year", "Punxsutawney Phil", "February Average Temperature", and "March Average Temperature". The "Punxsutawney Phil" column contains whether or not the groundhog saw his shadow or if no record was taken.
#
# ### 2.2.1 Calculate the Temperature Difference (6 points)
# Your first task is to add a column to the dataframe that takes the difference between the average temeprature columns ($\rm{Temperature \ Difference} = \rm{March \ Average \ Temperature} - \rm{February \ Average \ Temperature)}$

# %%
# put your answer here

# %%
### ANSWER

# Add a column for the difference in average temperature
groundhog_dayta['temp_difference'] = groundhog_dayta['March Average Temperature']-groundhog_dayta['February Average Temperature']

# %% [markdown]
# ### 2.2.2 Masking the Dataframe (6 points)
#
# To compare the temperature data for years where the groundhog does or does not see his shadow, we need to create two masked dataframes. In the cell below, create two new dataframes, one containing only the rows where "Punxsutawney Phil" is "Full Shadow", and one containing only the rows where "Punxsutawney Phil" is "No Shadow".

# %%
# put your answer here

# %%
### ANSWER
# Make two dataframes with the years with and without a shadow
shadow = groundhog_dayta[groundhog_dayta['Punxsutawney Phil']=='Full Shadow']
no_shadow = groundhog_dayta[groundhog_dayta['Punxsutawney Phil']=='No Shadow']
no_record = groundhog_dayta[groundhog_dayta['Punxsutawney Phil']=='No Record']

# %% [markdown]
# ### 2.3 Statistics (6 points)
#
# For each of your two dataframes, calculate the mean and standard deviation (using the built in functions in either numpy or pandas) of the "February Average Temperature" and "March Average Temperature" data columns and **print your results**.

# %%
# put your answer here

# %% [markdown]
# ### 2.3.1 Interpretation (6 points)
#
# The lore of the groundhog is that if he sees his shadow on February 2nd, we will have 6 more weeks of winter (and likely lower temperatures on average). Based on your mean and standard deviation calculations, does the groundhog shadow accurately predict continued colder temperatures? **Justify your answer.**

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ## Part 3: Curve Fitting (28 points)

# %% [markdown]
# 51 Pegasi b is famous for being [the first exoplanet discovered](https://en.wikipedia.org/wiki/51_Pegasi_b) orbiting a main sequence star. Since its discovery, astronomers have taken extensive data to learn more about this planet. Your task is to use `curve_fit()` to fit a function to the orbit of the planet.
#
# ### 3.1 Plotting the Data (5 points)
#
# Download the file "51Peg.csv" from the exam on D2L. In the cell below, make a scatter plot with the "Phase" column of the data on the x axis and the "Radial Velocity" column on the y-axis. The data is already read in for you using pandas, but you can also use numpy if you wish. Make sure you include axis labels.

# %%
# put your answer here
exoplanet_data = pd.read_csv('51Peg.csv')

# %%
### ANSWER 
exoplanet_data = pd.read_csv('51Peg.csv')

plt.scatter(exoplanet_data['Phase'],exoplanet_data['Radial_Velocity'])
plt.ylabel('Radial Velocity')
plt.xlabel('Phase')
# Out:
# Text(0.5, 0, 'Phase')

# %% [markdown]
# ### 3.2 Fitting the data
# Now we will fit the data for the exoplanet's orbit using `curve_fit`.
#
# ### 3.2.1 (6 points)
#
# The generic fit for an exoplanet orbit is $y = D+A\rm{sin}(Bx+C)$. Write a function (that you will use for `curve_fit()`) that takes in x values and the parameters A, B, C, and D and returns the y values of the function.
# **Note:** If you do not know how to do this or are having trouble, you can have the code provided to you in exchange for not receiving any points on this part of the problem (but you will be able to continue the rest of Part 3 for credit).

# %%
# put your answer here

# %%
### ANSWER
#sine function for fitting
def my_sine_function(x,A,B,C,D):
    import numpy as np
    return D+A*np.sin(B*x+C)

# %% [markdown]
# ### 3.2.2 Getting a Best Fit (10 points)
#
# In the cell(s) below, fill in the line with the correct information for running `curve_fit()`. Then, unpack the best-fit parameters and plot your best fit function as well as the original data.

# %%
# put your answer here

popt_sin,pcov_sin = curve_fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-a43d5f7c2d40> in <module>
#       1 # put your answer here
#       2
# ----> 3 popt_sin,pcov_sin = curve_fit()
#
# TypeError: curve_fit() missing 3 required positional arguments: 'f', 'xdata', and 'ydata'

# %%
### ANSWER
x_array = np.arange(0,2,0.01)
popt_sin,pcov_sin = curve_fit(my_sine_function,exoplanet_data['Phase'],exoplanet_data['Radial_Velocity'])
y_vals_sine = my_sine_function(x_array,popt_sin[0],popt_sin[1],popt_sin[2],popt_sin[3])

plt.scatter(exoplanet_data['Phase'],exoplanet_data['Radial_Velocity'])
plt.scatter(x_array,y_vals_sine,label='sine',color='orange')
plt.legend(loc='best')

# %% [markdown]
# ### 3.3.1 RMSE (3 points)
#
# In the cell below, describe what the RMSE is and provide one example of how we applied it in CMSE 201.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### 3.3.2 (4 points)
#
# Using the function below, calculate the RMSE of your fit from 3.2.2 and **print the value.**

# %%
# RMSE function (see In Class Day 12 and/or Bootcamp 9)
def rmse(x_points,y_points,y_pred):
    """
    A function for computing the RMSE of a model, based on a set of points.
    
    Input:
    x_points  : array
                A set of x points (e.g. times) that correspond to the data points, y

    y_points  : array
                A set of y points (e.g. transistor counts) that correspond to the times
                x
                
    y_pred    : array
                the array of predicted values for your model (same length as x_points and y_points)

                
                
    Output:
    rmse      : float
                The root mean squared error of the model, computed using x and y
    """
    
    nx = len(x_points)
    ny = len(y_points)
    
    if nx != ny:
        print("Error! x and y must have the same length!")
        
    sum_sq = 0
    for i in range(len(x_points)):
        sum_sq += (y_points[i] - y_pred[i])**2

    rmse = np.sqrt(sum_sq/nx)
    
    return rmse

# %%
# put your answer here

# %%
### ANSWER
y_predicted = my_sine_function(exoplanet_data['Phase'],popt_sin[0],popt_sin[1],popt_sin[2],popt_sin[3])

rmse(exoplanet_data['Phase'],exoplanet_data['Radial_Velocity'],y_predicted)
# Out:
# 7.621212825264754

# %% [markdown]
# # Part 4: Compartmental Models and `solve_ivp` (15 points)

# %% [markdown]
# ### 4.1 Solving Compartmental Model Problems (5 points)
#
# In your own words, summarize the process for solving a compartmental model problem as if you were explaining it to your fellow CMSE 201 students. Your explanation should begin with how to determine the compartments and parameters and end with how to visualize the model results.

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answer here.*

# %% [markdown]
# ### 4.2 Writing ODEs (5 points)
#
# Below is a compartmental model. Choose one compartment and fill in the corresponding ODE in the derivative function given.
#
# ![compartmental_model](https://github.com/msu-cmse-courses/cmse201-F21-data/blob/main/compartmental_model_new.png?raw=true)

# %%
# Fill in ONE of the lines below

def derivs(t,y,gamma,beta,delta,theta):
    A, B, C = y
    
    dAdt = # FILL IN
    dBdt = # FILL IN
    dCdt = # FILL IN
    
    return dAdt, dBdt, dCdt
# Out:
#   File "<ipython-input-120-5a61793b7f47>", line 6
#     dAdt = # FILL IN
#            ^
# SyntaxError: invalid syntax

# %%
### ANSWER
# Fill in ONE of the lines below

def derivs(t,y,gamma,beta,delta,theta):
    A, B, C = y
    
    dAdt = beta*A-delta*A-gamma*A*B
    dBdt = gamma*A*B-theta*B+theta*C
    dCdt = theta*B-theta*C
    
    return dAdt, dBdt, dCdt

# %% [markdown]
# ### 4.3 `solve_ivp` (5 points)
#
# Below is a labeled diagram of an example `solve_ivp` call. Describe all of the labeled components.
#
# ![solve_ivp_anatomy](https://github.com/msu-cmse-courses/cmse201-F21-data/blob/main/solve_ivp_empty.png?raw=true)

# %% [markdown]
# <font size=+3>&#9998;</font> *Put your answers here.*
#
# A.
#
# B.
#
# C.
#
# D.
#
# E.
#
# F.

# %% [markdown]
# # Congratulations, you are done!
#
# Thank you for a great semester!
