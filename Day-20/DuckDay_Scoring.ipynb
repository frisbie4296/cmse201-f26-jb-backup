# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Data Visualization Scoring Sheet FS25(1-337).csv') # Import Forms File
data = data[data["What section are you in?\n"] == "001: Robert Termuhlen"] # Change to your section!
data.head()
# Out:
#    ID       Start time  Completion time             Email  \
# 0   1  11/5/25 9:19:10  11/5/25 9:20:55  maurer17@msu.edu
# 1   2  11/5/25 9:18:21  11/5/25 9:21:21  swamyani@msu.edu
# 2   3  11/5/25 9:17:48  11/5/25 9:21:50  espin171@msu.edu
# 3   4  11/5/25 9:18:31  11/5/25 9:22:35  cialonee@msu.edu
# 4   5  11/5/25 9:18:02  11/5/25 9:22:41  chittan1@msu.edu
#
#                     Name  Last modified time  \
# 0           Jacob Maurer                 NaN
# 1       swamyani@msu.edu                 NaN
# 2  Lorena Espinosa Gomez                 NaN
# 3        Elliott Cialone                 NaN
# 4      Anwith Chittanuri                 NaN
#
#   What is your first and last name? What section are you in?\n  \
# 0                      Jacob Maurer      001: Robert Termuhlen
# 1                         Ani Swamy      001: Robert Termuhlen
# 2                  Lorena Espinosa       001: Robert Termuhlen
# 3                   Elliott Cialone      001: Robert Termuhlen
# ...

# %%
cols = data.columns[9:14] 
data['score'] = data[cols].sum(axis=1, numeric_only=True)/(8+3+4)

data2 = data.groupby('What group are you scoring here?\n')[['score']].mean()
data2.sort_values('score', ascending=False)
# Out:
#                                        score
# What group are you scoring here?\n
# Group 2                             1.190000
# Group 5                             1.123810
# Group 8                             1.117117
# Group 7                             1.115315
# Group 6                             1.095935
# Group 4                             1.084444
# Group 3                             1.078095
# Group 10                            1.072917
# Group 9                             0.894737
# Group 1                             0.889474
